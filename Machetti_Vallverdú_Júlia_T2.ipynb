# %%
#Enfoque basado en modelo de SentiWordNet o SenticNet para español
#Añadiendo reglas heurísticas (negación en ventana de máximo 5 tokens, intensificadores y atenuadores)
#Compara y evalúa cíticamente el rendimiento del modelo sin y con reglas heurísticas (lexicón y lexicón + reglas)
#Para comparar y evaluar, usa un dataset de evaluación: InterTASS, Multilingual Amazon Review sentiment...

# %%
#Análisis_del_sentimiento_y_la_connotación_Aprendizaje_basado_en_el_lexicón
#Apartado "Lexicones de polaridad" utiliza el lexicón de SentiWordNet y añade reglas heurísticas, pero es en inglés
#Cuidado porque en español se hace con Spacy en lugar de con NLTK
#SentiWordNet en español en el apartado "Análisis de sentimiento basado en aspecto", dentro de "Lexicones de polaridad"

# %% [markdown]
# Ahora vamos a usar SentiWordNet en español. Cargaremos el lexicón.

# %%
import csv
import spacy

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from es-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Cargar el modelo de spaCy para español
nlp_es = spacy.load("es_core_news_sm")

# Función para cargar el lexicón de SentiWordNet en español.
def load_spanish_sentiwordnet(filepath):
    """
    Carga el lexicón en español desde un archivo tab-delimitado con las columnas:
    pos, word_en, word_sp, positive, negative, objective, index, synset, meaning.
    Se utiliza la columna 'word_sp' (convertida a minúsculas) como clave.
    Devuelve un diccionario: {word_sp.lower(): (pos_tag, positive, negative, objective)}.
    """
    lexicon = {}
    with open(filepath, encoding="utf-8") as f:
        reader = csv.DictReader(f, delimiter="\t")
        for row in reader:
            word_sp = row["word_sp"].strip().replace('_', ' ')
            if word_sp == "":
                continue
            try:
                pos_tag = row["pos"].strip().lower()
                pos_score = float(row["positive"].replace("+", ""))
                neg_score = float(row["negative"].replace("-", ""))
                obj_score = float(row["objective"])
            except Exception:
                pos_score, neg_score, obj_score = 0.0, 0.0, 0.0
                pos_tag = ""
            key = word_sp.lower()
            lexicon[key] = (pos_tag, pos_score, neg_score, obj_score)
    return lexicon

# %%
# Cargar el lexicón en español desde el mismo cuaderno
# La ruta en la que he colocado el archivo es "/content/sentiwordnet_es.tsv"
es_sentiwordnet = '/content/sentiwordnet_es.tsv'

# %%
# Cargar el lexicón (ajusta la ruta al archivo de SentiWordNet en español)
spanish_sentiwordnet = load_spanish_sentiwordnet(es_sentiwordnet)
spanish_sentiwordnet
# Out:
# {'barrer con': ('v', 0.125, 0.0, 0.875),
#  'ganar': ('v', 0.375, 0.0, 0.625),
#  'abalizar': ('v', 0.125, 0.0, 0.875),
#  'ligarse': ('v', 0.125, 0.0, 0.875),
#  'unirse': ('v', 0.125, 0.0, 0.875),
#  'seguir': ('v', 0.375, 0.0, 0.625),
#  'raptar': ('v', 0.0, 0.125, 0.875),
#  'cautivar': ('v', 0.125, 0.0, 0.875),
#  'deambular': ('v', 0.125, 0.0, 0.875),
#  'platyhelminthes': ('n', 0.125, 0.0, 0.875),
#  'anomiidae': ('n', 0.125, 0.0, 0.875),
#  'pluvialis': ('n', 0.125, 0.0, 0.875),
#  'género pluvialis': ('n', 0.125, 0.0, 0.875),
#  'kogia': ('n', 0.125, 0.0, 0.875),
#  'considerar': ('v', 0.25, 0.0, 0.75),
#  'vanessa': ('n', 0.125, 0.0, 0.875),
#  'nesokia': ('n', 0.125, 0.0, 0.875),
#  'género nesokia': ('n', 0.125, 0.0, 0.875),
#  'socorrer': ('v', 0.125, 0.0, 0.875),
#  'diaforético': ('a', 0.125, 0.0, 0.875),
#  'vacacionar': ('v', 0.125, 0.0, 0.875),
#  'sudorífico': ('a', 0.125, 0.0, 0.875),
#  'lactogenico': ('a', 0.125, 0.0, 0.875),
#  'casa': ('n', 0.125, 0.0, 0.875),
#  'celda': ('n', 0.125, 0.0, 0.875),
#  'minarete': ('n', 0.125, 0.0, 0.875),
#  'ocasión': ('n', 0.125, 0.0, 0.875),
#  'oportunidad': ('n', 0.125, 0.0, 0.875),
#  'pertinencia': ('n', 0.125, 0.0, 0.875),
#  'inmediatez': ('n', 0.125, 0.0, 0.875),
#  'creencia': ('n', 0.125, 0.0, 0.875),
#  'comic': ('n', 0.125, 0.0, 0.875),
#  'aullido': ('n', 0.0, 0.25, 0.75),
#  'estertor': ('n', 0.125, 0.0, 0.875),
#  'bayat': ('n', 0.125, 0.0, 0.875),
#  'exageración': ('n', 0.125, 0.0, 0.875),
#  'alboroto': ('n', 0.0, 0.625, 0.375),
#  'bombo': ('n', 0.125, 0.0, 0.875),
#  'partidario de la no resistencia': ('n', 0.125, 0.0, 0.875),
#  'satanista': ('n', 0.125, 0.0, 0.875),
#  'sarraceno': ('n', 0.125, 0.0, 0.875),
#  'sorbedor': ('n', 0.125, 0.0, 0.875),
#  'fan': ('n', 0.125, 0.0, 0.875),
#  'solterona': ('n', 0.125, 0.0, 0.875),
#  'reyes': ('n', 0.125, 0.0, 0.875),
#  'neruda': ('n', 0.125, 0.0, 0.875),
#  'poe': ('n', 0.125, 0.0, 0.875),
#  'dylan marlais thomas': ('n', 0.125, 0.0, 0.875),
#  'evento fortuito': ('n', 0.125, 0.0, 0.875),
#  'inconscientemente': ('r', 0.0, 0.375, 0.625),
#  'cariñosamente': ('r', 0.125, 0.0, 0.875),
#  'correctamente': ('r', 0.125, 0.0, 0.875),
#  'en lo más íntimo y profundo': ('r', 0.125, 0.0, 0.875),
#  'es decir': ('r', 0.125, 0.0, 0.875),
#  'metereológicamente': ('r', 0.125, 0.0, 0.875),
#  'liberación': ('n', 0.0, 0.25, 0.75),
#  'atusar': ('v', 0.125, 0.0, 0.875),
#  'a efectos practicos': ('r', 0.125, 0.0, 0.875),
#  'de lejos': ('r', 0.125, 0.0, 0.875),
#  'por derecho': ('r', 0.125, 0.0, 0.875),
#  'adecuadamente': ('r', 0.125, 0.0, 0.875),
#  'mistificar': ('v', 0.125, 0.0, 0.875),
#  'eludir': ('v', 0.125, 0.0, 0.875),
#  'rehuir': ('v', 0.125, 0.0, 0.875),
#  'sobrevivir': ('v', 0.125, 0.0, 0.875),
#  'quedarse más tiempo': ('v', 0.125, 0.0, 0.875),
#  'apalache': ('a', 0.125, 0.0, 0.875),
#  'tardar': ('v', 0.125, 0.0, 0.875),
#  'duplicar': ('v', 0.125, 0.0, 0.875),
#  'hacer un paralelo': ('v', 0.125, 0.0, 0.875),
#  'reflejar': ('v', 0.125, 0.0, 0.875),
#  'behaviorista': ('a', 0.125, 0.0, 0.875),
#  'alargar': ('v', 0.125, 0.0, 0.875),
#  'aplicar': ('v', 0.25, 0.0, 0.75),
#  'colaborar': ('v', 0.0, 0.25, 0.75),
#  'agarrar a correazos': ('v', 0.125, 0.0, 0.875),
#  'dar de varillazos': ('v', 0.125, 0.0, 0.875),
#  'dar un golpe cortante': ('v', 0.125, 0.0, 0.875),
#  'dar un manotazo': ('v', 0.125, 0.0, 0.875),
#  'zanjar': ('v', 0.125, 0.0, 0.875),
#  'peinar': ('v', 0.25, 0.0, 0.75),
#  'familia crocodylidae': ('n', 0.125, 0.0, 0.875),
#  'sobresaltar': ('v', 0.0, 0.125, 0.875),
#  'deleitar': ('v', 0.125, 0.0, 0.875),
#  'pavonearse': ('v', 0.0, 0.5, 0.5),
#  'empujar': ('v', 0.125, 0.0, 0.875),
#  'pasar con rapidez': ('v', 0.125, 0.0, 0.875),
#  'filo platyhelminthes': ('n', 0.125, 0.0, 0.875),
#  'pogonophora': ('n', 0.125, 0.0, 0.875),
#  'ser llevado por el viento': ('v', 0.125, 0.0, 0.875),
#  'bivalvia': ('n', 0.125, 0.0, 0.875),
#  'ojear': ('v', 0.125, 0.0, 0.875),
#  'globo ocular': ('v', 0.125, 0.0, 0.875),
#  'género jaculus': ('n', 0.125, 0.0, 0.875),
#  'jaculus': ('n', 0.125, 0.0, 0.875),
#  'bathyergus': ('n', 0.125, 0.0, 0.875),
#  'añojo': ('n', 0.125, 0.0, 0.875),
#  'favorecer': ('v', 0.125, 0.0, 0.875),
#  'abandonarse a algo': ('v', 0.125, 0.0, 0.875),
#  'antibiótico': ('n', 0.125, 0.0, 0.875),
#  'droga antibiótica': ('n', 0.125, 0.0, 0.875),
#  'pender': ('v', 0.125, 0.0, 0.875),
#  'columpearse': ('v', 0.125, 0.0, 0.875),
#  'ir': ('v', 0.125, 0.0, 0.875),
#  'venir bien': ('v', 0.125, 0.0, 0.875),
#  'escamoso': ('a', 0.125, 0.0, 0.875),
#  'técnico': ('a', 0.125, 0.0, 0.875),
#  'etiológico': ('a', 0.125, 0.0, 0.875),
#  'chesterfield': ('n', 0.125, 0.0, 0.875),
#  'dramático': ('a', 0.125, 0.0, 0.875),
#  'pinzo': ('n', 0.125, 0.0, 0.875),
#  'domiciliación': ('n', 0.125, 0.0, 0.875),
#  'instrumento de lengüeta libre': ('n', 0.125, 0.0, 0.875),
#  'bomba de combustible': ('n', 0.125, 0.0, 0.875),
#  'surtidor de combustible': ('n', 0.125, 0.0, 0.875),
#  'gimnasio': ('n', 0.125, 0.0, 0.875),
#  'hostal de estudiantes': ('n', 0.125, 0.0, 0.875),
#  'arco apuntado': ('n', 0.25, 0.0, 0.75),
#  'puñal': ('n', 0.125, 0.0, 0.875),
#  'ring': ('n', 0.125, 0.0, 0.875),
#  'piso': ('n', 0.125, 0.0, 0.875),
#  'infravivienda': ('n', 0.125, 0.0, 0.875),
#  'hytrin': ('n', 0.125, 0.0, 0.875),
#  'veintidós': ('n', 0.125, 0.0, 0.875),
#  'vancomicina': ('n', 0.125, 0.0, 0.875),
#  'enredo': ('n', 0.125, 0.0, 0.875),
#  'alambrada': ('n', 0.125, 0.0, 0.875),
#  'alambrada metálica': ('n', 0.125, 0.0, 0.875),
#  'permutabilidad': ('n', 0.125, 0.0, 0.875),
#  'transposicionalidad': ('n', 0.125, 0.0, 0.875),
#  'literalidad': ('n', 0.125, 0.0, 0.875),
#  'sensibilidad': ('n', 0.125, 0.0, 0.875),
#  'empatía': ('n', 0.125, 0.0, 0.875),
#  'aplicación al estudio': ('n', 0.125, 0.0, 0.875),
#  'servilismo': ('n', 0.5, 0.0, 0.5),
#  'tipo': ('n', 0.125, 0.0, 0.875),
#  'somatotipo': ('n', 0.125, 0.0, 0.875),
#  'tipo atlético': ('n', 0.125, 0.0, 0.875),
#  'mesomorfo': ('n', 0.125, 0.0, 0.875),
#  'duración del servicio': ('n', 0.125, 0.0, 0.875),
#  'longevidad': ('n', 0.125, 0.0, 0.875),
#  'asertividad': ('n', 0.125, 0.0, 0.875),
#  'eosinófilo': ('n', 0.125, 0.0, 0.875),
#  'volición': ('n', 0.125, 0.0, 0.875),
#  'voluntad': ('n', 0.125, 0.0, 0.875),
#  'disección': ('n', 0.125, 0.0, 0.875),
#  'contemplación': ('n', 0.125, 0.0, 0.875),
#  'consideración': ('n', 0.75, 0.0, 0.25),
#  'conceptualizacion': ('n', 0.125, 0.0, 0.875),
#  'condición esencial': ('n', 0.125, 0.0, 0.875),
#  'sine qua non': ('n', 0.125, 0.0, 0.875),
#  'petición de principio': ('n', 0.125, 0.0, 0.875),
#  'ideal': ('n', 0.125, 0.0, 0.875),
#  'ídolo': ('n', 0.75, 0.0, 0.25),
#  'parangón': ('n', 0.125, 0.0, 0.875),
#  'perfección': ('n', 0.125, 0.0, 0.875),
#  'guía': ('n', 0.125, 0.0, 0.875),
#  'plantilla': ('n', 0.125, 0.0, 0.875),
#  'modelo': ('n', 0.5, 0.0, 0.5),
#  'ignorancia': ('n', 0.125, 0.0, 0.875),
#  'oscurantismo': ('n', 0.125, 0.0, 0.875),
#  'desconocimiento': ('n', 0.125, 0.0, 0.875),
#  'inconsciencia': ('n', 0.125, 0.0, 0.875),
#  'favor': ('n', 0.5, 0.0, 0.5),
#  'reverendo': ('n', 0.125, 0.0, 0.875),
#  'baronazgo': ('n', 0.125, 0.0, 0.875),
#  'versión revisada americana': ('n', 0.125, 0.0, 0.875),
#  'amnistía': ('n', 0.125, 0.0, 0.875),
#  'absurdo': ('n', 0.125, 0.0, 0.875),
#  'majadería': ('n', 0.125, 0.0, 0.875),
#  'chorradas': ('n', 0.25, 0.0, 0.75),
#  'jerigonza': ('n', 0.0, 0.25, 0.75),
#  'baratija': ('n', 0.125, 0.0, 0.875),
#  'diccionario electrónico': ('n', 0.125, 0.0, 0.875),
#  'diccionario leíble por máquina': ('n', 0.125, 0.0, 0.875),
#  'información confidencial': ('n', 0.125, 0.0, 0.875),
#  'aviso': ('n', 0.125, 0.0, 0.875),
#  'ventaja': ('n', 0.125, 0.0, 0.875),
#  'información': ('n', 0.125, 0.0, 0.875),
#  'doctor en educación': ('n', 0.125, 0.0, 0.875),
#  'doctor en salud pública': ('n', 0.125, 0.0, 0.875),
#  'respetos': ('n', 0.125, 0.0, 0.875),
#  'trincheras': ('n', 0.125, 0.0, 0.875),
#  'alojamiento': ('n', 0.125, 0.0, 0.875),
#  'red': ('n', 0.125, 0.0, 0.875),
#  'agerasia': ('n', 0.125, 0.0, 0.875),
#  'esfenión': ('n', 0.125, 0.0, 0.875),
#  'aptitud': ('n', 0.125, 0.0, 0.875),
#  'falta de memoria': ('n', 0.125, 0.0, 0.875),
#  'mente': ('v', 0.375, 0.0, 0.625),
#  'escena dramática': ('n', 0.125, 0.0, 0.875),
#  'vista': ('n', 0.0, 0.25, 0.75),
#  'vítor': ('n', 0.125, 0.0, 0.875),
#  'conminación': ('n', 0.125, 0.0, 0.875),
#  'declaración de principios': ('n', 0.125, 0.0, 0.875),
#  'comentario burlón': ('n', 0.125, 0.0, 0.875),
#  'pulla': ('n', 0.25, 0.0, 0.75),
#  'salida': ('n', 0.0, 0.125, 0.875),
#  'cuchufleta': ('n', 0.125, 0.0, 0.875),
#  'chiste verde': ('n', 0.125, 0.0, 0.875),
#  'interpretación': ('n', 0.125, 0.0, 0.875),
#  'presentación publica': ('n', 0.125, 0.0, 0.875),
#  'anglo': ('n', 0.125, 0.0, 0.875),
#  'juto': ('n', 0.125, 0.0, 0.875),
#  'kéntico': ('n', 0.125, 0.0, 0.875),
#  'tilde': ('n', 0.125, 0.0, 0.875),
#  'énfasis': ('n', 0.125, 0.0, 0.875),
#  'acento': ('n', 0.125, 0.0, 0.875),
#  'rima visual': ('n', 0.125, 0.0, 0.875),
#  'risa sardónica': ('n', 0.125, 0.0, 0.875),
#  'risa disimulada': ('n', 0.125, 0.0, 0.875),
#  'trivialidad': ('n', 0.125, 0.0, 0.875),
#  'lugar común': ('n', 0.125, 0.0, 0.875),
#  'perogrullada': ('n', 0.125, 0.0, 0.875),
#  'desambiguación léxica': ('n', 0.125, 0.0, 0.875),
#  'fanfarronería': ('n', 0.125, 0.0, 0.875),
#  'pavoneo': ('n', 0.125, 0.0, 0.875),
#  'delirio': ('n', 0.125, 0.0, 0.875),
#  'propaganda': ('n', 0.125, 0.0, 0.875),
#  'voto de confianza': ('n', 0.125, 0.0, 0.875),
#  'peripecia': ('n', 0.125, 0.0, 0.875),
#  'procesión': ('n', 0.125, 0.0, 0.875),
#  'origen': ('n', 0.125, 0.0, 0.875),
#  'cambio': ('n', 0.0, 0.125, 0.875),
#  'transformación': ('n', 0.5, 0.0, 0.5),
#  'transmutación': ('n', 0.125, 0.0, 0.875),
#  'aleación': ('n', 0.125, 0.0, 0.875),
#  'carrera': ('n', 0.125, 0.0, 0.875),
#  'victoria inminenta': ('n', 0.125, 0.0, 0.875),
#  'victoria sin mover un dedo': ('n', 0.125, 0.0, 0.875),
#  'mazapán': ('n', 0.125, 0.0, 0.875),
#  'ensalada de col': ('n', 0.125, 0.0, 0.875),
#  'huevo de caramelo': ('n', 0.125, 0.0, 0.875),
#  'saltamontes': ('n', 0.125, 0.0, 0.875),
#  'facultad de antropología': ('n', 0.125, 0.0, 0.875),
#  'facultad de biología': ('n', 0.125, 0.0, 0.875),
#  'facultad de química': ('n', 0.125, 0.0, 0.875),
#  'facultad de ciencias económicas': ('n', 0.125, 0.0, 0.875),
#  'facultad de filología inglesa': ('n', 0.125, 0.0, 0.875),
#  'facultad de historia': ('n', 0.125, 0.0, 0.875),
#  'facultad de lingüística': ('n', 0.125, 0.0, 0.875),
#  'facultad de matemáticas': ('n', 0.125, 0.0, 0.875),
#  'facultad de física': ('n', 0.125, 0.0, 0.875),
#  'facultad de música': ('n', 0.125, 0.0, 0.875),
#  'facultad de psicología': ('n', 0.125, 0.0, 0.875),
#  'facultad de sociología': ('n', 0.125, 0.0, 0.875),
#  'seguridad': ('n', 0.125, 0.0, 0.875),
#  'departamento de seguridad': ('n', 0.125, 0.0, 0.875),
#  'raf (royal air force)': ('n', 0.125, 0.0, 0.875),
#  'royal air force (raf)': ('n', 0.125, 0.0, 0.875),
#  'contingente': ('n', 0.125, 0.0, 0.875),
#  'destacamento': ('n', 0.125, 0.0, 0.875),
#  'posse comitatus': ('n', 0.125, 0.0, 0.875),
#  'archidiócesis': ('n', 0.125, 0.0, 0.875),
#  'necromanía': ('n', 0.125, 0.0, 0.875),
#  'necrofilia': ('n', 0.125, 0.0, 0.875),
#  'supresor': ('n', 0.125, 0.0, 0.875),
#  'lecho de minerales': ('n', 0.125, 0.0, 0.875),
#  'rafael': ('n', 0.125, 0.0, 0.875),
#  'urania': ('n', 0.125, 0.0, 0.875),
#  'freya': ('n', 0.125, 0.0, 0.875),
#  'freyja': ('n', 0.125, 0.0, 0.875),
#  'aspirante': ('n', 0.125, 0.0, 0.875),
#  'candidato': ('n', 0.125, 0.0, 0.875),
#  'imitador barato': ('n', 0.125, 0.0, 0.875),
#  'cestero': ('n', 0.125, 0.0, 0.875),
#  'instructor de bateo': ('n', 0.125, 0.0, 0.875),
#  'esteticista': ('n', 0.5, 0.0, 0.5),
#  'cosmetólogo': ('n', 0.125, 0.0, 0.875),
#  'galán': ('n', 0.125, 0.0, 0.875),
#  'caballero': ('n', 0.125, 0.0, 0.875),
#  'niño cantor': ('n', 0.125, 0.0, 0.875),
#  'demagogo': ('n', 0.125, 0.0, 0.875),
#  'agitador': ('n', 0.125, 0.0, 0.875),
#  'sargento escribiente': ('n', 0.125, 0.0, 0.875),
#  'crítico de teatro': ('n', 0.125, 0.0, 0.875),
#  'majorette': ('n', 0.125, 0.0, 0.875),
#  'borracho': ('n', 0.125, 0.0, 0.875),
#  'ebrio': ('n', 0.125, 0.0, 0.875),
#  'etiólogo': ('n', 0.125, 0.0, 0.875),
#  'niña': ('n', 0.125, 0.0, 0.875),
#  'pequeña': ('n', 0.125, 0.0, 0.875),
#  'esgrimista': ('n', 0.125, 0.0, 0.875),
#  'espadachín': ('n', 0.125, 0.0, 0.875),
#  'tontorrona': ('n', 0.125, 0.0, 0.875),
#  'sobrino nieto': ('n', 0.125, 0.0, 0.875),
#  'transportista': ('n', 0.125, 0.0, 0.875),
#  'equivoquista': ('n', 0.125, 0.0, 0.875),
#  'evasor': ('n', 0.125, 0.0, 0.875),
#  'tergiversador': ('n', 0.125, 0.0, 0.875),
#  'insomne': ('n', 0.125, 0.0, 0.875),
#  'persona sin sueño': ('n', 0.125, 0.0, 0.875),
#  'infiltrado': ('n', 0.0, 0.375, 0.625),
#  'adonis': ('n', 0.25, 0.0, 0.75),
#  'pistolero': ('n', 0.125, 0.0, 0.875),
#  'tirador': ('n', 0.125, 0.0, 0.875),
#  'francotirador': ('n', 0.125, 0.0, 0.875),
#  'monofisita': ('n', 0.125, 0.0, 0.875),
#  'charlatan de feria': ('n', 0.125, 0.0, 0.875),
#  'saltabancos': ('n', 0.125, 0.0, 0.875),
#  'ofertante': ('n', 0.125, 0.0, 0.875),
#  'oferente': ('n', 0.125, 0.0, 0.875),
#  'antigualla': ('n', 0.125, 0.0, 0.875),
#  'carcamal': ('n', 0.125, 0.0, 0.875),
#  'viejo': ('n', 0.125, 0.0, 0.875),
#  'anciano': ('n', 0.125, 0.0, 0.875),
#  'veterano': ('n', 0.125, 0.0, 0.875),
#  'pensionista': ('n', 0.125, 0.0, 0.875),
#  'el que hace mimos': ('n', 0.125, 0.0, 0.875),
#  'bobalicón': ('n', 0.0, 0.25, 0.75),
#  'profesor de equitación': ('n', 0.125, 0.0, 0.875),
#  'gorrón': ('n', 0.125, 0.0, 0.875),
#  'residente temporal': ('n', 0.125, 0.0, 0.875),
#  'papel de confidente o de coqueta': ('n', 0.125, 0.0, 0.875),
#  'prestamista': ('n', 0.125, 0.0, 0.875),
#  'usurero': ('n', 0.125, 0.0, 0.875),
#  'arnoseris ': ('n', 0.125, 0.0, 0.875),
#  'typha': ('n', 0.125, 0.0, 0.875),
#  'liposarcoma': ('n', 0.125, 0.0, 0.875),
#  'medio': ('n', 0.125, 0.0, 0.875),
#  'alrededores': ('n', 0.125, 0.0, 0.875),
#  'butilo': ('n', 0.125, 0.0, 0.875),
#  'reconocido': ('a', 0.125, 0.0, 0.875),
#  'perceptivamente': ('r', 0.125, 0.0, 0.875),
#  'cabriola': ('n', 0.125, 0.0, 0.875),
#  'samba': ('n', 0.125, 0.0, 0.875),
#  'levantar': ('v', 0.0, 0.125, 0.875),
#  'estampar': ('v', 0.125, 0.0, 0.875),
#  'ofrecer': ('v', 0.125, 0.0, 0.875),
#  'charlatanismo': ('n', 0.125, 0.0, 0.875),
#  'charlatanería': ('n', 0.125, 0.0, 0.875),
#  'asir': ('v', 0.375, 0.0, 0.625),
#  'armonizar': ('v', 0.125, 0.0, 0.875),
#  'transportar': ('v', 0.125, 0.0, 0.875),
#  'encantar': ('v', 0.125, 0.0, 0.875),
#  'embelezar': ('v', 0.125, 0.0, 0.875),
#  'caer': ('v', 0.0, 0.375, 0.625),
#  'relativo a la limnología': ('r', 0.125, 0.0, 0.875),
#  'renovación urbana': ('n', 0.125, 0.0, 0.875),
#  'abrazo': ('n', 0.125, 0.0, 0.875),
#  'apretón': ('n', 0.125, 0.0, 0.875),
#  'remitir': ('v', 0.125, 0.0, 0.875),
#  'aflojar': ('v', 0.125, 0.0, 0.875),
#  'manifiesta': ('v', 0.125, 0.0, 0.875),
#  'bajar': ('v', 0.0, 0.5, 0.5),
#  'cortar': ('v', 0.0, 0.125, 0.875),
#  'recortar': ('v', 0.0, 0.125, 0.875),
#  'reducir': ('v', 0.0, 0.125, 0.875),
#  'rebajar': ('v', 0.125, 0.0, 0.875),
#  'combate cuerpo a cuerpo': ('n', 0.125, 0.0, 0.875),
#  'distante': ('a', 0.125, 0.0, 0.875),
#  'remota': ('a', 0.125, 0.0, 0.875),
#  'sociológicamente': ('r', 0.125, 0.0, 0.875),
#  'pulimentar': ('v', 0.125, 0.0, 0.875),
#  'pulir': ('v', 0.125, 0.0, 0.875),
#  'refinar': ('v', 0.125, 0.0, 0.875),
#  'descontaminar': ('v', 0.125, 0.0, 0.875),
#  'brinco': ('n', 0.125, 0.0, 0.875),
#  'cognitivamente': ('r', 0.125, 0.0, 0.875),
#  'taxonómicamente': ('r', 0.125, 0.0, 0.875),
#  'animar': ('v', 0.375, 0.0, 0.625),
#  'bajar la fiebre': ('v', 0.125, 0.0, 0.875),
#  'paternidad': ('n', 0.125, 0.0, 0.875),
#  'mariscalía': ('n', 0.125, 0.0, 0.875),
#  'investigación': ('n', 0.125, 0.0, 0.875),
#  'razonar por silogismos': ('v', 0.125, 0.0, 0.875),
#  'eliminar': ('v', 0.0, 0.625, 0.375),
#  'rechazar': ('v', 0.0, 0.75, 0.25),
#  'descartar': ('v', 0.125, 0.0, 0.875),
#  'evitar': ('v', 0.0, 0.75, 0.25),
#  'pedir': ('v', 0.125, 0.0, 0.875),
#  'magnetizar': ('v', 0.125, 0.0, 0.875),
#  'fascinar': ('v', 0.375, 0.0, 0.625),
#  'hipnotizar': ('v', 0.125, 0.0, 0.875),
#  'embrujar': ('v', 0.125, 0.0, 0.875),
#  'abordar': ('v', 0.125, 0.0, 0.875),
#  'enganchar': ('v', 0.0, 0.125, 0.875),
#  'ofrecer sexo': ('v', 0.125, 0.0, 0.875),
#  'aventura': ('n', 0.25, 0.0, 0.75),
#  'desdecirse': ('v', 0.125, 0.0, 0.875),
#  'renegar': ('v', 0.0, 0.5, 0.5),
#  'abogar': ('v', 0.125, 0.0, 0.875),
#  'apoyar': ('v', 0.125, 0.0, 0.875),
#  'informar': ('v', 0.125, 0.0, 0.875),
#  'timar': ('v', 0.0, 0.125, 0.875),
#  'encandilar': ('v', 0.125, 0.0, 0.875),
#  'confundir': ('v', 0.0, 0.375, 0.625),
#  'onanismo': ('n', 0.125, 0.0, 0.875),
#  'avanzar': ('v', 0.125, 0.0, 0.875),
#  'proponer': ('v', 0.375, 0.0, 0.625),
#  'presentar': ('v', 0.125, 0.0, 0.875),
#  'recordar': ('v', 0.125, 0.0, 0.875),
#  'complacer': ('v', 0.125, 0.0, 0.875),
#  'enseñanza de la lectura': ('n', 0.125, 0.0, 0.875),
#  'dramatización': ('n', 0.125, 0.0, 0.875),
#  'aclamar': ('v', 0.375, 0.0, 0.625),
#  'anunciar': ('v', 0.125, 0.0, 0.875),
#  'dar a entender': ('v', 0.125, 0.0, 0.875),
#  'abigeato': ('n', 0.125, 0.0, 0.875),
#  'documentar': ('v', 0.125, 0.0, 0.875),
#  'prueba de inteligencia': ('n', 0.125, 0.0, 0.875),
#  'prueba de ci': ('n', 0.125, 0.0, 0.875),
#  'randomización': ('n', 0.125, 0.0, 0.875),
#  'pronunciar con sibilante': ('v', 0.125, 0.0, 0.875),
#  'desencantar': ('v', 0.125, 0.0, 0.875),
#  'demoler': ('v', 0.125, 0.0, 0.875),
#  'defenderse': ('v', 0.125, 0.0, 0.875),
#  'luchar': ('v', 0.0, 0.25, 0.75),
#  'enfrentarse': ('v', 0.0, 0.125, 0.875),
#  'derrotar': ('v', 0.125, 0.0, 0.875),
#  'oponerse': ('v', 0.125, 0.0, 0.875),
#  'vencer': ('v', 0.125, 0.0, 0.875),
#  'aplastar': ('v', 0.0, 0.125, 0.875),
#  'bombardear': ('v', 0.125, 0.0, 0.875),
#  'dar una paliza': ('v', 0.0, 0.75, 0.25),
#  'derrotar con trampas': ('v', 0.125, 0.0, 0.875),
#  'desobediencia': ('n', 0.125, 0.0, 0.875),
#  'reflotar': ('v', 0.125, 0.0, 0.875),
#  'buena acción': ('n', 0.125, 0.0, 0.875),
#  'empapar': ('v', 0.375, 0.0, 0.625),
#  'abrillantar': ('v', 0.125, 0.0, 0.875),
#  'bruñir': ('v', 0.125, 0.0, 0.875),
#  'adherirse': ('v', 0.125, 0.0, 0.875),
#  'asociarse': ('v', 0.125, 0.0, 0.875),
#  'pegarse': ('v', 0.125, 0.0, 0.875),
#  'incorporarse': ('v', 0.125, 0.0, 0.875),
#  'familia nitrobacteriaceae': ('n', 0.125, 0.0, 0.875),
#  'excepcionalmente': ('r', 0.125, 0.0, 0.875),
#  'buck and wing': ('n', 0.125, 0.0, 0.875),
#  'geotropismo': ('n', 0.125, 0.0, 0.875),
#  'misa mayor': ('n', 0.125, 0.0, 0.875),
#  'derrotar completamente': ('v', 0.125, 0.0, 0.875),
#  'aventajar': ('v', 0.125, 0.0, 0.875),
#  'avituallar': ('v', 0.125, 0.0, 0.875),
#  'aferrar': ('v', 0.125, 0.0, 0.875),
#  'envolver para regalo': ('v', 0.125, 0.0, 0.875),
#  'chlamydia trachomatis': ('n', 0.125, 0.0, 0.875),
#  'clase euglenophyceae': ('n', 0.125, 0.0, 0.875),
#  'euglenophyceae': ('n', 0.125, 0.0, 0.875),
#  'abofetear': ('v', 0.125, 0.0, 0.875),
#  'acnidosporidia': ('n', 0.125, 0.0, 0.875),
#  'género acnidosporidia': ('n', 0.125, 0.0, 0.875),
#  'chasquear': ('v', 0.0, 0.625, 0.375),
#  'arrebatar': ('v', 0.125, 0.0, 0.875),
#  'agarrar por la fuerza': ('v', 0.125, 0.0, 0.875),
#  'sardina hocido de puerco': ('n', 0.125, 0.0, 0.875),
#  'hypentelium nigricans': ('n', 0.125, 0.0, 0.875),
#  'orden zeomorphi': ('n', 0.125, 0.0, 0.875),
#  'zeomorphi': ('n', 0.125, 0.0, 0.875),
#  'lubricar': ('v', 0.125, 0.0, 0.875),
#  'enterrar': ('v', 0.125, 0.0, 0.875),
#  'hundir': ('v', 0.125, 0.0, 0.875),
#  'limpiar': ('v', 0.125, 0.0, 0.875),
#  'limpiar la corrupción': ('v', 0.125, 0.0, 0.875),
#  'empuñar': ('v', 0.125, 0.0, 0.875),
#  'sacar': ('v', 0.0, 0.125, 0.875),
#  'jalar': ('v', 0.125, 0.0, 0.875),
#  'pelliscar': ('v', 0.125, 0.0, 0.875),
#  'invitar': ('v', 0.125, 0.0, 0.875),
#  'conjurar': ('v', 0.125, 0.0, 0.875),
#  'evocar': ('v', 0.125, 0.0, 0.875),
#  'exponer': ('v', 0.125, 0.0, 0.875),
#  'invocar': ('v', 0.125, 0.0, 0.875),
#  'crocodylidae': ('n', 0.125, 0.0, 0.875),
#  'captar': ('v', 0.125, 0.0, 0.875),
#  'lograr': ('v', 0.125, 0.0, 0.875),
#  'bothrops': ('n', 0.125, 0.0, 0.875),
#  'género bothrops': ('n', 0.125, 0.0, 0.875),
#  'orden scorpionida': ('n', 0.125, 0.0, 0.875),
#  'scorpionida': ('n', 0.125, 0.0, 0.875),
#  'congraciarse': ('v', 0.125, 0.0, 0.875),
#  'avivar': ('v', 0.125, 0.0, 0.875),
#  'exaltar': ('v', 0.75, 0.0, 0.25),
#  'inspirar': ('v', 0.375, 0.0, 0.625),
#  'revigorizar': ('v', 0.125, 0.0, 0.875),
#  'temblar': ('v', 0.0, 0.125, 0.875),
#  'erinaceidae': ('n', 0.125, 0.0, 0.875),
#  'familia erinaceidae': ('n', 0.125, 0.0, 0.875),
#  'cestoda': ('n', 0.125, 0.0, 0.875),
#  'clase cestoda': ('n', 0.125, 0.0, 0.875),
#  'filo pogonophora': ('n', 0.125, 0.0, 0.875),
#  'clase lamellibranchia': ('n', 0.125, 0.0, 0.875),
#  'myaceae': ('n', 0.125, 0.0, 0.875),
#  'orden myaceae': ('n', 0.125, 0.0, 0.875),
#  'familia anomiidae': ('n', 0.125, 0.0, 0.875),
#  'familia pectinidae': ('n', 0.125, 0.0, 0.875),
#  'pectinidae': ('n', 0.125, 0.0, 0.875),
#  'octopoda': ('n', 0.125, 0.0, 0.875),
#  'orden octopoda': ('n', 0.125, 0.0, 0.875),
#  'familia sepiidae': ('n', 0.125, 0.0, 0.875),
#  'entrar': ('v', 0.125, 0.0, 0.875),
#  'ingresar': ('v', 0.125, 0.0, 0.875),
#  'hacer su llegada': ('v', 0.125, 0.0, 0.875),
#  'arribar': ('v', 0.125, 0.0, 0.875),
#  'género pedionomus': ('n', 0.125, 0.0, 0.875),
#  'pedionomus': ('n', 0.125, 0.0, 0.875),
#  'género phalaropus': ('n', 0.125, 0.0, 0.875),
#  'phalaropus': ('n', 0.125, 0.0, 0.875),
#  'en condiciones de vuelo': ('a', 0.125, 0.0, 0.875),
#  'embrutecerse': ('v', 0.125, 0.0, 0.875),
#  'idiotizarse': ('v', 0.125, 0.0, 0.875),
#  'tocar': ('v', 0.0, 0.125, 0.875),
#  'hacer justicia': ('v', 0.125, 0.0, 0.875),
#  'rrhinolophidae': ('n', 0.125, 0.0, 0.875),
#  'titilar': ('v', 0.0, 0.25, 0.75),
#  'chrysomelidae': ('n', 0.125, 0.0, 0.875),
#  'familia chrysomelidae': ('n', 0.125, 0.0, 0.875),
#  'adquirir': ('v', 0.125, 0.0, 0.875),
#  'obtener': ('v', 0.125, 0.0, 0.875),
#  'género megachile': ('n', 0.125, 0.0, 0.875),
#  'megachile': ('n', 0.125, 0.0, 0.875),
#  'fenusa': ('n', 0.125, 0.0, 0.875),
#  'género  fenusa': ('n', 0.125, 0.0, 0.875),
#  'familia phillidae': ('n', 0.125, 0.0, 0.875),
#  'familia phyllidae': ('n', 0.125, 0.0, 0.875),
#  'phillidae': ('n', 0.125, 0.0, 0.875),
#  'phyllidae': ('n', 0.125, 0.0, 0.875),
#  'género leptoglossus': ('n', 0.125, 0.0, 0.875),
#  'leptoglossus': ('n', 0.125, 0.0, 0.875),
#  'liquidar': ('v', 0.125, 0.0, 0.875),
#  'arrojar': ('v', 0.0, 0.25, 0.75),
#  'desperdiciar': ('v', 0.125, 0.0, 0.875),
#  'malgastar': ('v', 0.125, 0.0, 0.875),
#  'género vanessa': ('n', 0.125, 0.0, 0.875),
#  'familia tortricidae': ('n', 0.125, 0.0, 0.875),
#  'tortricidae': ('n', 0.125, 0.0, 0.875),
#  'superfamilia tineoidea': ('n', 0.125, 0.0, 0.875),
#  'tineoidea': ('n', 0.125, 0.0, 0.875),
#  'género hydromys': ('n', 0.125, 0.0, 0.875),
#  'hydromys': ('n', 0.125, 0.0, 0.875),
#  'florecer': ('v', 0.125, 0.0, 0.875),
#  'fly high': ('v', 0.125, 0.0, 0.875),
#  'prosperar': ('v', 0.125, 0.0, 0.875),
#  'proliferar': ('v', 0.125, 0.0, 0.875),
#  'dipodomys': ('n', 0.125, 0.0, 0.875),
#  'género dipodomys': ('n', 0.125, 0.0, 0.875),
#  'sanitizar': ('v', 0.125, 0.0, 0.875),
#  'cordero persa': ('n', 0.125, 0.0, 0.875),
#  'anthropoidea': ('n', 0.125, 0.0, 0.875),
#  'poner el pan sobre la mesa': ('v', 0.125, 0.0, 0.875),
#  'salir adelante': ('v', 0.125, 0.0, 0.875),
#  'cortejar': ('v', 0.125, 0.0, 0.875),
#  'teñir': ('v', 0.375, 0.0, 0.625),
#  'incentivar': ('v', 0.25, 0.0, 0.75),
#  'completar': ('v', 0.375, 0.0, 0.625),
#  'despachar': ('v', 0.0, 0.625, 0.375),
#  'engañar': ('v', 0.0, 0.625, 0.375),
#  'entrante': ('a', 0.125, 0.0, 0.875),
#  'tallista': ('n', 0.125, 0.0, 0.875),
#  'tallista en madera': ('n', 0.125, 0.0, 0.875),
#  'aleksandr aleksandrovich blok': ('n', 0.125, 0.0, 0.875),
#  'blok': ('n', 0.125, 0.0, 0.875),
#  'john anthony ciardi': ('n', 0.125, 0.0, 0.875),
#  'john ciardi': ('n', 0.125, 0.0, 0.875),
#  'donatello': ('n', 0.125, 0.0, 0.875),
#  'donato di betto bardi': ('n', 0.125, 0.0, 0.875),
#  'jorge': ('n', 0.125, 0.0, 0.875),
#  'jorge ii': ('n', 0.125, 0.0, 0.875),
#  'john keats': ('n', 0.125, 0.0, 0.875),
#  'keats': ('n', 0.125, 0.0, 0.875),
#  'franz liszt': ('n', 0.125, 0.0, 0.875),
#  'liszt': ('n', 0.125, 0.0, 0.875),
#  'neftalí ricardo reyes': ('n', 0.125, 0.0, 0.875),
#  'pablo neruda': ('n', 0.125, 0.0, 0.875),
#  'plath': ('n', 0.125, 0.0, 0.875),
#  'edgar allan poe': ('n', 0.125, 0.0, 0.875),
#  'aleksandr sergeyevich pushkin': ('n', 0.125, 0.0, 0.875),
#  'alexander pushkin': ('n', 0.125, 0.0, 0.875),
#  'pushkin': ('n', 0.125, 0.0, 0.875),
#  'percy bysshe shelley': ('n', 0.125, 0.0, 0.875),
#  'shelley': ('n', 0.125, 0.0, 0.875),
#  'adam smith': ('n', 0.125, 0.0, 0.875),
#  'smith': ('n', 0.125, 0.0, 0.875),
#  'john orley allen tate': ('n', 0.125, 0.0, 0.875),
#  'deems taylor': ('n', 0.125, 0.0, 0.875),
#  'taylor': ('n', 0.125, 0.0, 0.875),
#  'aldred tennyson': ('n', 0.125, 0.0, 0.875),
#  'dylan thomas': ('n', 0.125, 0.0, 0.875),
#  'thomas': ('n', 0.125, 0.0, 0.875),
#  'buena fortuna': ('n', 0.125, 0.0, 0.875),
#  'buena suerte': ('n', 0.125, 0.0, 0.875),
#  'pino contorta sierra': ('n', 0.125, 0.0, 0.875),
#  'canelero de china': ('n', 0.125, 0.0, 0.875),
#  'cinnamomum cassia': ('n', 0.125, 0.0, 0.875),
#  'corteza de cassia': ('n', 0.125, 0.0, 0.875),
#  'canela china': ('n', 0.125, 0.0, 0.875),
#  'banalidad': ('n', 0.125, 0.0, 0.875),
#  'cliché': ('n', 0.125, 0.0, 0.875),
#  'golpe teatral': ('n', 0.125, 0.0, 0.875),
#  'vianda': ('n', 0.125, 0.0, 0.875),
#  'zampada': ('n', 0.125, 0.0, 0.875),
#  'clase culta': ('n', 0.125, 0.0, 0.875),
#  'sodoma': ('n', 0.125, 0.0, 0.875),
#  'copérnico': ('n', 0.125, 0.0, 0.875),
#  'bardo': ('n', 0.125, 0.0, 0.875),
#  'corista': ('n', 0.125, 0.0, 0.875),
#  'ceceador': ('n', 0.125, 0.0, 0.875),
#  'ciardi': ('n', 0.125, 0.0, 0.875),
#  'tate': ('n', 0.125, 0.0, 0.875),
#  'género arnoseris': ('n', 0.125, 0.0, 0.875),
#  'género typha': ('n', 0.125, 0.0, 0.875),
#  'familia hydrocharidáceas': ('n', 0.125, 0.0, 0.875),
#  'familia hydrocharitáceas': ('n', 0.125, 0.0, 0.875),
#  'familia mordisco de rana': ('n', 0.125, 0.0, 0.875),
#  'hydrocharidáceas': ('n', 0.125, 0.0, 0.875),
#  'hydrocharitáceas': ('n', 0.125, 0.0, 0.875),
#  'género kolkwitzia': ('n', 0.125, 0.0, 0.875),
#  'kolkwitzia': ('n', 0.125, 0.0, 0.875),
#  'dimocarpus': ('n', 0.125, 0.0, 0.875),
#  'género dimocarpus': ('n', 0.125, 0.0, 0.875),
#  'cirro': ('n', 0.125, 0.0, 0.875),
#  'fronda': ('n', 0.125, 0.0, 0.875),
#  'compra': ('n', 0.125, 0.0, 0.875),
#  'alquiler exorbitante': ('n', 0.125, 0.0, 0.875),
#  'pérdida': ('n', 0.0, 0.75, 0.25),
#  'ocho peniques': ('n', 0.125, 0.0, 0.875),
#  'níquel': ('n', 0.125, 0.0, 0.875),
#  'taza': ('n', 0.125, 0.0, 0.875),
#  'fuerza convincente': ('n', 0.125, 0.0, 0.875),
#  'ets': ('n', 0.125, 0.0, 0.875),
#  'faringitis estreptocócica': ('n', 0.125, 0.0, 0.875),
#  'alucinación visual': ('n', 0.125, 0.0, 0.875),
#  'predisposición': ('n', 0.0, 0.875, 0.125),
#  'florecimiento': ('n', 0.125, 0.0, 0.875),
#  'la flor de la juventud': ('n', 0.125, 0.0, 0.875),
#  'tiempos mozos': ('n', 0.125, 0.0, 0.875),
#  'hoy': ('n', 0.125, 0.0, 0.875),
#  'respiro': ('n', 0.0, 0.75, 0.25),
#  'período de descanso': ('n', 0.125, 0.0, 0.875),
#  'sustancialmente': ('r', 0.125, 0.0, 0.875),
#  'aullar de risa': ('v', 0.125, 0.0, 0.875),
#  'reir a carcajadas': ('v', 0.125, 0.0, 0.875),
#  'peinar con estilo': ('v', 0.125, 0.0, 0.875),
#  'aderezar': ('v', 0.125, 0.0, 0.875),
#  'marcar': ('v', 0.125, 0.0, 0.875),
#  'mano a mano': ('r', 0.125, 0.0, 0.875),
#  'esencial?': ('a', 0.125, 0.0, 0.875),
#  'sustantivo?': ('a', 0.125, 0.0, 0.875),
#  'en cualquier caso': ('r', 0.125, 0.0, 0.875),
#  'mucho': ('r', 0.25, 0.0, 0.75),
#  'reavivar': ('v', 0.125, 0.0, 0.875),
#  'curar': ('v', 0.125, 0.0, 0.875),
#  'sanar': ('v', 0.125, 0.0, 0.875),
#  'continuamente': ('r', 0.125, 0.0, 0.875),
#  'hacia mí': ('r', 0.125, 0.0, 0.875),
#  'históricamente': ('r', 0.125, 0.0, 0.875),
#  'volumétricamente': ('r', 0.125, 0.0, 0.875),
#  'patológicamente': ('r', 0.125, 0.0, 0.875),
#  'en total': ('r', 0.125, 0.0, 0.875),
#  'gol': ('n', 0.125, 0.0, 0.875),
#  'vigorizar': ('v', 0.125, 0.0, 0.875),
#  'fluctuación': ('n', 0.125, 0.0, 0.875),
#  'convulsivamente': ('r', 0.125, 0.0, 0.875),
#  'domar': ('v', 0.375, 0.0, 0.625),
#  'justamente': ('r', 0.375, 0.0, 0.625),
#  'destitución': ('n', 0.125, 0.0, 0.875),
#  'debilitar': ('v', 0.375, 0.0, 0.625),
#  'purificación': ('n', 0.125, 0.0, 0.875),
#  'destrozar': ('v', 0.0, 0.25, 0.75),
#  'mantenimiento programado': ('n', 0.125, 0.0, 0.875),
#  'sensibilizar': ('v', 0.125, 0.0, 0.875),
#  'concienciar': ('v', 0.125, 0.0, 0.875),
#  'climáticamente': ('r', 0.125, 0.0, 0.875),
#  'ajustar': ('v', 0.125, 0.0, 0.875),
#  'descriptivamente': ('r', 0.125, 0.0, 0.875),
#  'devotamente': ('r', 0.125, 0.0, 0.875),
#  'geológicamente': ('r', 0.125, 0.0, 0.875),
#  'cómicamente': ('r', 0.125, 0.0, 0.875),
#  'risiblemente': ('r', 0.125, 0.0, 0.875),
#  'rehabilitación correccional': ('n', 0.125, 0.0, 0.875),
#  'nutricionalmente': ('r', 0.125, 0.0, 0.875),
#  'abrazo apasionado': ('n', 0.125, 0.0, 0.875),
#  'farmacológicamente': ('r', 0.125, 0.0, 0.875),
#  'aparecer': ('v', 0.125, 0.0, 0.875),
#  'acrobacias': ('n', 0.125, 0.0, 0.875),
#  'volteretas': ('n', 0.125, 0.0, 0.875),
#  'deporte ecuestre': ('n', 0.125, 0.0, 0.875),
#  'realinear': ('v', 0.125, 0.0, 0.875),
#  'enderezar': ('v', 0.125, 0.0, 0.875),
#  'afinar': ('v', 0.125, 0.0, 0.875),
#  'prejuiciar': ('v', 0.0, 0.375, 0.625),
#  'topográficamente': ('r', 0.125, 0.0, 0.875),
#  'cargar': ('v', 0.0, 0.875, 0.125),
#  'asibilar': ('v', 0.125, 0.0, 0.875),
#  'malabarismo': ('n', 0.125, 0.0, 0.875),
#  'ejercitar': ('v', 0.125, 0.0, 0.875),
#  'leer': ('v', 0.125, 0.0, 0.875),
#  'racionalizar': ('v', 0.125, 0.0, 0.875),
#  'nocturno': ('a', 0.125, 0.0, 0.875),
#  'creer': ('v', 0.125, 0.0, 0.875),
#  'concretar': ('v', 0.125, 0.0, 0.875),
#  'despertarse': ('v', 0.125, 0.0, 0.875),
#  'abandono': ('n', 0.125, 0.0, 0.875),
#  'bloqueado': ('a', 0.125, 0.0, 0.875),
#  'profesar': ('v', 0.125, 0.0, 0.875),
#  'instruir': ('v', 0.125, 0.0, 0.875),
#  'acusar': ('v', 0.125, 0.0, 0.875),
#  'culpar': ('v', 0.0, 0.375, 0.625),
#  'mofarse': ('v', 0.0, 0.375, 0.625),
#  'embaucar': ('v', 0.0, 0.875, 0.125),
#  'dar gato por liebre': ('v', 0.0, 0.125, 0.875),
#  'enredar': ('v', 0.125, 0.0, 0.875),
#  'falsear': ('v', 0.0, 0.375, 0.625),
#  'defraudar': ('v', 0.0, 0.125, 0.875),
#  'engatusar': ('v', 0.125, 0.0, 0.875),
#  'masturbación': ('n', 0.125, 0.0, 0.875),
#  'despertar': ('v', 0.125, 0.0, 0.875),
#  'retroalimentar': ('v', 0.125, 0.0, 0.875),
#  'dedicar': ('v', 0.125, 0.0, 0.875),
#  'disciplina': ('n', 0.125, 0.0, 0.875),
#  'capacidad': ('n', 0.125, 0.0, 0.875),
#  'explotación de depósitos minerales': ('n', 0.125, 0.0, 0.875),
#  'sugerir': ('v', 0.5, 0.0, 0.5),
#  'insinuar': ('v', 0.5, 0.0, 0.5),
#  'capitalización': ('n', 0.125, 0.0, 0.875),
#  'pelea cuerpo a cuerpo': ('n', 0.125, 0.0, 0.875),
#  'actualizar': ('v', 0.125, 0.0, 0.875),
#  'contrafirmar': ('v', 0.125, 0.0, 0.875),
#  'abstinencia': ('n', 0.125, 0.0, 0.875),
#  'grieta': ('n', 0.125, 0.0, 0.875),
#  'exención': ('n', 0.125, 0.0, 0.875),
#  'cachemira': ('n', 0.125, 0.0, 0.875),
#  'época de san miguel': ('n', 0.125, 0.0, 0.875),
#  'época de lammas': ('n', 0.125, 0.0, 0.875),
#  'época de pascua': ('n', 0.125, 0.0, 0.875),
#  'época de la epifanía': ('n', 0.125, 0.0, 0.875),
#  'período': ('n', 0.125, 0.0, 0.875),
#  'destruir': ('v', 0.0, 0.25, 0.75),
#  'hacer pedazos': ('v', 0.125, 0.0, 0.875),
#  'autolimitación': ('n', 0.125, 0.0, 0.875),
#  'ver': ('v', 0.125, 0.0, 0.875),
#  'explotar': ('v', 0.125, 0.0, 0.875),
#  'incumplimiento': ('n', 0.125, 0.0, 0.875),
#  'servir': ('v', 0.125, 0.0, 0.875),
#  'cuidar un bebé': ('v', 0.125, 0.0, 0.875),
#  'insistencia': ('n', 0.0, 0.125, 0.875),
#  'buen gesto': ('n', 0.125, 0.0, 0.875),
#  'absentismo': ('n', 0.125, 0.0, 0.875),
#  'ser fatal': ('v', 0.125, 0.0, 0.875),
#  'especie de bacterias': ('n', 0.125, 0.0, 0.875),
#  'pseudomonas pyocanea': ('n', 0.125, 0.0, 0.875),
#  'nitrobacteriaceae': ('n', 0.125, 0.0, 0.875),
#  'c. trachomatis': ('n', 0.125, 0.0, 0.875),
#  'apapachar': ('v', 0.125, 0.0, 0.875),
#  'derribar': ('v', 0.125, 0.0, 0.875),
#  'asear la casa': ('v', 0.125, 0.0, 0.875),
#  'agregar': ('v', 0.125, 0.0, 0.875),
#  'empastar': ('v', 0.125, 0.0, 0.875),
#  'traer': ('v', 0.125, 0.0, 0.875),
#  'llamar': ('v', 0.125, 0.0, 0.875),
#  'agitar': ('v', 0.125, 0.0, 0.875),
#  'dar': ('v', 0.0, 0.5, 0.5),
#  'producir': ('v', 0.125, 0.0, 0.875),
#  'indentar': ('v', 0.125, 0.0, 0.875),
#  'aficionarse': ('v', 0.125, 0.0, 0.875),
#  'asustar': ('v', 0.125, 0.0, 0.875),
#  'intimidar': ('v', 0.125, 0.0, 0.875),
#  'decepcionar': ('v', 0.125, 0.0, 0.875),
#  'andar en cámara': ('v', 0.125, 0.0, 0.875),
#  'desplazarse furtivamente': ('v', 0.125, 0.0, 0.875),
#  'coral hongo': ('n', 0.125, 0.0, 0.875),
#  'género echinococcus': ('n', 0.125, 0.0, 0.875),
#  'clase bivalvia': ('n', 0.125, 0.0, 0.875),
#  'clase pelecypoda': ('n', 0.125, 0.0, 0.875),
#  'almeja roja': ('n', 0.125, 0.0, 0.875),
#  'sepiidae': ('n', 0.125, 0.0, 0.875),
#  'hacer circular': ('v', 0.125, 0.0, 0.875),
#  'seleccionado': ('a', 0.125, 0.0, 0.875),
#  'mostrar': ('v', 0.125, 0.0, 0.875),
#  'phyllostomidae': ('n', 0.125, 0.0, 0.875),
#  'familia rrhinolophidae': ('n', 0.125, 0.0, 0.875),
#  'observar': ('v', 0.125, 0.0, 0.875),
#  'acordar': ('v', 0.125, 0.0, 0.875),
#  'asteroidea': ('n', 0.125, 0.0, 0.875),
#  'calse asteroidea': ('n', 0.125, 0.0, 0.875),
#  'enroscado': ('a', 0.125, 0.0, 0.875),
#  'género zapus': ('n', 0.125, 0.0, 0.875),
#  'zapus': ('n', 0.125, 0.0, 0.875),
#  'género bathyergus': ('n', 0.125, 0.0, 0.875),
#  'pastorear': ('v', 0.125, 0.0, 0.875),
#  'privilegiar': ('v', 0.125, 0.0, 0.875),
#  'suborden anthropoidea': ('n', 0.125, 0.0, 0.875),
#  'hominóideo': ('n', 0.125, 0.0, 0.875),
#  'homínido': ('n', 0.125, 0.0, 0.875),
#  'entretener': ('v', 0.125, 0.0, 0.875),
#  'cumplir lo prometido': ('v', 0.125, 0.0, 0.875),
#  'tener éxito': ('v', 0.125, 0.0, 0.875),
#  'triunfar': ('n', 0.625, 0.0, 0.375),
#  'jugársela': ('v', 0.125, 0.0, 0.875),
#  'flirtear': ('v', 0.125, 0.0, 0.875),
#  'fomentar': ('v', 0.125, 0.0, 0.875),
#  'impulsar': ('v', 0.125, 0.0, 0.875),
#  'estimular': ('v', 0.125, 0.0, 0.875),
#  'promover': ('v', 0.125, 0.0, 0.875),
#  'cumplir': ('v', 0.125, 0.0, 0.875),
#  'suspender por lluvia': ('v', 0.125, 0.0, 0.875),
#  'resistir': ('v', 0.0, 0.125, 0.875),
#  'mantenerse': ('v', 0.125, 0.0, 0.875),
#  'coprotagonizar': ('v', 0.125, 0.0, 0.875),
#  'dirigible': ('n', 0.125, 0.0, 0.875),
#  'wilsoniano': ('a', 0.125, 0.0, 0.875),
#  'proficiente': ('a', 0.125, 0.0, 0.875),
#  'poético': ('a', 0.125, 0.0, 0.875),
#  'mesiánico': ('a', 0.125, 0.0, 0.875),
#  'bombie': ('n', 0.125, 0.0, 0.875),
#  'gustativo': ('a', 0.125, 0.0, 0.875),
#  'gustatorio': ('a', 0.125, 0.0, 0.875),
#  'cubículo': ('n', 0.125, 0.0, 0.875),
#  'capote': ('n', 0.125, 0.0, 0.875),
#  'abrigo encapuchado': ('n', 0.125, 0.0, 0.875),
#  'epicúreo': ('a', 0.125, 0.0, 0.875),
#  'capilla': ('n', 0.125, 0.0, 0.875),
#  'adicional': ('a', 0.125, 0.0, 0.875),
#  'escurridor': ('n', 0.125, 0.0, 0.875),
#  'dentadura falsa': ('n', 0.125, 0.0, 0.875),
#  'tracería de abanicos': ('n', 0.125, 0.0, 0.875),
#  'aguada': ('n', 0.125, 0.0, 0.875),
#  'alabarda': ('n', 0.125, 0.0, 0.875),
#  'spa': ('n', 0.5, 0.0, 0.5),
#  'albergue juvenil': ('n', 0.125, 0.0, 0.875),
#  'youth hostel': ('n', 0.125, 0.0, 0.875),
#  'luneta': ('n', 0.125, 0.0, 0.875),
#  'sala de masajes': ('n', 0.125, 0.0, 0.875),
#  'placa madre': ('n', 0.125, 0.0, 0.875),
#  'reloj de péndulo': ('n', 0.125, 0.0, 0.875),
#  'estilete': ('n', 0.125, 0.0, 0.875),
#  'porcelana, cerámica': ('n', 0.125, 0.0, 0.875),
#  'espectroscopio de prisma': ('n', 0.125, 0.0, 0.875),
#  'espectroscopio': ('n', 0.125, 0.0, 0.875),
#  'terazosina': ('n', 0.125, 0.0, 0.875),
#  'parada de camiones': ('n', 0.125, 0.0, 0.875),
#  'tienda de golosinas': ('n', 0.125, 0.0, 0.875),
#  '22': ('n', 0.125, 0.0, 0.875),
#  'cristal veneciano': ('n', 0.125, 0.0, 0.875),
#  'espíritu': ('n', 0.125, 0.0, 0.875),
#  'progresión': ('n', 0.125, 0.0, 0.875),
#  'progresividad': ('n', 0.125, 0.0, 0.875),
#  'imprecisión': ('n', 0.125, 0.0, 0.875),
#  'previsión': ('n', 0.0, 0.125, 0.875),
#  'vena': ('n', 0.125, 0.0, 0.875),
#  'nombre': ('n', 0.0, 0.125, 0.875),
#  'recurso': ('n', 0.125, 0.0, 0.875),
#  'refugio': ('n', 0.0, 0.375, 0.625),
#  'apelación': ('n', 0.125, 0.0, 0.875),
#  'delantera': ('n', 0.125, 0.0, 0.875),
#  'abductor del dedo gordo del pie': ('n', 0.125, 0.0, 0.875),
#  'aductor del dedo gordo del pie': ('n', 0.125, 0.0, 0.875),
#  'conducto torácico': ('n', 0.125, 0.0, 0.875),
#  '(buena) mano': ('n', 0.125, 0.0, 0.875),
#  'complemento': ('n', 0.125, 0.0, 0.875),
#  'aprehensión inmediata': ('n', 0.125, 0.0, 0.875),
#  'vainilla': ('n', 0.125, 0.0, 0.875),
#  'verificación': ('n', 0.125, 0.0, 0.875),
#  'doble comprobación': ('n', 0.125, 0.0, 0.875),
#  'ensimismamiento': ('n', 0.0, 0.125, 0.875),
#  'reflexión': ('n', 0.125, 0.0, 0.875),
#  'meditación': ('n', 0.125, 0.0, 0.875),
#  'ponderación': ('n', 0.5, 0.0, 0.5),
#  'clave': ('n', 0.125, 0.0, 0.875),
#  'percepcion': ('n', 0.125, 0.0, 0.875),
#  'maestro': ('n', 0.125, 0.0, 0.875),
#  'yang': ('n', 0.125, 0.0, 0.875),
#  'teosofismo': ('n', 0.125, 0.0, 0.875),
#  'reconocimiento': ('n', 0.625, 0.0, 0.375),
#  'política de agresión': ('n', 0.125, 0.0, 0.875),
#  'vizcondado': ('n', 0.125, 0.0, 0.875),
#  'ditirambo': ('n', 0.125, 0.0, 0.875),
#  'versión estándar americana': ('n', 0.125, 0.0, 0.875),
#  'perdón': ('n', 0.125, 0.0, 0.875),
#  'tonterías': ('n', 0.0, 0.25, 0.75),
#  'morralla': ('n', 0.125, 0.0, 0.875),
#  'bobadas': ('n', 0.125, 0.0, 0.875),
#  'aguachirle': ('n', 0.125, 0.0, 0.875),
#  'prueba matemática': ('n', 0.125, 0.0, 0.875),
#  'consejo': ('n', 0.125, 0.0, 0.875),
#  'filtración': ('n', 0.125, 0.0, 0.875),
#  'doctor en osteopatía': ('n', 0.125, 0.0, 0.875),
#  'declaración discreta': ('n', 0.125, 0.0, 0.875),
#  'espectáculo': ('n', 0.125, 0.0, 0.875),
#  'floritura': ('n', 0.125, 0.0, 0.875),
#  'matiné': ('n', 0.125, 0.0, 0.875),
#  'alemán alto antiguo': ('n', 0.125, 0.0, 0.875),
#  'ilustración': ('n', 0.375, 0.0, 0.625),
#  'obra': ('n', 0.125, 0.0, 0.875),
#  'expresión': ('n', 0.125, 0.0, 0.875),
#  'aullidos': ('n', 0.125, 0.0, 0.875),
#  'compensación': ('n', 0.375, 0.0, 0.625),
#  'gracias': ('n', 0.0, 0.125, 0.875),
#  'inculpación': ('n', 0.125, 0.0, 0.875),
#  'prohibición': ('n', 0.125, 0.0, 0.875),
#  'cachondeo': ('n', 0.125, 0.0, 0.875),
#  'horror': ('n', 0.0, 0.5, 0.5),
#  'buen viaje': ('n', 0.125, 0.0, 0.875),
#  'efusión': ('n', 0.5, 0.0, 0.5),
#  'aniquilación': ('n', 0.0, 0.125, 0.875),
#  'desintegración': ('n', 0.125, 0.0, 0.875),
#  'ladrido': ('n', 0.125, 0.0, 0.875),
#  'descontento': ('n', 0.125, 0.0, 0.875),
#  'comida decente': ('n', 0.125, 0.0, 0.875),
#  'chowder': ('n', 0.125, 0.0, 0.875),
#  'caramelo de miel': ('n', 0.125, 0.0, 0.875),
#  'caramelo de azúcar': ('n', 0.125, 0.0, 0.875),
#  'quiche lorraine': ('n', 0.125, 0.0, 0.875),
#  'foie gras': ('n', 0.125, 0.0, 0.875),
#  'paté de foie gras': ('n', 0.125, 0.0, 0.875),
#  'ginebra artesanal': ('n', 0.125, 0.0, 0.875),
#  'manhattan': ('n', 0.125, 0.0, 0.875),
#  'arminianismo': ('n', 0.125, 0.0, 0.875),
#  'iglesia metodista': ('n', 0.125, 0.0, 0.875),
#  'metodistas': ('n', 0.125, 0.0, 0.875),
#  'taoísmo': ('n', 0.125, 0.0, 0.875),
#  'facultad de arte': ('n', 0.125, 0.0, 0.875),
#  'facultad de ciencias de la computación': ('n', 0.125, 0.0, 0.875),
#  'juglaría': ('n', 0.125, 0.0, 0.875),
#  'soldados hostiles': ('n', 0.125, 0.0, 0.875),
#  'esencia': ('n', 0.5, 0.0, 0.5),
#  'arzobispado': ('n', 0.125, 0.0, 0.875),
#  'reductor': ('n', 0.125, 0.0, 0.875),
#  'represor': ('n', 0.125, 0.0, 0.875),
#  'acortador': ('n', 0.125, 0.0, 0.875),
#  'aglaya': ('n', 0.125, 0.0, 0.875),
#  'eufrósine': ('n', 0.125, 0.0, 0.875),
#  'talía': ('n', 0.125, 0.0, 0.875),
#  'venus': ('n', 0.125, 0.0, 0.875),
#  'vali': ('n', 0.125, 0.0, 0.875),
#  'siervo': ('n', 0.125, 0.0, 0.875),
#  'alto mando': ('n', 0.125, 0.0, 0.875),
#  'revisor': ('n', 0.125, 0.0, 0.875),
#  'defensor': ('n', 0.125, 0.0, 0.875),
#  'promesa': ('n', 0.5, 0.0, 0.5),
#  'confesor': ('n', 0.125, 0.0, 0.875),
#  'buen conversador': ('n', 0.125, 0.0, 0.875),
#  'cubista': ('n', 0.125, 0.0, 0.875),
#  'dialéctico': ('n', 0.125, 0.0, 0.875),
#  'viejo verde': ('n', 0.125, 0.0, 0.875),
#  'aprovechador': ('n', 0.125, 0.0, 0.875),
#  'cariño': ('n', 0.125, 0.0, 0.875),
#  'metodista': ('n', 0.125, 0.0, 0.875),
#  'neoliberal': ('n', 0.125, 0.0, 0.875),
#  'partidario de la resistencia pasiva': ('n', 0.125, 0.0, 0.875),
#  'perfeccionador': ('n', 0.125, 0.0, 0.875),
#  'el que acaricia': ('n', 0.125, 0.0, 0.875),
#  'fusilero': ('n', 0.125, 0.0, 0.875),
#  'sacadineros': ('n', 0.125, 0.0, 0.875),
#  'marinero polémico': ('n', 0.125, 0.0, 0.875),
#  'persona muy reservada': ('n', 0.125, 0.0, 0.875),
#  'aficionado al deporte': ('n', 0.125, 0.0, 0.875),
#  'abanderado': ('n', 0.125, 0.0, 0.875),
#  'provocador': ('n', 0.125, 0.0, 0.875),
#  'mortificador': ('n', 0.125, 0.0, 0.875),
#  'esclavo': ('n', 0.125, 0.0, 0.875),
#  'arminiano': ('n', 0.125, 0.0, 0.875),
#  'ganador inesperado': ('n', 0.125, 0.0, 0.875),
#  'jaime': ('n', 0.125, 0.0, 0.875),
#  'santiago': ('n', 0.125, 0.0, 0.875),
#  'santiago apóstol': ('n', 0.125, 0.0, 0.875),
#  'san jaime': ('n', 0.125, 0.0, 0.875),
#  'san jaime apóstol': ('n', 0.125, 0.0, 0.875),
#  'sylvia plath': ('n', 0.125, 0.0, 0.875),
#  'allen tate': ('n', 0.125, 0.0, 0.875),
#  'joseph deems taylor': ('n', 0.125, 0.0, 0.875),
#  'alfred lord tennyson': ('n', 0.125, 0.0, 0.875),
#  'baron tennyson': ('n', 0.125, 0.0, 0.875),
#  'tiziano': ('n', 0.125, 0.0, 0.875),
#  'tiziano vecellio': ('n', 0.125, 0.0, 0.875),
#  'robert penn warren': ('n', 0.125, 0.0, 0.875),
#  'ola': ('n', 0.125, 0.0, 0.875),
#  'pino contorta murrayana': ('n', 0.125, 0.0, 0.875),
#  'ceratophyllum': ('n', 0.125, 0.0, 0.875),
#  'género ceratofiláceas': ('n', 0.125, 0.0, 0.875),
#  'género marrubium': ('n', 0.125, 0.0, 0.875),
#  'género chlorophyllum': ('n', 0.125, 0.0, 0.875),
#  'contribución': ('n', 0.125, 0.0, 0.875),
#  'capital social': ('n', 0.125, 0.0, 0.875),
#  'nueve peniques': ('n', 0.125, 0.0, 0.875),
#  'revisión puntual': ('n', 0.125, 0.0, 0.875),
#  'revisión': ('n', 0.625, 0.0, 0.375),
#  'bacteriostasis': ('n', 0.125, 0.0, 0.875),
#  'denominador': ('n', 0.125, 0.0, 0.875),
#  'ocupación hospitalaria': ('n', 0.125, 0.0, 0.875),
#  'cuarto': ('n', 0.125, 0.0, 0.875),
#  'disposición mental': ('n', 0.125, 0.0, 0.875),
#  'estado mental': ('n', 0.125, 0.0, 0.875),
#  'dosis': ('n', 0.125, 0.0, 0.875),
#  'enfermedad de transmisión sexual': ('n', 0.125, 0.0, 0.875),
#  'enfermedad social': ('n', 0.125, 0.0, 0.875),
#  'ev': ('n', 0.125, 0.0, 0.875),
#  'enfermedad venérea': ('n', 0.125, 0.0, 0.875),
#  'infección venérea': ('n', 0.125, 0.0, 0.875),
#  'faringitis sépticas': ('n', 0.125, 0.0, 0.875),
#  'amigdalitis estreptocócica': ('n', 0.125, 0.0, 0.875),
#  'inflamación de la garganta': ('n', 0.125, 0.0, 0.875),
#  'fiebre de texas': ('n', 0.125, 0.0, 0.875),
#  'soplo sistólico': ('n', 0.125, 0.0, 0.875),
#  'encefalitis hemorrágica aguda': ('n', 0.125, 0.0, 0.875),
#  'sangre azul': ('n', 0.125, 0.0, 0.875),
#  'vía': ('n', 0.125, 0.0, 0.875),
#  'pérdida auditiva sensorineural': ('n', 0.125, 0.0, 0.875),
#  'hiposmia': ('n', 0.125, 0.0, 0.875),
#  'fundición obtenida con un solo mineral': ('n', 0.125, 0.0, 0.875),
#  ...}

# %%
def map_spacy_to_wn(lexicon, spacy_to_wn):
#Mapea las etiquetas de Spacy a las etiquetas de wn

    new_lexicon = {}

    for word, (spacy_tag, pos_score, neg_score, obj_score) in lexicon.items():
        if spacy_tag in spacy_to_wn:
            # Obtener la etiqueta en WordNet
            wn_tag = spacy_to_wn[spacy_tag]
            new_lexicon[word] = (wn_tag, pos_score, neg_score, obj_score)
        else:
            # Mantener la etiqueta si no hay mapeo
            new_lexicon[word] = (spacy_tag, pos_score, neg_score, obj_score)

    return new_lexicon

# Diccionario para mapear las etiquetas de spaCy a las etiquetas esperadas en el lexicón
# Asumimos que en el lexicón se utilizan 'n' (noun), 'v' (verb), 'a' (adjective) y 'r' (adverb).
spacy_to_wn = {
    "n": "NOUN",
    "v": "VERB",
    "a": "ADJ",
    "r": "ADV"
}

# %%
spanish_sentiwordnet_to_wn = map_spacy_to_wn(spanish_sentiwordnet,spacy_to_wn)
spanish_sentiwordnet_to_wn
# Out:
# {'barrer con': ('VERB', 0.125, 0.0, 0.875),
#  'ganar': ('VERB', 0.375, 0.0, 0.625),
#  'abalizar': ('VERB', 0.125, 0.0, 0.875),
#  'ligarse': ('VERB', 0.125, 0.0, 0.875),
#  'unirse': ('VERB', 0.125, 0.0, 0.875),
#  'seguir': ('VERB', 0.375, 0.0, 0.625),
#  'raptar': ('VERB', 0.0, 0.125, 0.875),
#  'cautivar': ('VERB', 0.125, 0.0, 0.875),
#  'deambular': ('VERB', 0.125, 0.0, 0.875),
#  'platyhelminthes': ('NOUN', 0.125, 0.0, 0.875),
#  'anomiidae': ('NOUN', 0.125, 0.0, 0.875),
#  'pluvialis': ('NOUN', 0.125, 0.0, 0.875),
#  'género pluvialis': ('NOUN', 0.125, 0.0, 0.875),
#  'kogia': ('NOUN', 0.125, 0.0, 0.875),
#  'considerar': ('VERB', 0.25, 0.0, 0.75),
#  'vanessa': ('NOUN', 0.125, 0.0, 0.875),
#  'nesokia': ('NOUN', 0.125, 0.0, 0.875),
#  'género nesokia': ('NOUN', 0.125, 0.0, 0.875),
#  'socorrer': ('VERB', 0.125, 0.0, 0.875),
#  'diaforético': ('ADJ', 0.125, 0.0, 0.875),
#  'vacacionar': ('VERB', 0.125, 0.0, 0.875),
#  'sudorífico': ('ADJ', 0.125, 0.0, 0.875),
#  'lactogenico': ('ADJ', 0.125, 0.0, 0.875),
#  'casa': ('NOUN', 0.125, 0.0, 0.875),
#  'celda': ('NOUN', 0.125, 0.0, 0.875),
#  'minarete': ('NOUN', 0.125, 0.0, 0.875),
#  'ocasión': ('NOUN', 0.125, 0.0, 0.875),
#  'oportunidad': ('NOUN', 0.125, 0.0, 0.875),
#  'pertinencia': ('NOUN', 0.125, 0.0, 0.875),
#  'inmediatez': ('NOUN', 0.125, 0.0, 0.875),
#  'creencia': ('NOUN', 0.125, 0.0, 0.875),
#  'comic': ('NOUN', 0.125, 0.0, 0.875),
#  'aullido': ('NOUN', 0.0, 0.25, 0.75),
#  'estertor': ('NOUN', 0.125, 0.0, 0.875),
#  'bayat': ('NOUN', 0.125, 0.0, 0.875),
#  'exageración': ('NOUN', 0.125, 0.0, 0.875),
#  'alboroto': ('NOUN', 0.0, 0.625, 0.375),
#  'bombo': ('NOUN', 0.125, 0.0, 0.875),
#  'partidario de la no resistencia': ('NOUN', 0.125, 0.0, 0.875),
#  'satanista': ('NOUN', 0.125, 0.0, 0.875),
#  'sarraceno': ('NOUN', 0.125, 0.0, 0.875),
#  'sorbedor': ('NOUN', 0.125, 0.0, 0.875),
#  'fan': ('NOUN', 0.125, 0.0, 0.875),
#  'solterona': ('NOUN', 0.125, 0.0, 0.875),
#  'reyes': ('NOUN', 0.125, 0.0, 0.875),
#  'neruda': ('NOUN', 0.125, 0.0, 0.875),
#  'poe': ('NOUN', 0.125, 0.0, 0.875),
#  'dylan marlais thomas': ('NOUN', 0.125, 0.0, 0.875),
#  'evento fortuito': ('NOUN', 0.125, 0.0, 0.875),
#  'inconscientemente': ('ADV', 0.0, 0.375, 0.625),
#  'cariñosamente': ('ADV', 0.125, 0.0, 0.875),
#  'correctamente': ('ADV', 0.125, 0.0, 0.875),
#  'en lo más íntimo y profundo': ('ADV', 0.125, 0.0, 0.875),
#  'es decir': ('ADV', 0.125, 0.0, 0.875),
#  'metereológicamente': ('ADV', 0.125, 0.0, 0.875),
#  'liberación': ('NOUN', 0.0, 0.25, 0.75),
#  'atusar': ('VERB', 0.125, 0.0, 0.875),
#  'a efectos practicos': ('ADV', 0.125, 0.0, 0.875),
#  'de lejos': ('ADV', 0.125, 0.0, 0.875),
#  'por derecho': ('ADV', 0.125, 0.0, 0.875),
#  'adecuadamente': ('ADV', 0.125, 0.0, 0.875),
#  'mistificar': ('VERB', 0.125, 0.0, 0.875),
#  'eludir': ('VERB', 0.125, 0.0, 0.875),
#  'rehuir': ('VERB', 0.125, 0.0, 0.875),
#  'sobrevivir': ('VERB', 0.125, 0.0, 0.875),
#  'quedarse más tiempo': ('VERB', 0.125, 0.0, 0.875),
#  'apalache': ('ADJ', 0.125, 0.0, 0.875),
#  'tardar': ('VERB', 0.125, 0.0, 0.875),
#  'duplicar': ('VERB', 0.125, 0.0, 0.875),
#  'hacer un paralelo': ('VERB', 0.125, 0.0, 0.875),
#  'reflejar': ('VERB', 0.125, 0.0, 0.875),
#  'behaviorista': ('ADJ', 0.125, 0.0, 0.875),
#  'alargar': ('VERB', 0.125, 0.0, 0.875),
#  'aplicar': ('VERB', 0.25, 0.0, 0.75),
#  'colaborar': ('VERB', 0.0, 0.25, 0.75),
#  'agarrar a correazos': ('VERB', 0.125, 0.0, 0.875),
#  'dar de varillazos': ('VERB', 0.125, 0.0, 0.875),
#  'dar un golpe cortante': ('VERB', 0.125, 0.0, 0.875),
#  'dar un manotazo': ('VERB', 0.125, 0.0, 0.875),
#  'zanjar': ('VERB', 0.125, 0.0, 0.875),
#  'peinar': ('VERB', 0.25, 0.0, 0.75),
#  'familia crocodylidae': ('NOUN', 0.125, 0.0, 0.875),
#  'sobresaltar': ('VERB', 0.0, 0.125, 0.875),
#  'deleitar': ('VERB', 0.125, 0.0, 0.875),
#  'pavonearse': ('VERB', 0.0, 0.5, 0.5),
#  'empujar': ('VERB', 0.125, 0.0, 0.875),
#  'pasar con rapidez': ('VERB', 0.125, 0.0, 0.875),
#  'filo platyhelminthes': ('NOUN', 0.125, 0.0, 0.875),
#  'pogonophora': ('NOUN', 0.125, 0.0, 0.875),
#  'ser llevado por el viento': ('VERB', 0.125, 0.0, 0.875),
#  'bivalvia': ('NOUN', 0.125, 0.0, 0.875),
#  'ojear': ('VERB', 0.125, 0.0, 0.875),
#  'globo ocular': ('VERB', 0.125, 0.0, 0.875),
#  'género jaculus': ('NOUN', 0.125, 0.0, 0.875),
#  'jaculus': ('NOUN', 0.125, 0.0, 0.875),
#  'bathyergus': ('NOUN', 0.125, 0.0, 0.875),
#  'añojo': ('NOUN', 0.125, 0.0, 0.875),
#  'favorecer': ('VERB', 0.125, 0.0, 0.875),
#  'abandonarse a algo': ('VERB', 0.125, 0.0, 0.875),
#  'antibiótico': ('NOUN', 0.125, 0.0, 0.875),
#  'droga antibiótica': ('NOUN', 0.125, 0.0, 0.875),
#  'pender': ('VERB', 0.125, 0.0, 0.875),
#  'columpearse': ('VERB', 0.125, 0.0, 0.875),
#  'ir': ('VERB', 0.125, 0.0, 0.875),
#  'venir bien': ('VERB', 0.125, 0.0, 0.875),
#  'escamoso': ('ADJ', 0.125, 0.0, 0.875),
#  'técnico': ('ADJ', 0.125, 0.0, 0.875),
#  'etiológico': ('ADJ', 0.125, 0.0, 0.875),
#  'chesterfield': ('NOUN', 0.125, 0.0, 0.875),
#  'dramático': ('ADJ', 0.125, 0.0, 0.875),
#  'pinzo': ('NOUN', 0.125, 0.0, 0.875),
#  'domiciliación': ('NOUN', 0.125, 0.0, 0.875),
#  'instrumento de lengüeta libre': ('NOUN', 0.125, 0.0, 0.875),
#  'bomba de combustible': ('NOUN', 0.125, 0.0, 0.875),
#  'surtidor de combustible': ('NOUN', 0.125, 0.0, 0.875),
#  'gimnasio': ('NOUN', 0.125, 0.0, 0.875),
#  'hostal de estudiantes': ('NOUN', 0.125, 0.0, 0.875),
#  'arco apuntado': ('NOUN', 0.25, 0.0, 0.75),
#  'puñal': ('NOUN', 0.125, 0.0, 0.875),
#  'ring': ('NOUN', 0.125, 0.0, 0.875),
#  'piso': ('NOUN', 0.125, 0.0, 0.875),
#  'infravivienda': ('NOUN', 0.125, 0.0, 0.875),
#  'hytrin': ('NOUN', 0.125, 0.0, 0.875),
#  'veintidós': ('NOUN', 0.125, 0.0, 0.875),
#  'vancomicina': ('NOUN', 0.125, 0.0, 0.875),
#  'enredo': ('NOUN', 0.125, 0.0, 0.875),
#  'alambrada': ('NOUN', 0.125, 0.0, 0.875),
#  'alambrada metálica': ('NOUN', 0.125, 0.0, 0.875),
#  'permutabilidad': ('NOUN', 0.125, 0.0, 0.875),
#  'transposicionalidad': ('NOUN', 0.125, 0.0, 0.875),
#  'literalidad': ('NOUN', 0.125, 0.0, 0.875),
#  'sensibilidad': ('NOUN', 0.125, 0.0, 0.875),
#  'empatía': ('NOUN', 0.125, 0.0, 0.875),
#  'aplicación al estudio': ('NOUN', 0.125, 0.0, 0.875),
#  'servilismo': ('NOUN', 0.5, 0.0, 0.5),
#  'tipo': ('NOUN', 0.125, 0.0, 0.875),
#  'somatotipo': ('NOUN', 0.125, 0.0, 0.875),
#  'tipo atlético': ('NOUN', 0.125, 0.0, 0.875),
#  'mesomorfo': ('NOUN', 0.125, 0.0, 0.875),
#  'duración del servicio': ('NOUN', 0.125, 0.0, 0.875),
#  'longevidad': ('NOUN', 0.125, 0.0, 0.875),
#  'asertividad': ('NOUN', 0.125, 0.0, 0.875),
#  'eosinófilo': ('NOUN', 0.125, 0.0, 0.875),
#  'volición': ('NOUN', 0.125, 0.0, 0.875),
#  'voluntad': ('NOUN', 0.125, 0.0, 0.875),
#  'disección': ('NOUN', 0.125, 0.0, 0.875),
#  'contemplación': ('NOUN', 0.125, 0.0, 0.875),
#  'consideración': ('NOUN', 0.75, 0.0, 0.25),
#  'conceptualizacion': ('NOUN', 0.125, 0.0, 0.875),
#  'condición esencial': ('NOUN', 0.125, 0.0, 0.875),
#  'sine qua non': ('NOUN', 0.125, 0.0, 0.875),
#  'petición de principio': ('NOUN', 0.125, 0.0, 0.875),
#  'ideal': ('NOUN', 0.125, 0.0, 0.875),
#  'ídolo': ('NOUN', 0.75, 0.0, 0.25),
#  'parangón': ('NOUN', 0.125, 0.0, 0.875),
#  'perfección': ('NOUN', 0.125, 0.0, 0.875),
#  'guía': ('NOUN', 0.125, 0.0, 0.875),
#  'plantilla': ('NOUN', 0.125, 0.0, 0.875),
#  'modelo': ('NOUN', 0.5, 0.0, 0.5),
#  'ignorancia': ('NOUN', 0.125, 0.0, 0.875),
#  'oscurantismo': ('NOUN', 0.125, 0.0, 0.875),
#  'desconocimiento': ('NOUN', 0.125, 0.0, 0.875),
#  'inconsciencia': ('NOUN', 0.125, 0.0, 0.875),
#  'favor': ('NOUN', 0.5, 0.0, 0.5),
#  'reverendo': ('NOUN', 0.125, 0.0, 0.875),
#  'baronazgo': ('NOUN', 0.125, 0.0, 0.875),
#  'versión revisada americana': ('NOUN', 0.125, 0.0, 0.875),
#  'amnistía': ('NOUN', 0.125, 0.0, 0.875),
#  'absurdo': ('NOUN', 0.125, 0.0, 0.875),
#  'majadería': ('NOUN', 0.125, 0.0, 0.875),
#  'chorradas': ('NOUN', 0.25, 0.0, 0.75),
#  'jerigonza': ('NOUN', 0.0, 0.25, 0.75),
#  'baratija': ('NOUN', 0.125, 0.0, 0.875),
#  'diccionario electrónico': ('NOUN', 0.125, 0.0, 0.875),
#  'diccionario leíble por máquina': ('NOUN', 0.125, 0.0, 0.875),
#  'información confidencial': ('NOUN', 0.125, 0.0, 0.875),
#  'aviso': ('NOUN', 0.125, 0.0, 0.875),
#  'ventaja': ('NOUN', 0.125, 0.0, 0.875),
#  'información': ('NOUN', 0.125, 0.0, 0.875),
#  'doctor en educación': ('NOUN', 0.125, 0.0, 0.875),
#  'doctor en salud pública': ('NOUN', 0.125, 0.0, 0.875),
#  'respetos': ('NOUN', 0.125, 0.0, 0.875),
#  'trincheras': ('NOUN', 0.125, 0.0, 0.875),
#  'alojamiento': ('NOUN', 0.125, 0.0, 0.875),
#  'red': ('NOUN', 0.125, 0.0, 0.875),
#  'agerasia': ('NOUN', 0.125, 0.0, 0.875),
#  'esfenión': ('NOUN', 0.125, 0.0, 0.875),
#  'aptitud': ('NOUN', 0.125, 0.0, 0.875),
#  'falta de memoria': ('NOUN', 0.125, 0.0, 0.875),
#  'mente': ('VERB', 0.375, 0.0, 0.625),
#  'escena dramática': ('NOUN', 0.125, 0.0, 0.875),
#  'vista': ('NOUN', 0.0, 0.25, 0.75),
#  'vítor': ('NOUN', 0.125, 0.0, 0.875),
#  'conminación': ('NOUN', 0.125, 0.0, 0.875),
#  'declaración de principios': ('NOUN', 0.125, 0.0, 0.875),
#  'comentario burlón': ('NOUN', 0.125, 0.0, 0.875),
#  'pulla': ('NOUN', 0.25, 0.0, 0.75),
#  'salida': ('NOUN', 0.0, 0.125, 0.875),
#  'cuchufleta': ('NOUN', 0.125, 0.0, 0.875),
#  'chiste verde': ('NOUN', 0.125, 0.0, 0.875),
#  'interpretación': ('NOUN', 0.125, 0.0, 0.875),
#  'presentación publica': ('NOUN', 0.125, 0.0, 0.875),
#  'anglo': ('NOUN', 0.125, 0.0, 0.875),
#  'juto': ('NOUN', 0.125, 0.0, 0.875),
#  'kéntico': ('NOUN', 0.125, 0.0, 0.875),
#  'tilde': ('NOUN', 0.125, 0.0, 0.875),
#  'énfasis': ('NOUN', 0.125, 0.0, 0.875),
#  'acento': ('NOUN', 0.125, 0.0, 0.875),
#  'rima visual': ('NOUN', 0.125, 0.0, 0.875),
#  'risa sardónica': ('NOUN', 0.125, 0.0, 0.875),
#  'risa disimulada': ('NOUN', 0.125, 0.0, 0.875),
#  'trivialidad': ('NOUN', 0.125, 0.0, 0.875),
#  'lugar común': ('NOUN', 0.125, 0.0, 0.875),
#  'perogrullada': ('NOUN', 0.125, 0.0, 0.875),
#  'desambiguación léxica': ('NOUN', 0.125, 0.0, 0.875),
#  'fanfarronería': ('NOUN', 0.125, 0.0, 0.875),
#  'pavoneo': ('NOUN', 0.125, 0.0, 0.875),
#  'delirio': ('NOUN', 0.125, 0.0, 0.875),
#  'propaganda': ('NOUN', 0.125, 0.0, 0.875),
#  'voto de confianza': ('NOUN', 0.125, 0.0, 0.875),
#  'peripecia': ('NOUN', 0.125, 0.0, 0.875),
#  'procesión': ('NOUN', 0.125, 0.0, 0.875),
#  'origen': ('NOUN', 0.125, 0.0, 0.875),
#  'cambio': ('NOUN', 0.0, 0.125, 0.875),
#  'transformación': ('NOUN', 0.5, 0.0, 0.5),
#  'transmutación': ('NOUN', 0.125, 0.0, 0.875),
#  'aleación': ('NOUN', 0.125, 0.0, 0.875),
#  'carrera': ('NOUN', 0.125, 0.0, 0.875),
#  'victoria inminenta': ('NOUN', 0.125, 0.0, 0.875),
#  'victoria sin mover un dedo': ('NOUN', 0.125, 0.0, 0.875),
#  'mazapán': ('NOUN', 0.125, 0.0, 0.875),
#  'ensalada de col': ('NOUN', 0.125, 0.0, 0.875),
#  'huevo de caramelo': ('NOUN', 0.125, 0.0, 0.875),
#  'saltamontes': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de antropología': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de biología': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de química': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de ciencias económicas': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de filología inglesa': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de historia': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de lingüística': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de matemáticas': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de física': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de música': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de psicología': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de sociología': ('NOUN', 0.125, 0.0, 0.875),
#  'seguridad': ('NOUN', 0.125, 0.0, 0.875),
#  'departamento de seguridad': ('NOUN', 0.125, 0.0, 0.875),
#  'raf (royal air force)': ('NOUN', 0.125, 0.0, 0.875),
#  'royal air force (raf)': ('NOUN', 0.125, 0.0, 0.875),
#  'contingente': ('NOUN', 0.125, 0.0, 0.875),
#  'destacamento': ('NOUN', 0.125, 0.0, 0.875),
#  'posse comitatus': ('NOUN', 0.125, 0.0, 0.875),
#  'archidiócesis': ('NOUN', 0.125, 0.0, 0.875),
#  'necromanía': ('NOUN', 0.125, 0.0, 0.875),
#  'necrofilia': ('NOUN', 0.125, 0.0, 0.875),
#  'supresor': ('NOUN', 0.125, 0.0, 0.875),
#  'lecho de minerales': ('NOUN', 0.125, 0.0, 0.875),
#  'rafael': ('NOUN', 0.125, 0.0, 0.875),
#  'urania': ('NOUN', 0.125, 0.0, 0.875),
#  'freya': ('NOUN', 0.125, 0.0, 0.875),
#  'freyja': ('NOUN', 0.125, 0.0, 0.875),
#  'aspirante': ('NOUN', 0.125, 0.0, 0.875),
#  'candidato': ('NOUN', 0.125, 0.0, 0.875),
#  'imitador barato': ('NOUN', 0.125, 0.0, 0.875),
#  'cestero': ('NOUN', 0.125, 0.0, 0.875),
#  'instructor de bateo': ('NOUN', 0.125, 0.0, 0.875),
#  'esteticista': ('NOUN', 0.5, 0.0, 0.5),
#  'cosmetólogo': ('NOUN', 0.125, 0.0, 0.875),
#  'galán': ('NOUN', 0.125, 0.0, 0.875),
#  'caballero': ('NOUN', 0.125, 0.0, 0.875),
#  'niño cantor': ('NOUN', 0.125, 0.0, 0.875),
#  'demagogo': ('NOUN', 0.125, 0.0, 0.875),
#  'agitador': ('NOUN', 0.125, 0.0, 0.875),
#  'sargento escribiente': ('NOUN', 0.125, 0.0, 0.875),
#  'crítico de teatro': ('NOUN', 0.125, 0.0, 0.875),
#  'majorette': ('NOUN', 0.125, 0.0, 0.875),
#  'borracho': ('NOUN', 0.125, 0.0, 0.875),
#  'ebrio': ('NOUN', 0.125, 0.0, 0.875),
#  'etiólogo': ('NOUN', 0.125, 0.0, 0.875),
#  'niña': ('NOUN', 0.125, 0.0, 0.875),
#  'pequeña': ('NOUN', 0.125, 0.0, 0.875),
#  'esgrimista': ('NOUN', 0.125, 0.0, 0.875),
#  'espadachín': ('NOUN', 0.125, 0.0, 0.875),
#  'tontorrona': ('NOUN', 0.125, 0.0, 0.875),
#  'sobrino nieto': ('NOUN', 0.125, 0.0, 0.875),
#  'transportista': ('NOUN', 0.125, 0.0, 0.875),
#  'equivoquista': ('NOUN', 0.125, 0.0, 0.875),
#  'evasor': ('NOUN', 0.125, 0.0, 0.875),
#  'tergiversador': ('NOUN', 0.125, 0.0, 0.875),
#  'insomne': ('NOUN', 0.125, 0.0, 0.875),
#  'persona sin sueño': ('NOUN', 0.125, 0.0, 0.875),
#  'infiltrado': ('NOUN', 0.0, 0.375, 0.625),
#  'adonis': ('NOUN', 0.25, 0.0, 0.75),
#  'pistolero': ('NOUN', 0.125, 0.0, 0.875),
#  'tirador': ('NOUN', 0.125, 0.0, 0.875),
#  'francotirador': ('NOUN', 0.125, 0.0, 0.875),
#  'monofisita': ('NOUN', 0.125, 0.0, 0.875),
#  'charlatan de feria': ('NOUN', 0.125, 0.0, 0.875),
#  'saltabancos': ('NOUN', 0.125, 0.0, 0.875),
#  'ofertante': ('NOUN', 0.125, 0.0, 0.875),
#  'oferente': ('NOUN', 0.125, 0.0, 0.875),
#  'antigualla': ('NOUN', 0.125, 0.0, 0.875),
#  'carcamal': ('NOUN', 0.125, 0.0, 0.875),
#  'viejo': ('NOUN', 0.125, 0.0, 0.875),
#  'anciano': ('NOUN', 0.125, 0.0, 0.875),
#  'veterano': ('NOUN', 0.125, 0.0, 0.875),
#  'pensionista': ('NOUN', 0.125, 0.0, 0.875),
#  'el que hace mimos': ('NOUN', 0.125, 0.0, 0.875),
#  'bobalicón': ('NOUN', 0.0, 0.25, 0.75),
#  'profesor de equitación': ('NOUN', 0.125, 0.0, 0.875),
#  'gorrón': ('NOUN', 0.125, 0.0, 0.875),
#  'residente temporal': ('NOUN', 0.125, 0.0, 0.875),
#  'papel de confidente o de coqueta': ('NOUN', 0.125, 0.0, 0.875),
#  'prestamista': ('NOUN', 0.125, 0.0, 0.875),
#  'usurero': ('NOUN', 0.125, 0.0, 0.875),
#  'arnoseris ': ('NOUN', 0.125, 0.0, 0.875),
#  'typha': ('NOUN', 0.125, 0.0, 0.875),
#  'liposarcoma': ('NOUN', 0.125, 0.0, 0.875),
#  'medio': ('NOUN', 0.125, 0.0, 0.875),
#  'alrededores': ('NOUN', 0.125, 0.0, 0.875),
#  'butilo': ('NOUN', 0.125, 0.0, 0.875),
#  'reconocido': ('ADJ', 0.125, 0.0, 0.875),
#  'perceptivamente': ('ADV', 0.125, 0.0, 0.875),
#  'cabriola': ('NOUN', 0.125, 0.0, 0.875),
#  'samba': ('NOUN', 0.125, 0.0, 0.875),
#  'levantar': ('VERB', 0.0, 0.125, 0.875),
#  'estampar': ('VERB', 0.125, 0.0, 0.875),
#  'ofrecer': ('VERB', 0.125, 0.0, 0.875),
#  'charlatanismo': ('NOUN', 0.125, 0.0, 0.875),
#  'charlatanería': ('NOUN', 0.125, 0.0, 0.875),
#  'asir': ('VERB', 0.375, 0.0, 0.625),
#  'armonizar': ('VERB', 0.125, 0.0, 0.875),
#  'transportar': ('VERB', 0.125, 0.0, 0.875),
#  'encantar': ('VERB', 0.125, 0.0, 0.875),
#  'embelezar': ('VERB', 0.125, 0.0, 0.875),
#  'caer': ('VERB', 0.0, 0.375, 0.625),
#  'relativo a la limnología': ('ADV', 0.125, 0.0, 0.875),
#  'renovación urbana': ('NOUN', 0.125, 0.0, 0.875),
#  'abrazo': ('NOUN', 0.125, 0.0, 0.875),
#  'apretón': ('NOUN', 0.125, 0.0, 0.875),
#  'remitir': ('VERB', 0.125, 0.0, 0.875),
#  'aflojar': ('VERB', 0.125, 0.0, 0.875),
#  'manifiesta': ('VERB', 0.125, 0.0, 0.875),
#  'bajar': ('VERB', 0.0, 0.5, 0.5),
#  'cortar': ('VERB', 0.0, 0.125, 0.875),
#  'recortar': ('VERB', 0.0, 0.125, 0.875),
#  'reducir': ('VERB', 0.0, 0.125, 0.875),
#  'rebajar': ('VERB', 0.125, 0.0, 0.875),
#  'combate cuerpo a cuerpo': ('NOUN', 0.125, 0.0, 0.875),
#  'distante': ('ADJ', 0.125, 0.0, 0.875),
#  'remota': ('ADJ', 0.125, 0.0, 0.875),
#  'sociológicamente': ('ADV', 0.125, 0.0, 0.875),
#  'pulimentar': ('VERB', 0.125, 0.0, 0.875),
#  'pulir': ('VERB', 0.125, 0.0, 0.875),
#  'refinar': ('VERB', 0.125, 0.0, 0.875),
#  'descontaminar': ('VERB', 0.125, 0.0, 0.875),
#  'brinco': ('NOUN', 0.125, 0.0, 0.875),
#  'cognitivamente': ('ADV', 0.125, 0.0, 0.875),
#  'taxonómicamente': ('ADV', 0.125, 0.0, 0.875),
#  'animar': ('VERB', 0.375, 0.0, 0.625),
#  'bajar la fiebre': ('VERB', 0.125, 0.0, 0.875),
#  'paternidad': ('NOUN', 0.125, 0.0, 0.875),
#  'mariscalía': ('NOUN', 0.125, 0.0, 0.875),
#  'investigación': ('NOUN', 0.125, 0.0, 0.875),
#  'razonar por silogismos': ('VERB', 0.125, 0.0, 0.875),
#  'eliminar': ('VERB', 0.0, 0.625, 0.375),
#  'rechazar': ('VERB', 0.0, 0.75, 0.25),
#  'descartar': ('VERB', 0.125, 0.0, 0.875),
#  'evitar': ('VERB', 0.0, 0.75, 0.25),
#  'pedir': ('VERB', 0.125, 0.0, 0.875),
#  'magnetizar': ('VERB', 0.125, 0.0, 0.875),
#  'fascinar': ('VERB', 0.375, 0.0, 0.625),
#  'hipnotizar': ('VERB', 0.125, 0.0, 0.875),
#  'embrujar': ('VERB', 0.125, 0.0, 0.875),
#  'abordar': ('VERB', 0.125, 0.0, 0.875),
#  'enganchar': ('VERB', 0.0, 0.125, 0.875),
#  'ofrecer sexo': ('VERB', 0.125, 0.0, 0.875),
#  'aventura': ('NOUN', 0.25, 0.0, 0.75),
#  'desdecirse': ('VERB', 0.125, 0.0, 0.875),
#  'renegar': ('VERB', 0.0, 0.5, 0.5),
#  'abogar': ('VERB', 0.125, 0.0, 0.875),
#  'apoyar': ('VERB', 0.125, 0.0, 0.875),
#  'informar': ('VERB', 0.125, 0.0, 0.875),
#  'timar': ('VERB', 0.0, 0.125, 0.875),
#  'encandilar': ('VERB', 0.125, 0.0, 0.875),
#  'confundir': ('VERB', 0.0, 0.375, 0.625),
#  'onanismo': ('NOUN', 0.125, 0.0, 0.875),
#  'avanzar': ('VERB', 0.125, 0.0, 0.875),
#  'proponer': ('VERB', 0.375, 0.0, 0.625),
#  'presentar': ('VERB', 0.125, 0.0, 0.875),
#  'recordar': ('VERB', 0.125, 0.0, 0.875),
#  'complacer': ('VERB', 0.125, 0.0, 0.875),
#  'enseñanza de la lectura': ('NOUN', 0.125, 0.0, 0.875),
#  'dramatización': ('NOUN', 0.125, 0.0, 0.875),
#  'aclamar': ('VERB', 0.375, 0.0, 0.625),
#  'anunciar': ('VERB', 0.125, 0.0, 0.875),
#  'dar a entender': ('VERB', 0.125, 0.0, 0.875),
#  'abigeato': ('NOUN', 0.125, 0.0, 0.875),
#  'documentar': ('VERB', 0.125, 0.0, 0.875),
#  'prueba de inteligencia': ('NOUN', 0.125, 0.0, 0.875),
#  'prueba de ci': ('NOUN', 0.125, 0.0, 0.875),
#  'randomización': ('NOUN', 0.125, 0.0, 0.875),
#  'pronunciar con sibilante': ('VERB', 0.125, 0.0, 0.875),
#  'desencantar': ('VERB', 0.125, 0.0, 0.875),
#  'demoler': ('VERB', 0.125, 0.0, 0.875),
#  'defenderse': ('VERB', 0.125, 0.0, 0.875),
#  'luchar': ('VERB', 0.0, 0.25, 0.75),
#  'enfrentarse': ('VERB', 0.0, 0.125, 0.875),
#  'derrotar': ('VERB', 0.125, 0.0, 0.875),
#  'oponerse': ('VERB', 0.125, 0.0, 0.875),
#  'vencer': ('VERB', 0.125, 0.0, 0.875),
#  'aplastar': ('VERB', 0.0, 0.125, 0.875),
#  'bombardear': ('VERB', 0.125, 0.0, 0.875),
#  'dar una paliza': ('VERB', 0.0, 0.75, 0.25),
#  'derrotar con trampas': ('VERB', 0.125, 0.0, 0.875),
#  'desobediencia': ('NOUN', 0.125, 0.0, 0.875),
#  'reflotar': ('VERB', 0.125, 0.0, 0.875),
#  'buena acción': ('NOUN', 0.125, 0.0, 0.875),
#  'empapar': ('VERB', 0.375, 0.0, 0.625),
#  'abrillantar': ('VERB', 0.125, 0.0, 0.875),
#  'bruñir': ('VERB', 0.125, 0.0, 0.875),
#  'adherirse': ('VERB', 0.125, 0.0, 0.875),
#  'asociarse': ('VERB', 0.125, 0.0, 0.875),
#  'pegarse': ('VERB', 0.125, 0.0, 0.875),
#  'incorporarse': ('VERB', 0.125, 0.0, 0.875),
#  'familia nitrobacteriaceae': ('NOUN', 0.125, 0.0, 0.875),
#  'excepcionalmente': ('ADV', 0.125, 0.0, 0.875),
#  'buck and wing': ('NOUN', 0.125, 0.0, 0.875),
#  'geotropismo': ('NOUN', 0.125, 0.0, 0.875),
#  'misa mayor': ('NOUN', 0.125, 0.0, 0.875),
#  'derrotar completamente': ('VERB', 0.125, 0.0, 0.875),
#  'aventajar': ('VERB', 0.125, 0.0, 0.875),
#  'avituallar': ('VERB', 0.125, 0.0, 0.875),
#  'aferrar': ('VERB', 0.125, 0.0, 0.875),
#  'envolver para regalo': ('VERB', 0.125, 0.0, 0.875),
#  'chlamydia trachomatis': ('NOUN', 0.125, 0.0, 0.875),
#  'clase euglenophyceae': ('NOUN', 0.125, 0.0, 0.875),
#  'euglenophyceae': ('NOUN', 0.125, 0.0, 0.875),
#  'abofetear': ('VERB', 0.125, 0.0, 0.875),
#  'acnidosporidia': ('NOUN', 0.125, 0.0, 0.875),
#  'género acnidosporidia': ('NOUN', 0.125, 0.0, 0.875),
#  'chasquear': ('VERB', 0.0, 0.625, 0.375),
#  'arrebatar': ('VERB', 0.125, 0.0, 0.875),
#  'agarrar por la fuerza': ('VERB', 0.125, 0.0, 0.875),
#  'sardina hocido de puerco': ('NOUN', 0.125, 0.0, 0.875),
#  'hypentelium nigricans': ('NOUN', 0.125, 0.0, 0.875),
#  'orden zeomorphi': ('NOUN', 0.125, 0.0, 0.875),
#  'zeomorphi': ('NOUN', 0.125, 0.0, 0.875),
#  'lubricar': ('VERB', 0.125, 0.0, 0.875),
#  'enterrar': ('VERB', 0.125, 0.0, 0.875),
#  'hundir': ('VERB', 0.125, 0.0, 0.875),
#  'limpiar': ('VERB', 0.125, 0.0, 0.875),
#  'limpiar la corrupción': ('VERB', 0.125, 0.0, 0.875),
#  'empuñar': ('VERB', 0.125, 0.0, 0.875),
#  'sacar': ('VERB', 0.0, 0.125, 0.875),
#  'jalar': ('VERB', 0.125, 0.0, 0.875),
#  'pelliscar': ('VERB', 0.125, 0.0, 0.875),
#  'invitar': ('VERB', 0.125, 0.0, 0.875),
#  'conjurar': ('VERB', 0.125, 0.0, 0.875),
#  'evocar': ('VERB', 0.125, 0.0, 0.875),
#  'exponer': ('VERB', 0.125, 0.0, 0.875),
#  'invocar': ('VERB', 0.125, 0.0, 0.875),
#  'crocodylidae': ('NOUN', 0.125, 0.0, 0.875),
#  'captar': ('VERB', 0.125, 0.0, 0.875),
#  'lograr': ('VERB', 0.125, 0.0, 0.875),
#  'bothrops': ('NOUN', 0.125, 0.0, 0.875),
#  'género bothrops': ('NOUN', 0.125, 0.0, 0.875),
#  'orden scorpionida': ('NOUN', 0.125, 0.0, 0.875),
#  'scorpionida': ('NOUN', 0.125, 0.0, 0.875),
#  'congraciarse': ('VERB', 0.125, 0.0, 0.875),
#  'avivar': ('VERB', 0.125, 0.0, 0.875),
#  'exaltar': ('VERB', 0.75, 0.0, 0.25),
#  'inspirar': ('VERB', 0.375, 0.0, 0.625),
#  'revigorizar': ('VERB', 0.125, 0.0, 0.875),
#  'temblar': ('VERB', 0.0, 0.125, 0.875),
#  'erinaceidae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia erinaceidae': ('NOUN', 0.125, 0.0, 0.875),
#  'cestoda': ('NOUN', 0.125, 0.0, 0.875),
#  'clase cestoda': ('NOUN', 0.125, 0.0, 0.875),
#  'filo pogonophora': ('NOUN', 0.125, 0.0, 0.875),
#  'clase lamellibranchia': ('NOUN', 0.125, 0.0, 0.875),
#  'myaceae': ('NOUN', 0.125, 0.0, 0.875),
#  'orden myaceae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia anomiidae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia pectinidae': ('NOUN', 0.125, 0.0, 0.875),
#  'pectinidae': ('NOUN', 0.125, 0.0, 0.875),
#  'octopoda': ('NOUN', 0.125, 0.0, 0.875),
#  'orden octopoda': ('NOUN', 0.125, 0.0, 0.875),
#  'familia sepiidae': ('NOUN', 0.125, 0.0, 0.875),
#  'entrar': ('VERB', 0.125, 0.0, 0.875),
#  'ingresar': ('VERB', 0.125, 0.0, 0.875),
#  'hacer su llegada': ('VERB', 0.125, 0.0, 0.875),
#  'arribar': ('VERB', 0.125, 0.0, 0.875),
#  'género pedionomus': ('NOUN', 0.125, 0.0, 0.875),
#  'pedionomus': ('NOUN', 0.125, 0.0, 0.875),
#  'género phalaropus': ('NOUN', 0.125, 0.0, 0.875),
#  'phalaropus': ('NOUN', 0.125, 0.0, 0.875),
#  'en condiciones de vuelo': ('ADJ', 0.125, 0.0, 0.875),
#  'embrutecerse': ('VERB', 0.125, 0.0, 0.875),
#  'idiotizarse': ('VERB', 0.125, 0.0, 0.875),
#  'tocar': ('VERB', 0.0, 0.125, 0.875),
#  'hacer justicia': ('VERB', 0.125, 0.0, 0.875),
#  'rrhinolophidae': ('NOUN', 0.125, 0.0, 0.875),
#  'titilar': ('VERB', 0.0, 0.25, 0.75),
#  'chrysomelidae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia chrysomelidae': ('NOUN', 0.125, 0.0, 0.875),
#  'adquirir': ('VERB', 0.125, 0.0, 0.875),
#  'obtener': ('VERB', 0.125, 0.0, 0.875),
#  'género megachile': ('NOUN', 0.125, 0.0, 0.875),
#  'megachile': ('NOUN', 0.125, 0.0, 0.875),
#  'fenusa': ('NOUN', 0.125, 0.0, 0.875),
#  'género  fenusa': ('NOUN', 0.125, 0.0, 0.875),
#  'familia phillidae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia phyllidae': ('NOUN', 0.125, 0.0, 0.875),
#  'phillidae': ('NOUN', 0.125, 0.0, 0.875),
#  'phyllidae': ('NOUN', 0.125, 0.0, 0.875),
#  'género leptoglossus': ('NOUN', 0.125, 0.0, 0.875),
#  'leptoglossus': ('NOUN', 0.125, 0.0, 0.875),
#  'liquidar': ('VERB', 0.125, 0.0, 0.875),
#  'arrojar': ('VERB', 0.0, 0.25, 0.75),
#  'desperdiciar': ('VERB', 0.125, 0.0, 0.875),
#  'malgastar': ('VERB', 0.125, 0.0, 0.875),
#  'género vanessa': ('NOUN', 0.125, 0.0, 0.875),
#  'familia tortricidae': ('NOUN', 0.125, 0.0, 0.875),
#  'tortricidae': ('NOUN', 0.125, 0.0, 0.875),
#  'superfamilia tineoidea': ('NOUN', 0.125, 0.0, 0.875),
#  'tineoidea': ('NOUN', 0.125, 0.0, 0.875),
#  'género hydromys': ('NOUN', 0.125, 0.0, 0.875),
#  'hydromys': ('NOUN', 0.125, 0.0, 0.875),
#  'florecer': ('VERB', 0.125, 0.0, 0.875),
#  'fly high': ('VERB', 0.125, 0.0, 0.875),
#  'prosperar': ('VERB', 0.125, 0.0, 0.875),
#  'proliferar': ('VERB', 0.125, 0.0, 0.875),
#  'dipodomys': ('NOUN', 0.125, 0.0, 0.875),
#  'género dipodomys': ('NOUN', 0.125, 0.0, 0.875),
#  'sanitizar': ('VERB', 0.125, 0.0, 0.875),
#  'cordero persa': ('NOUN', 0.125, 0.0, 0.875),
#  'anthropoidea': ('NOUN', 0.125, 0.0, 0.875),
#  'poner el pan sobre la mesa': ('VERB', 0.125, 0.0, 0.875),
#  'salir adelante': ('VERB', 0.125, 0.0, 0.875),
#  'cortejar': ('VERB', 0.125, 0.0, 0.875),
#  'teñir': ('VERB', 0.375, 0.0, 0.625),
#  'incentivar': ('VERB', 0.25, 0.0, 0.75),
#  'completar': ('VERB', 0.375, 0.0, 0.625),
#  'despachar': ('VERB', 0.0, 0.625, 0.375),
#  'engañar': ('VERB', 0.0, 0.625, 0.375),
#  'entrante': ('ADJ', 0.125, 0.0, 0.875),
#  'tallista': ('NOUN', 0.125, 0.0, 0.875),
#  'tallista en madera': ('NOUN', 0.125, 0.0, 0.875),
#  'aleksandr aleksandrovich blok': ('NOUN', 0.125, 0.0, 0.875),
#  'blok': ('NOUN', 0.125, 0.0, 0.875),
#  'john anthony ciardi': ('NOUN', 0.125, 0.0, 0.875),
#  'john ciardi': ('NOUN', 0.125, 0.0, 0.875),
#  'donatello': ('NOUN', 0.125, 0.0, 0.875),
#  'donato di betto bardi': ('NOUN', 0.125, 0.0, 0.875),
#  'jorge': ('NOUN', 0.125, 0.0, 0.875),
#  'jorge ii': ('NOUN', 0.125, 0.0, 0.875),
#  'john keats': ('NOUN', 0.125, 0.0, 0.875),
#  'keats': ('NOUN', 0.125, 0.0, 0.875),
#  'franz liszt': ('NOUN', 0.125, 0.0, 0.875),
#  'liszt': ('NOUN', 0.125, 0.0, 0.875),
#  'neftalí ricardo reyes': ('NOUN', 0.125, 0.0, 0.875),
#  'pablo neruda': ('NOUN', 0.125, 0.0, 0.875),
#  'plath': ('NOUN', 0.125, 0.0, 0.875),
#  'edgar allan poe': ('NOUN', 0.125, 0.0, 0.875),
#  'aleksandr sergeyevich pushkin': ('NOUN', 0.125, 0.0, 0.875),
#  'alexander pushkin': ('NOUN', 0.125, 0.0, 0.875),
#  'pushkin': ('NOUN', 0.125, 0.0, 0.875),
#  'percy bysshe shelley': ('NOUN', 0.125, 0.0, 0.875),
#  'shelley': ('NOUN', 0.125, 0.0, 0.875),
#  'adam smith': ('NOUN', 0.125, 0.0, 0.875),
#  'smith': ('NOUN', 0.125, 0.0, 0.875),
#  'john orley allen tate': ('NOUN', 0.125, 0.0, 0.875),
#  'deems taylor': ('NOUN', 0.125, 0.0, 0.875),
#  'taylor': ('NOUN', 0.125, 0.0, 0.875),
#  'aldred tennyson': ('NOUN', 0.125, 0.0, 0.875),
#  'dylan thomas': ('NOUN', 0.125, 0.0, 0.875),
#  'thomas': ('NOUN', 0.125, 0.0, 0.875),
#  'buena fortuna': ('NOUN', 0.125, 0.0, 0.875),
#  'buena suerte': ('NOUN', 0.125, 0.0, 0.875),
#  'pino contorta sierra': ('NOUN', 0.125, 0.0, 0.875),
#  'canelero de china': ('NOUN', 0.125, 0.0, 0.875),
#  'cinnamomum cassia': ('NOUN', 0.125, 0.0, 0.875),
#  'corteza de cassia': ('NOUN', 0.125, 0.0, 0.875),
#  'canela china': ('NOUN', 0.125, 0.0, 0.875),
#  'banalidad': ('NOUN', 0.125, 0.0, 0.875),
#  'cliché': ('NOUN', 0.125, 0.0, 0.875),
#  'golpe teatral': ('NOUN', 0.125, 0.0, 0.875),
#  'vianda': ('NOUN', 0.125, 0.0, 0.875),
#  'zampada': ('NOUN', 0.125, 0.0, 0.875),
#  'clase culta': ('NOUN', 0.125, 0.0, 0.875),
#  'sodoma': ('NOUN', 0.125, 0.0, 0.875),
#  'copérnico': ('NOUN', 0.125, 0.0, 0.875),
#  'bardo': ('NOUN', 0.125, 0.0, 0.875),
#  'corista': ('NOUN', 0.125, 0.0, 0.875),
#  'ceceador': ('NOUN', 0.125, 0.0, 0.875),
#  'ciardi': ('NOUN', 0.125, 0.0, 0.875),
#  'tate': ('NOUN', 0.125, 0.0, 0.875),
#  'género arnoseris': ('NOUN', 0.125, 0.0, 0.875),
#  'género typha': ('NOUN', 0.125, 0.0, 0.875),
#  'familia hydrocharidáceas': ('NOUN', 0.125, 0.0, 0.875),
#  'familia hydrocharitáceas': ('NOUN', 0.125, 0.0, 0.875),
#  'familia mordisco de rana': ('NOUN', 0.125, 0.0, 0.875),
#  'hydrocharidáceas': ('NOUN', 0.125, 0.0, 0.875),
#  'hydrocharitáceas': ('NOUN', 0.125, 0.0, 0.875),
#  'género kolkwitzia': ('NOUN', 0.125, 0.0, 0.875),
#  'kolkwitzia': ('NOUN', 0.125, 0.0, 0.875),
#  'dimocarpus': ('NOUN', 0.125, 0.0, 0.875),
#  'género dimocarpus': ('NOUN', 0.125, 0.0, 0.875),
#  'cirro': ('NOUN', 0.125, 0.0, 0.875),
#  'fronda': ('NOUN', 0.125, 0.0, 0.875),
#  'compra': ('NOUN', 0.125, 0.0, 0.875),
#  'alquiler exorbitante': ('NOUN', 0.125, 0.0, 0.875),
#  'pérdida': ('NOUN', 0.0, 0.75, 0.25),
#  'ocho peniques': ('NOUN', 0.125, 0.0, 0.875),
#  'níquel': ('NOUN', 0.125, 0.0, 0.875),
#  'taza': ('NOUN', 0.125, 0.0, 0.875),
#  'fuerza convincente': ('NOUN', 0.125, 0.0, 0.875),
#  'ets': ('NOUN', 0.125, 0.0, 0.875),
#  'faringitis estreptocócica': ('NOUN', 0.125, 0.0, 0.875),
#  'alucinación visual': ('NOUN', 0.125, 0.0, 0.875),
#  'predisposición': ('NOUN', 0.0, 0.875, 0.125),
#  'florecimiento': ('NOUN', 0.125, 0.0, 0.875),
#  'la flor de la juventud': ('NOUN', 0.125, 0.0, 0.875),
#  'tiempos mozos': ('NOUN', 0.125, 0.0, 0.875),
#  'hoy': ('NOUN', 0.125, 0.0, 0.875),
#  'respiro': ('NOUN', 0.0, 0.75, 0.25),
#  'período de descanso': ('NOUN', 0.125, 0.0, 0.875),
#  'sustancialmente': ('ADV', 0.125, 0.0, 0.875),
#  'aullar de risa': ('VERB', 0.125, 0.0, 0.875),
#  'reir a carcajadas': ('VERB', 0.125, 0.0, 0.875),
#  'peinar con estilo': ('VERB', 0.125, 0.0, 0.875),
#  'aderezar': ('VERB', 0.125, 0.0, 0.875),
#  'marcar': ('VERB', 0.125, 0.0, 0.875),
#  'mano a mano': ('ADV', 0.125, 0.0, 0.875),
#  'esencial?': ('ADJ', 0.125, 0.0, 0.875),
#  'sustantivo?': ('ADJ', 0.125, 0.0, 0.875),
#  'en cualquier caso': ('ADV', 0.125, 0.0, 0.875),
#  'mucho': ('ADV', 0.25, 0.0, 0.75),
#  'reavivar': ('VERB', 0.125, 0.0, 0.875),
#  'curar': ('VERB', 0.125, 0.0, 0.875),
#  'sanar': ('VERB', 0.125, 0.0, 0.875),
#  'continuamente': ('ADV', 0.125, 0.0, 0.875),
#  'hacia mí': ('ADV', 0.125, 0.0, 0.875),
#  'históricamente': ('ADV', 0.125, 0.0, 0.875),
#  'volumétricamente': ('ADV', 0.125, 0.0, 0.875),
#  'patológicamente': ('ADV', 0.125, 0.0, 0.875),
#  'en total': ('ADV', 0.125, 0.0, 0.875),
#  'gol': ('NOUN', 0.125, 0.0, 0.875),
#  'vigorizar': ('VERB', 0.125, 0.0, 0.875),
#  'fluctuación': ('NOUN', 0.125, 0.0, 0.875),
#  'convulsivamente': ('ADV', 0.125, 0.0, 0.875),
#  'domar': ('VERB', 0.375, 0.0, 0.625),
#  'justamente': ('ADV', 0.375, 0.0, 0.625),
#  'destitución': ('NOUN', 0.125, 0.0, 0.875),
#  'debilitar': ('VERB', 0.375, 0.0, 0.625),
#  'purificación': ('NOUN', 0.125, 0.0, 0.875),
#  'destrozar': ('VERB', 0.0, 0.25, 0.75),
#  'mantenimiento programado': ('NOUN', 0.125, 0.0, 0.875),
#  'sensibilizar': ('VERB', 0.125, 0.0, 0.875),
#  'concienciar': ('VERB', 0.125, 0.0, 0.875),
#  'climáticamente': ('ADV', 0.125, 0.0, 0.875),
#  'ajustar': ('VERB', 0.125, 0.0, 0.875),
#  'descriptivamente': ('ADV', 0.125, 0.0, 0.875),
#  'devotamente': ('ADV', 0.125, 0.0, 0.875),
#  'geológicamente': ('ADV', 0.125, 0.0, 0.875),
#  'cómicamente': ('ADV', 0.125, 0.0, 0.875),
#  'risiblemente': ('ADV', 0.125, 0.0, 0.875),
#  'rehabilitación correccional': ('NOUN', 0.125, 0.0, 0.875),
#  'nutricionalmente': ('ADV', 0.125, 0.0, 0.875),
#  'abrazo apasionado': ('NOUN', 0.125, 0.0, 0.875),
#  'farmacológicamente': ('ADV', 0.125, 0.0, 0.875),
#  'aparecer': ('VERB', 0.125, 0.0, 0.875),
#  'acrobacias': ('NOUN', 0.125, 0.0, 0.875),
#  'volteretas': ('NOUN', 0.125, 0.0, 0.875),
#  'deporte ecuestre': ('NOUN', 0.125, 0.0, 0.875),
#  'realinear': ('VERB', 0.125, 0.0, 0.875),
#  'enderezar': ('VERB', 0.125, 0.0, 0.875),
#  'afinar': ('VERB', 0.125, 0.0, 0.875),
#  'prejuiciar': ('VERB', 0.0, 0.375, 0.625),
#  'topográficamente': ('ADV', 0.125, 0.0, 0.875),
#  'cargar': ('VERB', 0.0, 0.875, 0.125),
#  'asibilar': ('VERB', 0.125, 0.0, 0.875),
#  'malabarismo': ('NOUN', 0.125, 0.0, 0.875),
#  'ejercitar': ('VERB', 0.125, 0.0, 0.875),
#  'leer': ('VERB', 0.125, 0.0, 0.875),
#  'racionalizar': ('VERB', 0.125, 0.0, 0.875),
#  'nocturno': ('ADJ', 0.125, 0.0, 0.875),
#  'creer': ('VERB', 0.125, 0.0, 0.875),
#  'concretar': ('VERB', 0.125, 0.0, 0.875),
#  'despertarse': ('VERB', 0.125, 0.0, 0.875),
#  'abandono': ('NOUN', 0.125, 0.0, 0.875),
#  'bloqueado': ('ADJ', 0.125, 0.0, 0.875),
#  'profesar': ('VERB', 0.125, 0.0, 0.875),
#  'instruir': ('VERB', 0.125, 0.0, 0.875),
#  'acusar': ('VERB', 0.125, 0.0, 0.875),
#  'culpar': ('VERB', 0.0, 0.375, 0.625),
#  'mofarse': ('VERB', 0.0, 0.375, 0.625),
#  'embaucar': ('VERB', 0.0, 0.875, 0.125),
#  'dar gato por liebre': ('VERB', 0.0, 0.125, 0.875),
#  'enredar': ('VERB', 0.125, 0.0, 0.875),
#  'falsear': ('VERB', 0.0, 0.375, 0.625),
#  'defraudar': ('VERB', 0.0, 0.125, 0.875),
#  'engatusar': ('VERB', 0.125, 0.0, 0.875),
#  'masturbación': ('NOUN', 0.125, 0.0, 0.875),
#  'despertar': ('VERB', 0.125, 0.0, 0.875),
#  'retroalimentar': ('VERB', 0.125, 0.0, 0.875),
#  'dedicar': ('VERB', 0.125, 0.0, 0.875),
#  'disciplina': ('NOUN', 0.125, 0.0, 0.875),
#  'capacidad': ('NOUN', 0.125, 0.0, 0.875),
#  'explotación de depósitos minerales': ('NOUN', 0.125, 0.0, 0.875),
#  'sugerir': ('VERB', 0.5, 0.0, 0.5),
#  'insinuar': ('VERB', 0.5, 0.0, 0.5),
#  'capitalización': ('NOUN', 0.125, 0.0, 0.875),
#  'pelea cuerpo a cuerpo': ('NOUN', 0.125, 0.0, 0.875),
#  'actualizar': ('VERB', 0.125, 0.0, 0.875),
#  'contrafirmar': ('VERB', 0.125, 0.0, 0.875),
#  'abstinencia': ('NOUN', 0.125, 0.0, 0.875),
#  'grieta': ('NOUN', 0.125, 0.0, 0.875),
#  'exención': ('NOUN', 0.125, 0.0, 0.875),
#  'cachemira': ('NOUN', 0.125, 0.0, 0.875),
#  'época de san miguel': ('NOUN', 0.125, 0.0, 0.875),
#  'época de lammas': ('NOUN', 0.125, 0.0, 0.875),
#  'época de pascua': ('NOUN', 0.125, 0.0, 0.875),
#  'época de la epifanía': ('NOUN', 0.125, 0.0, 0.875),
#  'período': ('NOUN', 0.125, 0.0, 0.875),
#  'destruir': ('VERB', 0.0, 0.25, 0.75),
#  'hacer pedazos': ('VERB', 0.125, 0.0, 0.875),
#  'autolimitación': ('NOUN', 0.125, 0.0, 0.875),
#  'ver': ('VERB', 0.125, 0.0, 0.875),
#  'explotar': ('VERB', 0.125, 0.0, 0.875),
#  'incumplimiento': ('NOUN', 0.125, 0.0, 0.875),
#  'servir': ('VERB', 0.125, 0.0, 0.875),
#  'cuidar un bebé': ('VERB', 0.125, 0.0, 0.875),
#  'insistencia': ('NOUN', 0.0, 0.125, 0.875),
#  'buen gesto': ('NOUN', 0.125, 0.0, 0.875),
#  'absentismo': ('NOUN', 0.125, 0.0, 0.875),
#  'ser fatal': ('VERB', 0.125, 0.0, 0.875),
#  'especie de bacterias': ('NOUN', 0.125, 0.0, 0.875),
#  'pseudomonas pyocanea': ('NOUN', 0.125, 0.0, 0.875),
#  'nitrobacteriaceae': ('NOUN', 0.125, 0.0, 0.875),
#  'c. trachomatis': ('NOUN', 0.125, 0.0, 0.875),
#  'apapachar': ('VERB', 0.125, 0.0, 0.875),
#  'derribar': ('VERB', 0.125, 0.0, 0.875),
#  'asear la casa': ('VERB', 0.125, 0.0, 0.875),
#  'agregar': ('VERB', 0.125, 0.0, 0.875),
#  'empastar': ('VERB', 0.125, 0.0, 0.875),
#  'traer': ('VERB', 0.125, 0.0, 0.875),
#  'llamar': ('VERB', 0.125, 0.0, 0.875),
#  'agitar': ('VERB', 0.125, 0.0, 0.875),
#  'dar': ('VERB', 0.0, 0.5, 0.5),
#  'producir': ('VERB', 0.125, 0.0, 0.875),
#  'indentar': ('VERB', 0.125, 0.0, 0.875),
#  'aficionarse': ('VERB', 0.125, 0.0, 0.875),
#  'asustar': ('VERB', 0.125, 0.0, 0.875),
#  'intimidar': ('VERB', 0.125, 0.0, 0.875),
#  'decepcionar': ('VERB', 0.125, 0.0, 0.875),
#  'andar en cámara': ('VERB', 0.125, 0.0, 0.875),
#  'desplazarse furtivamente': ('VERB', 0.125, 0.0, 0.875),
#  'coral hongo': ('NOUN', 0.125, 0.0, 0.875),
#  'género echinococcus': ('NOUN', 0.125, 0.0, 0.875),
#  'clase bivalvia': ('NOUN', 0.125, 0.0, 0.875),
#  'clase pelecypoda': ('NOUN', 0.125, 0.0, 0.875),
#  'almeja roja': ('NOUN', 0.125, 0.0, 0.875),
#  'sepiidae': ('NOUN', 0.125, 0.0, 0.875),
#  'hacer circular': ('VERB', 0.125, 0.0, 0.875),
#  'seleccionado': ('ADJ', 0.125, 0.0, 0.875),
#  'mostrar': ('VERB', 0.125, 0.0, 0.875),
#  'phyllostomidae': ('NOUN', 0.125, 0.0, 0.875),
#  'familia rrhinolophidae': ('NOUN', 0.125, 0.0, 0.875),
#  'observar': ('VERB', 0.125, 0.0, 0.875),
#  'acordar': ('VERB', 0.125, 0.0, 0.875),
#  'asteroidea': ('NOUN', 0.125, 0.0, 0.875),
#  'calse asteroidea': ('NOUN', 0.125, 0.0, 0.875),
#  'enroscado': ('ADJ', 0.125, 0.0, 0.875),
#  'género zapus': ('NOUN', 0.125, 0.0, 0.875),
#  'zapus': ('NOUN', 0.125, 0.0, 0.875),
#  'género bathyergus': ('NOUN', 0.125, 0.0, 0.875),
#  'pastorear': ('VERB', 0.125, 0.0, 0.875),
#  'privilegiar': ('VERB', 0.125, 0.0, 0.875),
#  'suborden anthropoidea': ('NOUN', 0.125, 0.0, 0.875),
#  'hominóideo': ('NOUN', 0.125, 0.0, 0.875),
#  'homínido': ('NOUN', 0.125, 0.0, 0.875),
#  'entretener': ('VERB', 0.125, 0.0, 0.875),
#  'cumplir lo prometido': ('VERB', 0.125, 0.0, 0.875),
#  'tener éxito': ('VERB', 0.125, 0.0, 0.875),
#  'triunfar': ('NOUN', 0.625, 0.0, 0.375),
#  'jugársela': ('VERB', 0.125, 0.0, 0.875),
#  'flirtear': ('VERB', 0.125, 0.0, 0.875),
#  'fomentar': ('VERB', 0.125, 0.0, 0.875),
#  'impulsar': ('VERB', 0.125, 0.0, 0.875),
#  'estimular': ('VERB', 0.125, 0.0, 0.875),
#  'promover': ('VERB', 0.125, 0.0, 0.875),
#  'cumplir': ('VERB', 0.125, 0.0, 0.875),
#  'suspender por lluvia': ('VERB', 0.125, 0.0, 0.875),
#  'resistir': ('VERB', 0.0, 0.125, 0.875),
#  'mantenerse': ('VERB', 0.125, 0.0, 0.875),
#  'coprotagonizar': ('VERB', 0.125, 0.0, 0.875),
#  'dirigible': ('NOUN', 0.125, 0.0, 0.875),
#  'wilsoniano': ('ADJ', 0.125, 0.0, 0.875),
#  'proficiente': ('ADJ', 0.125, 0.0, 0.875),
#  'poético': ('ADJ', 0.125, 0.0, 0.875),
#  'mesiánico': ('ADJ', 0.125, 0.0, 0.875),
#  'bombie': ('NOUN', 0.125, 0.0, 0.875),
#  'gustativo': ('ADJ', 0.125, 0.0, 0.875),
#  'gustatorio': ('ADJ', 0.125, 0.0, 0.875),
#  'cubículo': ('NOUN', 0.125, 0.0, 0.875),
#  'capote': ('NOUN', 0.125, 0.0, 0.875),
#  'abrigo encapuchado': ('NOUN', 0.125, 0.0, 0.875),
#  'epicúreo': ('ADJ', 0.125, 0.0, 0.875),
#  'capilla': ('NOUN', 0.125, 0.0, 0.875),
#  'adicional': ('ADJ', 0.125, 0.0, 0.875),
#  'escurridor': ('NOUN', 0.125, 0.0, 0.875),
#  'dentadura falsa': ('NOUN', 0.125, 0.0, 0.875),
#  'tracería de abanicos': ('NOUN', 0.125, 0.0, 0.875),
#  'aguada': ('NOUN', 0.125, 0.0, 0.875),
#  'alabarda': ('NOUN', 0.125, 0.0, 0.875),
#  'spa': ('NOUN', 0.5, 0.0, 0.5),
#  'albergue juvenil': ('NOUN', 0.125, 0.0, 0.875),
#  'youth hostel': ('NOUN', 0.125, 0.0, 0.875),
#  'luneta': ('NOUN', 0.125, 0.0, 0.875),
#  'sala de masajes': ('NOUN', 0.125, 0.0, 0.875),
#  'placa madre': ('NOUN', 0.125, 0.0, 0.875),
#  'reloj de péndulo': ('NOUN', 0.125, 0.0, 0.875),
#  'estilete': ('NOUN', 0.125, 0.0, 0.875),
#  'porcelana, cerámica': ('NOUN', 0.125, 0.0, 0.875),
#  'espectroscopio de prisma': ('NOUN', 0.125, 0.0, 0.875),
#  'espectroscopio': ('NOUN', 0.125, 0.0, 0.875),
#  'terazosina': ('NOUN', 0.125, 0.0, 0.875),
#  'parada de camiones': ('NOUN', 0.125, 0.0, 0.875),
#  'tienda de golosinas': ('NOUN', 0.125, 0.0, 0.875),
#  '22': ('NOUN', 0.125, 0.0, 0.875),
#  'cristal veneciano': ('NOUN', 0.125, 0.0, 0.875),
#  'espíritu': ('NOUN', 0.125, 0.0, 0.875),
#  'progresión': ('NOUN', 0.125, 0.0, 0.875),
#  'progresividad': ('NOUN', 0.125, 0.0, 0.875),
#  'imprecisión': ('NOUN', 0.125, 0.0, 0.875),
#  'previsión': ('NOUN', 0.0, 0.125, 0.875),
#  'vena': ('NOUN', 0.125, 0.0, 0.875),
#  'nombre': ('NOUN', 0.0, 0.125, 0.875),
#  'recurso': ('NOUN', 0.125, 0.0, 0.875),
#  'refugio': ('NOUN', 0.0, 0.375, 0.625),
#  'apelación': ('NOUN', 0.125, 0.0, 0.875),
#  'delantera': ('NOUN', 0.125, 0.0, 0.875),
#  'abductor del dedo gordo del pie': ('NOUN', 0.125, 0.0, 0.875),
#  'aductor del dedo gordo del pie': ('NOUN', 0.125, 0.0, 0.875),
#  'conducto torácico': ('NOUN', 0.125, 0.0, 0.875),
#  '(buena) mano': ('NOUN', 0.125, 0.0, 0.875),
#  'complemento': ('NOUN', 0.125, 0.0, 0.875),
#  'aprehensión inmediata': ('NOUN', 0.125, 0.0, 0.875),
#  'vainilla': ('NOUN', 0.125, 0.0, 0.875),
#  'verificación': ('NOUN', 0.125, 0.0, 0.875),
#  'doble comprobación': ('NOUN', 0.125, 0.0, 0.875),
#  'ensimismamiento': ('NOUN', 0.0, 0.125, 0.875),
#  'reflexión': ('NOUN', 0.125, 0.0, 0.875),
#  'meditación': ('NOUN', 0.125, 0.0, 0.875),
#  'ponderación': ('NOUN', 0.5, 0.0, 0.5),
#  'clave': ('NOUN', 0.125, 0.0, 0.875),
#  'percepcion': ('NOUN', 0.125, 0.0, 0.875),
#  'maestro': ('NOUN', 0.125, 0.0, 0.875),
#  'yang': ('NOUN', 0.125, 0.0, 0.875),
#  'teosofismo': ('NOUN', 0.125, 0.0, 0.875),
#  'reconocimiento': ('NOUN', 0.625, 0.0, 0.375),
#  'política de agresión': ('NOUN', 0.125, 0.0, 0.875),
#  'vizcondado': ('NOUN', 0.125, 0.0, 0.875),
#  'ditirambo': ('NOUN', 0.125, 0.0, 0.875),
#  'versión estándar americana': ('NOUN', 0.125, 0.0, 0.875),
#  'perdón': ('NOUN', 0.125, 0.0, 0.875),
#  'tonterías': ('NOUN', 0.0, 0.25, 0.75),
#  'morralla': ('NOUN', 0.125, 0.0, 0.875),
#  'bobadas': ('NOUN', 0.125, 0.0, 0.875),
#  'aguachirle': ('NOUN', 0.125, 0.0, 0.875),
#  'prueba matemática': ('NOUN', 0.125, 0.0, 0.875),
#  'consejo': ('NOUN', 0.125, 0.0, 0.875),
#  'filtración': ('NOUN', 0.125, 0.0, 0.875),
#  'doctor en osteopatía': ('NOUN', 0.125, 0.0, 0.875),
#  'declaración discreta': ('NOUN', 0.125, 0.0, 0.875),
#  'espectáculo': ('NOUN', 0.125, 0.0, 0.875),
#  'floritura': ('NOUN', 0.125, 0.0, 0.875),
#  'matiné': ('NOUN', 0.125, 0.0, 0.875),
#  'alemán alto antiguo': ('NOUN', 0.125, 0.0, 0.875),
#  'ilustración': ('NOUN', 0.375, 0.0, 0.625),
#  'obra': ('NOUN', 0.125, 0.0, 0.875),
#  'expresión': ('NOUN', 0.125, 0.0, 0.875),
#  'aullidos': ('NOUN', 0.125, 0.0, 0.875),
#  'compensación': ('NOUN', 0.375, 0.0, 0.625),
#  'gracias': ('NOUN', 0.0, 0.125, 0.875),
#  'inculpación': ('NOUN', 0.125, 0.0, 0.875),
#  'prohibición': ('NOUN', 0.125, 0.0, 0.875),
#  'cachondeo': ('NOUN', 0.125, 0.0, 0.875),
#  'horror': ('NOUN', 0.0, 0.5, 0.5),
#  'buen viaje': ('NOUN', 0.125, 0.0, 0.875),
#  'efusión': ('NOUN', 0.5, 0.0, 0.5),
#  'aniquilación': ('NOUN', 0.0, 0.125, 0.875),
#  'desintegración': ('NOUN', 0.125, 0.0, 0.875),
#  'ladrido': ('NOUN', 0.125, 0.0, 0.875),
#  'descontento': ('NOUN', 0.125, 0.0, 0.875),
#  'comida decente': ('NOUN', 0.125, 0.0, 0.875),
#  'chowder': ('NOUN', 0.125, 0.0, 0.875),
#  'caramelo de miel': ('NOUN', 0.125, 0.0, 0.875),
#  'caramelo de azúcar': ('NOUN', 0.125, 0.0, 0.875),
#  'quiche lorraine': ('NOUN', 0.125, 0.0, 0.875),
#  'foie gras': ('NOUN', 0.125, 0.0, 0.875),
#  'paté de foie gras': ('NOUN', 0.125, 0.0, 0.875),
#  'ginebra artesanal': ('NOUN', 0.125, 0.0, 0.875),
#  'manhattan': ('NOUN', 0.125, 0.0, 0.875),
#  'arminianismo': ('NOUN', 0.125, 0.0, 0.875),
#  'iglesia metodista': ('NOUN', 0.125, 0.0, 0.875),
#  'metodistas': ('NOUN', 0.125, 0.0, 0.875),
#  'taoísmo': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de arte': ('NOUN', 0.125, 0.0, 0.875),
#  'facultad de ciencias de la computación': ('NOUN', 0.125, 0.0, 0.875),
#  'juglaría': ('NOUN', 0.125, 0.0, 0.875),
#  'soldados hostiles': ('NOUN', 0.125, 0.0, 0.875),
#  'esencia': ('NOUN', 0.5, 0.0, 0.5),
#  'arzobispado': ('NOUN', 0.125, 0.0, 0.875),
#  'reductor': ('NOUN', 0.125, 0.0, 0.875),
#  'represor': ('NOUN', 0.125, 0.0, 0.875),
#  'acortador': ('NOUN', 0.125, 0.0, 0.875),
#  'aglaya': ('NOUN', 0.125, 0.0, 0.875),
#  'eufrósine': ('NOUN', 0.125, 0.0, 0.875),
#  'talía': ('NOUN', 0.125, 0.0, 0.875),
#  'venus': ('NOUN', 0.125, 0.0, 0.875),
#  'vali': ('NOUN', 0.125, 0.0, 0.875),
#  'siervo': ('NOUN', 0.125, 0.0, 0.875),
#  'alto mando': ('NOUN', 0.125, 0.0, 0.875),
#  'revisor': ('NOUN', 0.125, 0.0, 0.875),
#  'defensor': ('NOUN', 0.125, 0.0, 0.875),
#  'promesa': ('NOUN', 0.5, 0.0, 0.5),
#  'confesor': ('NOUN', 0.125, 0.0, 0.875),
#  'buen conversador': ('NOUN', 0.125, 0.0, 0.875),
#  'cubista': ('NOUN', 0.125, 0.0, 0.875),
#  'dialéctico': ('NOUN', 0.125, 0.0, 0.875),
#  'viejo verde': ('NOUN', 0.125, 0.0, 0.875),
#  'aprovechador': ('NOUN', 0.125, 0.0, 0.875),
#  'cariño': ('NOUN', 0.125, 0.0, 0.875),
#  'metodista': ('NOUN', 0.125, 0.0, 0.875),
#  'neoliberal': ('NOUN', 0.125, 0.0, 0.875),
#  'partidario de la resistencia pasiva': ('NOUN', 0.125, 0.0, 0.875),
#  'perfeccionador': ('NOUN', 0.125, 0.0, 0.875),
#  'el que acaricia': ('NOUN', 0.125, 0.0, 0.875),
#  'fusilero': ('NOUN', 0.125, 0.0, 0.875),
#  'sacadineros': ('NOUN', 0.125, 0.0, 0.875),
#  'marinero polémico': ('NOUN', 0.125, 0.0, 0.875),
#  'persona muy reservada': ('NOUN', 0.125, 0.0, 0.875),
#  'aficionado al deporte': ('NOUN', 0.125, 0.0, 0.875),
#  'abanderado': ('NOUN', 0.125, 0.0, 0.875),
#  'provocador': ('NOUN', 0.125, 0.0, 0.875),
#  'mortificador': ('NOUN', 0.125, 0.0, 0.875),
#  'esclavo': ('NOUN', 0.125, 0.0, 0.875),
#  'arminiano': ('NOUN', 0.125, 0.0, 0.875),
#  'ganador inesperado': ('NOUN', 0.125, 0.0, 0.875),
#  'jaime': ('NOUN', 0.125, 0.0, 0.875),
#  'santiago': ('NOUN', 0.125, 0.0, 0.875),
#  'santiago apóstol': ('NOUN', 0.125, 0.0, 0.875),
#  'san jaime': ('NOUN', 0.125, 0.0, 0.875),
#  'san jaime apóstol': ('NOUN', 0.125, 0.0, 0.875),
#  'sylvia plath': ('NOUN', 0.125, 0.0, 0.875),
#  'allen tate': ('NOUN', 0.125, 0.0, 0.875),
#  'joseph deems taylor': ('NOUN', 0.125, 0.0, 0.875),
#  'alfred lord tennyson': ('NOUN', 0.125, 0.0, 0.875),
#  'baron tennyson': ('NOUN', 0.125, 0.0, 0.875),
#  'tiziano': ('NOUN', 0.125, 0.0, 0.875),
#  'tiziano vecellio': ('NOUN', 0.125, 0.0, 0.875),
#  'robert penn warren': ('NOUN', 0.125, 0.0, 0.875),
#  'ola': ('NOUN', 0.125, 0.0, 0.875),
#  'pino contorta murrayana': ('NOUN', 0.125, 0.0, 0.875),
#  'ceratophyllum': ('NOUN', 0.125, 0.0, 0.875),
#  'género ceratofiláceas': ('NOUN', 0.125, 0.0, 0.875),
#  'género marrubium': ('NOUN', 0.125, 0.0, 0.875),
#  'género chlorophyllum': ('NOUN', 0.125, 0.0, 0.875),
#  'contribución': ('NOUN', 0.125, 0.0, 0.875),
#  'capital social': ('NOUN', 0.125, 0.0, 0.875),
#  'nueve peniques': ('NOUN', 0.125, 0.0, 0.875),
#  'revisión puntual': ('NOUN', 0.125, 0.0, 0.875),
#  'revisión': ('NOUN', 0.625, 0.0, 0.375),
#  'bacteriostasis': ('NOUN', 0.125, 0.0, 0.875),
#  'denominador': ('NOUN', 0.125, 0.0, 0.875),
#  'ocupación hospitalaria': ('NOUN', 0.125, 0.0, 0.875),
#  'cuarto': ('NOUN', 0.125, 0.0, 0.875),
#  'disposición mental': ('NOUN', 0.125, 0.0, 0.875),
#  'estado mental': ('NOUN', 0.125, 0.0, 0.875),
#  'dosis': ('NOUN', 0.125, 0.0, 0.875),
#  'enfermedad de transmisión sexual': ('NOUN', 0.125, 0.0, 0.875),
#  'enfermedad social': ('NOUN', 0.125, 0.0, 0.875),
#  'ev': ('NOUN', 0.125, 0.0, 0.875),
#  'enfermedad venérea': ('NOUN', 0.125, 0.0, 0.875),
#  'infección venérea': ('NOUN', 0.125, 0.0, 0.875),
#  'faringitis sépticas': ('NOUN', 0.125, 0.0, 0.875),
#  'amigdalitis estreptocócica': ('NOUN', 0.125, 0.0, 0.875),
#  'inflamación de la garganta': ('NOUN', 0.125, 0.0, 0.875),
#  'fiebre de texas': ('NOUN', 0.125, 0.0, 0.875),
#  'soplo sistólico': ('NOUN', 0.125, 0.0, 0.875),
#  'encefalitis hemorrágica aguda': ('NOUN', 0.125, 0.0, 0.875),
#  'sangre azul': ('NOUN', 0.125, 0.0, 0.875),
#  'vía': ('NOUN', 0.125, 0.0, 0.875),
#  'pérdida auditiva sensorineural': ('NOUN', 0.125, 0.0, 0.875),
#  'hiposmia': ('NOUN', 0.125, 0.0, 0.875),
#  'fundición obtenida con un solo mineral': ('NOUN', 0.125, 0.0, 0.875),
#  ...}

# %% [markdown]
# Ahora vamos a probar el lexicón de SentiWordNet en español para calcular el sentimiento.

# %% [markdown]
# Hasta ahora hemos hecho un mapeo entre las etiquetas gramaticales ya incluídas en el lexicón de SentiWordNet a las etiquetas que usa WordNet, centrándonos únicamente en categorías léxicas (nombres, verbos, adjetivos, adverbios). Después, vamos a lematizar los tokens, esto es, quitar cualquier afijo para obtener la raíz de los mismos. Buscaremos el lema en WordNet y obtendremos el significado del primero, que es el más común. Por último, ofrecemos dos maneras de calcular el sentimiento:
#
# 1. Mediante la suma de la resta del sentimiento positivo y negativo de cada synset por palabra.
# 2. Mediante la media de la suma de los sentimientos positivos, negativos y objetivos de todas las palabras, escogiendo el valor más alto de los tres sentimientos.
#
# En el primer caso, consideraremos la misma escala de valores que vimos en VADER:
# si s es superior o igual a 0.05, positivo; si s es inferior o igual a -0.05, negativo; en el resto de los casos, neutro.
#
# En el segundo, calcularemos la media de la suma de los scores positivos, negativos y objetivos y tomaremos como polaridad aquel de los tres que tenga un valor mayor.

# %% [markdown]
# Ahora vamos a crear una función para cada una de los métodos para calcular el sentimiento y vamos a aplicar tal función al dataset anterior, reutilizando para ello el código del que nos servimos anteriormente para cargar el dataset, visualizarlo, manipularlo, etc.

# %%
def compute_sentiment_sum(text):

  doc = nlp_es(text)
  tokenized_sent = [token.text for token in doc]
  print(tokenized_sent)

  pos_tagged_tokens = nltk.pos_tag(tokenized_sent)
  print(pos_tagged_tokens)

####
  pos_score = 0.0
  neg_score = 0.0
  sentiment_value = 0.0
  sentiment_label = ""
  for word, tag in pos_tagged_tokens:
    print(word)
    wn_tag = map_spacy_to_wn(spanish_sentiwordnet,spacy_to_wn)
    print(wn_tag)
    if wn_tag == None:
     continue

    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    print(lemma)
    if not lemma:
      continue

    swn_synsets = list(swn.senti_synsets(lemma, pos=wn_tag))
    print(swn_synsets)
    if len(swn_synsets) == 0:
      continue
    pos_score = swn_synsets[0].pos_score()
    print(pos_score)
    neg_score =  swn_synsets[0].neg_score()
    print(neg_score)
    # podemos probar a calcular la media de la suma de los synsets por palabra y ver si arroja mejores resultados
    #pos_score = sum(synset.pos_score() for synset in swn_synsets)
    #neg_score = sum(synset.neg_score() for synset in swn_synsets)
    sentiment_value += pos_score - neg_score
    print(sentiment_value)

  if sentiment_value >= 0.05:
    sentiment_label = "positive"
  elif sentiment_value <= -0.05:
    sentiment_label = "negative"
  else:
    sentiment_label = "neutral"

  return sentiment_label

def compute_sentiment_mean(text):

  tokenized_sent = nltk.word_tokenize(text)
  pos_tagged_tokens = nltk.pos_tag(tokenized_sent)
  #english_stopwords = set(stopwords.words("english"))
  #pos_tagged_tokens = [word for word in pos_tagged_tokens if word[0] not in english_stopwords]

  pos_score = 0.0
  neg_score = 0.0
  obj_score = 0.0
  num_lemas_con_synset = 0
  sentiment_label = "neutral"

  for word, tag in pos_tagged_tokens:

    wn_tag = penn_to_wn(tag)
    if wn_tag == None:
     continue

    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    if not lemma:
      continue

    swn_synsets = list(swn.senti_synsets(lemma, pos=wn_tag))
    if len(swn_synsets) == 0:
      continue
    # podemos probar a calcular la media de la suma de los synsets por palabra y ver si arroja mejores resultados
    #pos_score += sum(synset.pos_score() for synset in swn_synsets) / len(swn_synsets)
    #neg_score += sum(synset.neg_score() for synset in swn_synsets) / len(swn_synsets)
    #obj_score += sum(synset.obj_score() for synset in swn_synsets) / len(swn_synsets)
    pos_score += swn_synsets[0].pos_score()
    neg_score += swn_synsets[0].neg_score()
    obj_score += swn_synsets[0].obj_score()
    num_lemas_con_synset += 1

  if num_lemas_con_synset > 0:
    pos_score_mean = pos_score / num_lemas_con_synset
    neg_score_mean = neg_score / num_lemas_con_synset
    obj_score_mean = obj_score / num_lemas_con_synset
    max_value = max(pos_score_mean, neg_score_mean, obj_score_mean)

    if max_value == pos_score_mean:
      sentiment_label = "positive"
    elif max_value == neg_score_mean:
      sentiment_label = "negative"

  return sentiment_label

# %%
text ="Hoy me he levantado alegre"
#doc = nlp_es(text)
#doc

# %%
valor_sentimiento = compute_sentiment_sum(text)
print(valor_sentimiento)
# Out:
# ['John', 'is', 'nice', 'and', 'is', 'my', 'new', 'best', 'friend']
# [('John', 'NNP'), ('is', 'VBZ'), ('nice', 'JJ'), ('and', 'CC'), ('is', 'VBZ'), ('my', 'PRP$'), ('new', 'JJ'), ('best', 'JJS'), ('friend', 'NN')]
# John
# n
# John
# [SentiSynset('toilet.n.01'), SentiSynset('john.n.02'), SentiSynset('john.n.03'), SentiSynset('whoremaster.n.01'), SentiSynset('john.n.05')]
# 0.0
# 0.0
# 0.0
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.375
# 0.25
# 0.125
# nice
# a
# nice
# [SentiSynset('nice.a.01'), SentiSynset('decent.s.01'), SentiSynset('nice.s.03'), SentiSynset('dainty.s.04'), SentiSynset('courteous.s.01')]
# 3.25
# 0.375
# 3.0
# and
# None
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.375
# 0.25
# 3.125
# my
# None
# new
# a
# new
# [SentiSynset('new.a.01'), SentiSynset('fresh.s.04'), SentiSynset('raw.s.12'), SentiSynset('new.s.04'), SentiSynset('new.s.05'), SentiSynset('new.a.06'), SentiSynset('newfangled.s.01'), SentiSynset('new.s.08'), SentiSynset('modern.s.05'), SentiSynset('new.s.10'), SentiSynset('new.s.11')]
# 1.5
# 1.25
# 3.375
# best
# a
# best
# [SentiSynset('best.a.01'), SentiSynset('better.s.03'), SentiSynset('good.a.01'), SentiSynset('full.s.06'), SentiSynset('good.a.03'), SentiSynset('estimable.s.02'), SentiSynset('beneficial.s.01'), SentiSynset('good.s.06'), SentiSynset('good.s.07'), SentiSynset('adept.s.01'), SentiSynset('good.s.09'), SentiSynset('dear.s.02'), SentiSynset('dependable.s.04'), SentiSynset('good.s.12'), SentiSynset('good.s.13'), SentiSynset('effective.s.04'), SentiSynset('good.s.15'), SentiSynset('good.s.16'), SentiSynset('good.s.17'), SentiSynset('good.s.18'), SentiSynset('good.s.19'), SentiSynset('good.s.20'), SentiSynset('good.s.21')]
# 14.5
# 0.125
# 17.75
# friend
# n
# friend
# [SentiSynset('friend.n.01'), SentiSynset('ally.n.02'), SentiSynset('acquaintance.n.03'), SentiSynset('supporter.n.01'), SentiSynset('friend.n.05')]
# 0.375
# 0.0
# 18.125
# positive

# %%
valor_sentimiento_mean = compute_sentiment_mean(text)
print(valor_sentimiento_mean)

# %%
#Función para formatear los datos del dataset (prepararlos)
def format_data(data):

  selected_data = data.iloc[:, [0, -1]]
  selected_data.columns = ['polarity_value', 'tweet_text']
  # Cambiar 0, 2, 4 a negativo, neutral y positivo respecticamente
  labels = {0: 'negative', 2: 'neutral', 4: 'positive'}
  selected_data['polarity_value'] = selected_data['polarity_value'].map(labels)

  # Retornar solo las dos columnas que nos interesan
  return selected_data[['tweet_text', 'polarity_value']]

# %%
import pandas as pd

#Cargamos dataset para comprobar los resultados
data_url = "https://raw.githubusercontent.com/keitazoumana/VADER_sentiment-Analysis/main/data/testdata.manual.2009.06.14.csv"
sentiment_data = pd.read_csv(data_url, header=None)

# Aplicar la transformación con la función anterior que definimos más arriba
data = format_data(sentiment_data)
data.head(10)
# Out:
# <ipython-input-27-8d0d4eb07fb0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['polarity_value'] = selected_data['polarity_value'].map(labels)
#                                           tweet_text polarity_value
# 0  @stellargirl I loooooooovvvvvveee my Kindle2. ...       positive
# 1  Reading my kindle2...  Love it... Lee childs i...       positive
# 2  Ok, first assesment of the #kindle2 ...it fuck...       positive
# 3  @kenburbary You'll love your Kindle2. I've had...       positive
# 4  @mikefish  Fair enough. But i have the Kindle2...       positive
# 5  @richardebaker no. it is too big. I'm quite ha...       positive
# 6  Fuck this economy. I hate aig and their non lo...       negative
# 7                      Jquery is my new best friend.       positive
# 8                                      Loves twitter       positive
# 9  how can you not love Obama? he makes jokes abo...       positive

# %%
# Ejecutar las predicciones y obtener nuevas columna con dichas predicciones
data["sentiwordnet_sum_prediction"] = data["tweet_text"].apply(compute_sentiment_sum)
data["sentiwordnet_mean_prediction"] = data["tweet_text"].apply(compute_sentiment_mean)

# Mostrar 5 filas aleatorias del dataset
data.sample(5)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.0
# :
# None
# //codylindley.com/jqueryselectors/
# n
# //codylindley.com/jqueryselectors/
# []
# ['How', 'to', 'implement', 'a', 'news', 'ticker', 'with', 'jQuery', 'and', 'ten', 'lines', 'of', 'code', 'http', ':', '//bit.ly/CZnFJ']
# [('How', 'WRB'), ('to', 'TO'), ('implement', 'VB'), ('a', 'DT'), ('news', 'NN'), ('ticker', 'NN'), ('with', 'IN'), ('jQuery', 'NN'), ('and', 'CC'), ('ten', 'JJ'), ('lines', 'NNS'), ('of', 'IN'), ('code', 'NN'), ('http', 'NN'), (':', ':'), ('//bit.ly/CZnFJ', 'NN')]
# How
# None
# to
# None
# implement
# v
# implement
# [SentiSynset('implement.v.01'), SentiSynset('enforce.v.01'), SentiSynset('follow_through.v.02')]
# 0.0
# 0.0
# 0.0
# a
# None
# news
# n
# news
# [SentiSynset('news.n.01'), SentiSynset('news.n.02'), SentiSynset('news_program.n.01'), SentiSynset('news.n.04'), SentiSynset('newsworthiness.n.01')]
# 0.0
# 0.0
# 0.0
# ticker
# n
# ticker
# [SentiSynset('heart.n.02'), SentiSynset('watch.n.01'), SentiSynset('ticker.n.03')]
# 0.0
# 0.0
# 0.0
# with
# None
# jQuery
# n
# jQuery
# []
# and
# None
# ten
# a
# ten
# [SentiSynset('ten.s.01')]
# 0.0
# 0.0
# 0.0
# lines
# n
# line
# [SentiSynset('line.n.01'), SentiSynset('line.n.02'), SentiSynset('line.n.03'), SentiSynset('line.n.04'), SentiSynset('line.n.05'), SentiSynset('line.n.06'), SentiSynset('line.n.07'), SentiSynset('argumentation.n.02'), SentiSynset('cable.n.02'), SentiSynset('course.n.02'), SentiSynset('line.n.11'), SentiSynset('wrinkle.n.01'), SentiSynset('pipeline.n.02'), SentiSynset('line.n.14'), SentiSynset('telephone_line.n.02'), SentiSynset('line.n.16'), SentiSynset('lineage.n.01'), SentiSynset('line.n.18'), SentiSynset('occupation.n.01'), SentiSynset('line.n.20'), SentiSynset('channel.n.05'), SentiSynset('line.n.22'), SentiSynset('line.n.23'), SentiSynset('agate_line.n.01'), SentiSynset('credit_line.n.01'), SentiSynset('tune.n.01'), SentiSynset('line.n.27'), SentiSynset('note.n.02'), SentiSynset('line.n.29'), SentiSynset('production_line.n.01')]
# 0.0
# 0.0
# 0.0
# of
# None
# code
# n
# code
# [SentiSynset('code.n.01'), SentiSynset('code.n.02'), SentiSynset('code.n.03')]
# 0.0
# 0.0
# 0.0
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.0
# :
# None
# //bit.ly/CZnFJ
# n
# //bit.ly/CZnFJ
# []
# ['What', "'s", 'Buffet', 'Doing', '?', 'Warren', 'Buffett', 'Kicks', 'Butt', 'In', 'Battle', 'of', 'the', 'Boots', ':', 'Posted', 'By', ':', 'Alex', 'Crippe', '..', 'http', ':', '//bit.ly/AUIzO']
# [('What', 'WP'), ("'s", 'VBZ'), ('Buffet', 'NNP'), ('Doing', 'NNP'), ('?', '.'), ('Warren', 'NNP'), ('Buffett', 'NNP'), ('Kicks', 'NNP'), ('Butt', 'NNP'), ('In', 'IN'), ('Battle', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Boots', 'NNP'), (':', ':'), ('Posted', 'VBN'), ('By', 'IN'), (':', ':'), ('Alex', 'NNP'), ('Crippe', 'NNP'), ('..', 'NNP'), ('http', 'NN'), (':', ':'), ('//bit.ly/AUIzO', 'NN')]
# What
# None
# 's
# v
# 's
# []
# Buffet
# n
# Buffet
# [SentiSynset('buffet.n.01'), SentiSynset('buffet.n.02'), SentiSynset('snack_bar.n.01')]
# 0.0
# 0.0
# 0.0
# Doing
# n
# Doing
# []
# ?
# None
# Warren
# n
# Warren
# [SentiSynset('warren.n.01'), SentiSynset('warren.n.02'), SentiSynset('warren.n.03'), SentiSynset('warren.n.04'), SentiSynset('warren.n.05')]
# 0.125
# 0.0
# 0.125
# Buffett
# n
# Buffett
# []
# Kicks
# n
# Kicks
# [SentiSynset('kick.n.01'), SentiSynset('bang.n.04'), SentiSynset('recoil.n.01'), SentiSynset('gripe.n.01'), SentiSynset('kick.n.05'), SentiSynset('kick.n.06')]
# 0.0
# 0.0
# 0.125
# Butt
# n
# Butt
# [SentiSynset('butt.n.01'), SentiSynset('butt.n.02'), SentiSynset('butt.n.03'), SentiSynset('buttocks.n.01'), SentiSynset('target.n.04'), SentiSynset('cigarette.n.01'), SentiSynset('butt_joint.n.01'), SentiSynset('butt.n.08'), SentiSynset('butt.n.09')]
# 0.0
# 0.0
# 0.125
# In
# None
# Battle
# n
# Battle
# [SentiSynset('battle.n.01'), SentiSynset('struggle.n.01'), SentiSynset('conflict.n.01')]
# 0.0
# 0.0
# 0.125
# of
# None
# the
# None
# Boots
# n
# Boots
# [SentiSynset('boot.n.01'), SentiSynset('boot.n.02'), SentiSynset('bang.n.04'), SentiSynset('boot.n.04'), SentiSynset('boot.n.05'), SentiSynset('boot.n.06'), SentiSynset('kick.n.01')]
# 0.0
# 0.0
# 0.125
# :
# None
# Posted
# v
# Posted
# [SentiSynset('post.v.01'), SentiSynset('post.v.02'), SentiSynset('post.v.03'), SentiSynset('station.v.01'), SentiSynset('post.v.05'), SentiSynset('post.v.06'), SentiSynset('post.v.07'), SentiSynset('post.v.08'), SentiSynset('stake.v.03'), SentiSynset('post.v.10'), SentiSynset('mail.v.02'), SentiSynset('post.v.12')]
# 0.0
# 0.0
# 0.125
# By
# None
# :
# None
# Alex
# n
# Alex
# []
# Crippe
# n
# Crippe
# []
# ..
# n
# ..
# []
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.125
# :
# None
# //bit.ly/AUIzO
# n
# //bit.ly/AUIzO
# []
# ['SUPER', 'INVESTORS', ':', 'A', 'great', 'weekend', 'read', 'here', 'from', 'Warren', 'Buffet', '.', 'Oldie', ',', 'but', 'a', 'goodie', '.', 'http', ':', '//tinyurl.com/oqxgga']
# [('SUPER', 'JJ'), ('INVESTORS', 'NN'), (':', ':'), ('A', 'DT'), ('great', 'JJ'), ('weekend', 'NN'), ('read', 'NN'), ('here', 'RB'), ('from', 'IN'), ('Warren', 'NNP'), ('Buffet', 'NNP'), ('.', '.'), ('Oldie', 'NNP'), (',', ','), ('but', 'CC'), ('a', 'DT'), ('goodie', 'NN'), ('.', '.'), ('http', 'NN'), (':', ':'), ('//tinyurl.com/oqxgga', 'NN')]
# SUPER
# a
# SUPER
# [SentiSynset('ace.s.01'), SentiSynset('super.s.02'), SentiSynset('super.s.03')]
# 0.625
# 0.0
# 0.625
# INVESTORS
# n
# INVESTORS
# [SentiSynset('investor.n.01')]
# 0.0
# 0.0
# 0.625
# :
# None
# A
# None
# great
# a
# great
# [SentiSynset('great.s.01'), SentiSynset('great.s.02'), SentiSynset('great.s.03'), SentiSynset('bang-up.s.01'), SentiSynset('capital.s.03'), SentiSynset('big.s.13')]
# 0.0
# 0.0
# 0.625
# weekend
# n
# weekend
# [SentiSynset('weekend.n.01')]
# 0.0
# 0.0
# 0.625
# read
# n
# read
# [SentiSynset('read.n.01')]
# 0.25
# 0.0
# 0.875
# here
# r
# here
# [SentiSynset('here.r.01'), SentiSynset('here.r.02'), SentiSynset('here.r.03'), SentiSynset('here.r.04')]
# 0.0
# 0.0
# 0.875
# from
# None
# Warren
# n
# Warren
# [SentiSynset('warren.n.01'), SentiSynset('warren.n.02'), SentiSynset('warren.n.03'), SentiSynset('warren.n.04'), SentiSynset('warren.n.05')]
# 0.125
# 0.0
# 1.0
# Buffet
# n
# Buffet
# [SentiSynset('buffet.n.01'), SentiSynset('buffet.n.02'), SentiSynset('snack_bar.n.01')]
# 0.0
# 0.0
# 1.0
# .
# None
# Oldie
# n
# Oldie
# [SentiSynset('oldie.n.01')]
# 0.0
# 0.0
# 1.0
# ,
# None
# but
# None
# a
# None
# goodie
# n
# goodie
# []
# .
# None
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 1.0
# :
# None
# //tinyurl.com/oqxgga
# n
# //tinyurl.com/oqxgga
# []
# ['I', "'m", 'truly', 'braindead', '.', 'I', 'could', "n't", 'come', 'up', 'with', 'Warren', 'Buffet', "'s", 'name', 'to', 'save', 'my', 'soul']
# [('I', 'PRP'), ("'m", 'VBP'), ('truly', 'RB'), ('braindead', 'JJ'), ('.', '.'), ('I', 'PRP'), ('could', 'MD'), ("n't", 'RB'), ('come', 'VB'), ('up', 'RP'), ('with', 'IN'), ('Warren', 'NNP'), ('Buffet', 'NNP'), ("'s", 'POS'), ('name', 'NN'), ('to', 'TO'), ('save', 'VB'), ('my', 'PRP$'), ('soul', 'NN')]
# I
# None
# 'm
# v
# 'm
# []
# truly
# r
# truly
# [SentiSynset('truly.r.01'), SentiSynset('rightfully.r.01'), SentiSynset('sincerely.r.01'), SentiSynset('in_truth.r.01')]
# 0.625
# 0.0
# 0.625
# braindead
# a
# braindead
# []
# .
# None
# I
# None
# could
# None
# n't
# r
# n't
# []
# come
# v
# come
# [SentiSynset('come.v.01'), SentiSynset('arrive.v.01'), SentiSynset('come.v.03'), SentiSynset('come.v.04'), SentiSynset('come.v.05'), SentiSynset('come.v.06'), SentiSynset('issue_forth.v.01'), SentiSynset('hail.v.02'), SentiSynset('come.v.09'), SentiSynset('come.v.10'), SentiSynset('come.v.11'), SentiSynset('fall.v.04'), SentiSynset('come.v.13'), SentiSynset('total.v.01'), SentiSynset('come.v.15'), SentiSynset('come.v.16'), SentiSynset('occur.v.02'), SentiSynset('derive.v.05'), SentiSynset('do.v.04'), SentiSynset('come.v.20'), SentiSynset('come.v.21')]
# 0.0
# 0.0
# 0.625
# up
# r
# up
# [SentiSynset('up.r.01'), SentiSynset('up.r.02'), SentiSynset('up.r.03'), SentiSynset('up.r.04'), SentiSynset('up.r.05')]
# 0.0
# 0.0
# 0.625
# with
# None
# Warren
# n
# Warren
# [SentiSynset('warren.n.01'), SentiSynset('warren.n.02'), SentiSynset('warren.n.03'), SentiSynset('warren.n.04'), SentiSynset('warren.n.05')]
# 0.125
# 0.0
# 0.75
# Buffet
# n
# Buffet
# [SentiSynset('buffet.n.01'), SentiSynset('buffet.n.02'), SentiSynset('snack_bar.n.01')]
# 0.0
# 0.0
# 0.75
# 's
# None
# name
# n
# name
# [SentiSynset('name.n.01'), SentiSynset('name.n.02'), SentiSynset('name.n.03'), SentiSynset('name.n.04'), SentiSynset('name.n.05'), SentiSynset('name.n.06')]
# 0.0
# 0.0
# 0.75
# to
# None
# save
# v
# save
# [SentiSynset('salvage.v.01'), SentiSynset('save.v.02'), SentiSynset('save.v.03'), SentiSynset('save.v.04'), SentiSynset('save.v.05'), SentiSynset('save.v.06'), SentiSynset('deliver.v.08'), SentiSynset('spare.v.01'), SentiSynset('save.v.09'), SentiSynset('keep_open.v.01'), SentiSynset('write.v.08')]
# 0.5
# 0.0
# 1.25
# my
# None
# soul
# n
# soul
# [SentiSynset('soul.n.01'), SentiSynset('person.n.01'), SentiSynset('soul.n.03'), SentiSynset('soul.n.04'), SentiSynset('soul.n.05')]
# 0.0
# 0.0
# 1.25
# ['reading', 'Michael', 'Palin', 'book', ',', 'The', 'Python', 'Years', '...', 'great', 'book', '.', 'I', 'also', 'recommend', 'Warren', 'Buffet', '&', 'amp', ';', 'Nelson', 'Mandela', "'s", 'bio']
# [('reading', 'VBG'), ('Michael', 'NNP'), ('Palin', 'NNP'), ('book', 'NN'), (',', ','), ('The', 'DT'), ('Python', 'NNP'), ('Years', 'NNS'), ('...', ':'), ('great', 'JJ'), ('book', 'NN'), ('.', '.'), ('I', 'PRP'), ('also', 'RB'), ('recommend', 'VBP'), ('Warren', 'NNP'), ('Buffet', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('Nelson', 'NNP'), ('Mandela', 'NNP'), ("'s", 'POS'), ('bio', 'NN')]
# reading
# v
# read
# [SentiSynset('read.v.01'), SentiSynset('read.v.02'), SentiSynset('read.v.03'), SentiSynset('read.v.04'), SentiSynset('read.v.05'), SentiSynset('take.v.06'), SentiSynset('learn.v.04'), SentiSynset('read.v.08'), SentiSynset('read.v.09'), SentiSynset('read.v.10'), SentiSynset('understand.v.03')]
# 0.0
# 0.0
# 0.0
# Michael
# n
# Michael
# [SentiSynset('michael.n.01')]
# 0.0
# 0.0
# 0.0
# Palin
# n
# Palin
# []
# book
# n
# book
# [SentiSynset('book.n.01'), SentiSynset('book.n.02'), SentiSynset('record.n.05'), SentiSynset('script.n.01'), SentiSynset('ledger.n.01'), SentiSynset('book.n.06'), SentiSynset('book.n.07'), SentiSynset('koran.n.01'), SentiSynset('bible.n.01'), SentiSynset('book.n.10'), SentiSynset('book.n.11')]
# 0.0
# 0.0
# 0.0
# ,
# None
# The
# None
# Python
# n
# Python
# [SentiSynset('python.n.01'), SentiSynset('python.n.02'), SentiSynset('python.n.03')]
# 0.0
# 0.0
# 0.0
# Years
# n
# Years
# [SentiSynset('old_age.n.01'), SentiSynset('long_time.n.01'), SentiSynset('days.n.01'), SentiSynset('year.n.01'), SentiSynset('year.n.02'), SentiSynset('year.n.03'), SentiSynset('class.n.06')]
# 0.0
# 0.0
# 0.0
# ...
# None
# great
# a
# great
# [SentiSynset('great.s.01'), SentiSynset('great.s.02'), SentiSynset('great.s.03'), SentiSynset('bang-up.s.01'), SentiSynset('capital.s.03'), SentiSynset('big.s.13')]
# 0.0
# 0.0
# 0.0
# book
# n
# book
# [SentiSynset('book.n.01'), SentiSynset('book.n.02'), SentiSynset('record.n.05'), SentiSynset('script.n.01'), SentiSynset('ledger.n.01'), SentiSynset('book.n.06'), SentiSynset('book.n.07'), SentiSynset('koran.n.01'), SentiSynset('bible.n.01'), SentiSynset('book.n.10'), SentiSynset('book.n.11')]
# 0.0
# 0.0
# 0.0
# .
# None
# I
# None
# also
# r
# also
# [SentiSynset('besides.r.02')]
# 0.0
# 0.0
# 0.0
# recommend
# v
# recommend
# [SentiSynset('recommend.v.01'), SentiSynset('commend.v.04'), SentiSynset('recommend.v.03')]
# 0.0
# 0.125
# -0.125
# Warren
# n
# Warren
# [SentiSynset('warren.n.01'), SentiSynset('warren.n.02'), SentiSynset('warren.n.03'), SentiSynset('warren.n.04'), SentiSynset('warren.n.05')]
# 0.125
# 0.0
# 0.0
# Buffet
# n
# Buffet
# [SentiSynset('buffet.n.01'), SentiSynset('buffet.n.02'), SentiSynset('snack_bar.n.01')]
# 0.0
# 0.0
# 0.0
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.0
# ;
# None
# Nelson
# n
# Nelson
# [SentiSynset('nelson.n.01'), SentiSynset('nelson.n.02')]
# 0.0
# 0.0
# 0.0
# Mandela
# n
# Mandela
# [SentiSynset('mandela.n.01')]
# 0.0
# 0.0
# 0.0
# 's
# None
# bio
# n
# bio
# []
# ['I', 'mean', ',', 'I', "'m", 'down', 'with', 'Notre', 'Dame', 'if', 'I', 'have', 'to', '.', 'It', "'s", 'a', 'good', 'school', ',', 'I', "'d", 'be', 'closer', 'to', 'Dan', ',', 'I', "'d", 'enjoy', 'it', '.']
# [('I', 'PRP'), ('mean', 'VBP'), (',', ','), ('I', 'PRP'), ("'m", 'VBP'), ('down', 'RP'), ('with', 'IN'), ('Notre', 'NNP'), ('Dame', 'NNP'), ('if', 'IN'), ('I', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('.', '.'), ('It', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('school', 'NN'), (',', ','), ('I', 'PRP'), ("'d", 'MD'), ('be', 'VB'), ('closer', 'JJR'), ('to', 'TO'), ('Dan', 'NNP'), (',', ','), ('I', 'PRP'), ("'d", 'MD'), ('enjoy', 'VB'), ('it', 'PRP'), ('.', '.')]
# I
# None
# mean
# v
# mean
# [SentiSynset('mean.v.01'), SentiSynset('entail.v.01'), SentiSynset('mean.v.03'), SentiSynset('intend.v.01'), SentiSynset('mean.v.05'), SentiSynset('think_of.v.04'), SentiSynset('mean.v.07')]
# 0.0
# 0.0
# 0.0
# ,
# None
# I
# None
# 'm
# v
# 'm
# []
# down
# r
# down
# [SentiSynset('down.r.01'), SentiSynset('down.r.02'), SentiSynset('down.r.03'), SentiSynset('down.r.04'), SentiSynset('down.r.05'), SentiSynset('down.r.06')]
# 0.0
# 0.125
# -0.125
# with
# None
# Notre
# n
# Notre
# []
# Dame
# n
# Dame
# [SentiSynset('dame.n.01'), SentiSynset('dame.n.02')]
# 0.0
# 0.0
# -0.125
# if
# None
# I
# None
# have
# v
# have
# [SentiSynset('have.v.01'), SentiSynset('have.v.02'), SentiSynset('experience.v.03'), SentiSynset('own.v.01'), SentiSynset('get.v.03'), SentiSynset('consume.v.02'), SentiSynset('have.v.07'), SentiSynset('hold.v.03'), SentiSynset('have.v.09'), SentiSynset('have.v.10'), SentiSynset('have.v.11'), SentiSynset('have.v.12'), SentiSynset('induce.v.02'), SentiSynset('accept.v.02'), SentiSynset('receive.v.01'), SentiSynset('suffer.v.02'), SentiSynset('have.v.17'), SentiSynset('give_birth.v.01'), SentiSynset('take.v.35')]
# 0.25
# 0.0
# 0.125
# to
# None
# .
# None
# It
# None
# 's
# v
# 's
# []
# a
# None
# good
# a
# good
# [SentiSynset('good.a.01'), SentiSynset('full.s.06'), SentiSynset('good.a.03'), SentiSynset('estimable.s.02'), SentiSynset('beneficial.s.01'), SentiSynset('good.s.06'), SentiSynset('good.s.07'), SentiSynset('adept.s.01'), SentiSynset('good.s.09'), SentiSynset('dear.s.02'), SentiSynset('dependable.s.04'), SentiSynset('good.s.12'), SentiSynset('good.s.13'), SentiSynset('effective.s.04'), SentiSynset('good.s.15'), SentiSynset('good.s.16'), SentiSynset('good.s.17'), SentiSynset('good.s.18'), SentiSynset('good.s.19'), SentiSynset('good.s.20'), SentiSynset('good.s.21')]
# 0.75
# 0.0
# 0.875
# school
# n
# school
# [SentiSynset('school.n.01'), SentiSynset('school.n.02'), SentiSynset('school.n.03'), SentiSynset('school.n.04'), SentiSynset('school.n.05'), SentiSynset('school.n.06'), SentiSynset('school.n.07')]
# 0.0
# 0.0
# 0.875
# ,
# None
# I
# None
# 'd
# None
# be
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 1.0
# closer
# a
# close
# [SentiSynset('close.a.01'), SentiSynset('close.a.02'), SentiSynset('near.a.01'), SentiSynset('close.s.04'), SentiSynset('close.s.05'), SentiSynset('close.s.06'), SentiSynset('close.s.07'), SentiSynset('airless.s.01'), SentiSynset('close.s.09'), SentiSynset('close.s.10'), SentiSynset('close.s.11'), SentiSynset('close.s.12'), SentiSynset('close.s.13'), SentiSynset('cheeseparing.s.01'), SentiSynset('close.s.15')]
# 0.0
# 0.0
# 1.0
# to
# None
# Dan
# n
# Dan
# []
# ,
# None
# I
# None
# 'd
# None
# enjoy
# v
# enjoy
# [SentiSynset('enjoy.v.01'), SentiSynset('enjoy.v.02'), SentiSynset('love.v.02'), SentiSynset('enjoy.v.04'), SentiSynset('delight.v.02')]
# 0.375
# 0.0
# 1.375
# it
# None
# .
# None
# ['I', 'ca', "n't", 'watch', 'TV', 'without', 'a', 'Tivo', '.', 'And', 'after', 'all', 'these', 'years', ',', 'the', 'Time/Warner', 'DVR', 'STILL', 'sucks', '.', 'http', ':', '//www.davehitt.com/march03/twdvr.html']
# [('I', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('watch', 'VB'), ('TV', 'NN'), ('without', 'IN'), ('a', 'DT'), ('Tivo', 'NNP'), ('.', '.'), ('And', 'CC'), ('after', 'IN'), ('all', 'PDT'), ('these', 'DT'), ('years', 'NNS'), (',', ','), ('the', 'DT'), ('Time/Warner', 'NNP'), ('DVR', 'NNP'), ('STILL', 'NNP'), ('sucks', 'VBZ'), ('.', '.'), ('http', 'NN'), (':', ':'), ('//www.davehitt.com/march03/twdvr.html', 'NN')]
# I
# None
# ca
# None
# n't
# r
# n't
# []
# watch
# v
# watch
# [SentiSynset('watch.v.01'), SentiSynset('watch.v.02'), SentiSynset('watch.v.03'), SentiSynset('watch.v.04'), SentiSynset('watch.v.05'), SentiSynset('watch.v.06'), SentiSynset('determine.v.08')]
# 0.125
# 0.0
# 0.125
# TV
# n
# TV
# [SentiSynset('television.n.01'), SentiSynset('television_receiver.n.01')]
# 0.0
# 0.0
# 0.125
# without
# None
# a
# None
# Tivo
# n
# Tivo
# []
# .
# None
# And
# None
# after
# None
# all
# None
# these
# None
# years
# n
# year
# [SentiSynset('year.n.01'), SentiSynset('year.n.02'), SentiSynset('year.n.03'), SentiSynset('class.n.06')]
# 0.0
# 0.0
# 0.125
# ,
# None
# the
# None
# Time/Warner
# n
# Time/Warner
# []
# DVR
# n
# DVR
# []
# STILL
# n
# STILL
# [SentiSynset('still.n.01'), SentiSynset('hush.n.01'), SentiSynset('still.n.03'), SentiSynset('distillery.n.01')]
# 0.0
# 0.0
# 0.125
# sucks
# v
# suck
# [SentiSynset('suck.v.01'), SentiSynset('suck.v.02'), SentiSynset('suck.v.03'), SentiSynset('suck.v.04'), SentiSynset('fellate.v.01'), SentiSynset('absorb.v.04'), SentiSynset('breastfeed.v.01')]
# 0.0
# 0.0
# 0.125
# .
# None
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.125
# :
# None
# //www.davehitt.com/march03/twdvr.html
# n
# //www.davehitt.com/march03/twdvr.html
# []
# ['I', "'d", 'say', 'some', 'sports', 'writers', 'are', 'idiots', 'for', 'saying', 'Roger', 'Federer', 'is', 'one', 'of', 'the', 'best', 'ever', 'in', 'Tennis', '.', 'Roger', 'Federer', 'is', 'THE', 'best', 'ever', 'in', 'Tennis']
# [('I', 'PRP'), ("'d", 'MD'), ('say', 'VB'), ('some', 'DT'), ('sports', 'NNS'), ('writers', 'NNS'), ('are', 'VBP'), ('idiots', 'NNS'), ('for', 'IN'), ('saying', 'VBG'), ('Roger', 'NNP'), ('Federer', 'NNP'), ('is', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('ever', 'RB'), ('in', 'IN'), ('Tennis', 'NNP'), ('.', '.'), ('Roger', 'NNP'), ('Federer', 'NNP'), ('is', 'VBZ'), ('THE', 'NNP'), ('best', 'JJS'), ('ever', 'RB'), ('in', 'IN'), ('Tennis', 'NNP')]
# I
# None
# 'd
# None
# say
# v
# say
# [SentiSynset('state.v.01'), SentiSynset('allege.v.01'), SentiSynset('suppose.v.01'), SentiSynset('read.v.02'), SentiSynset('order.v.01'), SentiSynset('pronounce.v.01'), SentiSynset('say.v.07'), SentiSynset('say.v.08'), SentiSynset('say.v.09'), SentiSynset('say.v.10'), SentiSynset('say.v.11')]
# 0.0
# 0.0
# 0.0
# some
# None
# sports
# n
# sport
# [SentiSynset('sport.n.01'), SentiSynset('sport.n.02'), SentiSynset('sport.n.03'), SentiSynset('sport.n.04'), SentiSynset('sport.n.05'), SentiSynset('mutant.n.01'), SentiSynset('fun.n.02')]
# 0.25
# 0.25
# 0.0
# writers
# n
# writer
# [SentiSynset('writer.n.01'), SentiSynset('writer.n.02')]
# 0.0
# 0.0
# 0.0
# are
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.125
# idiots
# n
# idiot
# [SentiSynset('idiot.n.01')]
# 0.0
# 0.125
# 0.0
# for
# None
# saying
# v
# say
# [SentiSynset('state.v.01'), SentiSynset('allege.v.01'), SentiSynset('suppose.v.01'), SentiSynset('read.v.02'), SentiSynset('order.v.01'), SentiSynset('pronounce.v.01'), SentiSynset('say.v.07'), SentiSynset('say.v.08'), SentiSynset('say.v.09'), SentiSynset('say.v.10'), SentiSynset('say.v.11')]
# 0.0
# 0.0
# 0.0
# Roger
# n
# Roger
# []
# Federer
# n
# Federer
# []
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.125
# one
# None
# of
# None
# the
# None
# best
# a
# best
# [SentiSynset('best.a.01'), SentiSynset('better.s.03'), SentiSynset('good.a.01'), SentiSynset('full.s.06'), SentiSynset('good.a.03'), SentiSynset('estimable.s.02'), SentiSynset('beneficial.s.01'), SentiSynset('good.s.06'), SentiSynset('good.s.07'), SentiSynset('adept.s.01'), SentiSynset('good.s.09'), SentiSynset('dear.s.02'), SentiSynset('dependable.s.04'), SentiSynset('good.s.12'), SentiSynset('good.s.13'), SentiSynset('effective.s.04'), SentiSynset('good.s.15'), SentiSynset('good.s.16'), SentiSynset('good.s.17'), SentiSynset('good.s.18'), SentiSynset('good.s.19'), SentiSynset('good.s.20'), SentiSynset('good.s.21')]
# 0.75
# 0.0
# 0.875
# ever
# r
# ever
# [SentiSynset('ever.r.01'), SentiSynset('always.r.01'), SentiSynset('ever.r.03')]
# 0.0
# 0.0
# 0.875
# in
# None
# Tennis
# n
# Tennis
# [SentiSynset('tennis.n.01')]
# 0.0
# 0.0
# 0.875
# .
# None
# Roger
# n
# Roger
# []
# Federer
# n
# Federer
# []
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 1.0
# THE
# n
# THE
# []
# best
# a
# best
# [SentiSynset('best.a.01'), SentiSynset('better.s.03'), SentiSynset('good.a.01'), SentiSynset('full.s.06'), SentiSynset('good.a.03'), SentiSynset('estimable.s.02'), SentiSynset('beneficial.s.01'), SentiSynset('good.s.06'), SentiSynset('good.s.07'), SentiSynset('adept.s.01'), SentiSynset('good.s.09'), SentiSynset('dear.s.02'), SentiSynset('dependable.s.04'), SentiSynset('good.s.12'), SentiSynset('good.s.13'), SentiSynset('effective.s.04'), SentiSynset('good.s.15'), SentiSynset('good.s.16'), SentiSynset('good.s.17'), SentiSynset('good.s.18'), SentiSynset('good.s.19'), SentiSynset('good.s.20'), SentiSynset('good.s.21')]
# 0.75
# 0.0
# 1.75
# ever
# r
# ever
# [SentiSynset('ever.r.01'), SentiSynset('always.r.01'), SentiSynset('ever.r.03')]
# 0.0
# 0.0
# 1.75
# in
# None
# Tennis
# n
# Tennis
# [SentiSynset('tennis.n.01')]
# 0.0
# 0.0
# 1.75
# ['I', 'still', 'love', 'my', 'Kindle2', 'but', 'reading', 'The', 'New', 'York', 'Times', 'on', 'it', 'does', 'not', 'feel', 'natural', '.', 'I', 'miss', 'the', 'Bloomingdale', 'ads', '.']
# [('I', 'PRP'), ('still', 'RB'), ('love', 'VB'), ('my', 'PRP$'), ('Kindle2', 'NNP'), ('but', 'CC'), ('reading', 'VBG'), ('The', 'DT'), ('New', 'NNP'), ('York', 'NNP'), ('Times', 'NNP'), ('on', 'IN'), ('it', 'PRP'), ('does', 'VBZ'), ('not', 'RB'), ('feel', 'VB'), ('natural', 'JJ'), ('.', '.'), ('I', 'PRP'), ('miss', 'VBP'), ('the', 'DT'), ('Bloomingdale', 'NNP'), ('ads', 'NNS'), ('.', '.')]
# I
# None
# still
# r
# still
# [SentiSynset('still.r.01'), SentiSynset('however.r.01'), SentiSynset('even.r.03'), SentiSynset('still.r.04')]
# 0.0
# 0.125
# -0.125
# love
# v
# love
# [SentiSynset('love.v.01'), SentiSynset('love.v.02'), SentiSynset('love.v.03'), SentiSynset('sleep_together.v.01')]
# 0.5
# 0.0
# 0.375
# my
# None
# Kindle2
# n
# Kindle2
# []
# but
# None
# reading
# v
# read
# [SentiSynset('read.v.01'), SentiSynset('read.v.02'), SentiSynset('read.v.03'), SentiSynset('read.v.04'), SentiSynset('read.v.05'), SentiSynset('take.v.06'), SentiSynset('learn.v.04'), SentiSynset('read.v.08'), SentiSynset('read.v.09'), SentiSynset('read.v.10'), SentiSynset('understand.v.03')]
# 0.0
# 0.0
# 0.375
# The
# None
# New
# n
# New
# []
# York
# n
# York
# [SentiSynset('york.n.01')]
# 0.0
# 0.0
# 0.375
# Times
# n
# Times
# [SentiSynset('times.n.01'), SentiSynset('multiplication.n.03'), SentiSynset('time.n.01'), SentiSynset('time.n.02'), SentiSynset('time.n.03'), SentiSynset('time.n.04'), SentiSynset('time.n.05'), SentiSynset('time.n.06'), SentiSynset('clock_time.n.01'), SentiSynset('fourth_dimension.n.01'), SentiSynset('meter.n.04'), SentiSynset('prison_term.n.01')]
# 0.5
# 0.0
# 0.875
# on
# None
# it
# None
# does
# v
# do
# [SentiSynset('make.v.01'), SentiSynset('perform.v.01'), SentiSynset('do.v.03'), SentiSynset('do.v.04'), SentiSynset('cause.v.01'), SentiSynset('practice.v.01'), SentiSynset('suffice.v.01'), SentiSynset('do.v.08'), SentiSynset('act.v.02'), SentiSynset('serve.v.09'), SentiSynset('do.v.11'), SentiSynset('dress.v.16'), SentiSynset('do.v.13')]
# 0.0
# 0.0
# 0.875
# not
# r
# not
# [SentiSynset('not.r.01')]
# 0.0
# 0.625
# 0.25
# feel
# v
# feel
# [SentiSynset('feel.v.01'), SentiSynset('find.v.05'), SentiSynset('feel.v.03'), SentiSynset('feel.v.04'), SentiSynset('feel.v.05'), SentiSynset('feel.v.06'), SentiSynset('feel.v.07'), SentiSynset('feel.v.08'), SentiSynset('feel.v.09'), SentiSynset('palpate.v.01'), SentiSynset('feel.v.11'), SentiSynset('feel.v.12'), SentiSynset('feel.v.13')]
# 0.125
# 0.25
# 0.125
# natural
# a
# natural
# [SentiSynset('natural.a.01'), SentiSynset('natural.a.02'), SentiSynset('natural.a.03'), SentiSynset('natural.s.04'), SentiSynset('natural.a.05'), SentiSynset('natural.s.06'), SentiSynset('natural.s.07'), SentiSynset('natural.s.08'), SentiSynset('natural.s.09'), SentiSynset('lifelike.s.02')]
# 0.25
# 0.0
# 0.375
# .
# None
# I
# None
# miss
# v
# miss
# [SentiSynset('miss.v.01'), SentiSynset('miss.v.02'), SentiSynset('miss.v.03'), SentiSynset('neglect.v.01'), SentiSynset('miss.v.05'), SentiSynset('miss.v.06'), SentiSynset('miss.v.07'), SentiSynset('miss.v.08'), SentiSynset('miss.v.09')]
# 0.0
# 0.25
# 0.125
# the
# None
# Bloomingdale
# n
# Bloomingdale
# []
# ads
# n
# ad
# [SentiSynset('ad.n.01')]
# 0.0
# 0.0
# 0.125
# .
# None
# ['I', 'love', 'my', 'Kindle2', '.', 'No', 'more', 'stacks', 'of', 'books', 'to', 'trip', 'over', 'on', 'the', 'way', 'to', 'the', 'loo', '.']
# [('I', 'PRP'), ('love', 'VBP'), ('my', 'PRP$'), ('Kindle2', 'NNP'), ('.', '.'), ('No', 'NNP'), ('more', 'JJR'), ('stacks', 'NNS'), ('of', 'IN'), ('books', 'NNS'), ('to', 'TO'), ('trip', 'NN'), ('over', 'IN'), ('on', 'IN'), ('the', 'DT'), ('way', 'NN'), ('to', 'TO'), ('the', 'DT'), ('loo', 'NN'), ('.', '.')]
# I
# None
# love
# v
# love
# [SentiSynset('love.v.01'), SentiSynset('love.v.02'), SentiSynset('love.v.03'), SentiSynset('sleep_together.v.01')]
# 0.5
# 0.0
# 0.5
# my
# None
# Kindle2
# n
# Kindle2
# []
# .
# None
# No
# n
# No
# [SentiSynset('no.n.01'), SentiSynset('nobelium.n.01')]
# 0.0
# 0.25
# 0.25
# more
# a
# more
# [SentiSynset('more.a.01'), SentiSynset('more.a.02')]
# 0.0
# 0.0
# 0.25
# stacks
# n
# stack
# [SentiSynset('stack.n.01'), SentiSynset('batch.n.02'), SentiSynset('push-down_list.n.01'), SentiSynset('smokestack.n.01'), SentiSynset('push-down_storage.n.01')]
# 0.0
# 0.125
# 0.125
# of
# None
# books
# n
# book
# [SentiSynset('book.n.01'), SentiSynset('book.n.02'), SentiSynset('record.n.05'), SentiSynset('script.n.01'), SentiSynset('ledger.n.01'), SentiSynset('book.n.06'), SentiSynset('book.n.07'), SentiSynset('koran.n.01'), SentiSynset('bible.n.01'), SentiSynset('book.n.10'), SentiSynset('book.n.11')]
# 0.0
# 0.0
# 0.125
# to
# None
# trip
# n
# trip
# [SentiSynset('trip.n.01'), SentiSynset('trip.n.02'), SentiSynset('slip.n.07'), SentiSynset('trip.n.04'), SentiSynset('tripper.n.04'), SentiSynset('trip.n.06'), SentiSynset('trip.n.07')]
# 0.0
# 0.0
# 0.125
# over
# None
# on
# None
# the
# None
# way
# n
# way
# [SentiSynset('manner.n.01'), SentiSynset('means.n.01'), SentiSynset('direction.n.01'), SentiSynset('way.n.04'), SentiSynset('way.n.05'), SentiSynset('way.n.06'), SentiSynset('way.n.07'), SentiSynset('room.n.02'), SentiSynset('way.n.09'), SentiSynset('way.n.10'), SentiSynset('way.n.11'), SentiSynset('way.n.12')]
# 0.0
# 0.0
# 0.125
# to
# None
# the
# None
# loo
# n
# loo
# [SentiSynset('water_closet.n.01')]
# 0.0
# 0.0
# 0.125
# .
# None
# ['Although', 'today', "'s", 'keynote', 'rocked', ',', 'for', 'every', 'great', 'announcement', ',', 'AT', '&', 'amp', ';', 'T', 'shit', 'on', 'us', 'just', 'a', 'little', 'bit', 'more', '.']
# [('Although', 'IN'), ('today', 'NN'), ("'s", 'POS'), ('keynote', 'NN'), ('rocked', 'VBD'), (',', ','), ('for', 'IN'), ('every', 'DT'), ('great', 'JJ'), ('announcement', 'NN'), (',', ','), ('AT', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('T', 'NNP'), ('shit', 'VBD'), ('on', 'IN'), ('us', 'PRP'), ('just', 'RB'), ('a', 'DT'), ('little', 'JJ'), ('bit', 'NN'), ('more', 'RBR'), ('.', '.')]
# Although
# None
# today
# n
# today
# [SentiSynset('today.n.01'), SentiSynset('today.n.02')]
# 0.125
# 0.0
# 0.125
# 's
# None
# keynote
# n
# keynote
# [SentiSynset('keynote.n.01'), SentiSynset('keynote.n.02'), SentiSynset('tonic.n.03')]
# 0.0
# 0.0
# 0.125
# rocked
# v
# rock
# [SentiSynset('rock.v.01'), SentiSynset('rock.v.02')]
# 0.0
# 0.0
# 0.125
# ,
# None
# for
# None
# every
# None
# great
# a
# great
# [SentiSynset('great.s.01'), SentiSynset('great.s.02'), SentiSynset('great.s.03'), SentiSynset('bang-up.s.01'), SentiSynset('capital.s.03'), SentiSynset('big.s.13')]
# 0.0
# 0.0
# 0.125
# announcement
# n
# announcement
# [SentiSynset('announcement.n.01'), SentiSynset('announcement.n.02')]
# 0.0
# 0.0
# 0.125
# ,
# None
# AT
# n
# AT
# [SentiSynset('astatine.n.01'), SentiSynset('at.n.02')]
# 0.0
# 0.0
# 0.125
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.125
# ;
# None
# T
# n
# T
# [SentiSynset('thymine.n.01'), SentiSynset('deoxythymidine_monophosphate.n.01'), SentiSynset('metric_ton.n.01'), SentiSynset('t.n.04'), SentiSynset('triiodothyronine.n.01'), SentiSynset('thyroxine.n.01')]
# 0.0
# 0.0
# 0.125
# shit
# v
# shit
# [SentiSynset('denounce.v.04'), SentiSynset('stool.v.04')]
# 0.0
# 0.25
# -0.125
# on
# None
# us
# None
# just
# r
# just
# [SentiSynset('merely.r.01'), SentiSynset('precisely.r.01'), SentiSynset('just.r.03'), SentiSynset('just.r.04'), SentiSynset('barely.r.01'), SentiSynset('just.r.06')]
# 0.0
# 0.0
# -0.125
# a
# None
# little
# a
# little
# [SentiSynset('small.a.01'), SentiSynset('little.a.02'), SentiSynset('little.s.03'), SentiSynset('fiddling.s.01'), SentiSynset('little.s.05'), SentiSynset('short.a.03'), SentiSynset('little.s.07'), SentiSynset('little.s.08')]
# 0.0
# 0.375
# -0.5
# bit
# n
# bit
# [SentiSynset('spot.n.10'), SentiSynset('bit.n.02'), SentiSynset('moment.n.02'), SentiSynset('piece.n.05'), SentiSynset('bit.n.05'), SentiSynset('bit.n.06'), SentiSynset('morsel.n.02'), SentiSynset('snatch.n.01'), SentiSynset('act.n.04'), SentiSynset('bit.n.10'), SentiSynset('bit.n.11')]
# 0.0
# 0.125
# -0.625
# more
# r
# more
# [SentiSynset('more.r.01'), SentiSynset('more.r.02')]
# 0.0
# 0.0
# -0.625
# .
# None
# ['@', 'sheridanmarfil', '-', 'its', 'not', 'so', 'much', 'my', 'obsession', 'with', 'cell', 'phones', ',', 'but', 'the', 'iphone', '!', 'i', "'m", 'a', 'slave', 'to', 'at', '&', 'amp', ';', 't', 'forever', 'because', 'of', 'it', '.', ':', ')']
# [('@', 'NN'), ('sheridanmarfil', 'SYM'), ('-', ':'), ('its', 'PRP$'), ('not', 'RB'), ('so', 'RB'), ('much', 'JJ'), ('my', 'PRP$'), ('obsession', 'NN'), ('with', 'IN'), ('cell', 'NN'), ('phones', 'NNS'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('iphone', 'NN'), ('!', '.'), ('i', 'NN'), ("'m", 'VBP'), ('a', 'DT'), ('slave', 'NN'), ('to', 'TO'), ('at', 'IN'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('t', 'CC'), ('forever', 'RB'), ('because', 'IN'), ('of', 'IN'), ('it', 'PRP'), ('.', '.'), (':', ':'), (')', ')')]
# @
# n
# @
# []
# sheridanmarfil
# None
# -
# None
# its
# None
# not
# r
# not
# [SentiSynset('not.r.01')]
# 0.0
# 0.625
# -0.625
# so
# r
# so
# [SentiSynset('so.r.01'), SentiSynset('so.r.02'), SentiSynset('so.r.03'), SentiSynset('so.r.04'), SentiSynset('so.r.05'), SentiSynset('thus.r.02'), SentiSynset('so.r.07'), SentiSynset('then.r.01'), SentiSynset('therefore.r.01'), SentiSynset('indeed.r.01')]
# 0.0
# 0.0
# -0.625
# much
# a
# much
# [SentiSynset('much.a.01')]
# 0.0
# 0.0
# -0.625
# my
# None
# obsession
# n
# obsession
# [SentiSynset('compulsion.n.02'), SentiSynset('obsession.n.02')]
# 0.25
# 0.0
# -0.375
# with
# None
# cell
# n
# cell
# [SentiSynset('cell.n.01'), SentiSynset('cell.n.02'), SentiSynset('cell.n.03'), SentiSynset('cell.n.04'), SentiSynset('cellular_telephone.n.01'), SentiSynset('cell.n.06'), SentiSynset('cell.n.07')]
# 0.0
# 0.0
# -0.375
# phones
# n
# phone
# [SentiSynset('telephone.n.01'), SentiSynset('phone.n.02'), SentiSynset('earphone.n.01')]
# 0.0
# 0.0
# -0.375
# ,
# None
# but
# None
# the
# None
# iphone
# n
# iphone
# []
# !
# None
# i
# n
# i
# [SentiSynset('iodine.n.01'), SentiSynset('one.n.01'), SentiSynset('i.n.03')]
# 0.0
# 0.0
# -0.375
# 'm
# v
# 'm
# []
# a
# None
# slave
# n
# slave
# [SentiSynset('slave.n.01'), SentiSynset('slave.n.02'), SentiSynset('slave.n.03')]
# 0.0
# 0.0
# -0.375
# to
# None
# at
# None
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# -0.375
# ;
# None
# t
# None
# forever
# r
# forever
# [SentiSynset('everlastingly.r.01'), SentiSynset('forever.r.02'), SentiSynset('constantly.r.02')]
# 0.125
# 0.125
# -0.375
# because
# None
# of
# None
# it
# None
# .
# None
# :
# None
# )
# None
# ['@', 'freitasm', 'oh', 'I', 'see', '.', 'I', 'thought', 'AT', '&', 'amp', ';', 'T', 'were', '900MHz', 'WCDMA', '?']
# [('@', 'JJ'), ('freitasm', 'NN'), ('oh', 'NN'), ('I', 'PRP'), ('see', 'VBP'), ('.', '.'), ('I', 'PRP'), ('thought', 'VBD'), ('AT', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('T', 'NNP'), ('were', 'VBD'), ('900MHz', 'CD'), ('WCDMA', 'NNP'), ('?', '.')]
# @
# a
# @
# []
# freitasm
# n
# freitasm
# []
# oh
# n
# oh
# [SentiSynset('ohio.n.01')]
# 0.0
# 0.0
# 0.0
# I
# None
# see
# v
# see
# [SentiSynset('see.v.01'), SentiSynset('understand.v.02'), SentiSynset('witness.v.02'), SentiSynset('visualize.v.01'), SentiSynset('see.v.05'), SentiSynset('learn.v.02'), SentiSynset('watch.v.03'), SentiSynset('meet.v.01'), SentiSynset('determine.v.08'), SentiSynset('see.v.10'), SentiSynset('see.v.11'), SentiSynset('see.v.12'), SentiSynset('visit.v.01'), SentiSynset('attend.v.02'), SentiSynset('see.v.15'), SentiSynset('go_steady.v.01'), SentiSynset('see.v.17'), SentiSynset('see.v.18'), SentiSynset('see.v.19'), SentiSynset('examine.v.02'), SentiSynset('experience.v.01'), SentiSynset('see.v.22'), SentiSynset('see.v.23'), SentiSynset('interpret.v.01')]
# 0.0
# 0.0
# 0.0
# .
# None
# I
# None
# thought
# v
# think
# [SentiSynset('think.v.01'), SentiSynset('think.v.02'), SentiSynset('think.v.03'), SentiSynset('remember.v.01'), SentiSynset('think.v.05'), SentiSynset('think.v.06'), SentiSynset('intend.v.01'), SentiSynset('think.v.08'), SentiSynset('think.v.09'), SentiSynset('think.v.10'), SentiSynset('think.v.11'), SentiSynset('think.v.12'), SentiSynset('think.v.13')]
# 0.0
# 0.0
# 0.0
# AT
# n
# AT
# [SentiSynset('astatine.n.01'), SentiSynset('at.n.02')]
# 0.0
# 0.0
# 0.0
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.0
# ;
# None
# T
# n
# T
# [SentiSynset('thymine.n.01'), SentiSynset('deoxythymidine_monophosphate.n.01'), SentiSynset('metric_ton.n.01'), SentiSynset('t.n.04'), SentiSynset('triiodothyronine.n.01'), SentiSynset('thyroxine.n.01')]
# 0.0
# 0.0
# 0.0
# were
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.125
# 900MHz
# None
# WCDMA
# n
# WCDMA
# []
# ?
# None
# ['@', 'Plip', 'Where', 'did', 'you', 'read', 'about', 'tethering', 'support', 'Phil', '?', 'Just', 'AT', '&', 'amp', ';', 'T', 'or', 'will', 'O2', 'be', 'joining', 'in', '?']
# [('@', 'NN'), ('Plip', 'NNP'), ('Where', 'NNP'), ('did', 'VBD'), ('you', 'PRP'), ('read', 'VB'), ('about', 'IN'), ('tethering', 'VBG'), ('support', 'NN'), ('Phil', 'NNP'), ('?', '.'), ('Just', 'NNP'), ('AT', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('T', 'NNP'), ('or', 'CC'), ('will', 'MD'), ('O2', 'VB'), ('be', 'VB'), ('joining', 'VBG'), ('in', 'IN'), ('?', '.')]
# @
# n
# @
# []
# Plip
# n
# Plip
# []
# Where
# n
# Where
# []
# did
# v
# do
# [SentiSynset('make.v.01'), SentiSynset('perform.v.01'), SentiSynset('do.v.03'), SentiSynset('do.v.04'), SentiSynset('cause.v.01'), SentiSynset('practice.v.01'), SentiSynset('suffice.v.01'), SentiSynset('do.v.08'), SentiSynset('act.v.02'), SentiSynset('serve.v.09'), SentiSynset('do.v.11'), SentiSynset('dress.v.16'), SentiSynset('do.v.13')]
# 0.0
# 0.0
# 0.0
# you
# None
# read
# v
# read
# [SentiSynset('read.v.01'), SentiSynset('read.v.02'), SentiSynset('read.v.03'), SentiSynset('read.v.04'), SentiSynset('read.v.05'), SentiSynset('take.v.06'), SentiSynset('learn.v.04'), SentiSynset('read.v.08'), SentiSynset('read.v.09'), SentiSynset('read.v.10'), SentiSynset('understand.v.03')]
# 0.0
# 0.0
# 0.0
# about
# None
# tethering
# v
# tether
# [SentiSynset('tether.v.01')]
# 0.0
# 0.0
# 0.0
# support
# n
# support
# [SentiSynset('support.n.01'), SentiSynset('support.n.02'), SentiSynset('support.n.03'), SentiSynset('support.n.04'), SentiSynset('documentation.n.03'), SentiSynset('support.n.06'), SentiSynset('support.n.07'), SentiSynset('support.n.08'), SentiSynset('accompaniment.n.02'), SentiSynset('support.n.10'), SentiSynset('support.n.11')]
# 0.0
# 0.0
# 0.0
# Phil
# n
# Phil
# []
# ?
# None
# Just
# n
# Just
# []
# AT
# n
# AT
# [SentiSynset('astatine.n.01'), SentiSynset('at.n.02')]
# 0.0
# 0.0
# 0.0
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.0
# ;
# None
# T
# n
# T
# [SentiSynset('thymine.n.01'), SentiSynset('deoxythymidine_monophosphate.n.01'), SentiSynset('metric_ton.n.01'), SentiSynset('t.n.04'), SentiSynset('triiodothyronine.n.01'), SentiSynset('thyroxine.n.01')]
# 0.0
# 0.0
# 0.0
# or
# None
# will
# None
# O2
# v
# O2
# []
# be
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.125
# joining
# v
# join
# [SentiSynset('join.v.01'), SentiSynset('join.v.02'), SentiSynset('join.v.03'), SentiSynset('join.v.04'), SentiSynset('connect.v.03')]
# 0.0
# 0.0
# 0.125
# in
# None
# ?
# None
# ['Fuzzball', 'is', 'more', 'fun', 'than', 'AT', '&', 'amp', ';', 'T', ';', 'P', 'http', ':', '//fuzz-ball.com/twitter']
# [('Fuzzball', 'NN'), ('is', 'VBZ'), ('more', 'RBR'), ('fun', 'JJ'), ('than', 'IN'), ('AT', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('T', 'NNP'), (';', ':'), ('P', 'NNP'), ('http', 'NN'), (':', ':'), ('//fuzz-ball.com/twitter', 'NN')]
# Fuzzball
# n
# Fuzzball
# []
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.125
# more
# r
# more
# [SentiSynset('more.r.01'), SentiSynset('more.r.02')]
# 0.0
# 0.0
# 0.125
# fun
# a
# fun
# []
# than
# None
# AT
# n
# AT
# [SentiSynset('astatine.n.01'), SentiSynset('at.n.02')]
# 0.0
# 0.0
# 0.125
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.125
# ;
# None
# T
# n
# T
# [SentiSynset('thymine.n.01'), SentiSynset('deoxythymidine_monophosphate.n.01'), SentiSynset('metric_ton.n.01'), SentiSynset('t.n.04'), SentiSynset('triiodothyronine.n.01'), SentiSynset('thyroxine.n.01')]
# 0.0
# 0.0
# 0.125
# ;
# None
# P
# n
# P
# [SentiSynset('phosphorus.n.01'), SentiSynset('p.n.02')]
# 0.0
# 0.0
# 0.125
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.125
# :
# None
# //fuzz-ball.com/twitter
# n
# //fuzz-ball.com/twitter
# []
# ['Today', 'is', 'a', 'good', 'day', 'to', 'dislike', 'AT', '&', 'amp', ';', 'T.', 'Vote', 'out', 'of', 'office', 'indeed', ',', '@', 'danielpunkass']
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('day', 'NN'), ('to', 'TO'), ('dislike', 'VB'), ('AT', 'NNP'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('T.', 'NNP'), ('Vote', 'NNP'), ('out', 'IN'), ('of', 'IN'), ('office', 'NN'), ('indeed', 'RB'), (',', ','), ('@', 'JJ'), ('danielpunkass', 'NN')]
# Today
# n
# Today
# [SentiSynset('today.n.01'), SentiSynset('today.n.02')]
# 0.125
# 0.0
# 0.125
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.25
# a
# None
# good
# a
# good
# [SentiSynset('good.a.01'), SentiSynset('full.s.06'), SentiSynset('good.a.03'), SentiSynset('estimable.s.02'), SentiSynset('beneficial.s.01'), SentiSynset('good.s.06'), SentiSynset('good.s.07'), SentiSynset('adept.s.01'), SentiSynset('good.s.09'), SentiSynset('dear.s.02'), SentiSynset('dependable.s.04'), SentiSynset('good.s.12'), SentiSynset('good.s.13'), SentiSynset('effective.s.04'), SentiSynset('good.s.15'), SentiSynset('good.s.16'), SentiSynset('good.s.17'), SentiSynset('good.s.18'), SentiSynset('good.s.19'), SentiSynset('good.s.20'), SentiSynset('good.s.21')]
# 0.75
# 0.0
# 1.0
# day
# n
# day
# [SentiSynset('day.n.01'), SentiSynset('day.n.02'), SentiSynset('day.n.03'), SentiSynset('day.n.04'), SentiSynset('day.n.05'), SentiSynset('day.n.06'), SentiSynset('day.n.07'), SentiSynset('sidereal_day.n.01'), SentiSynset('day.n.09'), SentiSynset('day.n.10')]
# 0.0
# 0.0
# 1.0
# to
# None
# dislike
# v
# dislike
# [SentiSynset('dislike.v.01')]
# 0.0
# 0.5
# 0.5
# AT
# n
# AT
# [SentiSynset('astatine.n.01'), SentiSynset('at.n.02')]
# 0.0
# 0.0
# 0.5
# &
# None
# amp
# n
# amp
# [SentiSynset('ampere.n.02'), SentiSynset('adenosine_monophosphate.n.01')]
# 0.0
# 0.0
# 0.5
# ;
# None
# T.
# n
# T.
# []
# Vote
# n
# Vote
# [SentiSynset('vote.n.01'), SentiSynset('vote.n.02'), SentiSynset('right_to_vote.n.01'), SentiSynset('vote.n.04'), SentiSynset('vote.n.05')]
# 0.125
# 0.0
# 0.625
# out
# None
# of
# None
# office
# n
# office
# [SentiSynset('office.n.01'), SentiSynset('agency.n.01'), SentiSynset('function.n.03'), SentiSynset('office.n.04'), SentiSynset('office.n.05'), SentiSynset('office.n.06'), SentiSynset('position.n.06')]
# 0.0
# 0.0
# 0.625
# indeed
# r
# indeed
# [SentiSynset('indeed.r.01'), SentiSynset('indeed.r.02')]
# 0.0
# 0.0
# 0.625
# ,
# None
# @
# a
# @
# []
# danielpunkass
# n
# danielpunkass
# []
# ['GOT', 'MY', 'WAVE', 'SANDBOX', 'INVITE', '!', 'Extra', 'excited', '!', 'Too', 'bad', 'I', 'have', 'class', 'now', '...', 'but', 'I', "'ll", 'play', 'with', 'it', 'soon', 'enough', '!', '#', 'io2009', '#', 'wave']
# [('GOT', 'NNP'), ('MY', 'NNP'), ('WAVE', 'NNP'), ('SANDBOX', 'NNP'), ('INVITE', 'NNP'), ('!', '.'), ('Extra', 'NNP'), ('excited', 'VBD'), ('!', '.'), ('Too', 'NNP'), ('bad', 'JJ'), ('I', 'PRP'), ('have', 'VBP'), ('class', 'NN'), ('now', 'RB'), ('...', ':'), ('but', 'CC'), ('I', 'PRP'), ("'ll", 'MD'), ('play', 'VB'), ('with', 'IN'), ('it', 'PRP'), ('soon', 'RB'), ('enough', 'RB'), ('!', '.'), ('#', '#'), ('io2009', 'JJ'), ('#', '#'), ('wave', 'NN')]
# GOT
# n
# GOT
# []
# MY
# n
# MY
# []
# WAVE
# n
# WAVE
# [SentiSynset('wave.n.01'), SentiSynset('wave.n.02'), SentiSynset('wave.n.03'), SentiSynset('wave.n.04'), SentiSynset('wave.n.05'), SentiSynset('wave.n.06'), SentiSynset('wave.n.07'), SentiSynset('wave.n.08'), SentiSynset('wave.n.09')]
# 0.0
# 0.0
# 0.0
# SANDBOX
# n
# SANDBOX
# [SentiSynset('sandbox.n.01'), SentiSynset('sandbox.n.02')]
# 0.0
# 0.0
# 0.0
# INVITE
# n
# INVITE
# [SentiSynset('invite.n.01')]
# 0.0
# 0.0
# 0.0
# !
# None
# Extra
# n
# Extra
# [SentiSynset('supernumerary.n.02'), SentiSynset('extra.n.02'), SentiSynset('extra.n.03')]
# 0.0
# 0.0
# 0.0
# excited
# v
# excite
# [SentiSynset('excite.v.01'), SentiSynset('stimulate.v.01'), SentiSynset('stimulate.v.06'), SentiSynset('agitate.v.02'), SentiSynset('arouse.v.07'), SentiSynset('stimulate.v.03'), SentiSynset('excite.v.07'), SentiSynset('excite.v.08')]
# 0.25
# 0.375
# -0.125
# !
# None
# Too
# n
# Too
# []
# bad
# a
# bad
# [SentiSynset('bad.a.01'), SentiSynset('bad.s.02'), SentiSynset('bad.s.03'), SentiSynset('bad.s.04'), SentiSynset('regretful.a.01'), SentiSynset('bad.s.06'), SentiSynset('bad.s.07'), SentiSynset('bad.s.08'), SentiSynset('bad.s.09'), SentiSynset('bad.s.10'), SentiSynset('bad.s.11'), SentiSynset('bad.s.12'), SentiSynset('bad.s.13'), SentiSynset('bad.s.14')]
# 0.0
# 0.625
# -0.75
# I
# None
# have
# v
# have
# [SentiSynset('have.v.01'), SentiSynset('have.v.02'), SentiSynset('experience.v.03'), SentiSynset('own.v.01'), SentiSynset('get.v.03'), SentiSynset('consume.v.02'), SentiSynset('have.v.07'), SentiSynset('hold.v.03'), SentiSynset('have.v.09'), SentiSynset('have.v.10'), SentiSynset('have.v.11'), SentiSynset('have.v.12'), SentiSynset('induce.v.02'), SentiSynset('accept.v.02'), SentiSynset('receive.v.01'), SentiSynset('suffer.v.02'), SentiSynset('have.v.17'), SentiSynset('give_birth.v.01'), SentiSynset('take.v.35')]
# 0.25
# 0.0
# -0.5
# class
# n
# class
# [SentiSynset('class.n.01'), SentiSynset('class.n.02'), SentiSynset('class.n.03'), SentiSynset('course.n.01'), SentiSynset('class.n.05'), SentiSynset('class.n.06'), SentiSynset('class.n.07'), SentiSynset('class.n.08')]
# 0.0
# 0.0
# -0.5
# now
# r
# now
# [SentiSynset('now.r.01'), SentiSynset('nowadays.r.01'), SentiSynset('now.r.03'), SentiSynset('now.r.04'), SentiSynset('immediately.r.01'), SentiSynset('now.r.06'), SentiSynset('now.r.07')]
# 0.0
# 0.0
# -0.5
# ...
# None
# but
# None
# I
# None
# 'll
# None
# play
# v
# play
# [SentiSynset('play.v.01'), SentiSynset('play.v.02'), SentiSynset('play.v.03'), SentiSynset('act.v.03'), SentiSynset('play.v.05'), SentiSynset('play.v.06'), SentiSynset('play.v.07'), SentiSynset('act.v.05'), SentiSynset('play.v.09'), SentiSynset('play.v.10'), SentiSynset('play.v.11'), SentiSynset('play.v.12'), SentiSynset('play.v.13'), SentiSynset('play.v.14'), SentiSynset('play.v.15'), SentiSynset('play.v.16'), SentiSynset('play.v.17'), SentiSynset('play.v.18'), SentiSynset('toy.v.02'), SentiSynset('play.v.20'), SentiSynset('dally.v.04'), SentiSynset('play.v.22'), SentiSynset('dally.v.01'), SentiSynset('play.v.24'), SentiSynset('act.v.10'), SentiSynset('play.v.26'), SentiSynset('bring.v.03'), SentiSynset('play.v.28'), SentiSynset('play.v.29'), SentiSynset('bet.v.02'), SentiSynset('play.v.31'), SentiSynset('play.v.32'), SentiSynset('play.v.33'), SentiSynset('meet.v.10'), SentiSynset('play.v.35')]
# 0.0
# 0.0
# -0.5
# with
# None
# it
# None
# soon
# r
# soon
# [SentiSynset('soon.r.01')]
# 0.0
# 0.125
# -0.625
# enough
# r
# enough
# [SentiSynset('enough.r.01')]
# 0.125
# 0.0
# -0.5
# !
# None
# #
# None
# io2009
# a
# io2009
# []
# #
# None
# wave
# n
# wave
# [SentiSynset('wave.n.01'), SentiSynset('wave.n.02'), SentiSynset('wave.n.03'), SentiSynset('wave.n.04'), SentiSynset('wave.n.05'), SentiSynset('wave.n.06'), SentiSynset('wave.n.07'), SentiSynset('wave.n.08'), SentiSynset('wave.n.09')]
# 0.0
# 0.0
# -0.5
# ['looks', 'like', 'summize', 'has', 'gone', 'down', '.', 'too', 'many', 'tweets', 'from', 'WWDC', 'perhaps', '?']
# [('looks', 'NNS'), ('like', 'IN'), ('summize', 'NN'), ('has', 'VBZ'), ('gone', 'VBN'), ('down', 'RB'), ('.', '.'), ('too', 'RB'), ('many', 'JJ'), ('tweets', 'NNS'), ('from', 'IN'), ('WWDC', 'NNP'), ('perhaps', 'RB'), ('?', '.')]
# looks
# n
# look
# [SentiSynset('expression.n.01'), SentiSynset('look.n.02'), SentiSynset('look.n.03'), SentiSynset('spirit.n.02')]
# 0.0
# 0.0
# 0.0
# like
# None
# summize
# n
# summize
# []
# has
# v
# have
# [SentiSynset('have.v.01'), SentiSynset('have.v.02'), SentiSynset('experience.v.03'), SentiSynset('own.v.01'), SentiSynset('get.v.03'), SentiSynset('consume.v.02'), SentiSynset('have.v.07'), SentiSynset('hold.v.03'), SentiSynset('have.v.09'), SentiSynset('have.v.10'), SentiSynset('have.v.11'), SentiSynset('have.v.12'), SentiSynset('induce.v.02'), SentiSynset('accept.v.02'), SentiSynset('receive.v.01'), SentiSynset('suffer.v.02'), SentiSynset('have.v.17'), SentiSynset('give_birth.v.01'), SentiSynset('take.v.35')]
# 0.25
# 0.0
# 0.25
# gone
# v
# go
# [SentiSynset('travel.v.01'), SentiSynset('go.v.02'), SentiSynset('go.v.03'), SentiSynset('become.v.01'), SentiSynset('go.v.05'), SentiSynset('run.v.05'), SentiSynset('run.v.03'), SentiSynset('proceed.v.04'), SentiSynset('go.v.09'), SentiSynset('go.v.10'), SentiSynset('sound.v.02'), SentiSynset('function.v.01'), SentiSynset('run_low.v.01'), SentiSynset('move.v.13'), SentiSynset('survive.v.01'), SentiSynset('go.v.16'), SentiSynset('die.v.01'), SentiSynset('belong.v.03'), SentiSynset('go.v.19'), SentiSynset('start.v.09'), SentiSynset('move.v.15'), SentiSynset('go.v.22'), SentiSynset('go.v.23'), SentiSynset('blend.v.02'), SentiSynset('go.v.25'), SentiSynset('fit.v.02'), SentiSynset('rifle.v.02'), SentiSynset('go.v.28'), SentiSynset('plump.v.04'), SentiSynset('fail.v.04')]
# 0.0
# 0.0
# 0.25
# down
# r
# down
# [SentiSynset('down.r.01'), SentiSynset('down.r.02'), SentiSynset('down.r.03'), SentiSynset('down.r.04'), SentiSynset('down.r.05'), SentiSynset('down.r.06')]
# 0.0
# 0.125
# 0.125
# .
# None
# too
# r
# too
# [SentiSynset('excessively.r.01'), SentiSynset('besides.r.02')]
# 0.125
# 0.25
# 0.0
# many
# a
# many
# [SentiSynset('many.a.01')]
# 0.0
# 0.0
# 0.0
# tweets
# n
# tweet
# [SentiSynset('tweet.n.01')]
# 0.0
# 0.0
# 0.0
# from
# None
# WWDC
# n
# WWDC
# []
# perhaps
# r
# perhaps
# [SentiSynset('possibly.r.01')]
# 0.0
# 0.0
# 0.0
# ?
# None
# ['I', 'hope', 'the', 'girl', 'at', 'work', 'buys', 'my', 'Kindle2']
# [('I', 'PRP'), ('hope', 'VBP'), ('the', 'DT'), ('girl', 'NN'), ('at', 'IN'), ('work', 'NN'), ('buys', 'NNS'), ('my', 'PRP$'), ('Kindle2', 'NNP')]
# I
# None
# hope
# v
# hope
# [SentiSynset('hope.v.01'), SentiSynset('hope.v.02'), SentiSynset('hope.v.03')]
# 0.125
# 0.125
# 0.0
# the
# None
# girl
# n
# girl
# [SentiSynset('girl.n.01'), SentiSynset('female_child.n.01'), SentiSynset('daughter.n.01'), SentiSynset('girlfriend.n.02'), SentiSynset('girl.n.05')]
# 0.0
# 0.0
# 0.0
# at
# None
# work
# n
# work
# ...
# and
# None
# loving
# v
# love
# [SentiSynset('love.v.01'), SentiSynset('love.v.02'), SentiSynset('love.v.03'), SentiSynset('sleep_together.v.01')]
# 0.5
# 0.0
# 0.5
# it
# None
# -
# None
# so
# r
# so
# [SentiSynset('so.r.01'), SentiSynset('so.r.02'), SentiSynset('so.r.03'), SentiSynset('so.r.04'), SentiSynset('so.r.05'), SentiSynset('thus.r.02'), SentiSynset('so.r.07'), SentiSynset('then.r.01'), SentiSynset('therefore.r.01'), SentiSynset('indeed.r.01')]
# 0.0
# 0.0
# 0.5
# much
# a
# much
# [SentiSynset('much.a.01')]
# 0.0
# 0.0
# 0.5
# nicer
# n
# nicer
# []
# than
# None
# windows
# n
# window
# [SentiSynset('window.n.01'), SentiSynset('window.n.02'), SentiSynset('window.n.03'), SentiSynset('window.n.04'), SentiSynset('window.n.05'), SentiSynset('windowpane.n.01'), SentiSynset('window.n.07'), SentiSynset('window.n.08')]
# 0.0
# 0.0
# 0.5
# ...
# None
# Looking
# v
# Looking
# [SentiSynset('look.v.01'), SentiSynset('look.v.02'), SentiSynset('look.v.03'), SentiSynset('search.v.02'), SentiSynset('front.v.01'), SentiSynset('attend.v.02'), SentiSynset('look.v.07'), SentiSynset('expect.v.03'), SentiSynset('look.v.09'), SentiSynset('count.v.08')]
# 0.0
# 0.0
# 0.5
# forward
# r
# forward
# [SentiSynset('forward.r.01'), SentiSynset('forth.r.02'), SentiSynset('ahead.r.02'), SentiSynset('ahead.r.03'), SentiSynset('fore.r.01')]
# 0.25
# 0.0
# 0.75
# to
# None
# using
# v
# use
# [SentiSynset('use.v.01'), SentiSynset('use.v.02'), SentiSynset('use.v.03'), SentiSynset('use.v.04'), SentiSynset('practice.v.04'), SentiSynset('use.v.06')]
# 0.0
# 0.0
# 0.75
# the
# None
# wysiwyg
# n
# wysiwyg
# []
# latex
# n
# latex
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# 0.75
# editor
# n
# editor
# [SentiSynset('editor.n.01'), SentiSynset('editor_program.n.01')]
# 0.0
# 0.0
# 0.75
# !
# None
# ['After', 'using', 'LaTeX', 'a', 'lot', ',', 'any', 'other', 'typeset', 'mathematics', 'just', 'looks', 'hideous', '.']
# [('After', 'IN'), ('using', 'VBG'), ('LaTeX', 'NNP'), ('a', 'DT'), ('lot', 'NN'), (',', ','), ('any', 'DT'), ('other', 'JJ'), ('typeset', 'NN'), ('mathematics', 'NNS'), ('just', 'RB'), ('looks', 'VBZ'), ('hideous', 'JJ'), ('.', '.')]
# After
# None
# using
# v
# use
# [SentiSynset('use.v.01'), SentiSynset('use.v.02'), SentiSynset('use.v.03'), SentiSynset('use.v.04'), SentiSynset('practice.v.04'), SentiSynset('use.v.06')]
# 0.0
# 0.0
# 0.0
# LaTeX
# n
# LaTeX
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# 0.0
# a
# None
# lot
# n
# lot
# [SentiSynset('batch.n.02'), SentiSynset('lot.n.02'), SentiSynset('set.n.05'), SentiSynset('fortune.n.04'), SentiSynset('draw.n.04'), SentiSynset('bunch.n.03'), SentiSynset('lot.n.07')]
# 0.0
# 0.0
# 0.0
# ,
# None
# any
# None
# other
# a
# other
# [SentiSynset('other.a.01'), SentiSynset('other.s.02'), SentiSynset('early.s.03'), SentiSynset('other.s.04')]
# 0.0
# 0.625
# -0.625
# typeset
# n
# typeset
# []
# mathematics
# n
# mathematics
# [SentiSynset('mathematics.n.01')]
# 0.0
# 0.0
# -0.625
# just
# r
# just
# [SentiSynset('merely.r.01'), SentiSynset('precisely.r.01'), SentiSynset('just.r.03'), SentiSynset('just.r.04'), SentiSynset('barely.r.01'), SentiSynset('just.r.06')]
# 0.0
# 0.0
# -0.625
# looks
# v
# look
# [SentiSynset('look.v.01'), SentiSynset('look.v.02'), SentiSynset('look.v.03'), SentiSynset('search.v.02'), SentiSynset('front.v.01'), SentiSynset('attend.v.02'), SentiSynset('look.v.07'), SentiSynset('expect.v.03'), SentiSynset('look.v.09'), SentiSynset('count.v.08')]
# 0.0
# 0.0
# -0.625
# hideous
# a
# hideous
# [SentiSynset('hideous.s.01'), SentiSynset('hideous.s.02')]
# 0.0
# 0.875
# -1.5
# .
# None
# ['Ask', 'Programming', ':', 'LaTeX', 'or', 'InDesign', '?', ':', 'submitted', 'by', 'calcio1', '[', 'link', ']', '[', '1', 'comment', ']', 'http', ':', '//tinyurl.com/myfmf7']
# [('Ask', 'NNP'), ('Programming', 'NNP'), (':', ':'), ('LaTeX', 'NNP'), ('or', 'CC'), ('InDesign', 'NNP'), ('?', '.'), (':', ':'), ('submitted', 'VBN'), ('by', 'IN'), ('calcio1', 'NN'), ('[', 'NNP'), ('link', 'NN'), (']', 'NNP'), ('[', 'VBD'), ('1', 'CD'), ('comment', 'NN'), (']', 'NN'), ('http', 'NN'), (':', ':'), ('//tinyurl.com/myfmf7', 'NN')]
# Ask
# n
# Ask
# []
# Programming
# n
# Programming
# [SentiSynset('scheduling.n.01'), SentiSynset('programming.n.02')]
# 0.0
# 0.0
# 0.0
# :
# None
# LaTeX
# n
# LaTeX
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# 0.0
# or
# None
# InDesign
# n
# InDesign
# []
# ?
# None
# :
# None
# submitted
# v
# submit
# [SentiSynset('submit.v.01'), SentiSynset('submit.v.02'), SentiSynset('submit.v.03'), SentiSynset('present.v.04'), SentiSynset('relegate.v.01'), SentiSynset('submit.v.06'), SentiSynset('take.v.19'), SentiSynset('put_in.v.05'), SentiSynset('render.v.06'), SentiSynset('resign.v.04')]
# 0.125
# 0.0
# 0.125
# by
# None
# calcio1
# n
# calcio1
# []
# [
# n
# [
# []
# link
# n
# link
# [SentiSynset('link.n.01'), SentiSynset('link.n.02'), SentiSynset('connection.n.02'), SentiSynset('connection.n.06'), SentiSynset('link.n.05'), SentiSynset('link.n.06'), SentiSynset('liaison.n.02'), SentiSynset('radio_link.n.01'), SentiSynset('link.n.09')]
# 0.0
# 0.0
# 0.125
# ]
# n
# ]
# []
# [
# v
# [
# []
# 1
# None
# comment
# n
# comment
# [SentiSynset('remark.n.01'), SentiSynset('comment.n.02'), SentiSynset('gossip.n.02')]
# 0.0
# 0.0
# 0.125
# ]
# n
# ]
# []
# http
# n
# http
# [SentiSynset('hypertext_transfer_protocol.n.01')]
# 0.0
# 0.0
# 0.125
# :
# None
# //tinyurl.com/myfmf7
# n
# //tinyurl.com/myfmf7
# []
# ['On', 'that', 'note', ',', 'I', 'hate', 'Word', '.', 'I', 'hate', 'Pages', '.', 'I', 'hate', 'LaTeX', '.', 'There', ',', 'I', 'said', 'it', '.', 'I', 'hate', 'LaTeX', '.', 'All', 'you', 'TEXN3RDS', 'can', 'come', 'kill', 'me', 'now', '.']
# [('On', 'IN'), ('that', 'DT'), ('note', 'NN'), (',', ','), ('I', 'PRP'), ('hate', 'VBP'), ('Word', 'NNP'), ('.', '.'), ('I', 'PRP'), ('hate', 'VBP'), ('Pages', 'NNS'), ('.', '.'), ('I', 'PRP'), ('hate', 'VBP'), ('LaTeX', 'NNP'), ('.', '.'), ('There', 'EX'), (',', ','), ('I', 'PRP'), ('said', 'VBD'), ('it', 'PRP'), ('.', '.'), ('I', 'PRP'), ('hate', 'VBP'), ('LaTeX', 'NNP'), ('.', '.'), ('All', 'NNP'), ('you', 'PRP'), ('TEXN3RDS', 'VBP'), ('can', 'MD'), ('come', 'VB'), ('kill', 'VB'), ('me', 'PRP'), ('now', 'RB'), ('.', '.')]
# On
# None
# that
# None
# note
# n
# note
# [SentiSynset('note.n.01'), SentiSynset('note.n.02'), SentiSynset('note.n.03'), SentiSynset('note.n.04'), SentiSynset('note.n.05'), SentiSynset('bill.n.03'), SentiSynset('note.n.07'), SentiSynset('eminence.n.01'), SentiSynset('note.n.09')]
# 0.0
# 0.0
# 0.0
# ,
# None
# I
# None
# hate
# v
# hate
# [SentiSynset('hate.v.01')]
# 0.0
# 0.75
# -0.75
# Word
# n
# Word
# [SentiSynset('word.n.01'), SentiSynset('word.n.02'), SentiSynset('news.n.01'), SentiSynset('word.n.04'), SentiSynset('discussion.n.02'), SentiSynset('parole.n.01'), SentiSynset('word.n.07'), SentiSynset('son.n.02'), SentiSynset('password.n.01'), SentiSynset('bible.n.01')]
# 0.0
# 0.0
# -0.75
# .
# None
# I
# None
# hate
# v
# hate
# [SentiSynset('hate.v.01')]
# 0.0
# 0.75
# -1.5
# Pages
# n
# Pages
# [SentiSynset('page.n.01'), SentiSynset('page.n.02'), SentiSynset('page.n.03'), SentiSynset('page.n.04'), SentiSynset('page.n.05'), SentiSynset('page.n.06')]
# 0.0
# 0.0
# -1.5
# .
# None
# I
# None
# hate
# v
# hate
# [SentiSynset('hate.v.01')]
# 0.0
# 0.75
# -2.25
# LaTeX
# n
# LaTeX
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# -2.25
# .
# None
# There
# None
# ,
# None
# I
# None
# said
# v
# say
# [SentiSynset('state.v.01'), SentiSynset('allege.v.01'), SentiSynset('suppose.v.01'), SentiSynset('read.v.02'), SentiSynset('order.v.01'), SentiSynset('pronounce.v.01'), SentiSynset('say.v.07'), SentiSynset('say.v.08'), SentiSynset('say.v.09'), SentiSynset('say.v.10'), SentiSynset('say.v.11')]
# 0.0
# 0.0
# -2.25
# it
# None
# .
# None
# I
# None
# hate
# v
# hate
# [SentiSynset('hate.v.01')]
# 0.0
# 0.75
# -3.0
# LaTeX
# n
# LaTeX
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# -3.0
# .
# None
# All
# n
# All
# []
# you
# None
# TEXN3RDS
# v
# TEXN3RDS
# []
# can
# None
# come
# v
# come
# [SentiSynset('come.v.01'), SentiSynset('arrive.v.01'), SentiSynset('come.v.03'), SentiSynset('come.v.04'), SentiSynset('come.v.05'), SentiSynset('come.v.06'), SentiSynset('issue_forth.v.01'), SentiSynset('hail.v.02'), SentiSynset('come.v.09'), SentiSynset('come.v.10'), SentiSynset('come.v.11'), SentiSynset('fall.v.04'), SentiSynset('come.v.13'), SentiSynset('total.v.01'), SentiSynset('come.v.15'), SentiSynset('come.v.16'), SentiSynset('occur.v.02'), SentiSynset('derive.v.05'), SentiSynset('do.v.04'), SentiSynset('come.v.20'), SentiSynset('come.v.21')]
# 0.0
# 0.0
# -3.0
# kill
# v
# kill
# [SentiSynset('kill.v.01'), SentiSynset('kill.v.02'), SentiSynset('stamp_out.v.01'), SentiSynset('kill.v.04'), SentiSynset('kill.v.05'), SentiSynset('kill.v.06'), SentiSynset('kill.v.07'), SentiSynset('kill.v.08'), SentiSynset('kill.v.09'), SentiSynset('kill.v.10'), SentiSynset('toss_off.v.02'), SentiSynset('kill.v.12'), SentiSynset('kill.v.13'), SentiSynset('kill.v.14'), SentiSynset('kill.v.15')]
# 0.0
# 0.5
# -3.5
# me
# None
# now
# r
# now
# [SentiSynset('now.r.01'), SentiSynset('nowadays.r.01'), SentiSynset('now.r.03'), SentiSynset('now.r.04'), SentiSynset('immediately.r.01'), SentiSynset('now.r.06'), SentiSynset('now.r.07')]
# 0.0
# 0.0
# -3.5
# .
# None
# ['Ahhh', '...', 'back', 'in', 'a', '*', 'real', '*', 'text', 'editing', 'environment', '.', 'I', '&', 'lt', ';', '3', 'LaTeX', '.']
# [('Ahhh', 'NN'), ('...', ':'), ('back', 'RB'), ('in', 'IN'), ('a', 'DT'), ('*', 'JJ'), ('real', 'JJ'), ('*', 'NN'), ('text', 'NN'), ('editing', 'VBG'), ('environment', 'NN'), ('.', '.'), ('I', 'PRP'), ('&', 'CC'), ('lt', 'VBD'), (';', ':'), ('3', 'CD'), ('LaTeX', 'NNP'), ('.', '.')]
# Ahhh
# n
# Ahhh
# []
# ...
# None
# back
# r
# back
# [SentiSynset('back.r.01'), SentiSynset('back.r.02'), SentiSynset('back.r.03'), SentiSynset('back.r.04'), SentiSynset('back.r.05'), SentiSynset('back.r.06')]
# 0.0
# 0.0
# 0.0
# in
# None
# a
# None
# *
# a
# *
# []
# real
# a
# real
# [SentiSynset('real.a.01'), SentiSynset('real.a.02'), SentiSynset('real.s.03'), SentiSynset('real.s.04'), SentiSynset('actual.s.03'), SentiSynset('real.a.06'), SentiSynset('substantial.a.03'), SentiSynset('real.s.08'), SentiSynset('veridical.s.01')]
# 0.0
# 0.0
# 0.0
# *
# n
# *
# []
# text
# n
# text
# [SentiSynset('text.n.01'), SentiSynset('text.n.02'), SentiSynset('textbook.n.01'), SentiSynset('text.n.04')]
# 0.0
# 0.0
# 0.0
# editing
# v
# edit
# [SentiSynset('edit.v.01'), SentiSynset('edit.v.02'), SentiSynset('edit.v.03'), SentiSynset('edit.v.04')]
# 0.0
# 0.0
# 0.0
# environment
# n
# environment
# [SentiSynset('environment.n.01'), SentiSynset('environment.n.02')]
# 0.0
# 0.0
# 0.0
# .
# None
# I
# None
# &
# None
# lt
# v
# lt
# []
# ;
# None
# 3
# None
# LaTeX
# n
# LaTeX
# [SentiSynset('latex.n.01'), SentiSynset('latex_paint.n.01')]
# 0.0
# 0.0
# 0.0
# .
# None
# ['Trouble', 'in', 'Iran', ',', 'I', 'see', '.', 'Hmm', '.', 'Iran', '.', 'Iran', 'so', 'far', 'away', '.', '#', 'flockofseagullsweregeopoliticallycorrect']
# [('Trouble', 'NN'), ('in', 'IN'), ('Iran', 'NNP'), (',', ','), ('I', 'PRP'), ('see', 'VBP'), ('.', '.'), ('Hmm', 'NNP'), ('.', '.'), ('Iran', 'NNP'), ('.', '.'), ('Iran', 'NNP'), ('so', 'RB'), ('far', 'RB'), ('away', 'RB'), ('.', '.'), ('#', '#'), ('flockofseagullsweregeopoliticallycorrect', 'NN')]
# Trouble
# n
# Trouble
# [SentiSynset('trouble.n.01'), SentiSynset('fuss.n.02'), SentiSynset('trouble.n.03'), SentiSynset('trouble.n.04'), SentiSynset('worry.n.02'), SentiSynset('trouble.n.06')]
# 0.0
# 0.25
# -0.25
# in
# None
# Iran
# n
# Iran
# [SentiSynset('iran.n.01')]
# 0.0
# 0.0
# -0.25
# ,
# None
# I
# None
# see
# v
# see
# [SentiSynset('see.v.01'), SentiSynset('understand.v.02'), SentiSynset('witness.v.02'), SentiSynset('visualize.v.01'), SentiSynset('see.v.05'), SentiSynset('learn.v.02'), SentiSynset('watch.v.03'), SentiSynset('meet.v.01'), SentiSynset('determine.v.08'), SentiSynset('see.v.10'), SentiSynset('see.v.11'), SentiSynset('see.v.12'), SentiSynset('visit.v.01'), SentiSynset('attend.v.02'), SentiSynset('see.v.15'), SentiSynset('go_steady.v.01'), SentiSynset('see.v.17'), SentiSynset('see.v.18'), SentiSynset('see.v.19'), SentiSynset('examine.v.02'), SentiSynset('experience.v.01'), SentiSynset('see.v.22'), SentiSynset('see.v.23'), SentiSynset('interpret.v.01')]
# 0.0
# 0.0
# -0.25
# .
# None
# Hmm
# n
# Hmm
# []
# .
# None
# Iran
# n
# Iran
# [SentiSynset('iran.n.01')]
# 0.0
# 0.0
# -0.25
# .
# None
# Iran
# n
# Iran
# [SentiSynset('iran.n.01')]
# 0.0
# 0.0
# -0.25
# so
# r
# so
# [SentiSynset('so.r.01'), SentiSynset('so.r.02'), SentiSynset('so.r.03'), SentiSynset('so.r.04'), SentiSynset('so.r.05'), SentiSynset('thus.r.02'), SentiSynset('so.r.07'), SentiSynset('then.r.01'), SentiSynset('therefore.r.01'), SentiSynset('indeed.r.01')]
# 0.0
# 0.0
# -0.25
# far
# r
# far
# [SentiSynset('far.r.01'), SentiSynset('far.r.02'), SentiSynset('far.r.03'), SentiSynset('far.r.04'), SentiSynset('far.r.05')]
# 0.0
# 0.0
# -0.25
# away
# r
# away
# [SentiSynset('away.r.01'), SentiSynset('away.r.02'), SentiSynset('aside.r.02'), SentiSynset('away.r.04'), SentiSynset('off.r.02'), SentiSynset('away.r.06'), SentiSynset('away.r.07'), SentiSynset('away.r.08'), SentiSynset('away.r.09'), SentiSynset('away.r.10'), SentiSynset('aside.r.06')]
# 0.0
# 0.0
# -0.25
# .
# None
# #
# None
# flockofseagullsweregeopoliticallycorrect
# n
# flockofseagullsweregeopoliticallycorrect
# []
# ['Reading', 'the', 'tweets', 'coming', 'out', 'of', 'Iran', '...', 'The', 'whole', 'thing', 'is', 'terrifying', 'and', 'incredibly', 'sad', '...']
# [('Reading', 'VBG'), ('the', 'DT'), ('tweets', 'NNS'), ('coming', 'VBG'), ('out', 'IN'), ('of', 'IN'), ('Iran', 'NNP'), ('...', ':'), ('The', 'DT'), ('whole', 'JJ'), ('thing', 'NN'), ('is', 'VBZ'), ('terrifying', 'VBG'), ('and', 'CC'), ('incredibly', 'RB'), ('sad', 'JJ'), ('...', ':')]
# Reading
# v
# Reading
# [SentiSynset('read.v.01'), SentiSynset('read.v.02'), SentiSynset('read.v.03'), SentiSynset('read.v.04'), SentiSynset('read.v.05'), SentiSynset('take.v.06'), SentiSynset('learn.v.04'), SentiSynset('read.v.08'), SentiSynset('read.v.09'), SentiSynset('read.v.10'), SentiSynset('understand.v.03')]
# 0.0
# 0.0
# 0.0
# the
# None
# tweets
# n
# tweet
# [SentiSynset('tweet.n.01')]
# 0.0
# 0.0
# 0.0
# coming
# v
# come
# [SentiSynset('come.v.01'), SentiSynset('arrive.v.01'), SentiSynset('come.v.03'), SentiSynset('come.v.04'), SentiSynset('come.v.05'), SentiSynset('come.v.06'), SentiSynset('issue_forth.v.01'), SentiSynset('hail.v.02'), SentiSynset('come.v.09'), SentiSynset('come.v.10'), SentiSynset('come.v.11'), SentiSynset('fall.v.04'), SentiSynset('come.v.13'), SentiSynset('total.v.01'), SentiSynset('come.v.15'), SentiSynset('come.v.16'), SentiSynset('occur.v.02'), SentiSynset('derive.v.05'), SentiSynset('do.v.04'), SentiSynset('come.v.20'), SentiSynset('come.v.21')]
# 0.0
# 0.0
# 0.0
# out
# None
# of
# None
# Iran
# n
# Iran
# [SentiSynset('iran.n.01')]
# 0.0
# 0.0
# 0.0
# ...
# None
# The
# None
# whole
# a
# whole
# [SentiSynset('whole.a.01'), SentiSynset('whole.a.02'), SentiSynset('unharmed.s.01'), SentiSynset('hale.s.01'), SentiSynset('solid.s.15')]
# 0.125
# 0.0
# 0.125
# thing
# n
# thing
# [SentiSynset('thing.n.01'), SentiSynset('thing.n.02'), SentiSynset('thing.n.03'), SentiSynset('thing.n.04'), SentiSynset('thing.n.05'), SentiSynset('matter.n.01'), SentiSynset('thing.n.07'), SentiSynset('thing.n.08'), SentiSynset('thing.n.09'), SentiSynset('thing.n.10'), SentiSynset('thing.n.11'), SentiSynset('thing.n.12')]
# 0.0
# 0.0
# 0.125
# is
# v
# be
# [SentiSynset('be.v.01'), SentiSynset('be.v.02'), SentiSynset('be.v.03'), SentiSynset('exist.v.01'), SentiSynset('be.v.05'), SentiSynset('equal.v.01'), SentiSynset('constitute.v.01'), SentiSynset('be.v.08'), SentiSynset('embody.v.02'), SentiSynset('be.v.10'), SentiSynset('be.v.11'), SentiSynset('be.v.12'), SentiSynset('cost.v.01')]
# 0.25
# 0.125
# 0.25
# terrifying
# v
# terrify
# [SentiSynset('terrify.v.01')]
# 0.25
# 0.0
# 0.5
# and
# None
# incredibly
# r
# incredibly
# [SentiSynset('incredibly.r.01'), SentiSynset('fabulously.r.01')]
# 0.0
# 0.5
# 0.0
# sad
# a
# sad
# [SentiSynset('sad.a.01'), SentiSynset('sad.s.02'), SentiSynset('deplorable.s.01')]
# 0.125
# 0.75
# -0.625
# ...
# None
#                                             tweet_text polarity_value  \
# 398               @sportsguy33 Time Warner = epic fail       negative
# 162  My wrist still hurts. I have to get it looked ...       positive
# 302  Now I can see why Dave Winer screams about lac...       negative
# 5    @richardebaker no. it is too big. I'm quite ha...       positive
# 13   Watchin Espn..Jus seen this new Nike Commerica...       positive
#
#     sentiwordnet_sum_prediction sentiwordnet_mean_prediction
# 398                     neutral                      neutral
# 162                    negative                      neutral
# 302                    positive                      neutral
# 5                      positive                      neutral
# 13                     positive                      neutral

# %%
from sklearn.metrics import classification_report

# %%
# Mostrar el informe de clasificación para cada uno de los métodos
print("Resultados del primer método de la suma:")
print(classification_report(data['polarity_value'], data['sentiwordnet_sum_prediction']))
print()
print("Resultados del segundo método de la media:")
print(classification_report(data['polarity_value'], data['sentiwordnet_mean_prediction']))
# Out:
# Resultados del primer método de la suma:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.47      0.56       177
#      neutral       0.51      0.37      0.43       139
#     positive       0.50      0.76      0.61       182
#
#     accuracy                           0.55       498
#    macro avg       0.57      0.54      0.53       498
# weighted avg       0.57      0.55      0.54       498
#
#
# Resultados del segundo método de la media:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.01      0.01       177
#      neutral       0.28      1.00      0.44       139
#     positive       1.00      0.01      0.01       182
#
#     accuracy                           0.28       498
#    macro avg       0.76      0.34      0.15       498
# weighted avg       0.80      0.28      0.13       498

# %% [markdown]
# Vamos a añadir algunas reglas heurísticas que tengan en cuenta la negación, intensificadores y atenuadores.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn

# Descargas necesarias
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")
nltk.download("stopwords")

# Inicializador del lematizador
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Lista de palabras de negación
negations = {"not", "no", "never", "n't", "none", "cannot", "doesn't", "don't", "neither", "nor"}

# Diccionario de modificadores de intensidad (incluye intensificadores y atenuadores)
intensity_modifiers = {
    # Intensificadores (factor > 1)
    "very": 1.5,
    "extremely": 1.8,
    "quite": 1.2,
    "really": 1.3,
    "absolutely": 1.8,
    "so": 1.2,
    "highly": 1.4,
    "incredibly": 1.5,
    # Atenuadores (factor < 1)
    "slightly": 0.8,
    "barely": 0.5,
    "hardly": 0.5,
    "somewhat": 0.7,
    "marginally": 0.6,
}

def compute_sentiment_sum(text):
    tokenized_sent = word_tokenize(text)
    pos_tagged_tokens = pos_tag(tokenized_sent)

    sentiment_value = 0.0

    for i, (word, tag) in enumerate(pos_tagged_tokens):
        wn_tag = penn_to_wn(tag)
        if wn_tag is None:
            continue
        lemma = lemmatizer.lemmatize(word, pos=wn_tag)
        if not lemma:
            continue
        swn_synsets = list(swn.senti_synsets(lemma, pos=wn_tag))
        if len(swn_synsets) == 0:
            continue

        pos_score = swn_synsets[0].pos_score()
        neg_score = swn_synsets[0].neg_score()
        word_sentiment = pos_score - neg_score

        # Heurística de Negación: ventana de 5 tokens a la izquierda
        window_start = max(0, i - 5)
        window = pos_tagged_tokens[window_start:i]
        if any(tok[0].lower() in negations for tok in window):
            word_sentiment = -word_sentiment

        # Heurística de Modificadores de Intensidad/Atenuación:
        if i > 0:
            prev_word = pos_tagged_tokens[i-1][0].lower()
            if prev_word in intensity_modifiers:
                word_sentiment *= intensity_modifiers[prev_word]

        sentiment_value += word_sentiment

    if sentiment_value >= 0.05:
        sentiment_label = "positive"
    elif sentiment_value <= -0.05:
        sentiment_label = "negative"
    else:
        sentiment_label = "neutral"

    return sentiment_label

def compute_sentiment_mean(text):
    tokenized_sent = word_tokenize(text)
    pos_tagged_tokens = pos_tag(tokenized_sent)

    pos_score_total = 0.0
    neg_score_total = 0.0
    obj_score_total = 0.0
    synset_count = 0

    for i, (word, tag) in enumerate(pos_tagged_tokens):
        wn_tag = penn_to_wn(tag)
        if wn_tag is None:
            continue
        lemma = lemmatizer.lemmatize(word, pos=wn_tag)
        if not lemma:
            continue
        swn_synsets = list(swn.senti_synsets(lemma, pos=wn_tag))
        if len(swn_synsets) == 0:
            continue

        pos_score = swn_synsets[0].pos_score()
        neg_score = swn_synsets[0].neg_score()
        obj_score = swn_synsets[0].obj_score()

        # Heurística de Negación: ventana de 5 tokens
        window_start = max(0, i - 5)
        window = pos_tagged_tokens[window_start:i]
        if any(tok[0].lower() in negations for tok in window):
            pos_score, neg_score = neg_score, pos_score  # Intercambia para reflejar la inversión

        # Heurística de Modificadores de Intensidad/Atenuación:
        if i > 0:
            prev_word = pos_tagged_tokens[i-1][0].lower()
            if prev_word in intensity_modifiers:
                multiplier = intensity_modifiers[prev_word]
                pos_score *= multiplier
                neg_score *= multiplier
                obj_score *= multiplier

        pos_score_total += pos_score
        neg_score_total += neg_score
        obj_score_total += obj_score
        synset_count += 1

    if synset_count == 0:
        return "neutral"

    pos_score_mean = pos_score_total / synset_count
    neg_score_mean = neg_score_total / synset_count
    obj_score_mean = obj_score_total / synset_count
    max_value = max(pos_score_mean, neg_score_mean, obj_score_mean)
    if max_value == pos_score_mean:
        sentiment_label = "positive"
    elif max_value == neg_score_mean:
        sentiment_label = "negative"
    else:
        sentiment_label = "neutral"

    return sentiment_label

# %%
# Ejemplo de uso:
text_example = "I do not really like this movie. It is not good at all, but it is extremely boring."
print("Sentiment (sum):", compute_sentiment_sum(text_example))
print("Sentiment (mean):", compute_sentiment_mean(text_example))
# Out:
# Sentiment (sum): negative
# Sentiment (mean): neutral

# %%
# Ejecutar las predicciones y obtener nuevas columna con dichas predicciones
data["sentiwordnet_sum_improved_prediction"] = data["tweet_text"].apply(compute_sentiment_sum)
data["sentiwordnet_mean_improved_prediction"] = data["tweet_text"].apply(compute_sentiment_mean)

# Mostrar 5 filas aleatorias del dataset
data.sample(5)
# Out:
#                                             tweet_text polarity_value  \
# 93   just got back from church, and I totally hate ...       negative
# 250  LEbron james got in a car accident i guess..ju...       negative
# 426  Saved money by opting for grocery store trip a...        neutral
# 104  is Twitter's connections API broken? Some twee...       negative
# 134  I saw Night at the Museum: Battle of the Swith...        neutral
#
#     sentiwordnet_sum_prediction sentiwordnet_mean_prediction  \
# 93                     negative                      neutral
# 250                    negative                      neutral
# 426                    positive                      neutral
# 104                     neutral                      neutral
# 134                    positive                      neutral
#
#     sentiwordnet_disambiguation_sum_prediction  \
# 93                                    positive
# 250                                   positive
# 426                                    neutral
# 104                                   positive
# 134                                   positive
#
#     sentiwordnet_disambiguation_mean_prediction  \
# 93                                      neutral
# 250                                     neutral
# 426                                     neutral
# 104                                     neutral
# 134                                     neutral
#
#     sentiwordnet_sum_improved_prediction sentiwordnet_mean_improved_prediction
# 93                              negative                               neutral
# 250                             negative                               neutral
# 426                             positive                               neutral
# 104                              neutral                               neutral
# 134                             positive                               neutral

# %%
# Mostrar el informe de clasificación para cada uno de los métodos
print("Resultados del primer método de la suma:")
print(classification_report(data['polarity_value'], data['sentiwordnet_sum_improved_prediction']))
print()
print("Resultados del segundo método de la media:")
print(classification_report(data['polarity_value'], data['sentiwordnet_mean_improved_prediction']))
# Out:
# Resultados del primer método de la suma:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.53      0.60       177
#      neutral       0.51      0.37      0.43       139
#     positive       0.52      0.75      0.62       182
#
#     accuracy                           0.57       498
#    macro avg       0.57      0.55      0.55       498
# weighted avg       0.58      0.57      0.56       498
#
#
# Resultados del segundo método de la media:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.01      0.01       177
#      neutral       0.28      1.00      0.44       139
#     positive       1.00      0.01      0.01       182
#
#     accuracy                           0.28       498
#    macro avg       0.76      0.34      0.15       498
# weighted avg       0.80      0.28      0.13       498
