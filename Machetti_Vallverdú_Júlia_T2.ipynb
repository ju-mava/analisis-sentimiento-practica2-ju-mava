# %%
#Enfoque basado en modelo de SentiWordNet o SenticNet para español
#Añadiendo reglas heurísticas (negación en ventana de máximo 5 tokens, intensificadores y atenuadores)
#Compara y evalúa cíticamente el rendimiento del modelo sin y con reglas heurísticas (lexicón y lexicón + reglas)
#Para comparar y evaluar, usa un dataset de evaluación: InterTASS, Multilingual Amazon Review sentiment...

# %%
#Análisis_del_sentimiento_y_la_connotación_Aprendizaje_basado_en_el_lexicón
#Apartado "Lexicones de polaridad" utiliza el lexicón de SentiWordNet y añade reglas heurísticas, pero es en inglés
#Cuidado porque en español se hace con Spacy en lugar de con NLTK
#SentiWordNet en español en el apartado "Análisis de sentimiento basado en aspecto", dentro de "Lexicones de polaridad"

# %% [markdown]
# Ahora vamos a usar SentiWordNet en español. Cargaremos el lexicón.

# %%
import csv
import spacy

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from es-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Cargar el modelo de spaCy para español
nlp_es = spacy.load("es_core_news_sm")

# Función para cargar el lexicón de SentiWordNet en español.
def load_spanish_sentiwordnet(filepath):
    """
    Carga el lexicón en español desde un archivo tab-delimitado con las columnas:
    pos, word_en, word_sp, positive, negative, objective, index, synset, meaning.
    Se utiliza la columna 'word_sp' (convertida a minúsculas) como clave.
    Devuelve un diccionario: {word_sp.lower(): (pos_tag, positive, negative, objective)}.
    """
    lexicon = {}
    with open(filepath, encoding="utf-8") as f:
        reader = csv.DictReader(f, delimiter="\t")
        for row in reader:
            word_sp = row["word_sp"].strip().replace('_', ' ')
            if word_sp == "":
                continue
            try:
                pos_tag = row["pos"].strip().lower()
                pos_score = float(row["positive"].replace("+", ""))
                neg_score = float(row["negative"].replace("-", ""))
                obj_score = float(row["objective"])
                synset_code = row["synset"]
            except Exception:
                pos_score, neg_score, obj_score = 0.0, 0.0, 0.0
                pos_tag = ""
                synset_code = ""
            key = word_sp.lower()
            lexicon[key] = (pos_tag, pos_score, neg_score, obj_score, synset_code)
    return lexicon

# %%
# Cargar el lexicón en español desde el mismo cuaderno
# La ruta en la que he colocado el archivo es "/content/sentiwordnet_es.tsv"
es_sentiwordnet = '/content/sentiwordnet_es.tsv'

# %%
# Cargar el lexicón (ajusta la ruta al archivo de SentiWordNet en español)
spanish_sentiwordnet = load_spanish_sentiwordnet(es_sentiwordnet)
spanish_sentiwordnet
# Out:
# {'barrer con': ('v', 0.125, 0.0, 0.875, '01109259'),
#  'ganar': ('v', 0.375, 0.0, 0.625, '02290461'),
#  'abalizar': ('v', 0.125, 0.0, 0.875, '01218512'),
#  'ligarse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'unirse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'seguir': ('v', 0.375, 0.0, 0.625, '00118764'),
#  'raptar': ('v', 0.0, 0.125, 0.875, '01471043'),
#  'cautivar': ('v', 0.125, 0.0, 0.875, '01817314'),
#  'deambular': ('v', 0.125, 0.0, 0.875, '01882081'),
#  'platyhelminthes': ('n', 0.125, 0.0, 0.875, '01924590'),
#  'anomiidae': ('n', 0.125, 0.0, 0.875, '01962223'),
#  'pluvialis': ('n', 0.125, 0.0, 0.875, '02024353'),
#  'género pluvialis': ('n', 0.125, 0.0, 0.875, '02024353'),
#  'kogia': ('n', 0.125, 0.0, 0.875, '02067462'),
#  'considerar': ('v', 0.25, 0.0, 0.75, '02166460'),
#  'vanessa': ('n', 0.125, 0.0, 0.875, '02275921'),
#  'nesokia': ('n', 0.125, 0.0, 0.875, '02334079'),
#  'género nesokia': ('n', 0.125, 0.0, 0.875, '02334079'),
#  'socorrer': ('v', 0.125, 0.0, 0.875, '02548710'),
#  'diaforético': ('a', 0.125, 0.0, 0.875, '02712125'),
#  'vacacionar': ('v', 0.125, 0.0, 0.875, '02708707'),
#  'sudorífico': ('a', 0.125, 0.0, 0.875, '02712125'),
#  'lactogenico': ('a', 0.125, 0.0, 0.875, '02754543'),
#  'casa': ('n', 0.125, 0.0, 0.875, '03195485'),
#  'celda': ('n', 0.125, 0.0, 0.875, '03684740'),
#  'minarete': ('n', 0.125, 0.0, 0.875, '03767745'),
#  'ocasión': ('n', 0.125, 0.0, 0.875, '09179264'),
#  'oportunidad': ('n', 0.125, 0.0, 0.875, '04718826'),
#  'pertinencia': ('n', 0.125, 0.0, 0.875, '04718826'),
#  'inmediatez': ('n', 0.125, 0.0, 0.875, '05708322'),
#  'creencia': ('n', 0.125, 0.0, 0.875, '05941423'),
#  'comic': ('n', 0.125, 0.0, 0.875, '06596364'),
#  'aullido': ('n', 0.0, 0.25, 0.75, '07385548'),
#  'estertor': ('n', 0.125, 0.0, 0.875, '07128060'),
#  'bayat': ('n', 0.125, 0.0, 0.875, '07227055'),
#  'exageración': ('n', 0.125, 0.0, 0.875, '07248507'),
#  'alboroto': ('n', 0.0, 0.625, 0.375, '13977366'),
#  'bombo': ('n', 0.125, 0.0, 0.875, '07248507'),
#  'partidario de la no resistencia': ('n', 0.125, 0.0, 0.875, '10362195'),
#  'satanista': ('n', 0.125, 0.0, 0.875, '10552486'),
#  'sarraceno': ('n', 0.125, 0.0, 0.875, '10552203'),
#  'sorbedor': ('n', 0.125, 0.0, 0.875, '10601362'),
#  'fan': ('n', 0.125, 0.0, 0.875, '10639925'),
#  'solterona': ('n', 0.125, 0.0, 0.875, '10636488'),
#  'reyes': ('n', 0.125, 0.0, 0.875, '11203795'),
#  'neruda': ('n', 0.125, 0.0, 0.875, '11203795'),
#  'poe': ('n', 0.125, 0.0, 0.875, '11240480'),
#  'dylan marlais thomas': ('n', 0.125, 0.0, 0.875, '11339041'),
#  'evento fortuito': ('n', 0.125, 0.0, 0.875, '11463746'),
#  'inconscientemente': ('r', 0.0, 0.375, 0.625, '00237833'),
#  'cariñosamente': ('r', 0.125, 0.0, 0.875, '00229074'),
#  'correctamente': ('r', 0.125, 0.0, 0.875, '00205375'),
#  'en lo más íntimo y profundo': ('r', 0.125, 0.0, 0.875, '00164353'),
#  'es decir': ('r', 0.125, 0.0, 0.875, '00152882'),
#  'metereológicamente': ('r', 0.125, 0.0, 0.875, '00134294'),
#  'liberación': ('n', 0.0, 0.25, 0.75, '07333649'),
#  'atusar': ('v', 0.125, 0.0, 0.875, '00038849'),
#  'a efectos practicos': ('r', 0.125, 0.0, 0.875, '00060300'),
#  'de lejos': ('r', 0.125, 0.0, 0.875, '00047056'),
#  'por derecho': ('r', 0.125, 0.0, 0.875, '00505450'),
#  'adecuadamente': ('r', 0.125, 0.0, 0.875, '00505450'),
#  'mistificar': ('v', 0.125, 0.0, 0.875, '00518653'),
#  'eludir': ('v', 0.125, 0.0, 0.875, '00812149'),
#  'rehuir': ('v', 0.125, 0.0, 0.875, '00812149'),
#  'sobrevivir': ('v', 0.125, 0.0, 0.875, '02619122'),
#  'quedarse más tiempo': ('v', 0.125, 0.0, 0.875, '02619291'),
#  'apalache': ('a', 0.125, 0.0, 0.875, '02635395'),
#  'tardar': ('v', 0.125, 0.0, 0.875, '02640226'),
#  'duplicar': ('v', 0.125, 0.0, 0.875, '02659358'),
#  'hacer un paralelo': ('v', 0.125, 0.0, 0.875, '02659358'),
#  'reflejar': ('v', 0.125, 0.0, 0.875, '02659358'),
#  'behaviorista': ('a', 0.125, 0.0, 0.875, '02660651'),
#  'alargar': ('v', 0.125, 0.0, 0.875, '02705428'),
#  'aplicar': ('v', 0.25, 0.0, 0.75, '02561332'),
#  'colaborar': ('v', 0.0, 0.25, 0.75, '02416751'),
#  'agarrar a correazos': ('v', 0.125, 0.0, 0.875, '01398682'),
#  'dar de varillazos': ('v', 0.125, 0.0, 0.875, '01411978'),
#  'dar un golpe cortante': ('v', 0.125, 0.0, 0.875, '01415454'),
#  'dar un manotazo': ('v', 0.125, 0.0, 0.875, '01417162'),
#  'zanjar': ('v', 0.125, 0.0, 0.875, '01556037'),
#  'peinar': ('v', 0.25, 0.0, 0.75, '00038365'),
#  'familia crocodylidae': ('n', 0.125, 0.0, 0.875, '01696849'),
#  'sobresaltar': ('v', 0.0, 0.125, 0.875, '01821634'),
#  'deleitar': ('v', 0.125, 0.0, 0.875, '01817314'),
#  'pavonearse': ('v', 0.0, 0.5, 0.5, '00883847'),
#  'empujar': ('v', 0.125, 0.0, 0.875, '01872877'),
#  'pasar con rapidez': ('v', 0.125, 0.0, 0.875, '01894520'),
#  'filo platyhelminthes': ('n', 0.125, 0.0, 0.875, '01924590'),
#  'pogonophora': ('n', 0.125, 0.0, 0.875, '01928737'),
#  'ser llevado por el viento': ('v', 0.125, 0.0, 0.875, '01940782'),
#  'bivalvia': ('n', 0.125, 0.0, 0.875, '01955463'),
#  'ojear': ('v', 0.125, 0.0, 0.875, '02167052'),
#  'globo ocular': ('v', 0.125, 0.0, 0.875, '02167052'),
#  'género jaculus': ('n', 0.125, 0.0, 0.875, '02352175'),
#  'jaculus': ('n', 0.125, 0.0, 0.875, '02352175'),
#  'bathyergus': ('n', 0.125, 0.0, 0.875, '02369170'),
#  'añojo': ('n', 0.125, 0.0, 0.875, '02403153'),
#  'favorecer': ('v', 0.125, 0.0, 0.875, '02453692'),
#  'abandonarse a algo': ('v', 0.125, 0.0, 0.875, '02511276'),
#  'antibiótico': ('n', 0.125, 0.0, 0.875, '02716866'),
#  'droga antibiótica': ('n', 0.125, 0.0, 0.875, '02716866'),
#  'pender': ('v', 0.125, 0.0, 0.875, '02717472'),
#  'columpearse': ('v', 0.125, 0.0, 0.875, '02717472'),
#  'ir': ('v', 0.125, 0.0, 0.875, '02724258'),
#  'venir bien': ('v', 0.125, 0.0, 0.875, '02724258'),
#  'escamoso': ('a', 0.125, 0.0, 0.875, '02729182'),
#  'técnico': ('a', 0.125, 0.0, 0.875, '02809220'),
#  'etiológico': ('a', 0.125, 0.0, 0.875, '02940953'),
#  'chesterfield': ('n', 0.125, 0.0, 0.875, '03015149'),
#  'dramático': ('a', 0.125, 0.0, 0.875, '03125227'),
#  'pinzo': ('n', 0.125, 0.0, 0.875, '03162714'),
#  'domiciliación': ('n', 0.125, 0.0, 0.875, '03195485'),
#  'instrumento de lengüeta libre': ('n', 0.125, 0.0, 0.875, '03393324'),
#  'bomba de combustible': ('n', 0.125, 0.0, 0.875, '03425413'),
#  'surtidor de combustible': ('n', 0.125, 0.0, 0.875, '03425413'),
#  'gimnasio': ('n', 0.125, 0.0, 0.875, '03506370'),
#  'hostal de estudiantes': ('n', 0.125, 0.0, 0.875, '03541537'),
#  'arco apuntado': ('n', 0.25, 0.0, 0.75, '03637787'),
#  'puñal': ('n', 0.125, 0.0, 0.875, '03981094'),
#  'ring': ('n', 0.125, 0.0, 0.875, '04092959'),
#  'piso': ('n', 0.125, 0.0, 0.875, '04409384'),
#  'infravivienda': ('n', 0.125, 0.0, 0.875, '04409384'),
#  'hytrin': ('n', 0.125, 0.0, 0.875, '04412550'),
#  'veintidós': ('n', 0.125, 0.0, 0.875, '04502851'),
#  'vancomicina': ('n', 0.125, 0.0, 0.875, '04520618'),
#  'enredo': ('n', 0.125, 0.0, 0.875, '04568557'),
#  'alambrada': ('n', 0.125, 0.0, 0.875, '04595762'),
#  'alambrada metálica': ('n', 0.125, 0.0, 0.875, '04595762'),
#  'permutabilidad': ('n', 0.125, 0.0, 0.875, '04737568'),
#  'transposicionalidad': ('n', 0.125, 0.0, 0.875, '04737568'),
#  'literalidad': ('n', 0.125, 0.0, 0.875, '04760611'),
#  'sensibilidad': ('n', 0.125, 0.0, 0.875, '14531772'),
#  'empatía': ('n', 0.125, 0.0, 0.875, '04842993'),
#  'aplicación al estudio': ('n', 0.125, 0.0, 0.875, '04866365'),
#  'servilismo': ('n', 0.5, 0.0, 0.5, '04906712'),
#  'tipo': ('n', 0.125, 0.0, 0.875, '04998966'),
#  'somatotipo': ('n', 0.125, 0.0, 0.875, '04998966'),
#  'tipo atlético': ('n', 0.125, 0.0, 0.875, '04999306'),
#  'mesomorfo': ('n', 0.125, 0.0, 0.875, '04999306'),
#  'duración del servicio': ('n', 0.125, 0.0, 0.875, '05051734'),
#  'longevidad': ('n', 0.125, 0.0, 0.875, '05051734'),
#  'asertividad': ('n', 0.125, 0.0, 0.875, '05167237'),
#  'eosinófilo': ('n', 0.125, 0.0, 0.875, '05453943'),
#  'volición': ('n', 0.125, 0.0, 0.875, '05652593'),
#  'voluntad': ('n', 0.125, 0.0, 0.875, '05652593'),
#  'disección': ('n', 0.125, 0.0, 0.875, '05782140'),
#  'contemplación': ('n', 0.125, 0.0, 0.875, '00878926'),
#  'consideración': ('n', 0.75, 0.0, 0.25, '06206800'),
#  'conceptualizacion': ('n', 0.125, 0.0, 0.875, '05836275'),
#  'condición esencial': ('n', 0.125, 0.0, 0.875, '05893261'),
#  'sine qua non': ('n', 0.125, 0.0, 0.875, '05893261'),
#  'petición de principio': ('n', 0.125, 0.0, 0.875, '05894814'),
#  'ideal': ('n', 0.125, 0.0, 0.875, '05924519'),
#  'ídolo': ('n', 0.75, 0.0, 0.25, '10441124'),
#  'parangón': ('n', 0.125, 0.0, 0.875, '05924519'),
#  'perfección': ('n', 0.125, 0.0, 0.875, '05924519'),
#  'guía': ('n', 0.125, 0.0, 0.875, '05938976'),
#  'plantilla': ('n', 0.125, 0.0, 0.875, '05938976'),
#  'modelo': ('n', 0.5, 0.0, 0.5, '10324851'),
#  'ignorancia': ('n', 0.125, 0.0, 0.875, '05988743'),
#  'oscurantismo': ('n', 0.125, 0.0, 0.875, '05988743'),
#  'desconocimiento': ('n', 0.125, 0.0, 0.875, '05988743'),
#  'inconsciencia': ('n', 0.125, 0.0, 0.875, '05988743'),
#  'favor': ('n', 0.5, 0.0, 0.5, '05156319'),
#  'reverendo': ('n', 0.125, 0.0, 0.875, '06341773'),
#  'baronazgo': ('n', 0.125, 0.0, 0.875, '06343364'),
#  'versión revisada americana': ('n', 0.125, 0.0, 0.875, '06449477'),
#  'amnistía': ('n', 0.125, 0.0, 0.875, '06552639'),
#  'absurdo': ('n', 0.125, 0.0, 0.875, '06608525'),
#  'majadería': ('n', 0.125, 0.0, 0.875, '06611998'),
#  'chorradas': ('n', 0.25, 0.0, 0.75, '06612266'),
#  'jerigonza': ('n', 0.0, 0.25, 0.75, '06608728'),
#  'baratija': ('n', 0.125, 0.0, 0.875, '06611998'),
#  'diccionario electrónico': ('n', 0.125, 0.0, 0.875, '06639023'),
#  'diccionario leíble por máquina': ('n', 0.125, 0.0, 0.875, '06639023'),
#  'información confidencial': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'aviso': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'ventaja': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'información': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'doctor en educación': ('n', 0.125, 0.0, 0.875, '06703213'),
#  'doctor en salud pública': ('n', 0.125, 0.0, 0.875, '06704366'),
#  'respetos': ('n', 0.125, 0.0, 0.875, '06714552'),
#  'trincheras': ('n', 0.125, 0.0, 0.875, '03195485'),
#  'alojamiento': ('n', 0.125, 0.0, 0.875, '03195485'),
#  'red': ('n', 0.125, 0.0, 0.875, '04568557'),
#  'agerasia': ('n', 0.125, 0.0, 0.875, '04674624'),
#  'esfenión': ('n', 0.125, 0.0, 0.875, '05235350'),
#  'aptitud': ('n', 0.125, 0.0, 0.875, '05622456'),
#  'falta de memoria': ('n', 0.125, 0.0, 0.875, '05673209'),
#  'mente': ('v', 0.375, 0.0, 0.625, '00609506'),
#  'escena dramática': ('n', 0.125, 0.0, 0.875, '05934780'),
#  'vista': ('n', 0.0, 0.25, 0.75, '04674861'),
#  'vítor': ('n', 0.125, 0.0, 0.875, '06692572'),
#  'conminación': ('n', 0.125, 0.0, 0.875, '06733682'),
#  'declaración de principios': ('n', 0.125, 0.0, 0.875, '06739676'),
#  'comentario burlón': ('n', 0.125, 0.0, 0.875, '06767777'),
#  'pulla': ('n', 0.25, 0.0, 0.75, '07153727'),
#  'salida': ('n', 0.0, 0.125, 0.875, '00311809'),
#  'cuchufleta': ('n', 0.125, 0.0, 0.875, '06767777'),
#  'chiste verde': ('n', 0.125, 0.0, 0.875, '06779096'),
#  'interpretación': ('n', 0.125, 0.0, 0.875, '06893565'),
#  'presentación publica': ('n', 0.125, 0.0, 0.875, '06891493'),
#  'anglo': ('n', 0.125, 0.0, 0.875, '06949852'),
#  'juto': ('n', 0.125, 0.0, 0.875, '06949946'),
#  'kéntico': ('n', 0.125, 0.0, 0.875, '06949946'),
#  'tilde': ('n', 0.125, 0.0, 0.875, '07085375'),
#  'énfasis': ('n', 0.125, 0.0, 0.875, '07085375'),
#  'acento': ('n', 0.125, 0.0, 0.875, '07085375'),
#  'rima visual': ('n', 0.125, 0.0, 0.875, '07098093'),
#  'risa sardónica': ('n', 0.125, 0.0, 0.875, '07128060'),
#  'risa disimulada': ('n', 0.125, 0.0, 0.875, '07128225'),
#  'trivialidad': ('n', 0.125, 0.0, 0.875, '07154046'),
#  'lugar común': ('n', 0.125, 0.0, 0.875, '07154046'),
#  'perogrullada': ('n', 0.125, 0.0, 0.875, '07154046'),
#  'desambiguación léxica': ('n', 0.125, 0.0, 0.875, '07171666'),
#  'fanfarronería': ('n', 0.125, 0.0, 0.875, '07229747'),
#  'pavoneo': ('n', 0.125, 0.0, 0.875, '07229747'),
#  'delirio': ('n', 0.125, 0.0, 0.875, '07243193'),
#  'propaganda': ('n', 0.125, 0.0, 0.875, '07248507'),
#  'voto de confianza': ('n', 0.125, 0.0, 0.875, '07253482'),
#  'peripecia': ('n', 0.125, 0.0, 0.875, '07298715'),
#  'procesión': ('n', 0.125, 0.0, 0.875, '07327288'),
#  'origen': ('n', 0.125, 0.0, 0.875, '07327288'),
#  'cambio': ('n', 0.0, 0.125, 0.875, '13388000'),
#  'transformación': ('n', 0.5, 0.0, 0.5, '00399223'),
#  'transmutación': ('n', 0.125, 0.0, 0.875, '07359599'),
#  'aleación': ('n', 0.125, 0.0, 0.875, '07375405'),
#  'carrera': ('n', 0.125, 0.0, 0.875, '07472657'),
#  'victoria inminenta': ('n', 0.125, 0.0, 0.875, '07475762'),
#  'victoria sin mover un dedo': ('n', 0.125, 0.0, 0.875, '07475762'),
#  'mazapán': ('n', 0.125, 0.0, 0.875, '07608245'),
#  'ensalada de col': ('n', 0.125, 0.0, 0.875, '07808587'),
#  'huevo de caramelo': ('n', 0.125, 0.0, 0.875, '07842130'),
#  'saltamontes': ('n', 0.125, 0.0, 0.875, '07915213'),
#  'facultad de antropología': ('n', 0.125, 0.0, 0.875, '08115602'),
#  'facultad de biología': ('n', 0.125, 0.0, 0.875, '08115912'),
#  'facultad de química': ('n', 0.125, 0.0, 0.875, '08116073'),
#  'facultad de ciencias económicas': ('n', 0.125, 0.0, 0.875, '08116398'),
#  'facultad de filología inglesa': ('n', 0.125, 0.0, 0.875, '08116565'),
#  'facultad de historia': ('n', 0.125, 0.0, 0.875, '08116734'),
#  'facultad de lingüística': ('n', 0.125, 0.0, 0.875, '08116879'),
#  'facultad de matemáticas': ('n', 0.125, 0.0, 0.875, '08117052'),
#  'facultad de física': ('n', 0.125, 0.0, 0.875, '08117379'),
#  'facultad de música': ('n', 0.125, 0.0, 0.875, '08117540'),
#  'facultad de psicología': ('n', 0.125, 0.0, 0.875, '08117702'),
#  'facultad de sociología': ('n', 0.125, 0.0, 0.875, '08117872'),
#  'seguridad': ('n', 0.125, 0.0, 0.875, '08120910'),
#  'departamento de seguridad': ('n', 0.125, 0.0, 0.875, '08120910'),
#  'raf (royal air force)': ('n', 0.125, 0.0, 0.875, '08195132'),
#  'royal air force (raf)': ('n', 0.125, 0.0, 0.875, '08195132'),
#  'contingente': ('n', 0.125, 0.0, 0.875, '08404549'),
#  'destacamento': ('n', 0.125, 0.0, 0.875, '08405490'),
#  'posse comitatus': ('n', 0.125, 0.0, 0.875, '08405490'),
#  'archidiócesis': ('n', 0.125, 0.0, 0.875, '08550862'),
#  'necromanía': ('n', 0.125, 0.0, 0.875, '09182650'),
#  'necrofilia': ('n', 0.125, 0.0, 0.875, '09182650'),
#  'supresor': ('n', 0.125, 0.0, 0.875, '09272468'),
#  'lecho de minerales': ('n', 0.125, 0.0, 0.875, '09379868'),
#  'rafael': ('n', 0.125, 0.0, 0.875, '09539640'),
#  'urania': ('n', 0.125, 0.0, 0.875, '09555127'),
#  'freya': ('n', 0.125, 0.0, 0.875, '09580354'),
#  'freyja': ('n', 0.125, 0.0, 0.875, '09580354'),
#  'aspirante': ('n', 0.125, 0.0, 0.875, '09801533'),
#  'candidato': ('n', 0.125, 0.0, 0.875, '09801533'),
#  'imitador barato': ('n', 0.125, 0.0, 0.875, '09801533'),
#  'cestero': ('n', 0.125, 0.0, 0.875, '09842288'),
#  'instructor de bateo': ('n', 0.125, 0.0, 0.875, '09844221'),
#  'esteticista': ('n', 0.5, 0.0, 0.5, '10064831'),
#  'cosmetólogo': ('n', 0.125, 0.0, 0.875, '09845999'),
#  'galán': ('n', 0.125, 0.0, 0.875, '09902256'),
#  'caballero': ('n', 0.125, 0.0, 0.875, '09902256'),
#  'niño cantor': ('n', 0.125, 0.0, 0.875, '09919690'),
#  'demagogo': ('n', 0.125, 0.0, 0.875, '10001481'),
#  'agitador': ('n', 0.125, 0.0, 0.875, '10001481'),
#  'sargento escribiente': ('n', 0.125, 0.0, 0.875, '10008254'),
#  'crítico de teatro': ('n', 0.125, 0.0, 0.875, '10030147'),
#  'majorette': ('n', 0.125, 0.0, 0.875, '10036692'),
#  'borracho': ('n', 0.125, 0.0, 0.875, '10037385'),
#  'ebrio': ('n', 0.125, 0.0, 0.875, '10037385'),
#  'etiólogo': ('n', 0.125, 0.0, 0.875, '10066059'),
#  'niña': ('n', 0.125, 0.0, 0.875, '10084295'),
#  'pequeña': ('n', 0.125, 0.0, 0.875, '10084295'),
#  'esgrimista': ('n', 0.125, 0.0, 0.875, '10085217'),
#  'espadachín': ('n', 0.125, 0.0, 0.875, '10085217'),
#  'tontorrona': ('n', 0.125, 0.0, 0.875, '10096126'),
#  'sobrino nieto': ('n', 0.125, 0.0, 0.875, '10146002'),
#  'transportista': ('n', 0.125, 0.0, 0.875, '10162507'),
#  'equivoquista': ('n', 0.125, 0.0, 0.875, '10493093'),
#  'evasor': ('n', 0.125, 0.0, 0.875, '10168012'),
#  'tergiversador': ('n', 0.125, 0.0, 0.875, '10168012'),
#  'insomne': ('n', 0.125, 0.0, 0.875, '10208748'),
#  'persona sin sueño': ('n', 0.125, 0.0, 0.875, '10208748'),
#  'infiltrado': ('n', 0.0, 0.375, 0.625, '10205714'),
#  'adonis': ('n', 0.25, 0.0, 0.75, '09547629'),
#  'pistolero': ('n', 0.125, 0.0, 0.875, '10294953'),
#  'tirador': ('n', 0.125, 0.0, 0.875, '10294953'),
#  'francotirador': ('n', 0.125, 0.0, 0.875, '10294953'),
#  'monofisita': ('n', 0.125, 0.0, 0.875, '10329251'),
#  'charlatan de feria': ('n', 0.125, 0.0, 0.875, '10334782'),
#  'saltabancos': ('n', 0.125, 0.0, 0.875, '10334782'),
#  'ofertante': ('n', 0.125, 0.0, 0.875, '10371052'),
#  'oferente': ('n', 0.125, 0.0, 0.875, '10371052'),
#  'antigualla': ('n', 0.125, 0.0, 0.875, '10376890'),
#  'carcamal': ('n', 0.125, 0.0, 0.875, '10376890'),
#  'viejo': ('n', 0.125, 0.0, 0.875, '10376890'),
#  'anciano': ('n', 0.125, 0.0, 0.875, '10376890'),
#  'veterano': ('n', 0.125, 0.0, 0.875, '10376890'),
#  'pensionista': ('n', 0.125, 0.0, 0.875, '10414612'),
#  'el que hace mimos': ('n', 0.125, 0.0, 0.875, '10420649'),
#  'bobalicón': ('n', 0.0, 0.25, 0.75, '10358794'),
#  'profesor de equitación': ('n', 0.125, 0.0, 0.875, '10530383'),
#  'gorrón': ('n', 0.125, 0.0, 0.875, '10557699'),
#  'residente temporal': ('n', 0.125, 0.0, 0.875, '10621847'),
#  'papel de confidente o de coqueta': ('n', 0.125, 0.0, 0.875, '10626994'),
#  'prestamista': ('n', 0.125, 0.0, 0.875, '10742384'),
#  'usurero': ('n', 0.125, 0.0, 0.875, '10742384'),
#  'arnoseris ': ('n', 0.125, 0.0, 0.875, '11927616'),
#  'typha': ('n', 0.125, 0.0, 0.875, '12155459'),
#  'liposarcoma': ('n', 0.125, 0.0, 0.875, '14241241'),
#  'medio': ('n', 0.125, 0.0, 0.875, '14513944'),
#  'alrededores': ('n', 0.125, 0.0, 0.875, '14513944'),
#  'butilo': ('n', 0.125, 0.0, 0.875, '15008025'),
#  'reconocido': ('a', 0.125, 0.0, 0.875, '00027247'),
#  'perceptivamente': ('r', 0.125, 0.0, 0.875, '00419876'),
#  'cabriola': ('n', 0.125, 0.0, 0.875, '00512267'),
#  'samba': ('n', 0.125, 0.0, 0.875, '00537192'),
#  'levantar': ('v', 0.0, 0.125, 0.875, '01873666'),
#  'estampar': ('v', 0.125, 0.0, 0.875, '00674517'),
#  'ofrecer': ('v', 0.125, 0.0, 0.875, '00706557'),
#  'charlatanismo': ('n', 0.125, 0.0, 0.875, '00750306'),
#  'charlatanería': ('n', 0.125, 0.0, 0.875, '00750306'),
#  'asir': ('v', 0.375, 0.0, 0.625, '01224653'),
#  'armonizar': ('v', 0.125, 0.0, 0.875, '01707306'),
#  'transportar': ('v', 0.125, 0.0, 0.875, '01817314'),
#  'encantar': ('v', 0.125, 0.0, 0.875, '00777522'),
#  'embelezar': ('v', 0.125, 0.0, 0.875, '01817314'),
#  'caer': ('v', 0.0, 0.375, 0.625, '00342314'),
#  'relativo a la limnología': ('r', 0.125, 0.0, 0.875, '00391476'),
#  'renovación urbana': ('n', 0.125, 0.0, 0.875, '00401194'),
#  'abrazo': ('n', 0.125, 0.0, 0.875, '00417859'),
#  'apretón': ('n', 0.125, 0.0, 0.875, '00417859'),
#  'remitir': ('v', 0.125, 0.0, 0.875, '00421125'),
#  'aflojar': ('v', 0.125, 0.0, 0.875, '00421125'),
#  'manifiesta': ('v', 0.125, 0.0, 0.875, '00423075'),
#  'bajar': ('v', 0.0, 0.5, 0.5, '00204391'),
#  'cortar': ('v', 0.0, 0.125, 0.875, '00226071'),
#  'recortar': ('v', 0.0, 0.125, 0.875, '02404076'),
#  'reducir': ('v', 0.0, 0.125, 0.875, '00226071'),
#  'rebajar': ('v', 0.125, 0.0, 0.875, '00429060'),
#  'combate cuerpo a cuerpo': ('n', 0.125, 0.0, 0.875, '00446411'),
#  'distante': ('a', 0.125, 0.0, 0.875, '00450606'),
#  'remota': ('a', 0.125, 0.0, 0.875, '00450606'),
#  'sociológicamente': ('r', 0.125, 0.0, 0.875, '00460747'),
#  'pulimentar': ('v', 0.125, 0.0, 0.875, '00474017'),
#  'pulir': ('v', 0.125, 0.0, 0.875, '01246095'),
#  'refinar': ('v', 0.125, 0.0, 0.875, '01262813'),
#  'descontaminar': ('v', 0.125, 0.0, 0.875, '00493052'),
#  'brinco': ('n', 0.125, 0.0, 0.875, '00512267'),
#  'cognitivamente': ('r', 0.125, 0.0, 0.875, '00512992'),
#  'taxonómicamente': ('r', 0.125, 0.0, 0.875, '00516034'),
#  'animar': ('v', 0.375, 0.0, 0.625, '00193130'),
#  'bajar la fiebre': ('v', 0.125, 0.0, 0.875, '00571901'),
#  'paternidad': ('n', 0.125, 0.0, 0.875, '00592367'),
#  'mariscalía': ('n', 0.125, 0.0, 0.875, '00595032'),
#  'investigación': ('n', 0.125, 0.0, 0.875, '00633864'),
#  'razonar por silogismos': ('v', 0.125, 0.0, 0.875, '00653449'),
#  'eliminar': ('v', 0.0, 0.625, 0.375, '02482425'),
#  'rechazar': ('v', 0.0, 0.75, 0.25, '00824767'),
#  'descartar': ('v', 0.125, 0.0, 0.875, '00685419'),
#  'evitar': ('v', 0.0, 0.75, 0.25, '00811171'),
#  'pedir': ('v', 0.125, 0.0, 0.875, '00758887'),
#  'magnetizar': ('v', 0.125, 0.0, 0.875, '00777522'),
#  'fascinar': ('v', 0.375, 0.0, 0.625, '01770252'),
#  'hipnotizar': ('v', 0.125, 0.0, 0.875, '00777522'),
#  'embrujar': ('v', 0.125, 0.0, 0.875, '00777522'),
#  'abordar': ('v', 0.125, 0.0, 0.875, '00781652'),
#  'enganchar': ('v', 0.0, 0.125, 0.875, '02276866'),
#  'ofrecer sexo': ('v', 0.125, 0.0, 0.875, '00781652'),
#  'aventura': ('n', 0.25, 0.0, 0.75, '00796315'),
#  'desdecirse': ('v', 0.125, 0.0, 0.875, '00800242'),
#  'renegar': ('v', 0.0, 0.5, 0.5, '00910973'),
#  'abogar': ('v', 0.125, 0.0, 0.875, '00827730'),
#  'apoyar': ('v', 0.125, 0.0, 0.875, '00827730'),
#  'informar': ('v', 0.125, 0.0, 0.875, '00831074'),
#  'timar': ('v', 0.0, 0.125, 0.875, '02572119'),
#  'encandilar': ('v', 0.125, 0.0, 0.875, '00854904'),
#  'confundir': ('v', 0.0, 0.375, 0.625, '00620532'),
#  'onanismo': ('n', 0.125, 0.0, 0.875, '00855674'),
#  'avanzar': ('v', 0.125, 0.0, 0.875, '00875806'),
#  'proponer': ('v', 0.375, 0.0, 0.625, '00879540'),
#  'presentar': ('v', 0.125, 0.0, 0.875, '00878636'),
#  'recordar': ('v', 0.125, 0.0, 0.875, '00882802'),
#  'complacer': ('v', 0.125, 0.0, 0.875, '00885925'),
#  'enseñanza de la lectura': ('n', 0.125, 0.0, 0.875, '00888284'),
#  'dramatización': ('n', 0.125, 0.0, 0.875, '00899292'),
#  'aclamar': ('v', 0.375, 0.0, 0.625, '00861725'),
#  'anunciar': ('v', 0.125, 0.0, 0.875, '00900376'),
#  'dar a entender': ('v', 0.125, 0.0, 0.875, '00927711'),
#  'abigeato': ('n', 0.125, 0.0, 0.875, '00966504'),
#  'documentar': ('v', 0.125, 0.0, 0.875, '01002297'),
#  'prueba de inteligencia': ('n', 0.125, 0.0, 0.875, '01007053'),
#  'prueba de ci': ('n', 0.125, 0.0, 0.875, '01007053'),
#  'randomización': ('n', 0.125, 0.0, 0.875, '01009001'),
#  'pronunciar con sibilante': ('v', 0.125, 0.0, 0.875, '01055404'),
#  'desencantar': ('v', 0.125, 0.0, 0.875, '01064696'),
#  'demoler': ('v', 0.125, 0.0, 0.875, '01083373'),
#  'defenderse': ('v', 0.125, 0.0, 0.875, '01091427'),
#  'luchar': ('v', 0.0, 0.25, 0.75, '01092366'),
#  'enfrentarse': ('v', 0.0, 0.125, 0.875, '01079172'),
#  'derrotar': ('v', 0.125, 0.0, 0.875, '01101913'),
#  'oponerse': ('v', 0.125, 0.0, 0.875, '01091427'),
#  'vencer': ('v', 0.125, 0.0, 0.875, '01109259'),
#  'aplastar': ('v', 0.0, 0.125, 0.875, '00478682'),
#  'bombardear': ('v', 0.125, 0.0, 0.875, '01101913'),
#  'dar una paliza': ('v', 0.0, 0.75, 0.25, '00824767'),
#  'derrotar con trampas': ('v', 0.125, 0.0, 0.875, '01109259'),
#  'desobediencia': ('n', 0.125, 0.0, 0.875, '01179707'),
#  'reflotar': ('v', 0.125, 0.0, 0.875, '01218512'),
#  'buena acción': ('n', 0.125, 0.0, 0.875, '01227083'),
#  'empapar': ('v', 0.375, 0.0, 0.625, '00602255'),
#  'abrillantar': ('v', 0.125, 0.0, 0.875, '01246095'),
#  'bruñir': ('v', 0.125, 0.0, 0.875, '01246095'),
#  'adherirse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'asociarse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'pegarse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'incorporarse': ('v', 0.125, 0.0, 0.875, '01356750'),
#  'familia nitrobacteriaceae': ('n', 0.125, 0.0, 0.875, '01361973'),
#  'excepcionalmente': ('r', 0.125, 0.0, 0.875, '00484801'),
#  'buck and wing': ('n', 0.125, 0.0, 0.875, '00528298'),
#  'geotropismo': ('n', 0.125, 0.0, 0.875, '00861990'),
#  'misa mayor': ('n', 0.125, 0.0, 0.875, '01042465'),
#  'derrotar completamente': ('v', 0.125, 0.0, 0.875, '01103180'),
#  'aventajar': ('v', 0.125, 0.0, 0.875, '01109644'),
#  'avituallar': ('v', 0.125, 0.0, 0.875, '01167188'),
#  'aferrar': ('v', 0.125, 0.0, 0.875, '01216004'),
#  'envolver para regalo': ('v', 0.125, 0.0, 0.875, '01284160'),
#  'chlamydia trachomatis': ('n', 0.125, 0.0, 0.875, '01373090'),
#  'clase euglenophyceae': ('n', 0.125, 0.0, 0.875, '01406262'),
#  'euglenophyceae': ('n', 0.125, 0.0, 0.875, '01406262'),
#  'abofetear': ('v', 0.125, 0.0, 0.875, '01417162'),
#  'acnidosporidia': ('n', 0.125, 0.0, 0.875, '01425817'),
#  'género acnidosporidia': ('n', 0.125, 0.0, 0.875, '01425817'),
#  'chasquear': ('v', 0.0, 0.625, 0.375, '02575723'),
#  'arrebatar': ('v', 0.125, 0.0, 0.875, '01439745'),
#  'agarrar por la fuerza': ('v', 0.125, 0.0, 0.875, '01439745'),
#  'sardina hocido de puerco': ('n', 0.125, 0.0, 0.875, '01445857'),
#  'hypentelium nigricans': ('n', 0.125, 0.0, 0.875, '01445857'),
#  'orden zeomorphi': ('n', 0.125, 0.0, 0.875, '01452496'),
#  'zeomorphi': ('n', 0.125, 0.0, 0.875, '01452496'),
#  'lubricar': ('v', 0.125, 0.0, 0.875, '01484982'),
#  'enterrar': ('v', 0.125, 0.0, 0.875, '01530098'),
#  'hundir': ('v', 0.125, 0.0, 0.875, '01530098'),
#  'limpiar': ('v', 0.125, 0.0, 0.875, '01533442'),
#  'limpiar la corrupción': ('v', 0.125, 0.0, 0.875, '01533442'),
#  'empuñar': ('v', 0.125, 0.0, 0.875, '01572978'),
#  'sacar': ('v', 0.0, 0.125, 0.875, '01873294'),
#  'jalar': ('v', 0.125, 0.0, 0.875, '01592456'),
#  'pelliscar': ('v', 0.125, 0.0, 0.875, '01592456'),
#  'invitar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'conjurar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'evocar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'exponer': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'invocar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'crocodylidae': ('n', 0.125, 0.0, 0.875, '01696849'),
#  'captar': ('v', 0.125, 0.0, 0.875, '01738107'),
#  'lograr': ('v', 0.125, 0.0, 0.875, '01738107'),
#  'bothrops': ('n', 0.125, 0.0, 0.875, '01758019'),
#  'género bothrops': ('n', 0.125, 0.0, 0.875, '01758019'),
#  'orden scorpionida': ('n', 0.125, 0.0, 0.875, '01770263'),
#  'scorpionida': ('n', 0.125, 0.0, 0.875, '01770263'),
#  'congraciarse': ('v', 0.125, 0.0, 0.875, '01804595'),
#  'avivar': ('v', 0.125, 0.0, 0.875, '00192836'),
#  'exaltar': ('v', 0.75, 0.0, 0.25, '00860620'),
#  'inspirar': ('v', 0.375, 0.0, 0.625, '00193130'),
#  'revigorizar': ('v', 0.125, 0.0, 0.875, '01812720'),
#  'temblar': ('v', 0.0, 0.125, 0.875, '00014034'),
#  'erinaceidae': ('n', 0.125, 0.0, 0.875, '01893535'),
#  'familia erinaceidae': ('n', 0.125, 0.0, 0.875, '01893535'),
#  'cestoda': ('n', 0.125, 0.0, 0.875, '01927301'),
#  'clase cestoda': ('n', 0.125, 0.0, 0.875, '01927301'),
#  'filo pogonophora': ('n', 0.125, 0.0, 0.875, '01928737'),
#  'clase lamellibranchia': ('n', 0.125, 0.0, 0.875, '01955463'),
#  'myaceae': ('n', 0.125, 0.0, 0.875, '01956924'),
#  'orden myaceae': ('n', 0.125, 0.0, 0.875, '01956924'),
#  'familia anomiidae': ('n', 0.125, 0.0, 0.875, '01962223'),
#  'familia pectinidae': ('n', 0.125, 0.0, 0.875, '01965747'),
#  'pectinidae': ('n', 0.125, 0.0, 0.875, '01965747'),
#  'octopoda': ('n', 0.125, 0.0, 0.875, '01969550'),
#  'orden octopoda': ('n', 0.125, 0.0, 0.875, '01969550'),
#  'familia sepiidae': ('n', 0.125, 0.0, 0.875, '01972283'),
#  'entrar': ('v', 0.125, 0.0, 0.875, '02015384'),
#  'ingresar': ('v', 0.125, 0.0, 0.875, '02015384'),
#  'hacer su llegada': ('v', 0.125, 0.0, 0.875, '02015384'),
#  'arribar': ('v', 0.125, 0.0, 0.875, '02015384'),
#  'género pedionomus': ('n', 0.125, 0.0, 0.875, '02020450'),
#  'pedionomus': ('n', 0.125, 0.0, 0.875, '02020450'),
#  'género phalaropus': ('n', 0.125, 0.0, 0.875, '02037713'),
#  'phalaropus': ('n', 0.125, 0.0, 0.875, '02037713'),
#  'en condiciones de vuelo': ('a', 0.125, 0.0, 0.875, '02088198'),
#  'embrutecerse': ('v', 0.125, 0.0, 0.875, '02115618'),
#  'idiotizarse': ('v', 0.125, 0.0, 0.875, '02115618'),
#  'tocar': ('v', 0.0, 0.125, 0.875, '01207527'),
#  'hacer justicia': ('v', 0.125, 0.0, 0.875, '02138453'),
#  'rrhinolophidae': ('n', 0.125, 0.0, 0.875, '02143293'),
#  'titilar': ('v', 0.0, 0.25, 0.75, '02763609'),
#  'chrysomelidae': ('n', 0.125, 0.0, 0.875, '02169345'),
#  'familia chrysomelidae': ('n', 0.125, 0.0, 0.875, '02169345'),
#  'adquirir': ('v', 0.125, 0.0, 0.875, '02210855'),
#  'obtener': ('v', 0.125, 0.0, 0.875, '02210855'),
#  'género megachile': ('n', 0.125, 0.0, 0.875, '02211283'),
#  'megachile': ('n', 0.125, 0.0, 0.875, '02211283'),
#  'fenusa': ('n', 0.125, 0.0, 0.875, '02218912'),
#  'género  fenusa': ('n', 0.125, 0.0, 0.875, '02218912'),
#  'familia phillidae': ('n', 0.125, 0.0, 0.875, '02231930'),
#  'familia phyllidae': ('n', 0.125, 0.0, 0.875, '02231930'),
#  'phillidae': ('n', 0.125, 0.0, 0.875, '02231930'),
#  'phyllidae': ('n', 0.125, 0.0, 0.875, '02231930'),
#  'género leptoglossus': ('n', 0.125, 0.0, 0.875, '02239934'),
#  'leptoglossus': ('n', 0.125, 0.0, 0.875, '02239934'),
#  'liquidar': ('v', 0.125, 0.0, 0.875, '02256589'),
#  'arrojar': ('v', 0.0, 0.25, 0.75, '01507407'),
#  'desperdiciar': ('v', 0.125, 0.0, 0.875, '02268351'),
#  'malgastar': ('v', 0.125, 0.0, 0.875, '02268351'),
#  'género vanessa': ('n', 0.125, 0.0, 0.875, '02275921'),
#  'familia tortricidae': ('n', 0.125, 0.0, 0.875, '02283728'),
#  'tortricidae': ('n', 0.125, 0.0, 0.875, '02283728'),
#  'superfamilia tineoidea': ('n', 0.125, 0.0, 0.875, '02291024'),
#  'tineoidea': ('n', 0.125, 0.0, 0.875, '02291024'),
#  'género hydromys': ('n', 0.125, 0.0, 0.875, '02335007'),
#  'hydromys': ('n', 0.125, 0.0, 0.875, '02335007'),
#  'florecer': ('v', 0.125, 0.0, 0.875, '02342800'),
#  'fly high': ('v', 0.125, 0.0, 0.875, '02342800'),
#  'prosperar': ('v', 0.125, 0.0, 0.875, '02342800'),
#  'proliferar': ('v', 0.125, 0.0, 0.875, '02342800'),
#  'dipodomys': ('n', 0.125, 0.0, 0.875, '02349980'),
#  'género dipodomys': ('n', 0.125, 0.0, 0.875, '02349980'),
#  'sanitizar': ('v', 0.125, 0.0, 0.875, '02361981'),
#  'cordero persa': ('n', 0.125, 0.0, 0.875, '02412977'),
#  'anthropoidea': ('n', 0.125, 0.0, 0.875, '02470451'),
#  'poner el pan sobre la mesa': ('v', 0.125, 0.0, 0.875, '02524171'),
#  'salir adelante': ('v', 0.125, 0.0, 0.875, '02524171'),
#  'cortejar': ('v', 0.125, 0.0, 0.875, '02534936'),
#  'teñir': ('v', 0.375, 0.0, 0.625, '00283584'),
#  'incentivar': ('v', 0.25, 0.0, 0.75, '01818235'),
#  'completar': ('v', 0.375, 0.0, 0.625, '01117484'),
#  'despachar': ('v', 0.0, 0.625, 0.375, '02482425'),
#  'engañar': ('v', 0.0, 0.625, 0.375, '02575723'),
#  'entrante': ('a', 0.125, 0.0, 0.875, '02592015'),
#  'tallista': ('n', 0.125, 0.0, 0.875, '10789963'),
#  'tallista en madera': ('n', 0.125, 0.0, 0.875, '10789963'),
#  'aleksandr aleksandrovich blok': ('n', 0.125, 0.0, 0.875, '10853628'),
#  'blok': ('n', 0.125, 0.0, 0.875, '10853628'),
#  'john anthony ciardi': ('n', 0.125, 0.0, 0.875, '10897796'),
#  'john ciardi': ('n', 0.125, 0.0, 0.875, '10897796'),
#  'donatello': ('n', 0.125, 0.0, 0.875, '10939040'),
#  'donato di betto bardi': ('n', 0.125, 0.0, 0.875, '10939040'),
#  'jorge': ('n', 0.125, 0.0, 0.875, '10995115'),
#  'jorge ii': ('n', 0.125, 0.0, 0.875, '10995115'),
#  'john keats': ('n', 0.125, 0.0, 0.875, '11098601'),
#  'keats': ('n', 0.125, 0.0, 0.875, '11098601'),
#  'franz liszt': ('n', 0.125, 0.0, 0.875, '11135236'),
#  'liszt': ('n', 0.125, 0.0, 0.875, '11135236'),
#  'neftalí ricardo reyes': ('n', 0.125, 0.0, 0.875, '11203795'),
#  'pablo neruda': ('n', 0.125, 0.0, 0.875, '11203795'),
#  'plath': ('n', 0.125, 0.0, 0.875, '11239143'),
#  'edgar allan poe': ('n', 0.125, 0.0, 0.875, '11240480'),
#  'aleksandr sergeyevich pushkin': ('n', 0.125, 0.0, 0.875, '11249191'),
#  'alexander pushkin': ('n', 0.125, 0.0, 0.875, '11249191'),
#  'pushkin': ('n', 0.125, 0.0, 0.875, '11249191'),
#  'percy bysshe shelley': ('n', 0.125, 0.0, 0.875, '11296914'),
#  'shelley': ('n', 0.125, 0.0, 0.875, '11296914'),
#  'adam smith': ('n', 0.125, 0.0, 0.875, '11305258'),
#  'smith': ('n', 0.125, 0.0, 0.875, '11305258'),
#  'john orley allen tate': ('n', 0.125, 0.0, 0.875, '11332423'),
#  'deems taylor': ('n', 0.125, 0.0, 0.875, '11333601'),
#  'taylor': ('n', 0.125, 0.0, 0.875, '11333601'),
#  'aldred tennyson': ('n', 0.125, 0.0, 0.875, '11335330'),
#  'dylan thomas': ('n', 0.125, 0.0, 0.875, '11339041'),
#  'thomas': ('n', 0.125, 0.0, 0.875, '11339041'),
#  'buena fortuna': ('n', 0.125, 0.0, 0.875, '11463746'),
#  'buena suerte': ('n', 0.125, 0.0, 0.875, '11463746'),
#  'pino contorta sierra': ('n', 0.125, 0.0, 0.875, '11615259'),
#  'canelero de china': ('n', 0.125, 0.0, 0.875, '11705171'),
#  'cinnamomum cassia': ('n', 0.125, 0.0, 0.875, '11705171'),
#  'corteza de cassia': ('n', 0.125, 0.0, 0.875, '11705387'),
#  'canela china': ('n', 0.125, 0.0, 0.875, '11705387'),
#  'banalidad': ('n', 0.125, 0.0, 0.875, '07154046'),
#  'cliché': ('n', 0.125, 0.0, 0.875, '07154046'),
#  'golpe teatral': ('n', 0.125, 0.0, 0.875, '07298543'),
#  'vianda': ('n', 0.125, 0.0, 0.875, '07593471'),
#  'zampada': ('n', 0.125, 0.0, 0.875, '07884182'),
#  'clase culta': ('n', 0.125, 0.0, 0.875, '08387603'),
#  'sodoma': ('n', 0.125, 0.0, 0.875, '08795880'),
#  'copérnico': ('n', 0.125, 0.0, 0.875, '09256182'),
#  'bardo': ('n', 0.125, 0.0, 0.875, '09839022'),
#  'corista': ('n', 0.125, 0.0, 0.875, '09920771'),
#  'ceceador': ('n', 0.125, 0.0, 0.875, '10265801'),
#  'ciardi': ('n', 0.125, 0.0, 0.875, '10897796'),
#  'tate': ('n', 0.125, 0.0, 0.875, '11332423'),
#  'género arnoseris': ('n', 0.125, 0.0, 0.875, '11927616'),
#  'género typha': ('n', 0.125, 0.0, 0.875, '12155459'),
#  'familia hydrocharidáceas': ('n', 0.125, 0.0, 0.875, '12612913'),
#  'familia hydrocharitáceas': ('n', 0.125, 0.0, 0.875, '12612913'),
#  'familia mordisco de rana': ('n', 0.125, 0.0, 0.875, '12612913'),
#  'hydrocharidáceas': ('n', 0.125, 0.0, 0.875, '12612913'),
#  'hydrocharitáceas': ('n', 0.125, 0.0, 0.875, '12612913'),
#  'género kolkwitzia': ('n', 0.125, 0.0, 0.875, '12672497'),
#  'kolkwitzia': ('n', 0.125, 0.0, 0.875, '12672497'),
#  'dimocarpus': ('n', 0.125, 0.0, 0.875, '12743232'),
#  'género dimocarpus': ('n', 0.125, 0.0, 0.875, '12743232'),
#  'cirro': ('n', 0.125, 0.0, 0.875, '13102946'),
#  'fronda': ('n', 0.125, 0.0, 0.875, '13154494'),
#  'compra': ('n', 0.125, 0.0, 0.875, '13253612'),
#  'alquiler exorbitante': ('n', 0.125, 0.0, 0.875, '13296194'),
#  'pérdida': ('n', 0.0, 0.75, 0.25, '05162985'),
#  'ocho peniques': ('n', 0.125, 0.0, 0.875, '13391610'),
#  'níquel': ('n', 0.125, 0.0, 0.875, '13395652'),
#  'taza': ('n', 0.125, 0.0, 0.875, '13766733'),
#  'fuerza convincente': ('n', 0.125, 0.0, 0.875, '13794793'),
#  'ets': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'faringitis estreptocócica': ('n', 0.125, 0.0, 0.875, '14184986'),
#  'alucinación visual': ('n', 0.125, 0.0, 0.875, '14378439'),
#  'predisposición': ('n', 0.0, 0.875, 0.125, '06201908'),
#  'florecimiento': ('n', 0.125, 0.0, 0.875, '15151641'),
#  'la flor de la juventud': ('n', 0.125, 0.0, 0.875, '15151641'),
#  'tiempos mozos': ('n', 0.125, 0.0, 0.875, '15151641'),
#  'hoy': ('n', 0.125, 0.0, 0.875, '15262921'),
#  'respiro': ('n', 0.0, 0.75, 0.25, '14446034'),
#  'período de descanso': ('n', 0.125, 0.0, 0.875, '15274074'),
#  'sustancialmente': ('r', 0.125, 0.0, 0.875, '00014285'),
#  'aullar de risa': ('v', 0.125, 0.0, 0.875, '00029836'),
#  'reir a carcajadas': ('v', 0.125, 0.0, 0.875, '00029836'),
#  'peinar con estilo': ('v', 0.125, 0.0, 0.875, '00038849'),
#  'aderezar': ('v', 0.125, 0.0, 0.875, '00038849'),
#  'marcar': ('v', 0.125, 0.0, 0.875, '00038849'),
#  'mano a mano': ('r', 0.125, 0.0, 0.875, '00054750'),
#  'esencial?': ('a', 0.125, 0.0, 0.875, '00055539'),
#  'sustantivo?': ('a', 0.125, 0.0, 0.875, '00055539'),
#  'en cualquier caso': ('r', 0.125, 0.0, 0.875, '00056916'),
#  'mucho': ('r', 0.25, 0.0, 0.75, '00059171'),
#  'reavivar': ('v', 0.125, 0.0, 0.875, '00081725'),
#  'curar': ('v', 0.125, 0.0, 0.875, '00081725'),
#  'sanar': ('v', 0.125, 0.0, 0.875, '00081725'),
#  'continuamente': ('r', 0.125, 0.0, 0.875, '00088931'),
#  'hacia mí': ('r', 0.125, 0.0, 0.875, '00096921'),
#  'históricamente': ('r', 0.125, 0.0, 0.875, '00109569'),
#  'volumétricamente': ('r', 0.125, 0.0, 0.875, '00118253'),
#  'patológicamente': ('r', 0.125, 0.0, 0.875, '00132673'),
#  'en total': ('r', 0.125, 0.0, 0.875, '00150432'),
#  'gol': ('n', 0.125, 0.0, 0.875, '00187337'),
#  'vigorizar': ('v', 0.125, 0.0, 0.875, '00192836'),
#  'fluctuación': ('n', 0.125, 0.0, 0.875, '00195938'),
#  'convulsivamente': ('r', 0.125, 0.0, 0.875, '00198531'),
#  'domar': ('v', 0.375, 0.0, 0.625, '00202445'),
#  'justamente': ('r', 0.375, 0.0, 0.625, '00106759'),
#  'destitución': ('n', 0.125, 0.0, 0.875, '00216607'),
#  'debilitar': ('v', 0.375, 0.0, 0.625, '00542533'),
#  'purificación': ('n', 0.125, 0.0, 0.875, '00253070'),
#  'destrozar': ('v', 0.0, 0.25, 0.75, '00863277'),
#  'mantenimiento programado': ('n', 0.125, 0.0, 0.875, '00270539'),
#  'sensibilizar': ('v', 0.125, 0.0, 0.875, '00272391'),
#  'concienciar': ('v', 0.125, 0.0, 0.875, '00272391'),
#  'climáticamente': ('r', 0.125, 0.0, 0.875, '00286026'),
#  'ajustar': ('v', 0.125, 0.0, 0.875, '00298067'),
#  'descriptivamente': ('r', 0.125, 0.0, 0.875, '00301354'),
#  'devotamente': ('r', 0.125, 0.0, 0.875, '00310290'),
#  'geológicamente': ('r', 0.125, 0.0, 0.875, '00347717'),
#  'cómicamente': ('r', 0.125, 0.0, 0.875, '00387017'),
#  'risiblemente': ('r', 0.125, 0.0, 0.875, '00387017'),
#  'rehabilitación correccional': ('n', 0.125, 0.0, 0.875, '00400851'),
#  'nutricionalmente': ('r', 0.125, 0.0, 0.875, '00411045'),
#  'abrazo apasionado': ('n', 0.125, 0.0, 0.875, '00417859'),
#  'farmacológicamente': ('r', 0.125, 0.0, 0.875, '00421471'),
#  'aparecer': ('v', 0.125, 0.0, 0.875, '00425522'),
#  'acrobacias': ('n', 0.125, 0.0, 0.875, '00434075'),
#  'volteretas': ('n', 0.125, 0.0, 0.875, '00434075'),
#  'deporte ecuestre': ('n', 0.125, 0.0, 0.875, '00450700'),
#  'realinear': ('v', 0.125, 0.0, 0.875, '00465145'),
#  'enderezar': ('v', 0.125, 0.0, 0.875, '00465145'),
#  'afinar': ('v', 0.125, 0.0, 0.875, '00474017'),
#  'prejuiciar': ('v', 0.0, 0.375, 0.625, '00680485'),
#  'topográficamente': ('r', 0.125, 0.0, 0.875, '00479470'),
#  'cargar': ('v', 0.0, 0.875, 0.125, '00748084'),
#  'asibilar': ('v', 0.125, 0.0, 0.875, '00547022'),
#  'malabarismo': ('n', 0.125, 0.0, 0.875, '00562179'),
#  'ejercitar': ('v', 0.125, 0.0, 0.875, '00606335'),
#  'leer': ('v', 0.125, 0.0, 0.875, '00620239'),
#  'racionalizar': ('v', 0.125, 0.0, 0.875, '00633265'),
#  'nocturno': ('a', 0.125, 0.0, 0.875, '00678923'),
#  'creer': ('v', 0.125, 0.0, 0.875, '00684068'),
#  'concretar': ('v', 0.125, 0.0, 0.875, '00715769'),
#  'despertarse': ('v', 0.125, 0.0, 0.875, '00736095'),
#  'abandono': ('n', 0.125, 0.0, 0.875, '00738966'),
#  'bloqueado': ('a', 0.125, 0.0, 0.875, '00778161'),
#  'profesar': ('v', 0.125, 0.0, 0.875, '00819756'),
#  'instruir': ('v', 0.125, 0.0, 0.875, '00831074'),
#  'acusar': ('v', 0.125, 0.0, 0.875, '00843468'),
#  'culpar': ('v', 0.0, 0.375, 0.625, '00842772'),
#  'mofarse': ('v', 0.0, 0.375, 0.625, '00850192'),
#  'embaucar': ('v', 0.0, 0.875, 0.125, '02593001'),
#  'dar gato por liebre': ('v', 0.0, 0.125, 0.875, '02572119'),
#  'enredar': ('v', 0.125, 0.0, 0.875, '00854904'),
#  'falsear': ('v', 0.0, 0.375, 0.625, '02576921'),
#  'defraudar': ('v', 0.0, 0.125, 0.875, '02572119'),
#  'engatusar': ('v', 0.125, 0.0, 0.875, '00854904'),
#  'masturbación': ('n', 0.125, 0.0, 0.875, '00855674'),
#  'despertar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'retroalimentar': ('v', 0.125, 0.0, 0.875, '00876200'),
#  'dedicar': ('v', 0.125, 0.0, 0.875, '00887142'),
#  'disciplina': ('n', 0.125, 0.0, 0.875, '00893836'),
#  'capacidad': ('n', 0.125, 0.0, 0.875, '00914795'),
#  'explotación de depósitos minerales': ('n', 0.125, 0.0, 0.875, '00922727'),
#  'sugerir': ('v', 0.5, 0.0, 0.5, '00927430'),
#  'insinuar': ('v', 0.5, 0.0, 0.5, '00927430'),
#  'capitalización': ('n', 0.125, 0.0, 0.875, '00951626'),
#  'pelea cuerpo a cuerpo': ('n', 0.125, 0.0, 0.875, '00959537'),
#  'actualizar': ('v', 0.125, 0.0, 0.875, '00987870'),
#  'contrafirmar': ('v', 0.125, 0.0, 0.875, '00997432'),
#  'abstinencia': ('n', 0.125, 0.0, 0.875, '01069867'),
#  'grieta': ('n', 0.125, 0.0, 0.875, '14464793'),
#  'exención': ('n', 0.125, 0.0, 0.875, '14528873'),
#  'cachemira': ('n', 0.125, 0.0, 0.875, '15104669'),
#  'época de san miguel': ('n', 0.125, 0.0, 0.875, '15186596'),
#  'época de lammas': ('n', 0.125, 0.0, 0.875, '15190424'),
#  'época de pascua': ('n', 0.125, 0.0, 0.875, '15191587'),
#  'época de la epifanía': ('n', 0.125, 0.0, 0.875, '15194860'),
#  'período': ('n', 0.125, 0.0, 0.875, '15289779'),
#  'destruir': ('v', 0.0, 0.25, 0.75, '01566185'),
#  'hacer pedazos': ('v', 0.125, 0.0, 0.875, '01083920'),
#  'autolimitación': ('n', 0.125, 0.0, 0.875, '01124110'),
#  'ver': ('v', 0.125, 0.0, 0.875, '01156568'),
#  'explotar': ('v', 0.125, 0.0, 0.875, '01164906'),
#  'incumplimiento': ('n', 0.125, 0.0, 0.875, '01179707'),
#  'servir': ('v', 0.125, 0.0, 0.875, '02555434'),
#  'cuidar un bebé': ('v', 0.125, 0.0, 0.875, '01186844'),
#  'insistencia': ('n', 0.0, 0.125, 0.875, '07191777'),
#  'buen gesto': ('n', 0.125, 0.0, 0.875, '01228544'),
#  'absentismo': ('n', 0.125, 0.0, 0.875, '01234528'),
#  'ser fatal': ('v', 0.125, 0.0, 0.875, '01326323'),
#  'especie de bacterias': ('n', 0.125, 0.0, 0.875, '01353411'),
#  'pseudomonas pyocanea': ('n', 0.125, 0.0, 0.875, '01353658'),
#  'nitrobacteriaceae': ('n', 0.125, 0.0, 0.875, '01361973'),
#  'c. trachomatis': ('n', 0.125, 0.0, 0.875, '01373090'),
#  'apapachar': ('v', 0.125, 0.0, 0.875, '01424867'),
#  'derribar': ('v', 0.125, 0.0, 0.875, '01479874'),
#  'asear la casa': ('v', 0.125, 0.0, 0.875, '01533442'),
#  'agregar': ('v', 0.125, 0.0, 0.875, '01541231'),
#  'empastar': ('v', 0.125, 0.0, 0.875, '01612818'),
#  'traer': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'llamar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'agitar': ('v', 0.125, 0.0, 0.875, '01629958'),
#  'dar': ('v', 0.0, 0.5, 0.5, '02343595'),
#  'producir': ('v', 0.125, 0.0, 0.875, '01652139'),
#  'indentar': ('v', 0.125, 0.0, 0.875, '01745377'),
#  'aficionarse': ('v', 0.125, 0.0, 0.875, '01777107'),
#  'asustar': ('v', 0.125, 0.0, 0.875, '01780104'),
#  'intimidar': ('v', 0.125, 0.0, 0.875, '01781180'),
#  'decepcionar': ('v', 0.125, 0.0, 0.875, '01816645'),
#  'andar en cámara': ('v', 0.125, 0.0, 0.875, '01840929'),
#  'desplazarse furtivamente': ('v', 0.125, 0.0, 0.875, '01869299'),
#  'coral hongo': ('n', 0.125, 0.0, 0.875, '01917882'),
#  'género echinococcus': ('n', 0.125, 0.0, 0.875, '01927816'),
#  'clase bivalvia': ('n', 0.125, 0.0, 0.875, '01955463'),
#  'clase pelecypoda': ('n', 0.125, 0.0, 0.875, '01955463'),
#  'almeja roja': ('n', 0.125, 0.0, 0.875, '01963479'),
#  'sepiidae': ('n', 0.125, 0.0, 0.875, '01972283'),
#  'hacer circular': ('v', 0.125, 0.0, 0.875, '02043501'),
#  'seleccionado': ('a', 0.125, 0.0, 0.875, '02123475'),
#  'mostrar': ('v', 0.125, 0.0, 0.875, '02137132'),
#  'phyllostomidae': ('n', 0.125, 0.0, 0.875, '02142064'),
#  'familia rrhinolophidae': ('n', 0.125, 0.0, 0.875, '02143293'),
#  'observar': ('v', 0.125, 0.0, 0.875, '02169352'),
#  'acordar': ('v', 0.125, 0.0, 0.875, '02254258'),
#  'asteroidea': ('n', 0.125, 0.0, 0.875, '02317212'),
#  'calse asteroidea': ('n', 0.125, 0.0, 0.875, '02317212'),
#  'enroscado': ('a', 0.125, 0.0, 0.875, '02317327'),
#  'género zapus': ('n', 0.125, 0.0, 0.875, '02351212'),
#  'zapus': ('n', 0.125, 0.0, 0.875, '02351212'),
#  'género bathyergus': ('n', 0.125, 0.0, 0.875, '02369170'),
#  'pastorear': ('v', 0.125, 0.0, 0.875, '02446660'),
#  'privilegiar': ('v', 0.125, 0.0, 0.875, '02453692'),
#  'suborden anthropoidea': ('n', 0.125, 0.0, 0.875, '02470451'),
#  'hominóideo': ('n', 0.125, 0.0, 0.875, '02471300'),
#  'homínido': ('n', 0.125, 0.0, 0.875, '02471762'),
#  'entretener': ('v', 0.125, 0.0, 0.875, '02492198'),
#  'cumplir lo prometido': ('v', 0.125, 0.0, 0.875, '02524171'),
#  'tener éxito': ('v', 0.125, 0.0, 0.875, '02524171'),
#  'triunfar': ('n', 0.625, 0.0, 0.375, '00064504'),
#  'jugársela': ('v', 0.125, 0.0, 0.875, '02531500'),
#  'flirtear': ('v', 0.125, 0.0, 0.875, '02535093'),
#  'fomentar': ('v', 0.125, 0.0, 0.875, '02554922'),
#  'impulsar': ('v', 0.125, 0.0, 0.875, '02554922'),
#  'estimular': ('v', 0.125, 0.0, 0.875, '02554922'),
#  'promover': ('v', 0.125, 0.0, 0.875, '02554922'),
#  'cumplir': ('v', 0.125, 0.0, 0.875, '02563724'),
#  'suspender por lluvia': ('v', 0.125, 0.0, 0.875, '02594833'),
#  'resistir': ('v', 0.0, 0.125, 0.875, '02706816'),
#  'mantenerse': ('v', 0.125, 0.0, 0.875, '02619122'),
#  'coprotagonizar': ('v', 0.125, 0.0, 0.875, '02631537'),
#  'dirigible': ('n', 0.125, 0.0, 0.875, '02692877'),
#  'wilsoniano': ('a', 0.125, 0.0, 0.875, '02696515'),
#  'proficiente': ('a', 0.125, 0.0, 0.875, '02809220'),
#  'poético': ('a', 0.125, 0.0, 0.875, '02857295'),
#  'mesiánico': ('a', 0.125, 0.0, 0.875, '02867242'),
#  'bombie': ('n', 0.125, 0.0, 0.875, '02868068'),
#  'gustativo': ('a', 0.125, 0.0, 0.875, '02868916'),
#  'gustatorio': ('a', 0.125, 0.0, 0.875, '02868916'),
#  'cubículo': ('n', 0.125, 0.0, 0.875, '02874214'),
#  'capote': ('n', 0.125, 0.0, 0.875, '02956883'),
#  'abrigo encapuchado': ('n', 0.125, 0.0, 0.875, '02956883'),
#  'epicúreo': ('a', 0.125, 0.0, 0.875, '03001153'),
#  'capilla': ('n', 0.125, 0.0, 0.875, '03006788'),
#  'adicional': ('a', 0.125, 0.0, 0.875, '03139363'),
#  'escurridor': ('n', 0.125, 0.0, 0.875, '03232676'),
#  'dentadura falsa': ('n', 0.125, 0.0, 0.875, '03319576'),
#  'tracería de abanicos': ('n', 0.125, 0.0, 0.875, '03321843'),
#  'aguada': ('n', 0.125, 0.0, 0.875, '03449217'),
#  'alabarda': ('n', 0.125, 0.0, 0.875, '03477410'),
#  'spa': ('n', 0.5, 0.0, 0.5, '08678615'),
#  'albergue juvenil': ('n', 0.125, 0.0, 0.875, '03541537'),
#  'youth hostel': ('n', 0.125, 0.0, 0.875, '03541537'),
#  'luneta': ('n', 0.125, 0.0, 0.875, '03697812'),
#  'sala de masajes': ('n', 0.125, 0.0, 0.875, '03726116'),
#  'placa madre': ('n', 0.125, 0.0, 0.875, '03902220'),
#  'reloj de péndulo': ('n', 0.125, 0.0, 0.875, '03909406'),
#  'estilete': ('n', 0.125, 0.0, 0.875, '03981094'),
#  'porcelana, cerámica': ('n', 0.125, 0.0, 0.875, '03984234'),
#  'espectroscopio de prisma': ('n', 0.125, 0.0, 0.875, '04273064'),
#  'espectroscopio': ('n', 0.125, 0.0, 0.875, '04273064'),
#  'terazosina': ('n', 0.125, 0.0, 0.875, '04412550'),
#  'parada de camiones': ('n', 0.125, 0.0, 0.875, '04490730'),
#  'tienda de golosinas': ('n', 0.125, 0.0, 0.875, '04495450'),
#  '22': ('n', 0.125, 0.0, 0.875, '04502851'),
#  'cristal veneciano': ('n', 0.125, 0.0, 0.875, '04525729'),
#  'espíritu': ('n', 0.125, 0.0, 0.875, '04723286'),
#  'progresión': ('n', 0.125, 0.0, 0.875, '04737743'),
#  'progresividad': ('n', 0.125, 0.0, 0.875, '04737743'),
#  'imprecisión': ('n', 0.125, 0.0, 0.875, '04885609'),
#  'previsión': ('n', 0.0, 0.125, 0.875, '05775829'),
#  'vena': ('n', 0.125, 0.0, 0.875, '04920435'),
#  'nombre': ('n', 0.0, 0.125, 0.875, '01139636'),
#  'recurso': ('n', 0.125, 0.0, 0.875, '05155123'),
#  'refugio': ('n', 0.0, 0.375, 0.625, '04192238'),
#  'apelación': ('n', 0.125, 0.0, 0.875, '05155123'),
#  'delantera': ('n', 0.125, 0.0, 0.875, '05157143'),
#  'abductor del dedo gordo del pie': ('n', 0.125, 0.0, 0.875, '05291495'),
#  'aductor del dedo gordo del pie': ('n', 0.125, 0.0, 0.875, '05292359'),
#  'conducto torácico': ('n', 0.125, 0.0, 0.875, '05396690'),
#  '(buena) mano': ('n', 0.125, 0.0, 0.875, '05677340'),
#  'complemento': ('n', 0.125, 0.0, 0.875, '05696297'),
#  'aprehensión inmediata': ('n', 0.125, 0.0, 0.875, '05708322'),
#  'vainilla': ('n', 0.125, 0.0, 0.875, '05716462'),
#  'verificación': ('n', 0.125, 0.0, 0.875, '05738894'),
#  'doble comprobación': ('n', 0.125, 0.0, 0.875, '05738894'),
#  'ensimismamiento': ('n', 0.0, 0.125, 0.875, '07533607'),
#  'reflexión': ('n', 0.125, 0.0, 0.875, '05785508'),
#  'meditación': ('n', 0.125, 0.0, 0.875, '05785508'),
#  'ponderación': ('n', 0.5, 0.0, 0.5, '05785067'),
#  'clave': ('n', 0.125, 0.0, 0.875, '05794057'),
#  'percepcion': ('n', 0.125, 0.0, 0.875, '05836468'),
#  'maestro': ('n', 0.125, 0.0, 0.875, '05854812'),
#  'yang': ('n', 0.125, 0.0, 0.875, '05915356'),
#  'teosofismo': ('n', 0.125, 0.0, 0.875, '05953804'),
#  'reconocimiento': ('n', 0.625, 0.0, 0.375, '06691684'),
#  'política de agresión': ('n', 0.125, 0.0, 0.875, '06221790'),
#  'vizcondado': ('n', 0.125, 0.0, 0.875, '06343440'),
#  'ditirambo': ('n', 0.125, 0.0, 0.875, '06379094'),
#  'versión estándar americana': ('n', 0.125, 0.0, 0.875, '06449477'),
#  'perdón': ('n', 0.125, 0.0, 0.875, '06552639'),
#  'tonterías': ('n', 0.0, 0.25, 0.75, '06609909'),
#  'morralla': ('n', 0.125, 0.0, 0.875, '06611998'),
#  'bobadas': ('n', 0.125, 0.0, 0.875, '06611998'),
#  'aguachirle': ('n', 0.125, 0.0, 0.875, '06611998'),
#  'prueba matemática': ('n', 0.125, 0.0, 0.875, '06647864'),
#  'consejo': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'filtración': ('n', 0.125, 0.0, 0.875, '06651577'),
#  'doctor en osteopatía': ('n', 0.125, 0.0, 0.875, '06703733'),
#  'declaración discreta': ('n', 0.125, 0.0, 0.875, '06762602'),
#  'espectáculo': ('n', 0.125, 0.0, 0.875, '06889138'),
#  'floritura': ('n', 0.125, 0.0, 0.875, '06890470'),
#  'matiné': ('n', 0.125, 0.0, 0.875, '06894111'),
#  'alemán alto antiguo': ('n', 0.125, 0.0, 0.875, '06950886'),
#  'ilustración': ('n', 0.375, 0.0, 0.625, '05985999'),
#  'obra': ('n', 0.125, 0.0, 0.875, '07018931'),
#  'expresión': ('n', 0.125, 0.0, 0.875, '07082198'),
#  'aullidos': ('n', 0.125, 0.0, 0.875, '07123012'),
#  'compensación': ('n', 0.375, 0.0, 0.625, '13300828'),
#  'gracias': ('n', 0.0, 0.125, 0.875, '01208797'),
#  'inculpación': ('n', 0.125, 0.0, 0.875, '07237409'),
#  'prohibición': ('n', 0.125, 0.0, 0.875, '07255174'),
#  'cachondeo': ('n', 0.125, 0.0, 0.875, '07282695'),
#  'horror': ('n', 0.0, 0.5, 0.5, '03537866'),
#  'buen viaje': ('n', 0.125, 0.0, 0.875, '07319549'),
#  'efusión': ('n', 0.5, 0.0, 0.5, '07014320'),
#  'aniquilación': ('n', 0.0, 0.125, 0.875, '00218208'),
#  'desintegración': ('n', 0.125, 0.0, 0.875, '07330828'),
#  'ladrido': ('n', 0.125, 0.0, 0.875, '07376731'),
#  'descontento': ('n', 0.125, 0.0, 0.875, '07538965'),
#  'comida decente': ('n', 0.125, 0.0, 0.875, '07573563'),
#  'chowder': ('n', 0.125, 0.0, 0.875, '07587441'),
#  'caramelo de miel': ('n', 0.125, 0.0, 0.875, '07606191'),
#  'caramelo de azúcar': ('n', 0.125, 0.0, 0.875, '07609215'),
#  'quiche lorraine': ('n', 0.125, 0.0, 0.875, '07619786'),
#  'foie gras': ('n', 0.125, 0.0, 0.875, '07858197'),
#  'paté de foie gras': ('n', 0.125, 0.0, 0.875, '07858197'),
#  'ginebra artesanal': ('n', 0.125, 0.0, 0.875, '07902698'),
#  'manhattan': ('n', 0.125, 0.0, 0.875, '07915618'),
#  'arminianismo': ('n', 0.125, 0.0, 0.875, '08092190'),
#  'iglesia metodista': ('n', 0.125, 0.0, 0.875, '08092340'),
#  'metodistas': ('n', 0.125, 0.0, 0.875, '08092340'),
#  'taoísmo': ('n', 0.125, 0.0, 0.875, '08098346'),
#  'facultad de arte': ('n', 0.125, 0.0, 0.875, '08115778'),
#  'facultad de ciencias de la computación': ('n',
#   0.125,
#   0.0,
#   0.875,
#   '08116240'),
#  'juglaría': ('n', 0.125, 0.0, 0.875, '08189371'),
#  'soldados hostiles': ('n', 0.125, 0.0, 0.875, '08397675'),
#  'esencia': ('n', 0.5, 0.0, 0.5, '14050434'),
#  'arzobispado': ('n', 0.125, 0.0, 0.875, '08550455'),
#  'reductor': ('n', 0.125, 0.0, 0.875, '09310460'),
#  'represor': ('n', 0.125, 0.0, 0.875, '09407541'),
#  'acortador': ('n', 0.125, 0.0, 0.875, '09433952'),
#  'aglaya': ('n', 0.125, 0.0, 0.875, '09495619'),
#  'eufrósine': ('n', 0.125, 0.0, 0.875, '09495732'),
#  'talía': ('n', 0.125, 0.0, 0.875, '09495849'),
#  'venus': ('n', 0.125, 0.0, 0.875, '09555127'),
#  'vali': ('n', 0.125, 0.0, 0.875, '09584079'),
#  'siervo': ('n', 0.125, 0.0, 0.875, '09865398'),
#  'alto mando': ('n', 0.125, 0.0, 0.875, '09873242'),
#  'revisor': ('n', 0.125, 0.0, 0.875, '09912995'),
#  'defensor': ('n', 0.125, 0.0, 0.875, '09913593'),
#  'promesa': ('n', 0.5, 0.0, 0.5, '07228105'),
#  'confesor': ('n', 0.125, 0.0, 0.875, '09954355'),
#  'buen conversador': ('n', 0.125, 0.0, 0.875, '09961999'),
#  'cubista': ('n', 0.125, 0.0, 0.875, '09982013'),
#  'dialéctico': ('n', 0.125, 0.0, 0.875, '10011360'),
#  'viejo verde': ('n', 0.125, 0.0, 0.875, '10015792'),
#  'aprovechador': ('n', 0.125, 0.0, 0.875, '10110893'),
#  'cariño': ('n', 0.125, 0.0, 0.875, '10279540'),
#  'metodista': ('n', 0.125, 0.0, 0.875, '10312773'),
#  'neoliberal': ('n', 0.125, 0.0, 0.875, '10352782'),
#  'partidario de la resistencia pasiva': ('n', 0.125, 0.0, 0.875, '10362195'),
#  'perfeccionador': ('n', 0.125, 0.0, 0.875, '10415439'),
#  'el que acaricia': ('n', 0.125, 0.0, 0.875, '10420649'),
#  'fusilero': ('n', 0.125, 0.0, 0.875, '10530677'),
#  'sacadineros': ('n', 0.125, 0.0, 0.875, '10557699'),
#  'marinero polémico': ('n', 0.125, 0.0, 0.875, '10567172'),
#  'persona muy reservada': ('n', 0.125, 0.0, 0.875, '10618146'),
#  'aficionado al deporte': ('n', 0.125, 0.0, 0.875, '10639925'),
#  'abanderado': ('n', 0.125, 0.0, 0.875, '10647475'),
#  'provocador': ('n', 0.125, 0.0, 0.875, '10690849'),
#  'mortificador': ('n', 0.125, 0.0, 0.875, '10690849'),
#  'esclavo': ('n', 0.125, 0.0, 0.875, '10709435'),
#  'arminiano': ('n', 0.125, 0.0, 0.875, '10738871'),
#  'ganador inesperado': ('n', 0.125, 0.0, 0.875, '10740594'),
#  'jaime': ('n', 0.125, 0.0, 0.875, '11078982'),
#  'santiago': ('n', 0.125, 0.0, 0.875, '11078982'),
#  'santiago apóstol': ('n', 0.125, 0.0, 0.875, '11078982'),
#  'san jaime': ('n', 0.125, 0.0, 0.875, '11078982'),
#  'san jaime apóstol': ('n', 0.125, 0.0, 0.875, '11078982'),
#  'sylvia plath': ('n', 0.125, 0.0, 0.875, '11239143'),
#  'allen tate': ('n', 0.125, 0.0, 0.875, '11332423'),
#  'joseph deems taylor': ('n', 0.125, 0.0, 0.875, '11333601'),
#  'alfred lord tennyson': ('n', 0.125, 0.0, 0.875, '11335330'),
#  'baron tennyson': ('n', 0.125, 0.0, 0.875, '11335330'),
#  'tiziano': ('n', 0.125, 0.0, 0.875, '11343507'),
#  'tiziano vecellio': ('n', 0.125, 0.0, 0.875, '11343507'),
#  'robert penn warren': ('n', 0.125, 0.0, 0.875, '11374952'),
#  'ola': ('n', 0.125, 0.0, 0.875, '11524451'),
#  'pino contorta murrayana': ('n', 0.125, 0.0, 0.875, '11615259'),
#  'ceratophyllum': ('n', 0.125, 0.0, 0.875, '11702081'),
#  'género ceratofiláceas': ('n', 0.125, 0.0, 0.875, '11702081'),
#  'género marrubium': ('n', 0.125, 0.0, 0.875, '12853901'),
#  'género chlorophyllum': ('n', 0.125, 0.0, 0.875, '13012835'),
#  'contribución': ('n', 0.125, 0.0, 0.875, '13269890'),
#  'capital social': ('n', 0.125, 0.0, 0.875, '13334650'),
#  'nueve peniques': ('n', 0.125, 0.0, 0.875, '13391693'),
#  'revisión puntual': ('n', 0.125, 0.0, 0.875, '13411533'),
#  'revisión': ('n', 0.625, 0.0, 0.375, '00143536'),
#  'bacteriostasis': ('n', 0.125, 0.0, 0.875, '13437495'),
#  'denominador': ('n', 0.125, 0.0, 0.875, '13733066'),
#  'ocupación hospitalaria': ('n', 0.125, 0.0, 0.875, '13818736'),
#  'cuarto': ('n', 0.125, 0.0, 0.875, '13830166'),
#  'disposición mental': ('n', 0.125, 0.0, 0.875, '14016114'),
#  'estado mental': ('n', 0.125, 0.0, 0.875, '14016114'),
#  'dosis': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'enfermedad de transmisión sexual': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'enfermedad social': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'ev': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'enfermedad venérea': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'infección venérea': ('n', 0.125, 0.0, 0.875, '14133159'),
#  'faringitis sépticas': ('n', 0.125, 0.0, 0.875, '14184986'),
#  'amigdalitis estreptocócica': ('n', 0.125, 0.0, 0.875, '14184986'),
#  'inflamación de la garganta': ('n', 0.125, 0.0, 0.875, '14184986'),
#  'fiebre de texas': ('n', 0.125, 0.0, 0.875, '14276081'),
#  'soplo sistólico': ('n', 0.125, 0.0, 0.875, '14335006'),
#  'encefalitis hemorrágica aguda': ('n', 0.125, 0.0, 0.875, '14342742'),
#  'sangre azul': ('n', 0.125, 0.0, 0.875, '14432271'),
#  'vía': ('n', 0.125, 0.0, 0.875, '14485811'),
#  'pérdida auditiva sensorineural': ('n', 0.125, 0.0, 0.875, '14551565'),
#  'hiposmia': ('n', 0.125, 0.0, 0.875, '14552718'),
#  'fundición obtenida con un solo mineral': ('n',
#   0.125,
#   0.0,
#   0.875,
#   '14953005'),
#  ...}

# %%
# Función que incluye el diccionario para mapear las etiquetas de spaCy a las etiquetas esperadas en el lexicón.
# Asumimos que en el lexicón se utilizan 'n' (noun), 'v' (verb), 'a' (adjective) y 'r' (adverb).
def map_spacy_tag(spacy_tag):

    spacy_to_wn = {
        "NOUN": "n",
        "VERB": "v",
        "ADJ": "a",
        "ADV": "r"
    }

    return spacy_to_wn.get(spacy_tag, None)

# %% [markdown]
# Ahora vamos a probar el lexicón de SentiWordNet en español para calcular el sentimiento.

# %% [markdown]
# Hasta ahora hemos hecho un mapeo entre las etiquetas gramaticales ya incluídas en el lexicón de SentiWordNet a las etiquetas que usa WordNet, centrándonos únicamente en categorías léxicas (nombres, verbos, adjetivos, adverbios). Después, vamos a lematizar los tokens, esto es, quitar cualquier afijo para obtener la raíz de los mismos. Buscaremos el lema en WordNet y obtendremos el significado del primero, que es el más común. Por último, ofrecemos dos maneras de calcular el sentimiento:
#
# 1. Mediante la suma de la resta del sentimiento positivo y negativo de cada synset por palabra.
# 2. Mediante la media de la suma de los sentimientos positivos, negativos y objetivos de todas las palabras, escogiendo el valor más alto de los tres sentimientos.
#
# En el primer caso, consideraremos la misma escala de valores que vimos en VADER:
# si s es superior o igual a 0.05, positivo; si s es inferior o igual a -0.05, negativo; en el resto de los casos, neutro.
#
# En el segundo, calcularemos la media de la suma de los scores positivos, negativos y objetivos y tomaremos como polaridad aquel de los tres que tenga un valor mayor.

# %% [markdown]
# Ahora vamos a crear una función para cada una de los métodos para calcular el sentimiento y vamos a aplicar tal función al dataset anterior, reutilizando para ello el código del que nos servimos anteriormente para cargar el dataset, visualizarlo, manipularlo, etc.

# %%
def compute_sentiment_sum(text):

  doc = nlp_es(text)
  tokenized_sent = [token.text for token in doc]
  print(tokenized_sent)

  pos_tagged_tokens = [(token.text, token.pos_) for token in doc]
  print(pos_tagged_tokens)

  pos_score = 0.0
  neg_score = 0.0
  sentiment_value = 0.0
  sentiment_label = ""

  for word_text, tag in pos_tagged_tokens:
    print(word_text)
    wn_tag = map_spacy_tag(tag)
    print(wn_tag)
    if wn_tag == None:
     continue

    word = next((token for token in doc if token.text == word_text), None)
    if word is None:
      continue

    lemma = word.lemma_
    print(lemma)
    if not lemma:
      continue

    # Verificar si la palabra lematizada está en el diccionario de SentiWordNet
    # y crear la lista de synsets
    if lemma in spanish_sentiwordnet:
        # Obtener los puntajes positivos, negativos y los códigos de los synsets
        pos_tag, pos_score_lemma, _, neg_score_lemma, synset = spanish_sentiwordnet[lemma]

        swn_synsets = []
        for key, value in spanish_sentiwordnet.items():
          # Comprobar si el synset de la palabra coincide con el synset del diccionario
          if synset == value[4]:  # value[4] es el synset
              swn_synsets.append(f"SentiSynset('{key}.{pos_tag}')")

        print(swn_synsets)
        if len(swn_synsets) == 0:
          continue

        print(f"Positive score for {lemma}: {pos_score_lemma}")
        print(f"Negative score for {lemma}: {neg_score_lemma}")

        pos_score += pos_score_lemma
        neg_score += neg_score_lemma

        # Calcular el valor del sentimiento
        sentiment_value += pos_score - neg_score
        print(f"Sentiment value: {sentiment_value}")

  # Clasificación final según el valor de sentimiento
  if sentiment_value >= 0.05:
      sentiment_label = "positive"
  elif sentiment_value <= -0.05:
      sentiment_label = "negative"
  else:
      sentiment_label = "neutral"

  return sentiment_label

# %%
text ="Hoy me he levantado alegre considerando que estoy tristemente enfermo"

# %%
valor_sentimiento = compute_sentiment_sum(text)
print(valor_sentimiento)
# Out:
# ['Hoy', 'me', 'he', 'levantado', 'alegre', 'considerando', 'que', 'estoy', 'tristemente', 'enfermo']
# [('Hoy', 'ADV'), ('me', 'PRON'), ('he', 'AUX'), ('levantado', 'VERB'), ('alegre', 'ADJ'), ('considerando', 'VERB'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('tristemente', 'ADV'), ('enfermo', 'NOUN')]
# Hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -0.75
# me
# None
# he
# None
# levantado
# v
# levantar
# ["SentiSynset('levantar.v')"]
# Positive score for levantar: 0.0
# Negative score for levantar: 0.875
# Sentiment value: -2.375
# alegre
# a
# alegre
# considerando
# v
# considerar
# ["SentiSynset('considerar.v')", "SentiSynset('estudiar.v')"]
# Positive score for considerar: 0.25
# Negative score for considerar: 0.75
# Sentiment value: -4.5
# que
# None
# estoy
# None
# tristemente
# r
# tristemente
# ["SentiSynset('tristemente.r')"]
# Positive score for tristemente: 0.0
# Negative score for tristemente: 0.375
# Sentiment value: -7.0
# enfermo
# n
# enfermo
# negative

# %%
def compute_sentiment_mean(text):

  doc = nlp_es(text)
  tokenized_sent = [token.text for token in doc]
  print(tokenized_sent)

  pos_tagged_tokens = [(token.text, token.pos_) for token in doc]
  print(pos_tagged_tokens)

  pos_score = 0.0
  neg_score = 0.0
  obj_score = 0.0
  num_lemas_con_synset = 0
  sentiment_label = "neutral"

  for word_text, tag in pos_tagged_tokens:

    wn_tag = map_spacy_tag(tag)
    if wn_tag == None:
     continue

    word = next((token for token in doc if token.text == word_text), None)
    if word is None:
      continue

    lemma = word.lemma_
    if not lemma:
      continue

    # Initialize pos_score_lemma, neg_score_lemma, and obj_score_lemma before the if statement
    pos_score_lemma = 0.0
    neg_score_lemma = 0.0
    obj_score_lemma = 0.0

    if lemma in spanish_sentiwordnet:
      # Obtener los puntajes positivos, negativos y los códigos de los synsets
      pos_tag, pos_score_lemma, obj_score_lemma, neg_score_lemma, synset = spanish_sentiwordnet[lemma]

      swn_synsets = []
      for key, value in spanish_sentiwordnet.items():
        # Comprobar si el synset de la palabra coincide con el synset del diccionario
        if synset == value[4]:  # value[4] es el synset
            swn_synsets.append(f"SentiSynset('{key}.{pos_tag}')")

      if len(swn_synsets) == 0:
        continue

    pos_score += pos_score_lemma
    neg_score += neg_score_lemma
    obj_score += obj_score_lemma
    num_lemas_con_synset += 1

  if num_lemas_con_synset > 0:
    pos_score_mean = pos_score / num_lemas_con_synset
    neg_score_mean = neg_score / num_lemas_con_synset
    obj_score_mean = obj_score / num_lemas_con_synset
    max_value = max(pos_score_mean, neg_score_mean, obj_score_mean)

    if max_value == pos_score_mean:
      sentiment_label = "positive"
    elif max_value == neg_score_mean:
      sentiment_label = "negative"

  return sentiment_label

# %%
valor_sentimiento_mean = compute_sentiment_mean(text)
print(valor_sentimiento_mean)
# Out:
# ['Hoy', 'me', 'he', 'levantado', 'alegre', 'considerando', 'que', 'estoy', 'tristemente', 'enfermo']
# [('Hoy', 'ADV'), ('me', 'PRON'), ('he', 'AUX'), ('levantado', 'VERB'), ('alegre', 'ADJ'), ('considerando', 'VERB'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('tristemente', 'ADV'), ('enfermo', 'NOUN')]
# negative

# %%
#Definición de una función que da formato a los datos de la tabla y los prepara para poder trabajar con ellos.
#Selección de las columnas que nos interesan, asignación de un nombre a dichas columnas, sustitución
#de las etiquetas de sentimiento por otras más descriptivas y eliminación de las celdas en las que el
#sentimiento del tweet ha sido etiquetado como "none".

def format_data(data):

  selected_data = data.iloc[:, [-1, -2]] # Seleccionar todas las filas; escoger penúltima y última columna
  selected_data.columns = ['polarity_value', 'tweet_text']
  # Cambiar N, P, NEU a negativo, positivo y neutral respectivamente
  labels = {'N': 'negative', 'P': 'positive', 'NEU': 'neutral', 'NONE': 'none'}
  selected_data['polarity_value'] = selected_data['polarity_value'].map(labels)

  # Eliminar filas donde el sentimiento sea "none"
  selected_data = selected_data[selected_data['polarity_value'] != 'none']

  # Retornar solo las dos columnas que nos interesan
  return selected_data[['tweet_text', 'polarity_value']]

# %%
import pandas as pd

#Cargamos dataset para comprobar los resultados
#Para ello, tenemos en cuenta que los datos estan estructurados en formato csv
data_url_test = "https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/refs/heads/master/1-Machine_Learning_Classic/Analisis_sentimientos_Twitter/spanish/datasets/Corpus/tass_2017/InterTASS/InterTASS_global.csv"
sentiment_data = pd.read_csv(data_url_test, header=None)
sentiment_data.head(10)
# Out:
#                     0                                                  1     2
# 0  770567971701940224  @LonelySoad mientras que no te pillen la prime...     N
# 1  770503386789711872  @ceemeese ya era hora de volver al csgo y deja...     P
# 2  770502863017635840  @mireiaescribano justo cuando se terminan las ...     P
# 3  770599972102348800  @LuisMartinez22_ pensba q iba a hacer @wxplosi...     N
# 4  770599962216390656  @Vic_Phantomhive Si lo encuentro, sin compañer...     P
# 5  770599405816864768  @MentalistGirl @PamplingNews lo sé, lo sé...la...     P
# 6  770453393714348032  Eso de echar de menos tu propia casa son leyen...     P
# 7  770466143098241025  @kaveri_miguel yo estoy igual, he dormido nada...     N
# 8  770536258682617856        @Aymerich97 yo solo puse las evos de eevee   NONE
# 9  770613199200620545  @Caspitoo el día que te vi en persona estuvist...     N

# %%
#Preparamos los datos y aplicamos la transformación
#Imprimimos en pantalla las primeras diez instancias del dataset
data = format_data(sentiment_data)
data.head(10)
# Out:
# <ipython-input-91-800da3ff8acb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['polarity_value'] = selected_data['polarity_value'].map(labels)
#                                            tweet_text polarity_value
# 0   @LonelySoad mientras que no te pillen la prime...       negative
# 1   @ceemeese ya era hora de volver al csgo y deja...       positive
# 2   @mireiaescribano justo cuando se terminan las ...       positive
# 3   @LuisMartinez22_ pensba q iba a hacer @wxplosi...       negative
# 4   @Vic_Phantomhive Si lo encuentro, sin compañer...       positive
# 5   @MentalistGirl @PamplingNews lo sé, lo sé...la...       positive
# 6   Eso de echar de menos tu propia casa son leyen...       positive
# 7   @kaveri_miguel yo estoy igual, he dormido nada...       negative
# 9   @Caspitoo el día que te vi en persona estuvist...       negative
# 10  Echo de menos las sudaderas y los pantalones l...       negative

# %%
# Ejecutar las predicciones y obtener nuevas columna con dichas predicciones
data["sentiwordnet_sum_prediction"] = data["tweet_text"].apply(compute_sentiment_sum)
data["sentiwordnet_mean_prediction"] = data["tweet_text"].apply(compute_sentiment_mean)

# Mostrar 5 filas aleatorias del dataset
data.sample(5)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
#
# None
# @May_BloodArmor
# n
# @may_bloodarmor
# ['@SalvaSuay', 'No', 'te', 'veo', 'desde', '2013', ',', '¿', 'lo', 'ves', 'normal', '?']
# [('@SalvaSuay', 'VERB'), ('No', 'ADV'), ('te', 'PRON'), ('veo', 'VERB'), ('desde', 'ADP'), ('2013', 'NOUN'), (',', 'PUNCT'), ('¿', 'PUNCT'), ('lo', 'PRON'), ('ves', 'VERB'), ('normal', 'ADJ'), ('?', 'PUNCT')]
# @SalvaSuay
# v
# @salvasuay
# No
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# te
# None
# veo
# v
# ver
# ["SentiSynset('ver.v')"]
# Positive score for ver: 0.125
# Negative score for ver: 0.875
# Sentiment value: -2.25
# desde
# None
# 2013
# n
# 2013
# ,
# None
# ¿
# None
# lo
# None
# ves
# v
# ver
# ["SentiSynset('ver.v')"]
# Positive score for ver: 0.125
# Negative score for ver: 0.875
# Sentiment value: -4.5
# normal
# a
# normal
# ?
# None
# ['Porque', 'he', 'sido', 'muy', 'buena']
# [('Porque', 'SCONJ'), ('he', 'AUX'), ('sido', 'AUX'), ('muy', 'ADV'), ('buena', 'ADJ')]
# Porque
# None
# he
# None
# sido
# None
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.5
# buena
# a
# buen
# ['@MariaJosRosillo', 'lo', 'peor', 'es', 'que', 'no']
# [('@MariaJosRosillo', 'VERB'), ('lo', 'PRON'), ('peor', 'ADJ'), ('es', 'AUX'), ('que', 'SCONJ'), ('no', 'ADV')]
# @MariaJosRosillo
# v
# @mariajosrosillir
# lo
# None
# peor
# a
# peor
# ["SentiSynset('peor.r')"]
# Positive score for peor: 0.0
# Negative score for peor: 0.125
# Sentiment value: -0.125
# es
# None
# que
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -1.0
# ['No', 'tengo', 'resaca', 'porque', 'aun', 'voy', 'borracha']
# [('No', 'ADV'), ('tengo', 'VERB'), ('resaca', 'NOUN'), ('porque', 'SCONJ'), ('aun', 'ADV'), ('voy', 'VERB'), ('borracha', 'NOUN')]
# No
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# tengo
# v
# tener
# resaca
# n
# resaca
# porque
# None
# aun
# r
# aun
# voy
# v
# ir
# ["SentiSynset('ir.v')", "SentiSynset('venir bien.v')"]
# Positive score for ir: 0.125
# Negative score for ir: 0.875
# Sentiment value: -2.25
# borracha
# n
# borracha
# ['@EleBlue', '_', 'eres', 'muy', 'peque', 'para', 'eso']
# [('@EleBlue', 'AUX'), ('_', 'PROPN'), ('eres', 'AUX'), ('muy', 'ADV'), ('peque', 'VERB'), ('para', 'ADP'), ('eso', 'PRON')]
# @EleBlue
# None
# _
# None
# eres
# None
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.5
# peque
# v
# peque
# para
# None
# eso
# None
# ['hoy', 'se', 'les', 'veía', 'muy', 'contentos']
# [('hoy', 'ADV'), ('se', 'PRON'), ('les', 'PRON'), ('veía', 'VERB'), ('muy', 'ADV'), ('contentos', 'ADJ')]
# hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -0.75
# se
# None
# les
# None
# veía
# v
# ver
# ["SentiSynset('ver.v')"]
# Positive score for ver: 0.125
# Negative score for ver: 0.875
# Sentiment value: -2.25
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -4.25
# contentos
# a
# contento
# ['Todo', 'era', 'mejor', 'en', 'la', 'playa']
# [('Todo', 'PRON'), ('era', 'AUX'), ('mejor', 'ADJ'), ('en', 'ADP'), ('la', 'DET'), ('playa', 'NOUN')]
# Todo
# None
# era
# None
# mejor
# a
# mejor
# ["SentiSynset('mejor.a')"]
# Positive score for mejor: 0.875
# Negative score for mejor: 0.125
# Sentiment value: 0.75
# en
# None
# la
# None
# playa
# n
# playa
# ['le', 'irá', 'tan', 'bien', 'estoy', 'muy', 'orgullosa', 'de', 'él']
# [('le', 'PRON'), ('irá', 'VERB'), ('tan', 'ADV'), ('bien', 'ADV'), ('estoy', 'AUX'), ('muy', 'ADV'), ('orgullosa', 'ADJ'), ('de', 'ADP'), ('él', 'PRON')]
# le
# None
# irá
# v
# ir
# ["SentiSynset('ir.v')", "SentiSynset('venir bien.v')"]
# Positive score for ir: 0.125
# Negative score for ir: 0.875
# Sentiment value: -0.75
# tan
# r
# tanto
# bien
# r
# bien
# ["SentiSynset('bien.r')"]
# Positive score for bien: 0.75
# Negative score for bien: 0.25
# Sentiment value: -1.0
# estoy
# None
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -1.75
# orgullosa
# a
# orgulloso
# de
# None
# él
# None
# ['Me', 'quemao', "'", 'en', 'la', 'piscina', '.']
# [('Me', 'PRON'), ('quemao', 'VERB'), ("'", 'SYM'), ('en', 'ADP'), ('la', 'DET'), ('piscina', 'NOUN'), ('.', 'PUNCT')]
# Me
# None
# quemao
# v
# quemao
# '
# None
# en
# None
# la
# None
# piscina
# n
# piscina
# .
# None
# ['@Plata_y_Verde', 'En', 'eso', 'estaba', 'pero', 'me', 'dio', 'atake', ' ', 'ya', 'voy', 'ya', 'voy']
# [('@Plata_y_Verde', 'PROPN'), ('En', 'ADP'), ('eso', 'PRON'), ('estaba', 'AUX'), ('pero', 'CCONJ'), ('me', 'PRON'), ('dio', 'VERB'), ('atake', 'VERB'), (' ', 'SPACE'), ('ya', 'ADV'), ('voy', 'AUX'), ('ya', 'ADV'), ('voy', 'AUX')]
# @Plata_y_Verde
# None
# En
# None
# eso
# None
# estaba
# None
# pero
# None
# me
# None
# dio
# v
# dar
# ["SentiSynset('dar.v')", "SentiSynset('sacrificar.v')"]
# Positive score for dar: 0.0
# Negative score for dar: 0.5
# Sentiment value: -0.5
# atake
# v
# atakir
#
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -1.875
# voy
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -4.125
# voy
# None
# ['@CharizardOnFire', 'No', 'estoy', 'hecho', 'de', 'oro']
# [('@CharizardOnFire', 'ADJ'), ('No', 'ADV'), ('estoy', 'AUX'), ('hecho', 'ADJ'), ('de', 'ADP'), ('oro', 'NOUN')]
# @CharizardOnFire
# a
# @charizardonfire
# No
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# estoy
# None
# hecho
# a
# hecho
# de
# None
# oro
# n
# oro
# ['@Josanguz', 'ya', 'se', 'que', 'no', 'toy', 'bueno']
# [('@Josanguz', 'PROPN'), ('ya', 'ADV'), ('se', 'PRON'), ('que', 'SCONJ'), ('no', 'ADV'), ('toy', 'VERB'), ('bueno', 'ADJ')]
# @Josanguz
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# se
# None
# que
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -2.5
# toy
# v
# tar
# bueno
# a
# bueno
# ["SentiSynset('bueno.a')"]
# Positive score for bueno: 1.0
# Negative score for bueno: 0.0
# Sentiment value: -3.125
# ['Soy', 'una', 'atrevida', 'ay', ' ', 'todos', 'me', 'lo', 'dicen']
# [('Soy', 'AUX'), ('una', 'DET'), ('atrevida', 'ADJ'), ('ay', 'INTJ'), (' ', 'SPACE'), ('todos', 'PRON'), ('me', 'PRON'), ('lo', 'PRON'), ('dicen', 'VERB')]
# Soy
# None
# una
# None
# atrevida
# a
# atrevido
# ay
# None
#
# None
# todos
# None
# me
# None
# lo
# None
# dicen
# v
# decir
# ["SentiSynset('decir.v')"]
# Positive score for decir: 0.5
# Negative score for decir: 0.5
# Sentiment value: 0.0
# ['@_Eva_13', 'yo', 'estoy', 'cansada', 'de', 'todo']
# [('@_Eva_13', 'PROPN'), ('yo', 'PRON'), ('estoy', 'AUX'), ('cansada', 'ADJ'), ('de', 'ADP'), ('todo', 'PRON')]
# @_Eva_13
# None
# yo
# None
# estoy
# None
# cansada
# a
# cansado
# de
# None
# todo
# None
# ['FF', 'a', 'los', 'geniales', 'de', '@Cinesa', '!', '!']
# [('FF', 'PROPN'), ('a', 'ADP'), ('los', 'DET'), ('geniales', 'NOUN'), ('de', 'ADP'), ('@Cinesa', 'PROPN'), ('!', 'PUNCT'), ('!', 'PUNCT')]
# FF
# None
# a
# None
# los
# None
# geniales
# n
# genial
# de
# None
# @Cinesa
# None
# !
# None
# !
# None
# ['tengo', 'un', 'porrito', 'ya', 'liado', '..', 'pero', 'no', 'se', 'para', 'cuando']
# [('tengo', 'VERB'), ('un', 'DET'), ('porrito', 'NOUN'), ('ya', 'ADV'), ('liado', 'ADJ'), ('..', 'PUNCT'), ('pero', 'CCONJ'), ('no', 'ADV'), ('se', 'PRON'), ('para', 'ADP'), ('cuando', 'SCONJ')]
# tengo
# v
# tener
# un
# None
# porrito
# n
# porrito
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# liado
# a
# liado
# ..
# None
# pero
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -2.5
# se
# None
# para
# None
# cuando
# None
# ['@flyintothestorm', 'la', 'tienes', 'pequeña', 'al']
# [('@flyintothestorm', 'PROPN'), ('la', 'DET'), ('tienes', 'NOUN'), ('pequeña', 'ADJ'), ('al', 'ADP')]
# @flyintothestorm
# None
# la
# None
# tienes
# n
# tién
# pequeña
# a
# pequeño
# al
# None
# ['12', '.', 'Ron', ',', 'es', 'complicado', 'para', 'mí', 'hacer', 'de', 'gry']
# [('12', 'NUM'), ('.', 'PUNCT'), ('Ron', 'PROPN'), (',', 'PUNCT'), ('es', 'AUX'), ('complicado', 'ADJ'), ('para', 'ADP'), ('mí', 'PRON'), ('hacer', 'VERB'), ('de', 'ADP'), ('gry', 'NOUN')]
# 12
# None
# .
# None
# Ron
# None
# ,
# None
# es
# None
# complicado
# a
# complicado
# para
# None
# mí
# None
# hacer
# v
# hacer
# de
# None
# gry
# n
# gry
# ['No', 'las', 'quiero', 'tan', 'grandes']
# [('No', 'ADV'), ('las', 'PRON'), ('quiero', 'VERB'), ('tan', 'ADV'), ('grandes', 'ADJ')]
# No
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# las
# None
# quiero
# v
# querer
# tan
# r
# tanto
# grandes
# a
# grande
# ['Mi', 'noche', 'de', 'hoy', 'es', 'un', 'constante', '"', 'no', '"', '.']
# [('Mi', 'DET'), ('noche', 'NOUN'), ('de', 'ADP'), ('hoy', 'ADV'), ('es', 'AUX'), ('un', 'DET'), ('constante', 'ADJ'), ('"', 'PUNCT'), ('no', 'ADV'), ('"', 'PUNCT'), ('.', 'PUNCT')]
# Mi
# None
# noche
# n
# noche
# ["SentiSynset('noche.n')"]
# Positive score for noche: 0.0
# Negative score for noche: 0.625
# Sentiment value: -0.625
# de
# None
# hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -2.0
# es
# None
# un
# None
# constante
# a
# constante
# "
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -4.125
# "
# None
# .
# None
# ['Todo', 'fue', 'una', 'noche', 'fugaz']
# [('Todo', 'PRON'), ('fue', 'AUX'), ('una', 'DET'), ('noche', 'NOUN'), ('fugaz', 'ADJ')]
# Todo
# None
# fue
# None
# una
# None
# noche
# n
# noche
# ["SentiSynset('noche.n')"]
# Positive score for noche: 0.0
# Negative score for noche: 0.625
# Sentiment value: -0.625
# fugaz
# a
# fugaz
# ['hoy', 'ha', 'sido', 'un', 'día', 'muy', 'malo', 'para', 'mi']
# [('hoy', 'ADV'), ('ha', 'AUX'), ('sido', 'AUX'), ('un', 'DET'), ('día', 'NOUN'), ('muy', 'ADV'), ('malo', 'ADJ'), ('para', 'ADP'), ('mi', 'DET')]
# hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -0.75
# ha
# None
# sido
# None
# un
# None
# día
# n
# día
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -2.0
# malo
# a
# malo
# ["SentiSynset('malo.a')"]
# Positive score for malo: 0.0
# Negative score for malo: 0.125
# Sentiment value: -3.375
# para
# None
# mi
# None
# ['Era', 'mas', 'el', 'ambiente', 'chungo']
# [('Era', 'AUX'), ('mas', 'ADV'), ('el', 'DET'), ('ambiente', 'NOUN'), ('chungo', 'VERB')]
# Era
# None
# mas
# r
# mas
# el
# None
# ambiente
# n
# ambiente
# chungo
# v
# chunguir
# ['Bendito', 'año', 'el', 'que', 'me', 'espera']
# [('Bendito', 'ADJ'), ('año', 'NOUN'), ('el', 'DET'), ('que', 'PRON'), ('me', 'PRON'), ('espera', 'VERB')]
# Bendito
# a
# bendito
# año
# n
# año
# el
# None
# que
# None
# me
# None
# espera
# v
# esperar
# ["SentiSynset('esperar.v')", "SentiSynset('esperar con expectación.v')"]
# Positive score for esperar: 0.0
# Negative score for esperar: 0.75
# Sentiment value: -0.75
# ['No', 'se', 'me', 'enciende', 'el', 'ruter']
# [('No', 'ADV'), ('se', 'PRON'), ('me', 'PRON'), ('enciende', 'VERB'), ('el', 'DET'), ('ruter', 'NOUN')]
# No
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# se
# None
# me
# None
# enciende
# v
# encender
# el
# None
# ruter
# n
# ruter
# ['Cuando', 'llevas', 'todo', 'el', 'día', 'solo']
# [('Cuando', 'SCONJ'), ('llevas', 'VERB'), ('todo', 'DET'), ('el', 'DET'), ('día', 'NOUN'), ('solo', 'ADJ')]
# Cuando
# None
# llevas
# v
# llevar
# ["SentiSynset('llevar.v')", "SentiSynset('conservar.v')", "SentiSynset('mantener.v')", "SentiSynset('preservar.v')"]
# Positive score for llevar: 0.0
# Negative score for llevar: 0.625
# Sentiment value: -0.625
# todo
# None
# el
# None
# día
# n
# día
# solo
# a
# solo
# ['Oye', ',', 'me', 'tenéis', 'un', 'poco', 'abandonada', ' ', 'https://t.co/ywr9ry5Dqo']
# [('Oye', 'VERB'), (',', 'PUNCT'), ('me', 'PRON'), ('tenéis', 'VERB'), ('un', 'DET'), ('poco', 'ADV'), ('abandonada', 'ADJ'), (' ', 'SPACE'), ('https://t.co/ywr9ry5Dqo', 'VERB')]
# Oye
# v
# oír
# ,
# None
# me
# None
# tenéis
# v
# tenéis
# un
# None
# poco
# r
# poco
# abandonada
# a
# abandonado
#
# None
# https://t.co/ywr9ry5Dqo
# v
# https://t.co/ywr9ry5dqir
# ['@PabloBSanchez', 'tas', 'copiao', 'un', 'poco', 'no', '?', '?']
# [('@PabloBSanchez', 'PROPN'), ('tas', 'AUX'), ('copiao', 'VERB'), ('un', 'DET'), ('poco', 'ADV'), ('no', 'ADV'), ('?', 'PUNCT'), ('?', 'PUNCT')]
# @PabloBSanchez
# None
# tas
# None
# copiao
# v
# copiao
# un
# None
# poco
# r
# poco
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# ?
# None
# ?
# None
# ['Hoy', 'ha', 'hecho', 'un', 'día', 'espléndido', '.', 'En', 'todos', 'los', 'sentidos', '.']
# [('Hoy', 'ADV'), ('ha', 'AUX'), ('hecho', 'VERB'), ('un', 'DET'), ('día', 'NOUN'), ('espléndido', 'ADJ'), ('.', 'PUNCT'), ('En', 'ADP'), ('todos', 'DET'), ('los', 'DET'), ('sentidos', 'NOUN'), ('.', 'PUNCT')]
# Hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -0.75
# ha
# None
# hecho
# v
# hacer
# un
# None
# día
# n
# día
# espléndido
# a
# espléndido
# .
# None
# En
# None
# todos
# None
# los
# None
# sentidos
# n
# sentido
# .
# None
# ['Decidme', 'en', 'el', 'cc', 'que', 'soy', 'muy', 'guapa']
# [('Decidme', 'PROPN'), ('en', 'ADP'), ('el', 'DET'), ('cc', 'NOUN'), ('que', 'PRON'), ('soy', 'AUX'), ('muy', 'ADV'), ('guapa', 'ADJ')]
# Decidme
# None
# en
# None
# el
# None
# cc
# n
# cc
# que
# None
# soy
# None
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.5
# guapa
# a
# guapo
# ['@AlezcoII', 'por', 'que', 'sois', 'todos', 'tan', 'mayores']
# [('@AlezcoII', 'VERB'), ('por', 'ADP'), ('que', 'SCONJ'), ('sois', 'VERB'), ('todos', 'PRON'), ('tan', 'ADV'), ('mayores', 'ADJ')]
# @AlezcoII
# v
# @alezcoii
# por
# None
# que
# None
# sois
# v
# sois
# todos
# None
# tan
# r
# tanto
# mayores
# a
# mayor
# ['Todavía', 'son', 'las', 'nueveeee', 'e', 'e', 'e', 'e', 'e', 'e', 'eeee', 'Uf']
# [('Todavía', 'ADV'), ('son', 'AUX'), ('las', 'DET'), ('nueveeee', 'NOUN'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('eeee', 'VERB'), ('Uf', 'PROPN')]
# Todavía
# r
# todavía
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for todavía: 0.0
# Negative score for todavía: 0.875
# Sentiment value: -0.875
# son
# None
# las
# None
# nueveeee
# n
# nueveeee
# e
# None
# e
# None
# e
# None
# e
# None
# e
# None
# e
# None
# eeee
# v
# eeee
# Uf
# None
# ['La', 'soja', 'no', 'es', 'buena']
# [('La', 'DET'), ('soja', 'NOUN'), ('no', 'ADV'), ('es', 'AUX'), ('buena', 'ADJ')]
# La
# None
# soja
# n
# soja
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# es
# None
# buena
# a
# buen
# ['@vaporuvis', 'tia', ',', 'no', 'estabas', 'conectada']
# [('@vaporuvis', 'NUM'), ('tia', 'NOUN'), (',', 'PUNCT'), ('no', 'ADV'), ('estabas', 'VERB'), ('conectada', 'ADJ')]
# @vaporuvis
# None
# tia
# n
# tia
# ,
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# estabas
# v
# estabar
# conectada
# a
# conectado
# ['@FreeEleanor', '¿', 'Tu', 'también', 'lo', 'das', 'por', 'perdido', '?']
# [('@FreeEleanor', 'NOUN'), ('¿', 'PUNCT'), ('Tu', 'PROPN'), ('también', 'ADV'), ('lo', 'PRON'), ('das', 'VERB'), ('por', 'ADP'), ('perdido', 'NOUN'), ('?', 'PUNCT')]
# @FreeEleanor
# n
# @freeeleanor
# ¿
# None
# Tu
# None
# también
# r
# también
# lo
# None
# das
# v
# dar
# ["SentiSynset('dar.v')", "SentiSynset('sacrificar.v')"]
# Positive score for dar: 0.0
# Negative score for dar: 0.5
# Sentiment value: -0.5
# por
# None
# perdido
# n
# perdido
# ?
# None
# ['tercer', 'día', 'y', 'ya', 'voy', 'en', 'chándal']
# [('tercer', 'ADJ'), ('día', 'NOUN'), ('y', 'CCONJ'), ('ya', 'ADV'), ('voy', 'VERB'), ('en', 'ADP'), ('chándal', 'NOUN')]
# tercer
# a
# tercer
# día
# n
# día
# y
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# voy
# v
# ir
# ["SentiSynset('ir.v')", "SentiSynset('venir bien.v')"]
# Positive score for ir: 0.125
# Negative score for ir: 0.875
# Sentiment value: -2.5
# en
# None
# chándal
# n
# chándal
# ['tengo', 'ya', 'examen', 'en', 'un', 'mes', ',', 'qué', 'bonito']
# [('tengo', 'VERB'), ('ya', 'ADV'), ('examen', 'NOUN'), ('en', 'ADP'), ('un', 'DET'), ('mes', 'NOUN'), (',', 'PUNCT'), ('qué', 'PRON'), ('bonito', 'ADJ')]
# tengo
# v
# tener
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# examen
# n
# examen
# en
# None
# un
# None
# mes
# n
# mes
# ,
# None
# qué
# None
# bonito
# a
# bonito
# ['¿', 'por', 'qué', 'os', 'empeñáis', 'en', 'que', 'no', 'soy', 'española', '?']
# [('¿', 'PUNCT'), ('por', 'ADP'), ('qué', 'PRON'), ('os', 'PRON'), ('empeñáis', 'VERB'), ('en', 'ADP'), ('que', 'SCONJ'), ('no', 'ADV'), ('soy', 'AUX'), ('española', 'ADJ'), ('?', 'PUNCT')]
# ¿
# None
# por
# None
# qué
# None
# os
# None
# empeñáis
# v
# empeñáis
# en
# None
# que
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# soy
# None
# española
# a
# español
# ?
# None
# ['@Juan_H_8', 'ya', 'está', ',', 'soy', 'la', 'puta', 'ama']
# [('@Juan_H_8', 'PROPN'), ('ya', 'ADV'), ('está', 'AUX'), (',', 'PUNCT'), ('soy', 'AUX'), ('la', 'DET'), ('puta', 'NOUN'), ('ama', 'NOUN')]
# @Juan_H_8
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# está
# None
# ,
# None
# soy
# None
# la
# None
# puta
# n
# puta
# ama
# n
# ama
# ['@eeeinn', 'es', 'muy', 'muy', 'duro']
# [('@eeeinn', 'VERB'), ('es', 'AUX'), ('muy', 'ADV'), ('muy', 'ADV'), ('duro', 'ADJ')]
# @eeeinn
# v
# @eeeinn
# es
# None
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.5
# muy
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -1.5
# duro
# a
# duro
# ["SentiSynset('duro.a')"]
# Positive score for duro: 0.0
# Negative score for duro: 0.25
# Sentiment value: -2.75
# ['comienza', 'otro', 'dia', 'de', 'mierrrrrrda']
# [('comienza', 'VERB'), ('otro', 'DET'), ('dia', 'PROPN'), ('de', 'ADP'), ('mierrrrrrda', 'NOUN')]
# comienza
# v
# comenzar
# otro
# None
# dia
# None
# de
# None
# mierrrrrrda
# n
# mierrrrrrda
# ['La', 'pulsera', 'es', 'preciosa', 'tio']
# [('La', 'DET'), ('pulsera', 'NOUN'), ('es', 'AUX'), ('preciosa', 'ADJ'), ('tio', 'NOUN')]
# La
# None
# pulsera
# n
# pulsera
# es
# None
# preciosa
# a
# precioso
# tio
# n
# tio
# ['Buenos', 'dias', '!', ' ', 'V', 'I', 'E', 'R', 'N', 'E', 'S']
# [('Buenos', 'PROPN'), ('dias', 'ADJ'), ('!', 'PUNCT'), (' ', 'SPACE'), ('V', 'PROPN'), ('I', 'CCONJ'), ('E', 'PROPN'), ('R', 'PROPN'), ('N', 'PROPN'), ('E', 'PROPN'), ('S', 'PROPN')]
# Buenos
# None
# dias
# a
# dia
# !
# None
#
# None
# V
# None
# I
# None
# E
# None
# R
# None
# N
# None
# E
# None
# S
# None
# ['@yolindasd', 'qué', 'va', ',', 'me', 'es', 'imposible', 'pf', ' ', 'otra', 'vez', 'será']
# [('@yolindasd', 'PROPN'), ('qué', 'PRON'), ('va', 'VERB'), (',', 'PUNCT'), ('me', 'PRON'), ('es', 'AUX'), ('imposible', 'ADJ'), ('pf', 'ADP'), (' ', 'SPACE'), ('otra', 'DET'), ('vez', 'NOUN'), ('será', 'AUX')]
# @yolindasd
# None
# qué
# None
# va
# v
# ir
# ["SentiSynset('ir.v')", "SentiSynset('venir bien.v')"]
# Positive score for ir: 0.125
# Negative score for ir: 0.875
# Sentiment value: -0.75
# ,
# None
# me
# None
# es
# None
# imposible
# a
# imposible
# pf
# None
#
# None
# otra
# None
# vez
# n
# vez
# será
# None
# ['Que', 'os', 'peten', 'el', 'ojete']
# [('Que', 'SCONJ'), ('os', 'PRON'), ('peten', 'VERB'), ('el', 'DET'), ('ojete', 'NOUN')]
# Que
# None
# os
# None
# peten
# v
# petir
# el
# None
# ojete
# n
# ojete
# ['@Adri_Rll', '_', 'por', 'que', 'es', 'triste', 'no', '?']
# [('@Adri_Rll', 'PROPN'), ('_', 'PROPN'), ('por', 'ADP'), ('que', 'SCONJ'), ('es', 'AUX'), ('triste', 'ADJ'), ('no', 'ADV'), ('?', 'PUNCT')]
# @Adri_Rll
# None
# _
# None
# por
# None
# que
# None
# es
# None
# triste
# a
# triste
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# ?
# None
# ['@123pnz', 'Eso', 'de', 'las', 'pilotos-plátano', 'ya', 'no', 'es', 'lo', 'que', 'era', '...']
# [('@123pnz', 'NOUN'), ('Eso', 'PROPN'), ('de', 'ADP'), ('las', 'DET'), ('pilotos-plátano', 'PROPN'), ('ya', 'ADV'), ('no', 'ADV'), ('es', 'AUX'), ('lo', 'PRON'), ('que', 'PRON'), ('era', 'AUX'), ('...', 'PUNCT')]
# @123pnz
# n
# @123pnz
# Eso
# None
# de
# None
# las
# None
# pilotos-plátano
# None
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -2.5
# es
# None
# lo
# None
# que
# None
# era
# None
# ...
# None
# ['Estoy', 'mala', 'y', 'tengo', 'mucho', 'que', 'estudiar']
# [('Estoy', 'AUX'), ('mala', 'ADJ'), ('y', 'CCONJ'), ('tengo', 'VERB'), ('mucho', 'ADV'), ('que', 'SCONJ'), ('estudiar', 'VERB')]
# Estoy
# None
# mala
# a
# malo
# ["SentiSynset('malo.a')"]
# Positive score for malo: 0.0
# Negative score for malo: 0.125
# Sentiment value: -0.125
# y
# None
# tengo
# v
# tener
# mucho
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.75
# que
# None
# estudiar
# v
# estudiar
# ["SentiSynset('considerar.v')", "SentiSynset('estudiar.v')"]
# Positive score for estudiar: 0.25
# Negative score for estudiar: 0.75
# Sentiment value: -1.875
# ['La', 'vida', 'no', 'es', 'bella']
# [('La', 'DET'), ('vida', 'NOUN'), ('no', 'ADV'), ('es', 'AUX'), ('bella', 'ADJ')]
# La
# None
# vida
# n
# vida
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# es
# None
# bella
# a
# bello
# ['@PETEVANDYK3', 'que', 'va', 'tío', ',', 'aún', 'no', 'lo', 'he', 'probado']
# [('@PETEVANDYK3', 'NOUN'), ('que', 'PRON'), ('va', 'VERB'), ('tío', 'NOUN'), (',', 'PUNCT'), ('aún', 'ADV'), ('no', 'ADV'), ('lo', 'PRON'), ('he', 'AUX'), ('probado', 'VERB')]
# @PETEVANDYK3
# n
# @petevandyk3
# que
# None
# va
# v
# ir
# ["SentiSynset('ir.v')", "SentiSynset('venir bien.v')"]
# Positive score for ir: 0.125
# Negative score for ir: 0.875
# Sentiment value: -0.75
# tío
# n
# tío
# ,
# None
# aún
# r
# aún
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for aún: 0.0
# Negative score for aún: 0.875
# Sentiment value: -2.375
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -4.75
# lo
# None
# he
# None
# probado
# v
# probar
# ['@gypsyheart_xo', 'pero', 'no', 'es', 'lo', 'mismo']
# [('@gypsyheart_xo', 'VERB'), ('pero', 'CCONJ'), ('no', 'ADV'), ('es', 'AUX'), ('lo', 'PRON'), ('mismo', 'DET')]
# @gypsyheart_xo
# v
# @gypsyheart_xir
# pero
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# es
# None
# lo
# None
# mismo
# None
# ['@Mg08Gonza', 'no', 'sé', 'tío', ',', 'aun', 'no', 'lo', 'he', 'probado']
# [('@Mg08Gonza', 'PUNCT'), ('no', 'ADV'), ('sé', 'VERB'), ('tío', 'NOUN'), (',', 'PUNCT'), ('aun', 'ADV'), ('no', 'ADV'), ('lo', 'PRON'), ('he', 'AUX'), ('probado', 'VERB')]
# @Mg08Gonza
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# sé
# v
# saber
# ["SentiSynset('sabiduría.n')", "SentiSynset('saber.n')", "SentiSynset('sapiencia.n')"]
# Positive score for saber: 0.375
# Negative score for saber: 0.625
# Sentiment value: -1.75
# tío
# n
# tío
# ,
# None
# aun
# r
# aun
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -3.5
# lo
# None
# he
# None
# probado
# v
# probar
# ['Es', 'que', 'el', 'batido', 'es', 'mucho', 'batido']
# [('Es', 'AUX'), ('que', 'SCONJ'), ('el', 'DET'), ('batido', 'NOUN'), ('es', 'AUX'), ('mucho', 'ADV'), ('batido', 'ADJ')]
# Es
# None
# que
# None
# el
# None
# batido
# n
# batido
# es
# None
# mucho
# r
# mucho
# ["SentiSynset('mucho.r')", "SentiSynset('muchisimo.r')"]
# Positive score for mucho: 0.25
# Negative score for mucho: 0.75
# Sentiment value: -0.5
# batido
# a
# batido
# ['Lo', 'malita', 'que', 'estoy', 'y', 'lo', 'poco', 'que', 'me', 'quejo']
# [('Lo', 'PRON'), ('malita', 'VERB'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('y', 'CCONJ'), ('lo', 'PRON'), ('poco', 'ADV'), ('que', 'SCONJ'), ('me', 'PRON'), ('quejo', 'VERB')]
# Lo
# None
# malita
# v
# malitar
# que
# None
# estoy
# None
# y
# None
# lo
# None
# poco
# r
# poco
# que
# None
# me
# None
# quejo
# v
# quejo
# ['@elenasdfghjk', 'yo', 'lo', 'hice', 'Con', 'mi', 'ex', ' ']
# [('@elenasdfghjk', 'PROPN'), ('yo', 'PRON'), ('lo', 'PRON'), ('hice', 'VERB'), ('Con', 'ADP'), ('mi', 'DET'), ('ex', 'ADJ'), (' ', 'SPACE')]
# @elenasdfghjk
# None
# yo
# None
# lo
# None
# hice
# v
# hacer
# Con
# None
# mi
# None
# ex
# a
# ex
#
# None
# ['Hoy', 'por', 'primera', 'vez', 'me', 'ha', 'funcionado', 'el', 'sad', '.', ' ']
# [('Hoy', 'ADV'), ('por', 'ADP'), ('primera', 'ADJ'), ('vez', 'NOUN'), ('me', 'PRON'), ('ha', 'AUX'), ('funcionado', 'VERB'), ('el', 'DET'), ('sad', 'NOUN'), ('.', 'PUNCT'), (' ', 'SPACE')]
# Hoy
# r
# hoy
# ["SentiSynset('hoy.n')"]
# Positive score for hoy: 0.125
# Negative score for hoy: 0.875
# Sentiment value: -0.75
# por
# None
# primera
# a
# primero
# vez
# n
# vez
# me
# None
# ha
# None
# funcionado
# v
# funcionar
# el
# None
# sad
# n
# sad
# .
# None
#
# None
# ['#', 'FF', 'a', 'los', 'magníficos', 'de', '@AccionCine', '!', '!']
# [('#', 'NOUN'), ('FF', 'PROPN'), ('a', 'ADP'), ('los', 'DET'), ('magníficos', 'NOUN'), ('de', 'ADP'), ('@AccionCine', 'NOUN'), ('!', 'PUNCT'), ('!', 'PUNCT')]
# #
# n
# #
# FF
# None
# a
# None
# los
# None
# magníficos
# n
# magnífico
# de
# None
# @AccionCine
# n
# @accioncine
# !
# None
# !
# None
# ['Aún', 'me', 'duele', 'el', 'ojo', 'derecho']
# [('Aún', 'ADV'), ('me', 'PRON'), ('duele', 'VERB'), ('el', 'DET'), ('ojo', 'NOUN'), ('derecho', 'ADJ')]
# Aún
# r
# aún
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for aún: 0.0
# Negative score for aún: 0.875
# Sentiment value: -0.875
# me
# None
# duele
# v
# doler
# el
# None
# ojo
# n
# ojo
# derecho
# a
# derecho
# ['tio', 'que', 'dolor', 'de', 'piernas']
# [('tio', 'NOUN'), ('que', 'SCONJ'), ('dolor', 'VERB'), ('de', 'ADP'), ('piernas', 'NOUN')]
# tio
# n
# tio
# que
# None
# dolor
# v
# dolor
# de
# None
# piernas
# n
# pierna
# ['Hace', 'un', 'día', 'estupendo', '.', 'Otra', 'vez']
# [('Hace', 'VERB'), ('un', 'DET'), ('día', 'NOUN'), ('estupendo', 'VERB'), ('.', 'PUNCT'), ('Otra', 'DET'), ('vez', 'NOUN')]
# Hace
# v
# hacer
# un
# None
# día
# n
# día
# estupendo
# v
# estupendo
# .
# None
# Otra
# None
# vez
# n
# vez
# ['@Mr_Wath', 'con', 'lo', 'majo', 'que', 'eres']
# [('@Mr_Wath', 'ADJ'), ('con', 'ADP'), ('lo', 'PRON'), ('majo', 'NOUN'), ('que', 'PRON'), ('eres', 'AUX')]
# @Mr_Wath
# a
# @mr_wath
# con
# None
# lo
# None
# majo
# n
# majo
# que
# None
# eres
# None
# ['Me', 'congelo', 'cuando', 'me', 'despierto']
# [('Me', 'PRON'), ('congelo', 'VERB'), ('cuando', 'SCONJ'), ('me', 'PRON'), ('despierto', 'VERB')]
# Me
# None
# congelo
# v
# congelo
# cuando
# None
# me
# None
# despierto
# v
# despertar
# ["SentiSynset('invitar.v')", "SentiSynset('conjurar.v')", "SentiSynset('evocar.v')", "SentiSynset('exponer.v')", "SentiSynset('invocar.v')", "SentiSynset('despertar.v')", "SentiSynset('traer.v')", "SentiSynset('llamar.v')", "SentiSynset('agitar.v')"]
# Positive score for despertar: 0.125
# Negative score for despertar: 0.875
# Sentiment value: -0.75
# ['@Rafafakari', 'que', 'no', 'que', 'estoy', 'mala']
# [('@Rafafakari', 'NOUN'), ('que', 'SCONJ'), ('no', 'ADV'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('mala', 'ADJ')]
# @Rafafakari
# n
# @rafafakari
# que
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# que
# None
# estoy
# None
# mala
# a
# malo
# ["SentiSynset('malo.a')"]
# Positive score for malo: 0.0
# Negative score for malo: 0.125
# Sentiment value: -1.625
# ['@Bammz87', 'ya', 'eres', 'bueno', 'a', 'esto', 'o', 'qué', '?']
# [('@Bammz87', 'VERB'), ('ya', 'ADV'), ('eres', 'AUX'), ('bueno', 'ADJ'), ('a', 'ADP'), ('esto', 'PRON'), ('o', 'CCONJ'), ('qué', 'PRON'), ('?', 'PUNCT')]
# @Bammz87
# v
# @bammz87
# ya
# r
# ya
# ["SentiSynset('todavía.r')", "SentiSynset('ya.r')", "SentiSynset('aún.r')"]
# Positive score for ya: 0.0
# Negative score for ya: 0.875
# Sentiment value: -0.875
# eres
# None
# bueno
# a
# bueno
# ["SentiSynset('bueno.a')"]
# Positive score for bueno: 1.0
# Negative score for bueno: 0.0
# Sentiment value: -0.75
# a
# None
# esto
# None
# o
# None
# qué
# None
# ?
# None
# ['@Radinosaurio', ' ', 'yo', 'soy', 'asi', 'con', 'mis', 'amigos', 'pero', 'ellos', 'no', 'son', 'así']
# [('@Radinosaurio', 'ADJ'), (' ', 'SPACE'), ('yo', 'PRON'), ('soy', 'AUX'), ('asi', 'ADV'), ('con', 'ADP'), ('mis', 'DET'), ('amigos', 'NOUN'), ('pero', 'CCONJ'), ('ellos', 'PRON'), ('no', 'ADV'), ('son', 'AUX'), ('así', 'ADV')]
# @Radinosaurio
# a
# @radinosaurio
#
# None
# yo
# None
# soy
# None
# asi
# r
# asi
# con
# None
# mis
# None
# amigos
# n
# amigo
# ["SentiSynset('amigo.n')"]
# Positive score for amigo: 0.25
# Negative score for amigo: 0.75
# Sentiment value: -0.5
# pero
# None
# ellos
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -1.75
# son
# None
# así
# r
# así
# ['@ElTerral', 'somos', 'más', 'felices', 'sin', 'ti']
# [('@ElTerral', 'ADJ'), ('somos', 'AUX'), ('más', 'ADV'), ('felices', 'ADJ'), ('sin', 'ADP'), ('ti', 'PRON')]
# @ElTerral
# a
# @elterral
# somos
# None
# más
# r
# más
# felices
# a
# feliz
# sin
# None
# ti
# None
# ['Que', 'agobio', 'tío', 'que', 'mala', 'estoy']
# [('Que', 'SCONJ'), ('agobio', 'ADJ'), ('tío', 'NOUN'), ('que', 'PRON'), ('mala', 'VERB'), ('estoy', 'AUX')]
# Que
# None
# agobio
# a
# agobio
# tío
# n
# tío
# que
# None
# mala
# v
# malir
# estoy
# None
# ['Y', 'eso', 'es', 'triste', 'la', 'vdd', '.', 'Por', 'vosotros', ',', 'no', 'por', 'mi']
# [('Y', 'CCONJ'), ('eso', 'PRON'), ('es', 'AUX'), ('triste', 'ADJ'), ('la', 'DET'), ('vdd', 'NOUN'), ('.', 'PUNCT'), ('Por', 'ADP'), ('vosotros', 'NOUN'), (',', 'PUNCT'), ('no', 'ADV'), ('por', 'ADP'), ('mi', 'DET')]
# Y
# None
# eso
# None
# es
# None
# triste
# a
# triste
# la
# None
# vdd
# n
# vdd
# .
# None
# Por
# None
# vosotros
# n
# vosotro
# ,
# None
# no
# r
# no
# ["SentiSynset('no.n')"]
# Positive score for no: 0.0
# Negative score for no: 0.75
# Sentiment value: -0.75
# por
# None
# mi
# None
# ['@LonelySoad', 'mientras', 'que', 'no', 'te', 'pillen', 'la', 'primera', 'semana', 'que', 'es', 'cuando', 'tienes', 'la', 'nariz', 'como', 'un', 'payaso']
# [('@LonelySoad', 'PROPN'), ('mientras', 'CCONJ'), ('que', 'SCONJ'), ('no', 'ADV'), ('te', 'PRON'), ('pillen', 'VERB'), ('la', 'DET'), ('primera', 'ADJ'), ('semana', 'NOUN'), ('que', 'PRON'), ('es', 'AUX'), ('cuando', 'SCONJ'), ('tienes', 'VERB'), ('la', 'DET'), ('nariz', 'NOUN'), ('como', 'SCONJ'), ('un', 'DET'), ('payaso', 'NOUN')]
# ['@ceemeese', 'ya', 'era', 'hora', 'de', 'volver', 'al', 'csgo', 'y', 'dejares', 'el', 'padel', 'bienvenida']
# [('@ceemeese', 'PRON'), ('ya', 'ADV'), ('era', 'AUX'), ('hora', 'NOUN'), ('de', 'ADP'), ('volver', 'VERB'), ('al', 'ADP'), ('csgo', 'NOUN'), ('y', 'CCONJ'), ('dejares', 'NOUN'), ('el', 'DET'), ('padel', 'NOUN'), ('bienvenida', 'ADJ')]
# ['@mireiaescribano', 'justo', 'cuando', 'se', 'terminan', 'las', 'fiestas', 'de', 'verano', ',', 'me', 'viene', 'genial', ' ']
# [('@mireiaescribano', 'VERB'), ('justo', 'ADJ'), ('cuando', 'SCONJ'), ('se', 'PRON'), ('terminan', 'VERB'), ('las', 'DET'), ('fiestas', 'NOUN'), ('de', 'ADP'), ('verano', 'NOUN'), (',', 'PUNCT'), ('me', 'PRON'), ('viene', 'VERB'), ('genial', 'ADJ'), (' ', 'SPACE')]
# ['@LuisMartinez22', '_', 'pensba', 'q', 'iba', 'a', 'hacer', '@wxplosive', 'una', 'reflexion', 'profunda', 'de', 'las', 'q', 'me', 'hace', 'a', 'mi', 'pero']
# [('@LuisMartinez22', 'VERB'), ('_', 'ADJ'), ('pensba', 'ADJ'), ('q', 'CCONJ'), ('iba', 'AUX'), ('a', 'ADP'), ('hacer', 'VERB'), ('@wxplosive', 'NOUN'), ('una', 'DET'), ('reflexion', 'NOUN'), ('profunda', 'ADJ'), ('de', 'ADP'), ('las', 'DET'), ('q', 'PRON'), ('me', 'PRON'), ('hace', 'VERB'), ('a', 'ADP'), ('mi', 'DET'), ('pero', 'CCONJ')]
# ['@Vic_Phantomhive', 'Si', 'lo', 'encuentro', ',', 'sin', 'compañeros', 'y', 'barato', ',', 'me', 'iría', 'hasta', 'ahora', 'mismo']
# [('@Vic_Phantomhive', 'VERB'), ('Si', 'SCONJ'), ('lo', 'PRON'), ('encuentro', 'VERB'), (',', 'PUNCT'), ('sin', 'ADP'), ('compañeros', 'NOUN'), ('y', 'CCONJ'), ('barato', 'ADJ'), (',', 'PUNCT'), ('me', 'PRON'), ('iría', 'VERB'), ('hasta', 'ADP'), ('ahora', 'ADV'), ('mismo', 'DET')]
# ['@MentalistGirl', '@PamplingNews', 'lo', 'sé', ',', 'lo', 'sé', '...', 'la', 'sigo', 'desde', 'hace', 'tiempo', 'Jajajaja', 'es', 'de', 'mis', 'favoritas']
# [('@MentalistGirl', 'PROPN'), ('@PamplingNews', 'PROPN'), ('lo', 'PRON'), ('sé', 'VERB'), (',', 'PUNCT'), ('lo', 'PRON'), ('sé', 'VERB'), ('...', 'PUNCT'), ('la', 'DET'), ('sigo', 'VERB'), ('desde', 'ADP'), ('hace', 'VERB'), ('tiempo', 'NOUN'), ('Jajajaja', 'PROPN'), ('es', 'AUX'), ('de', 'ADP'), ('mis', 'DET'), ('favoritas', 'NOUN')]
# ['Eso', 'de', 'echar', 'de', 'menos', 'tu', 'propia', 'casa', 'son', 'leyendas', 'urbanas']
# [('Eso', 'PRON'), ('de', 'ADP'), ('echar', 'VERB'), ('de', 'ADP'), ('menos', 'ADV'), ('tu', 'PROPN'), ('propia', 'DET'), ('casa', 'NOUN'), ('son', 'AUX'), ('leyendas', 'ADJ'), ('urbanas', 'ADJ')]
# ['@kaveri_miguel', 'yo', 'estoy', 'igual', ',', 'he', 'dormido', 'nada', 'o', 'menos', '...', 'Y', 'en', 'una', 'hora', 'en', 'marcha', 'a', 'currar']
# [('@kaveri_miguel', 'PROPN'), ('yo', 'PRON'), ('estoy', 'AUX'), ('igual', 'ADJ'), (',', 'PUNCT'), ('he', 'AUX'), ('dormido', 'VERB'), ('nada', 'PRON'), ('o', 'CCONJ'), ('menos', 'ADV'), ('...', 'PUNCT'), ('Y', 'CCONJ'), ('en', 'ADP'), ('una', 'DET'), ('hora', 'NOUN'), ('en', 'ADP'), ('marcha', 'NOUN'), ('a', 'ADP'), ('currar', 'VERB')]
# ['@Caspitoo', 'el', 'día', 'que', 'te', 'vi', 'en', 'persona', 'estuviste', 'híper', 'soso', 'conmigo', '...', '¡', 'nunca', 'lo', 'olvidaré', '!']
# [('@Caspitoo', 'VERB'), ('el', 'DET'), ('día', 'NOUN'), ('que', 'PRON'), ('te', 'PRON'), ('vi', 'VERB'), ('en', 'ADP'), ('persona', 'NOUN'), ('estuviste', 'NOUN'), ('híper', 'VERB'), ('soso', 'ADJ'), ('conmigo', 'NOUN'), ('...', 'PUNCT'), ('¡', 'PUNCT'), ('nunca', 'ADV'), ('lo', 'PRON'), ('olvidaré', 'VERB'), ('!', 'PUNCT')]
# ['Echo', 'de', 'menos', 'las', 'sudaderas', 'y', 'los', 'pantalones', 'largos']
# [('Echo', 'PROPN'), ('de', 'ADP'), ('menos', 'ADV'), ('las', 'DET'), ('sudaderas', 'NOUN'), ('y', 'CCONJ'), ('los', 'DET'), ('pantalones', 'NOUN'), ('largos', 'ADJ')]
# ['Quiero', 'mimos', '.', 'Y', 'un', 'zumo', 'de', 'naranja', '.', 'Estoy', 'enfermita']
# [('Quiero', 'VERB'), ('mimos', 'VERB'), ('.', 'PUNCT'), ('Y', 'CCONJ'), ('un', 'DET'), ('zumo', 'NOUN'), ('de', 'ADP'), ('naranja', 'NOUN'), ('.', 'PUNCT'), ('Estoy', 'AUX'), ('enfermita', 'VERB')]
# ['@zambricanto', '@ConsueCaballer', 'me', 'he', 'quedado', 'sorprendida', '!', ' ', 'Me', 'encantan', '!', 'Y', 'me', 'alegro', 'de', 'lo', 'de', 'Blas']
# [('@zambricanto', 'NOUN'), ('@ConsueCaballer', 'PROPN'), ('me', 'PRON'), ('he', 'AUX'), ('quedado', 'VERB'), ('sorprendida', 'ADJ'), ('!', 'PUNCT'), (' ', 'SPACE'), ('Me', 'PRON'), ('encantan', 'VERB'), ('!', 'PUNCT'), ('Y', 'CCONJ'), ('me', 'PRON'), ('alegro', 'VERB'), ('de', 'ADP'), ('lo', 'PRON'), ('de', 'ADP'), ('Blas', 'PROPN')]
# ['@Nebirous', 'una', 'de', 'mis', 'favoritas', 'de', 'tu', 'galería', ',', 'la', 'luz', 'que', 'captaste', 'es', 'muy', 'misteriosa', 'además', '...', 'me', 'encanta', '!']
# [('@Nebirous', 'VERB'), ('una', 'PRON'), ('de', 'ADP'), ('mis', 'DET'), ('favoritas', 'NOUN'), ('de', 'ADP'), ('tu', 'DET'), ('galería', 'NOUN'), (',', 'PUNCT'), ('la', 'DET'), ('luz', 'NOUN'), ('que', 'PRON'), ('captaste', 'VERB'), ('es', 'AUX'), ('muy', 'ADV'), ('misteriosa', 'ADJ'), ('además', 'ADV'), ('...', 'PUNCT'), ('me', 'PRON'), ('encanta', 'VERB'), ('!', 'PUNCT')]
# ['A', 'ver', 'sé', 'que', 'mido', 'menos', 'de', "1'50", 'pero', 'que', 'NO', 'TENGO', '10', 'AÑOS', 'o', 'sea', 'os', 'lo', 'digo', 'en', 'serio', 'no', 'tengo', '10', 'años']
# [('A', 'ADP'), ('ver', 'VERB'), ('sé', 'VERB'), ('que', 'SCONJ'), ('mido', 'ADJ'), ('menos', 'ADV'), ('de', 'ADP'), ("1'50", 'NUM'), ('pero', 'CCONJ'), ('que', 'PRON'), ('NO', 'ADV'), ('TENGO', 'VERB'), ('10', 'NUM'), ('AÑOS', 'PROPN'), ('o', 'CCONJ'), ('sea', 'NOUN'), ('os', 'PRON'), ('lo', 'PRON'), ('digo', 'VERB'), ('en', 'ADP'), ('serio', 'NOUN'), ('no', 'ADV'), ('tengo', 'VERB'), ('10', 'NUM'), ('años', 'NOUN')]
# ['@enekoolabuenaga', 'seguramente', 'no', 'podré', 'estar', 'online', 'hasta', 'mañana']
# [('@enekoolabuenaga', 'VERB'), ('seguramente', 'ADV'), ('no', 'ADV'), ('podré', 'AUX'), ('estar', 'AUX'), ('online', 'ADJ'), ('hasta', 'ADP'), ('mañana', 'ADV')]
# ['Yo', 'a', 'las', '5', 'a', 'No', 'puedo', 'dormir', '*', 'se', 'pone', 'a', 'ver', 'Peppa', 'Pig*esto', 'es', 'peor']
# [('Yo', 'PRON'), ('a', 'ADP'), ('las', 'DET'), ('5', 'NUM'), ('a', 'ADP'), ('No', 'ADV'), ('puedo', 'AUX'), ('dormir', 'VERB'), ('*', 'NUM'), ('se', 'PRON'), ('pone', 'VERB'), ('a', 'ADP'), ('ver', 'VERB'), ('Peppa', 'PROPN'), ('Pig*esto', 'PROPN'), ('es', 'AUX'), ('peor', 'ADJ')]
# ['@Miriam_Munuera', 'calor', '?', '!', 'Calor', '?', '?', 'Hoy', 'mehe', 'muerto', 'de', 'frío']
# [('@Miriam_Munuera', 'DET'), ('calor', 'NOUN'), ('?', 'PUNCT'), ('!', 'PUNCT'), ('Calor', 'NOUN'), ('?', 'PUNCT'), ('?', 'PUNCT'), ('Hoy', 'ADV'), ('mehe', 'VERB'), ('muerto', 'ADJ'), ('de', 'ADP'), ('frío', 'NOUN')]
# ['Buenos', 'dias', ',', 'vamos', 'a', 'hacer', 'algunos', 'recados', 'y', 'a', 'empezar', 'el', 'dia', 'con', 'energia', '!', '!']
# [('Buenos', 'PROPN'), ('dias', 'PROPN'), (',', 'PUNCT'), ('vamos', 'AUX'), ('a', 'ADP'), ('hacer', 'VERB'), ('algunos', 'DET'), ('recados', 'NOUN'), ('y', 'CCONJ'), ('a', 'ADP'), ('empezar', 'VERB'), ('el', 'DET'), ('dia', 'PROPN'), ('con', 'ADP'), ('energia', 'NOUN'), ('!', 'PUNCT'), ('!', 'PUNCT')]
# ['sabes', 'que', 'tu', 'vida', 'es', 'muy', 'puta', 'cuando', 'empiezas', 'las', 'clases', 'en', 'menos', 'de', 'una', 'semana']
# [('sabes', 'VERB'), ('que', 'SCONJ'), ('tu', 'DET'), ('vida', 'NOUN'), ('es', 'AUX'), ('muy', 'ADV'), ('puta', 'NOUN'), ('cuando', 'SCONJ'), ('empiezas', 'NOUN'), ('las', 'DET'), ('clases', 'NOUN'), ('en', 'ADP'), ('menos', 'ADV'), ('de', 'ADP'), ('una', 'DET'), ('semana', 'NOUN')]
# ['@EstreMaimona', 'Hija', 'mía', '...', 'Haces', 'inteligente', 'a', 'la', 'anormal', 'de', '"', 'yolanda', 'morin', '"', '....']
# [('@EstreMaimona', 'PROPN'), ('Hija', 'PROPN'), ('mía', 'DET'), ('...', 'PUNCT'), ('Haces', 'PROPN'), ('inteligente', 'ADJ'), ('a', 'ADP'), ('la', 'DET'), ('anormal', 'NOUN'), ('de', 'ADP'), ('"', 'PUNCT'), ('yolanda', 'NOUN'), ('morin', 'NOUN'), ('"', 'PUNCT'), ('....', 'PUNCT')]
# ['Acaso', 'se', 'nota', 'que', 'extraño', 'muchísimo', 'a', 'Irene', 'y', 'a', 'LucíaAAAAA', '.', 'Es', 'una', 'broma', 'esto']
# [('Acaso', 'ADV'), ('se', 'PRON'), ('nota', 'VERB'), ('que', 'SCONJ'), ('extraño', 'VERB'), ('muchísimo', 'ADJ'), ('a', 'ADP'), ('Irene', 'PROPN'), ('y', 'CCONJ'), ('a', 'ADP'), ('LucíaAAAAA', 'PROPN'), ('.', 'PUNCT'), ('Es', 'AUX'), ('una', 'DET'), ('broma', 'ADJ'), ('esto', 'PRON')]
# ['@apr15', '_', '_', 'seamos', 'como', 'seamos', 'siempre', 'vamos', 'a', 'ser', 'criticados', '....', 'la', 'vida', 'es', 'asi']
# [('@apr15', 'VERB'), ('_', 'PROPN'), ('_', 'ADJ'), ('seamos', 'AUX'), ('como', 'SCONJ'), ('seamos', 'AUX'), ('siempre', 'ADV'), ('vamos', 'AUX'), ('a', 'ADP'), ('ser', 'AUX'), ('criticados', 'VERB'), ('....', 'PUNCT'), ('la', 'DET'), ('vida', 'NOUN'), ('es', 'AUX'), ('asi', 'ADV')]
# ['q', 'en', 'horas', 'estemos', 'en', 'septiembre', ',', 'perdona', '?', '?', '?', '?', '?', ' ', '24', 'junio', 'dnde', 'stas']
# [('q', 'CCONJ'), ('en', 'ADP'), ('horas', 'NOUN'), ('estemos', 'AUX'), ('en', 'ADP'), ('septiembre', 'NOUN'), (',', 'PUNCT'), ('perdona', 'NOUN'), ('?', 'PUNCT'), ('?', 'PUNCT'), ('?', 'PUNCT'), ('?', 'PUNCT'), ('?', 'PUNCT'), (' ', 'SPACE'), ('24', 'NUM'), ('junio', 'NOUN'), ('dnde', 'VERB'), ('stas', 'NOUN')]
# ['Vas', 'tranquilo', 'por', 'la', 'calle', 'y', 'por', 'la', 'cara', 'te', 'encuentras', 'a', 'una', 'persona', 'que', 'no', 'tienes', 'ganas', 'de', 'ver']
# [('Vas', 'AUX'), ('tranquilo', 'ADJ'), ('por', 'ADP'), ('la', 'DET'), ('calle', 'NOUN'), ('y', 'CCONJ'), ('por', 'ADP'), ('la', 'DET'), ('cara', 'NOUN'), ('te', 'PRON'), ('encuentras', 'VERB'), ('a', 'ADP'), ('una', 'DET'), ('persona', 'NOUN'), ('que', 'PRON'), ('no', 'ADV'), ('tienes', 'VERB'), ('ganas', 'NOUN'), ('de', 'ADP'), ('ver', 'VERB')]
# ['Noemi', 'duerme', 'y', 'yo', 'estoy', 'abandonada', ',', 'hacedme', 'caso']
# [('Noemi', 'PROPN'), ('duerme', 'VERB'), ('y', 'CCONJ'), ('yo', 'PRON'), ('estoy', 'AUX'), ('abandonada', 'ADJ'), (',', 'PUNCT'), ('hacedme', 'PROPN'), ('caso', 'PROPN')]
# ['@OnceInfinito', 'lo', 'malo', 'es', 'cuando', 'no', 'hace', 'falta', 'traducirlos', 'porque', 'los', 'entiendes', '...', ' ']
# [('@OnceInfinito', 'NOUN'), ('lo', 'PRON'), ('malo', 'ADJ'), ('es', 'AUX'), ('cuando', 'SCONJ'), ('no', 'ADV'), ('hace', 'VERB'), ('falta', 'NOUN'), ('traducirlos', 'NOUN'), ('porque', 'SCONJ'), ('los', 'DET'), ('entiendes', 'NOUN'), ('...', 'PUNCT'), (' ', 'SPACE')]
# ['@dinomamut', '_', 'Buenos', 'días', '!', 'Ojalá', 'extras', 'todos', 'los', 'meses', ',', 'sí']
# [('@dinomamut', 'PROPN'), ('_', 'PROPN'), ('Buenos', 'PROPN'), ('días', 'NOUN'), ('!', 'PUNCT'), ('Ojalá', 'INTJ'), ('extras', 'NOUN'), ('todos', 'DET'), ('los', 'DET'), ('meses', 'NOUN'), (',', 'PUNCT'), ('sí', 'INTJ')]
# ['Que', 'me', 'dejen', 'de', 'llegar', 'correos', 'de', 'la', 'universidad', 'cuando', 'estoy', 'en', 'el', 'pueblo', 'POR', 'FAVOR']
# [('Que', 'SCONJ'), ('me', 'PRON'), ('dejen', 'VERB'), ('de', 'ADP'), ('llegar', 'VERB'), ('correos', 'NOUN'), ('de', 'ADP'), ('la', 'DET'), ('universidad', 'NOUN'), ('cuando', 'SCONJ'), ('estoy', 'VERB'), ('en', 'ADP'), ('el', 'DET'), ('pueblo', 'NOUN'), ('POR', 'ADP'), ('FAVOR', 'PROPN')]
# ['Muchas', 'gracias', 'por', 'este', 'fantástico', 'post', ' ', '@conelmorrofino']
# [('Muchas', 'PRON'), ('gracias', 'NOUN'), ('por', 'ADP'), ('este', 'DET'), ('fantástico', 'ADJ'), ('post', 'NOUN'), (' ', 'SPACE'), ('@conelmorrofino', 'NOUN')]
# ['@AngelMica13', 'Es', 'que', 'los', 'tiempos', 'son', 'distintos', 'en', 'cada', 'país', ' ', 'A', 'trabajar', 'todos', '!']
# [('@AngelMica13', 'NOUN'), ('Es', 'NOUN'), ('que', 'SCONJ'), ('los', 'DET'), ('tiempos', 'NOUN'), ('son', 'AUX'), ('distintos', 'ADJ'), ('en', 'ADP'), ('cada', 'DET'), ('país', 'NOUN'), (' ', 'SPACE'), ('A', 'ADP'), ('trabajar', 'VERB'), ('todos', 'PRON'), ('!', 'PUNCT')]
# ['@Roberto_R_R', 'De', 'verdad', ',', 'la', 'involución', 'humana', 'es', 'un', 'hecho', 'ya', '...', '¡', 'Qué', 'pena', '!', ' ', '@elcorreogallego']
# [('@Roberto_R_R', 'VERB'), ('De', 'ADP'), ('verdad', 'NOUN'), (',', 'PUNCT'), ('la', 'DET'), ('involución', 'NOUN'), ('humana', 'ADJ'), ('es', 'AUX'), ('un', 'DET'), ('hecho', 'NOUN'), ('ya', 'ADV'), ('...', 'PUNCT'), ('¡', 'PUNCT'), ('Qué', 'DET'), ('pena', 'NOUN'), ('!', 'PUNCT'), (' ', 'SPACE'), ('@elcorreogallego', 'NOUN')]
# ['@nightmareoscura', 'malditos', 'conductores', 'a', 'los', 'que', 'dan', 'el', 'carnet', 'en', 'la', 'tómbola']
# [('@nightmareoscura', 'ADJ'), ('malditos', 'NOUN'), ('conductores', 'ADJ'), ('a', 'ADP'), ('los', 'DET'), ('que', 'PRON'), ('dan', 'VERB'), ('el', 'DET'), ('carnet', 'NOUN'), ('en', 'ADP'), ('la', 'DET'), ('tómbola', 'NOUN')]
# ['@RoarFurii', 'Furiiii', 'a', 'que', 'hora', 'a', 'acabado', 'el', 'directo', '?', 'no', 'llege', 'a', 'verlo']
# [('@RoarFurii', 'VERB'), ('Furiiii', 'PROPN'), ('a', 'ADP'), ('que', 'SCONJ'), ('hora', 'VERB'), ('a', 'ADP'), ('acabado', 'VERB'), ('el', 'DET'), ('directo', 'ADJ'), ('?', 'PUNCT'), ('no', 'ADV'), ('llege', 'VERB'), ('a', 'ADP'), ('verlo', 'VERB')]
# ['@NariSpringfield', 'No', 'sé', 'si', 'saldrá', 'algo', 'relacionado', 'con', 'Escocia', ',', 'pero', 'los', 'paisajes', 'son', 'increíbles']
# [('@NariSpringfield', 'NOUN'), ('No', 'ADV'), ('sé', 'VERB'), ('si', 'SCONJ'), ('saldrá', 'VERB'), ('algo', 'PRON'), ('relacionado', 'ADJ'), ('con', 'ADP'), ('Escocia', 'PROPN'), (',', 'PUNCT'), ('pero', 'CCONJ'), ('los', 'DET'), ('paisajes', 'NOUN'), ('son', 'AUX'), ('increíbles', 'ADJ')]
# ['@MattiaSola1', '@kalashkokirikov', 'tío', ',', 'que', 'no', ',', 'que', 'yo', 'soy', 'el', 'dalas', 'pero', 'cutre', ',', 'déjame']
# [('@MattiaSola1', 'PROPN'), ('@kalashkokirikov', 'PROPN'), ('tío', 'PROPN'), (',', 'PUNCT'), ('que', 'PRON'), ('no', 'ADV'), (',', 'PUNCT'), ('que', 'SCONJ'), ('yo', 'PRON'), ('soy', 'AUX'), ('el', 'DET'), ('dalas', 'NOUN'), ('pero', 'CCONJ'), ('cutre', 'ADJ'), (',', 'PUNCT'), ('déjame', 'VERB')]
# ['quiero', 'hacer', 'un', 'video', 'en', 'youtube', 'desahogándome']
# [('quiero', 'VERB'), ('hacer', 'VERB'), ('un', 'DET'), ('video', 'NOUN'), ('en', 'ADP'), ('youtube', 'PROPN'), ('desahogándome', 'VERB')]
# ['@Juansfy', 'yo', 'solo', 'quiero', 'que', 'tu', 'cuerpo', 'este', 'tan', 'fuerte', 'como', 'tu', 'mente']
# [('@Juansfy', 'VERB'), ('yo', 'PRON'), ('solo', 'ADJ'), ('quiero', 'VERB'), ('que', 'SCONJ'), ('tu', 'DET'), ('cuerpo', 'NOUN'), ('este', 'DET'), ('tan', 'ADV'), ('fuerte', 'ADJ'), ('como', 'SCONJ'), ('tu', 'DET'), ('mente', 'PROPN')]
# ['@pauladiaz_coach', 'un', 'placer', 'guapa', '!', '!', '@alexdurana', 'es', 'un', 'sol', '!', '!', 'bueno', ',', 'los', 'dos', 'los', 'sois']
# [('@pauladiaz_coach', 'NUM'), ('un', 'DET'), ('placer', 'NOUN'), ('guapa', 'ADJ'), ('!', 'PUNCT'), ('!', 'PUNCT'), ('@alexdurana', 'ADJ'), ('es', 'AUX'), ('un', 'DET'), ('sol', 'NOUN'), ('!', 'PUNCT'), ('!', 'PUNCT'), ('bueno', 'ADJ'), (',', 'PUNCT'), ('los', 'DET'), ('dos', 'NUM'), ('los', 'DET'), ('sois', 'PROPN')]
# ['@NoEsUnPagaro', 'que', 'te', 'pasa', 'necesitas', 'ayuda', '?', 'favea', 'si', 'te', 'tienen', 'secuestrada']
# [('@NoEsUnPagaro', 'ADJ'), ('que', 'PRON'), ('te', 'PRON'), ('pasa', 'VERB'), ('necesitas', 'NOUN'), ('ayuda', 'ADJ'), ('?', 'PUNCT'), ('favea', 'VERB'), ('si', 'SCONJ'), ('te', 'PRON'), ('tienen', 'VERB'), ('secuestrada', 'ADJ')]
# ['La', 'escena', 'spoby', 'es', 'tan', 'bonita', 'y', 'tan', 'triste', 'y', 'no', 'paro', 'de', 'llorar', 'damn']
# [('La', 'DET'), ('escena', 'NOUN'), ('spoby', 'VERB'), ('es', 'AUX'), ('tan', 'ADV'), ('bonita', 'ADJ'), ('y', 'CCONJ'), ('tan', 'ADV'), ('triste', 'ADJ'), ('y', 'CCONJ'), ('no', 'ADV'), ('paro', 'VERB'), ('de', 'ADP'), ('llorar', 'VERB'), ('damn', 'NOUN')]
# ['No', 'me', 'pongáis', 'Galantis', 'que', 'pienso', 'en', 'el', 'Arenal', 'y', 'lloro']
# [('No', 'ADV'), ('me', 'PRON'), ('pongáis', 'VERB'), ('Galantis', 'PROPN'), ('que', 'PRON'), ('pienso', 'VERB'), ('en', 'ADP'), ('el', 'DET'), ('Arenal', 'PROPN'), ('y', 'CCONJ'), ('lloro', 'ADJ')]
# ['@SaraWiggum', '@SergloPsycho', 'lo', 'gracioso', 'es', 'que', 'no', 'se', 'de', 'donde', 'voy', 'a', 'sacar', 'tiempo']
# [('@SaraWiggum', 'VERB'), ('@SergloPsycho', 'PRON'), ('lo', 'PRON'), ('gracioso', 'ADJ'), ('es', 'AUX'), ('que', 'SCONJ'), ('no', 'ADV'), ('se', 'PRON'), ('de', 'ADP'), ('donde', 'PRON'), ('voy', 'AUX'), ('a', 'ADP'), ('sacar', 'VERB'), ('tiempo', 'NOUN')]
# ['"', 'Es', 'la', 'crónica', 'de', 'un', 'ciego', 'y', 'su', 'mentira', ',', 'que', 'mil', 'veces', 'repetida', 'se', 'convertirá', 'en', 'verdad', '...', '"', '#', 'MN']
# [('"', 'PUNCT'), ('Es', 'AUX'), ('la', 'DET'), ('crónica', 'NOUN'), ('de', 'ADP'), ('un', 'DET'), ('ciego', 'NOUN'), ('y', 'CCONJ'), ('su', 'DET'), ('mentira', 'NOUN'), (',', 'PUNCT'), ('que', 'SCONJ'), ('mil', 'NUM'), ('veces', 'NOUN'), ('repetida', 'ADJ'), ('se', 'PRON'), ('convertirá', 'VERB'), ('en', 'ADP'), ('verdad', 'NOUN'), ('...', 'PUNCT'), ('"', 'PUNCT'), ('#', 'NOUN'), ('MN', 'PROPN')]
# ['@LaLiLoLaiLoLeo', '!', 'Croquetas', '!', ' ', 'A', 'mí', 'me', 'gustan', 'pelín', 'más', 'hechas', '.']
# [('@LaLiLoLaiLoLeo', 'PROPN'), ('!', 'PUNCT'), ('Croquetas', 'PROPN'), ('!', 'PUNCT'), (' ', 'SPACE'), ('A', 'ADP'), ('mí', 'PRON'), ('me', 'PRON'), ('gustan', 'VERB'), ('pelín', 'NOUN'), ('más', 'ADV'), ('hechas', 'ADJ'), ('.', 'PUNCT')]
# ['@JAGambero', '@tehubriego', 'Porque', ',', 'España', ',', 'es', 'un', 'país', ',', 'Opresor', '¡', '¡', 'malvado', 'y', 'esclavista', '¡', '...']
# [('@JAGambero', 'NOUN'), ('@tehubriego', 'PROPN'), ('Porque', 'SCONJ'), (',', 'PUNCT'), ('España', 'PROPN'), (',', 'PUNCT'), ('es', 'AUX'), ('un', 'DET'), ('país', 'NOUN'), (',', 'PUNCT'), ('Opresor', 'PROPN'), ('¡', 'PUNCT'), ('¡', 'PUNCT'), ('malvado', 'ADJ'), ('y', 'CCONJ'), ('esclavista', 'ADJ'), ('¡', 'PUNCT'), ('...', 'PUNCT')]
# ['@IKEASpain', 'es', 'el', 'mismo', 'así', 'que', 'tomo', 'nota', 'de', 'todo', ' ', '#', 'gracias']
# [('@IKEASpain', 'PROPN'), ('es', 'AUX'), ('el', 'DET'), ('mismo', 'PRON'), ('así', 'ADV'), ('que', 'SCONJ'), ('tomo', 'PROPN'), ('nota', 'NOUN'), ('de', 'ADP'), ('todo', 'DET'), (' ', 'SPACE'), ('#', 'NOUN'), ('gracias', 'NOUN')]
# ...
# ['@SrSerpiente1', 'pero', 'el', 'NDA', 'es', 'poderoso']
# [('@SrSerpiente1', 'NOUN'), ('pero', 'CCONJ'), ('el', 'DET'), ('NDA', 'PROPN'), ('es', 'AUX'), ('poderoso', 'ADJ')]
# ['En', 'serio', 'me', 'estoy', 'asando']
# [('En', 'ADP'), ('serio', 'NOUN'), ('me', 'PRON'), ('estoy', 'AUX'), ('asando', 'VERB')]
# ['Uff', 'que', 'día', 'más', 'pesado', '...', 'Y', 'aún', 'no', 'ha', 'terminado']
# [('Uff', 'PROPN'), ('que', 'PRON'), ('día', 'NOUN'), ('más', 'ADV'), ('pesado', 'ADJ'), ('...', 'PUNCT'), ('Y', 'CCONJ'), ('aún', 'ADV'), ('no', 'ADV'), ('ha', 'AUX'), ('terminado', 'VERB')]
# ['Que', 'por', 'cierto', ',', 'a', 'todo', 'esto', ',', 'está', 'siendo', 'TT']
# [('Que', 'SCONJ'), ('por', 'ADP'), ('cierto', 'ADJ'), (',', 'PUNCT'), ('a', 'ADP'), ('todo', 'DET'), ('esto', 'PRON'), (',', 'PUNCT'), ('está', 'AUX'), ('siendo', 'AUX'), ('TT', 'DET')]
# ['@Dickfluid', 'por', 'que', 'tan', 'bajito', '?']
# [('@Dickfluid', 'NOUN'), ('por', 'ADP'), ('que', 'SCONJ'), ('tan', 'ADV'), ('bajito', 'ADJ'), ('?', 'PUNCT')]
# ['ay', 'no', ',', 'seguid', 'con', 'las', 'preguntas', 'pls']
# [('ay', 'INTJ'), ('no', 'ADV'), (',', 'PUNCT'), ('seguid', 'VERB'), ('con', 'ADP'), ('las', 'DET'), ('preguntas', 'NOUN'), ('pls', 'ADJ')]
# ['@SltCnmg', 'pues', 'no', 'está', 'nada', 'mal']
# [('@SltCnmg', 'NOUN'), ('pues', 'SCONJ'), ('no', 'ADV'), ('está', 'AUX'), ('nada', 'PRON'), ('mal', 'ADV')]
# ['Tu', 'estas', 'buena', 'pero', 'no', ' ', '@May_BloodArmor']
# [('Tu', 'PROPN'), ('estas', 'DET'), ('buena', 'ADJ'), ('pero', 'CCONJ'), ('no', 'ADV'), (' ', 'SPACE'), ('@May_BloodArmor', 'NOUN')]
# ['@SalvaSuay', 'No', 'te', 'veo', 'desde', '2013', ',', '¿', 'lo', 'ves', 'normal', '?']
# [('@SalvaSuay', 'VERB'), ('No', 'ADV'), ('te', 'PRON'), ('veo', 'VERB'), ('desde', 'ADP'), ('2013', 'NOUN'), (',', 'PUNCT'), ('¿', 'PUNCT'), ('lo', 'PRON'), ('ves', 'VERB'), ('normal', 'ADJ'), ('?', 'PUNCT')]
# ['Porque', 'he', 'sido', 'muy', 'buena']
# [('Porque', 'SCONJ'), ('he', 'AUX'), ('sido', 'AUX'), ('muy', 'ADV'), ('buena', 'ADJ')]
# ['@MariaJosRosillo', 'lo', 'peor', 'es', 'que', 'no']
# [('@MariaJosRosillo', 'VERB'), ('lo', 'PRON'), ('peor', 'ADJ'), ('es', 'AUX'), ('que', 'SCONJ'), ('no', 'ADV')]
# ['No', 'tengo', 'resaca', 'porque', 'aun', 'voy', 'borracha']
# [('No', 'ADV'), ('tengo', 'VERB'), ('resaca', 'NOUN'), ('porque', 'SCONJ'), ('aun', 'ADV'), ('voy', 'VERB'), ('borracha', 'NOUN')]
# ['@EleBlue', '_', 'eres', 'muy', 'peque', 'para', 'eso']
# [('@EleBlue', 'AUX'), ('_', 'PROPN'), ('eres', 'AUX'), ('muy', 'ADV'), ('peque', 'VERB'), ('para', 'ADP'), ('eso', 'PRON')]
# ['hoy', 'se', 'les', 'veía', 'muy', 'contentos']
# [('hoy', 'ADV'), ('se', 'PRON'), ('les', 'PRON'), ('veía', 'VERB'), ('muy', 'ADV'), ('contentos', 'ADJ')]
# ['Todo', 'era', 'mejor', 'en', 'la', 'playa']
# [('Todo', 'PRON'), ('era', 'AUX'), ('mejor', 'ADJ'), ('en', 'ADP'), ('la', 'DET'), ('playa', 'NOUN')]
# ['le', 'irá', 'tan', 'bien', 'estoy', 'muy', 'orgullosa', 'de', 'él']
# [('le', 'PRON'), ('irá', 'VERB'), ('tan', 'ADV'), ('bien', 'ADV'), ('estoy', 'AUX'), ('muy', 'ADV'), ('orgullosa', 'ADJ'), ('de', 'ADP'), ('él', 'PRON')]
# ['Me', 'quemao', "'", 'en', 'la', 'piscina', '.']
# [('Me', 'PRON'), ('quemao', 'VERB'), ("'", 'SYM'), ('en', 'ADP'), ('la', 'DET'), ('piscina', 'NOUN'), ('.', 'PUNCT')]
# ['@Plata_y_Verde', 'En', 'eso', 'estaba', 'pero', 'me', 'dio', 'atake', ' ', 'ya', 'voy', 'ya', 'voy']
# [('@Plata_y_Verde', 'PROPN'), ('En', 'ADP'), ('eso', 'PRON'), ('estaba', 'AUX'), ('pero', 'CCONJ'), ('me', 'PRON'), ('dio', 'VERB'), ('atake', 'VERB'), (' ', 'SPACE'), ('ya', 'ADV'), ('voy', 'AUX'), ('ya', 'ADV'), ('voy', 'AUX')]
# ['@CharizardOnFire', 'No', 'estoy', 'hecho', 'de', 'oro']
# [('@CharizardOnFire', 'ADJ'), ('No', 'ADV'), ('estoy', 'AUX'), ('hecho', 'ADJ'), ('de', 'ADP'), ('oro', 'NOUN')]
# ['@Josanguz', 'ya', 'se', 'que', 'no', 'toy', 'bueno']
# [('@Josanguz', 'PROPN'), ('ya', 'ADV'), ('se', 'PRON'), ('que', 'SCONJ'), ('no', 'ADV'), ('toy', 'VERB'), ('bueno', 'ADJ')]
# ['Soy', 'una', 'atrevida', 'ay', ' ', 'todos', 'me', 'lo', 'dicen']
# [('Soy', 'AUX'), ('una', 'DET'), ('atrevida', 'ADJ'), ('ay', 'INTJ'), (' ', 'SPACE'), ('todos', 'PRON'), ('me', 'PRON'), ('lo', 'PRON'), ('dicen', 'VERB')]
# ['@_Eva_13', 'yo', 'estoy', 'cansada', 'de', 'todo']
# [('@_Eva_13', 'PROPN'), ('yo', 'PRON'), ('estoy', 'AUX'), ('cansada', 'ADJ'), ('de', 'ADP'), ('todo', 'PRON')]
# ['FF', 'a', 'los', 'geniales', 'de', '@Cinesa', '!', '!']
# [('FF', 'PROPN'), ('a', 'ADP'), ('los', 'DET'), ('geniales', 'NOUN'), ('de', 'ADP'), ('@Cinesa', 'PROPN'), ('!', 'PUNCT'), ('!', 'PUNCT')]
# ['tengo', 'un', 'porrito', 'ya', 'liado', '..', 'pero', 'no', 'se', 'para', 'cuando']
# [('tengo', 'VERB'), ('un', 'DET'), ('porrito', 'NOUN'), ('ya', 'ADV'), ('liado', 'ADJ'), ('..', 'PUNCT'), ('pero', 'CCONJ'), ('no', 'ADV'), ('se', 'PRON'), ('para', 'ADP'), ('cuando', 'SCONJ')]
# ['@flyintothestorm', 'la', 'tienes', 'pequeña', 'al']
# [('@flyintothestorm', 'PROPN'), ('la', 'DET'), ('tienes', 'NOUN'), ('pequeña', 'ADJ'), ('al', 'ADP')]
# ['12', '.', 'Ron', ',', 'es', 'complicado', 'para', 'mí', 'hacer', 'de', 'gry']
# [('12', 'NUM'), ('.', 'PUNCT'), ('Ron', 'PROPN'), (',', 'PUNCT'), ('es', 'AUX'), ('complicado', 'ADJ'), ('para', 'ADP'), ('mí', 'PRON'), ('hacer', 'VERB'), ('de', 'ADP'), ('gry', 'NOUN')]
# ['No', 'las', 'quiero', 'tan', 'grandes']
# [('No', 'ADV'), ('las', 'PRON'), ('quiero', 'VERB'), ('tan', 'ADV'), ('grandes', 'ADJ')]
# ['Mi', 'noche', 'de', 'hoy', 'es', 'un', 'constante', '"', 'no', '"', '.']
# [('Mi', 'DET'), ('noche', 'NOUN'), ('de', 'ADP'), ('hoy', 'ADV'), ('es', 'AUX'), ('un', 'DET'), ('constante', 'ADJ'), ('"', 'PUNCT'), ('no', 'ADV'), ('"', 'PUNCT'), ('.', 'PUNCT')]
# ['Todo', 'fue', 'una', 'noche', 'fugaz']
# [('Todo', 'PRON'), ('fue', 'AUX'), ('una', 'DET'), ('noche', 'NOUN'), ('fugaz', 'ADJ')]
# ['hoy', 'ha', 'sido', 'un', 'día', 'muy', 'malo', 'para', 'mi']
# [('hoy', 'ADV'), ('ha', 'AUX'), ('sido', 'AUX'), ('un', 'DET'), ('día', 'NOUN'), ('muy', 'ADV'), ('malo', 'ADJ'), ('para', 'ADP'), ('mi', 'DET')]
# ['Era', 'mas', 'el', 'ambiente', 'chungo']
# [('Era', 'AUX'), ('mas', 'ADV'), ('el', 'DET'), ('ambiente', 'NOUN'), ('chungo', 'VERB')]
# ['Bendito', 'año', 'el', 'que', 'me', 'espera']
# [('Bendito', 'ADJ'), ('año', 'NOUN'), ('el', 'DET'), ('que', 'PRON'), ('me', 'PRON'), ('espera', 'VERB')]
# ['No', 'se', 'me', 'enciende', 'el', 'ruter']
# [('No', 'ADV'), ('se', 'PRON'), ('me', 'PRON'), ('enciende', 'VERB'), ('el', 'DET'), ('ruter', 'NOUN')]
# ['Cuando', 'llevas', 'todo', 'el', 'día', 'solo']
# [('Cuando', 'SCONJ'), ('llevas', 'VERB'), ('todo', 'DET'), ('el', 'DET'), ('día', 'NOUN'), ('solo', 'ADJ')]
# ['Oye', ',', 'me', 'tenéis', 'un', 'poco', 'abandonada', ' ', 'https://t.co/ywr9ry5Dqo']
# [('Oye', 'VERB'), (',', 'PUNCT'), ('me', 'PRON'), ('tenéis', 'VERB'), ('un', 'DET'), ('poco', 'ADV'), ('abandonada', 'ADJ'), (' ', 'SPACE'), ('https://t.co/ywr9ry5Dqo', 'VERB')]
# ['@PabloBSanchez', 'tas', 'copiao', 'un', 'poco', 'no', '?', '?']
# [('@PabloBSanchez', 'PROPN'), ('tas', 'AUX'), ('copiao', 'VERB'), ('un', 'DET'), ('poco', 'ADV'), ('no', 'ADV'), ('?', 'PUNCT'), ('?', 'PUNCT')]
# ['Hoy', 'ha', 'hecho', 'un', 'día', 'espléndido', '.', 'En', 'todos', 'los', 'sentidos', '.']
# [('Hoy', 'ADV'), ('ha', 'AUX'), ('hecho', 'VERB'), ('un', 'DET'), ('día', 'NOUN'), ('espléndido', 'ADJ'), ('.', 'PUNCT'), ('En', 'ADP'), ('todos', 'DET'), ('los', 'DET'), ('sentidos', 'NOUN'), ('.', 'PUNCT')]
# ['Decidme', 'en', 'el', 'cc', 'que', 'soy', 'muy', 'guapa']
# [('Decidme', 'PROPN'), ('en', 'ADP'), ('el', 'DET'), ('cc', 'NOUN'), ('que', 'PRON'), ('soy', 'AUX'), ('muy', 'ADV'), ('guapa', 'ADJ')]
# ['@AlezcoII', 'por', 'que', 'sois', 'todos', 'tan', 'mayores']
# [('@AlezcoII', 'VERB'), ('por', 'ADP'), ('que', 'SCONJ'), ('sois', 'VERB'), ('todos', 'PRON'), ('tan', 'ADV'), ('mayores', 'ADJ')]
# ['Todavía', 'son', 'las', 'nueveeee', 'e', 'e', 'e', 'e', 'e', 'e', 'eeee', 'Uf']
# [('Todavía', 'ADV'), ('son', 'AUX'), ('las', 'DET'), ('nueveeee', 'NOUN'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('e', 'CCONJ'), ('eeee', 'VERB'), ('Uf', 'PROPN')]
# ['La', 'soja', 'no', 'es', 'buena']
# [('La', 'DET'), ('soja', 'NOUN'), ('no', 'ADV'), ('es', 'AUX'), ('buena', 'ADJ')]
# ['@vaporuvis', 'tia', ',', 'no', 'estabas', 'conectada']
# [('@vaporuvis', 'NUM'), ('tia', 'NOUN'), (',', 'PUNCT'), ('no', 'ADV'), ('estabas', 'VERB'), ('conectada', 'ADJ')]
# ['@FreeEleanor', '¿', 'Tu', 'también', 'lo', 'das', 'por', 'perdido', '?']
# [('@FreeEleanor', 'NOUN'), ('¿', 'PUNCT'), ('Tu', 'PROPN'), ('también', 'ADV'), ('lo', 'PRON'), ('das', 'VERB'), ('por', 'ADP'), ('perdido', 'NOUN'), ('?', 'PUNCT')]
# ['tercer', 'día', 'y', 'ya', 'voy', 'en', 'chándal']
# [('tercer', 'ADJ'), ('día', 'NOUN'), ('y', 'CCONJ'), ('ya', 'ADV'), ('voy', 'VERB'), ('en', 'ADP'), ('chándal', 'NOUN')]
# ['tengo', 'ya', 'examen', 'en', 'un', 'mes', ',', 'qué', 'bonito']
# [('tengo', 'VERB'), ('ya', 'ADV'), ('examen', 'NOUN'), ('en', 'ADP'), ('un', 'DET'), ('mes', 'NOUN'), (',', 'PUNCT'), ('qué', 'PRON'), ('bonito', 'ADJ')]
# ['¿', 'por', 'qué', 'os', 'empeñáis', 'en', 'que', 'no', 'soy', 'española', '?']
# [('¿', 'PUNCT'), ('por', 'ADP'), ('qué', 'PRON'), ('os', 'PRON'), ('empeñáis', 'VERB'), ('en', 'ADP'), ('que', 'SCONJ'), ('no', 'ADV'), ('soy', 'AUX'), ('española', 'ADJ'), ('?', 'PUNCT')]
# ['@Juan_H_8', 'ya', 'está', ',', 'soy', 'la', 'puta', 'ama']
# [('@Juan_H_8', 'PROPN'), ('ya', 'ADV'), ('está', 'AUX'), (',', 'PUNCT'), ('soy', 'AUX'), ('la', 'DET'), ('puta', 'NOUN'), ('ama', 'NOUN')]
# ['@eeeinn', 'es', 'muy', 'muy', 'duro']
# [('@eeeinn', 'VERB'), ('es', 'AUX'), ('muy', 'ADV'), ('muy', 'ADV'), ('duro', 'ADJ')]
# ['comienza', 'otro', 'dia', 'de', 'mierrrrrrda']
# [('comienza', 'VERB'), ('otro', 'DET'), ('dia', 'PROPN'), ('de', 'ADP'), ('mierrrrrrda', 'NOUN')]
# ['La', 'pulsera', 'es', 'preciosa', 'tio']
# [('La', 'DET'), ('pulsera', 'NOUN'), ('es', 'AUX'), ('preciosa', 'ADJ'), ('tio', 'NOUN')]
# ['Buenos', 'dias', '!', ' ', 'V', 'I', 'E', 'R', 'N', 'E', 'S']
# [('Buenos', 'PROPN'), ('dias', 'ADJ'), ('!', 'PUNCT'), (' ', 'SPACE'), ('V', 'PROPN'), ('I', 'CCONJ'), ('E', 'PROPN'), ('R', 'PROPN'), ('N', 'PROPN'), ('E', 'PROPN'), ('S', 'PROPN')]
# ['@yolindasd', 'qué', 'va', ',', 'me', 'es', 'imposible', 'pf', ' ', 'otra', 'vez', 'será']
# [('@yolindasd', 'PROPN'), ('qué', 'PRON'), ('va', 'VERB'), (',', 'PUNCT'), ('me', 'PRON'), ('es', 'AUX'), ('imposible', 'ADJ'), ('pf', 'ADP'), (' ', 'SPACE'), ('otra', 'DET'), ('vez', 'NOUN'), ('será', 'AUX')]
# ['Que', 'os', 'peten', 'el', 'ojete']
# [('Que', 'SCONJ'), ('os', 'PRON'), ('peten', 'VERB'), ('el', 'DET'), ('ojete', 'NOUN')]
# ['@Adri_Rll', '_', 'por', 'que', 'es', 'triste', 'no', '?']
# [('@Adri_Rll', 'PROPN'), ('_', 'PROPN'), ('por', 'ADP'), ('que', 'SCONJ'), ('es', 'AUX'), ('triste', 'ADJ'), ('no', 'ADV'), ('?', 'PUNCT')]
# ['@123pnz', 'Eso', 'de', 'las', 'pilotos-plátano', 'ya', 'no', 'es', 'lo', 'que', 'era', '...']
# [('@123pnz', 'NOUN'), ('Eso', 'PROPN'), ('de', 'ADP'), ('las', 'DET'), ('pilotos-plátano', 'PROPN'), ('ya', 'ADV'), ('no', 'ADV'), ('es', 'AUX'), ('lo', 'PRON'), ('que', 'PRON'), ('era', 'AUX'), ('...', 'PUNCT')]
# ['Estoy', 'mala', 'y', 'tengo', 'mucho', 'que', 'estudiar']
# [('Estoy', 'AUX'), ('mala', 'ADJ'), ('y', 'CCONJ'), ('tengo', 'VERB'), ('mucho', 'ADV'), ('que', 'SCONJ'), ('estudiar', 'VERB')]
# ['La', 'vida', 'no', 'es', 'bella']
# [('La', 'DET'), ('vida', 'NOUN'), ('no', 'ADV'), ('es', 'AUX'), ('bella', 'ADJ')]
# ['@PETEVANDYK3', 'que', 'va', 'tío', ',', 'aún', 'no', 'lo', 'he', 'probado']
# [('@PETEVANDYK3', 'NOUN'), ('que', 'PRON'), ('va', 'VERB'), ('tío', 'NOUN'), (',', 'PUNCT'), ('aún', 'ADV'), ('no', 'ADV'), ('lo', 'PRON'), ('he', 'AUX'), ('probado', 'VERB')]
# ['@gypsyheart_xo', 'pero', 'no', 'es', 'lo', 'mismo']
# [('@gypsyheart_xo', 'VERB'), ('pero', 'CCONJ'), ('no', 'ADV'), ('es', 'AUX'), ('lo', 'PRON'), ('mismo', 'DET')]
# ['@Mg08Gonza', 'no', 'sé', 'tío', ',', 'aun', 'no', 'lo', 'he', 'probado']
# [('@Mg08Gonza', 'PUNCT'), ('no', 'ADV'), ('sé', 'VERB'), ('tío', 'NOUN'), (',', 'PUNCT'), ('aun', 'ADV'), ('no', 'ADV'), ('lo', 'PRON'), ('he', 'AUX'), ('probado', 'VERB')]
# ['Es', 'que', 'el', 'batido', 'es', 'mucho', 'batido']
# [('Es', 'AUX'), ('que', 'SCONJ'), ('el', 'DET'), ('batido', 'NOUN'), ('es', 'AUX'), ('mucho', 'ADV'), ('batido', 'ADJ')]
# ['Lo', 'malita', 'que', 'estoy', 'y', 'lo', 'poco', 'que', 'me', 'quejo']
# [('Lo', 'PRON'), ('malita', 'VERB'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('y', 'CCONJ'), ('lo', 'PRON'), ('poco', 'ADV'), ('que', 'SCONJ'), ('me', 'PRON'), ('quejo', 'VERB')]
# ['@elenasdfghjk', 'yo', 'lo', 'hice', 'Con', 'mi', 'ex', ' ']
# [('@elenasdfghjk', 'PROPN'), ('yo', 'PRON'), ('lo', 'PRON'), ('hice', 'VERB'), ('Con', 'ADP'), ('mi', 'DET'), ('ex', 'ADJ'), (' ', 'SPACE')]
# ['Hoy', 'por', 'primera', 'vez', 'me', 'ha', 'funcionado', 'el', 'sad', '.', ' ']
# [('Hoy', 'ADV'), ('por', 'ADP'), ('primera', 'ADJ'), ('vez', 'NOUN'), ('me', 'PRON'), ('ha', 'AUX'), ('funcionado', 'VERB'), ('el', 'DET'), ('sad', 'NOUN'), ('.', 'PUNCT'), (' ', 'SPACE')]
# ['#', 'FF', 'a', 'los', 'magníficos', 'de', '@AccionCine', '!', '!']
# [('#', 'NOUN'), ('FF', 'PROPN'), ('a', 'ADP'), ('los', 'DET'), ('magníficos', 'NOUN'), ('de', 'ADP'), ('@AccionCine', 'NOUN'), ('!', 'PUNCT'), ('!', 'PUNCT')]
# ['Aún', 'me', 'duele', 'el', 'ojo', 'derecho']
# [('Aún', 'ADV'), ('me', 'PRON'), ('duele', 'VERB'), ('el', 'DET'), ('ojo', 'NOUN'), ('derecho', 'ADJ')]
# ['tio', 'que', 'dolor', 'de', 'piernas']
# [('tio', 'NOUN'), ('que', 'SCONJ'), ('dolor', 'VERB'), ('de', 'ADP'), ('piernas', 'NOUN')]
# ['Hace', 'un', 'día', 'estupendo', '.', 'Otra', 'vez']
# [('Hace', 'VERB'), ('un', 'DET'), ('día', 'NOUN'), ('estupendo', 'VERB'), ('.', 'PUNCT'), ('Otra', 'DET'), ('vez', 'NOUN')]
# ['@Mr_Wath', 'con', 'lo', 'majo', 'que', 'eres']
# [('@Mr_Wath', 'ADJ'), ('con', 'ADP'), ('lo', 'PRON'), ('majo', 'NOUN'), ('que', 'PRON'), ('eres', 'AUX')]
# ['Me', 'congelo', 'cuando', 'me', 'despierto']
# [('Me', 'PRON'), ('congelo', 'VERB'), ('cuando', 'SCONJ'), ('me', 'PRON'), ('despierto', 'VERB')]
# ['@Rafafakari', 'que', 'no', 'que', 'estoy', 'mala']
# [('@Rafafakari', 'NOUN'), ('que', 'SCONJ'), ('no', 'ADV'), ('que', 'SCONJ'), ('estoy', 'AUX'), ('mala', 'ADJ')]
# ['@Bammz87', 'ya', 'eres', 'bueno', 'a', 'esto', 'o', 'qué', '?']
# [('@Bammz87', 'VERB'), ('ya', 'ADV'), ('eres', 'AUX'), ('bueno', 'ADJ'), ('a', 'ADP'), ('esto', 'PRON'), ('o', 'CCONJ'), ('qué', 'PRON'), ('?', 'PUNCT')]
# ['@Radinosaurio', ' ', 'yo', 'soy', 'asi', 'con', 'mis', 'amigos', 'pero', 'ellos', 'no', 'son', 'así']
# [('@Radinosaurio', 'ADJ'), (' ', 'SPACE'), ('yo', 'PRON'), ('soy', 'AUX'), ('asi', 'ADV'), ('con', 'ADP'), ('mis', 'DET'), ('amigos', 'NOUN'), ('pero', 'CCONJ'), ('ellos', 'PRON'), ('no', 'ADV'), ('son', 'AUX'), ('así', 'ADV')]
# ['@ElTerral', 'somos', 'más', 'felices', 'sin', 'ti']
# [('@ElTerral', 'ADJ'), ('somos', 'AUX'), ('más', 'ADV'), ('felices', 'ADJ'), ('sin', 'ADP'), ('ti', 'PRON')]
# ['Que', 'agobio', 'tío', 'que', 'mala', 'estoy']
# [('Que', 'SCONJ'), ('agobio', 'ADJ'), ('tío', 'NOUN'), ('que', 'PRON'), ('mala', 'VERB'), ('estoy', 'AUX')]
# ['Y', 'eso', 'es', 'triste', 'la', 'vdd', '.', 'Por', 'vosotros', ',', 'no', 'por', 'mi']
# [('Y', 'CCONJ'), ('eso', 'PRON'), ('es', 'AUX'), ('triste', 'ADJ'), ('la', 'DET'), ('vdd', 'NOUN'), ('.', 'PUNCT'), ('Por', 'ADP'), ('vosotros', 'NOUN'), (',', 'PUNCT'), ('no', 'ADV'), ('por', 'ADP'), ('mi', 'DET')]
#                                              tweet_text polarity_value  \
# 506   @_Miss_Donovan Laura!  Que luego te distraes d...       negative
# 234   Que rápido pasa el tiempo solo se que cobro ca...       negative
# 1580  @bau_er no. Del rosa paso al negro mate y la s...       negative
# 735   @SanchezBurgos Suelo leer críticas muy diversa...        neutral
# 593   Han aparecido unas niñas jugando a las palmas ...       negative
#
#      sentiwordnet_sum_prediction sentiwordnet_mean_prediction
# 506                      neutral                     positive
# 234                     negative                     negative
# 1580                    negative                     negative
# 735                     negative                     negative
# 593                     negative                     negative

# %%
from sklearn.metrics import classification_report

# %%
# Mostrar el informe de clasificación para cada uno de los métodos
print("Resultados del primer método de la suma:")
print(classification_report(data['polarity_value'], data['sentiwordnet_sum_prediction']))
print()
print("Resultados del segundo método de la media:")
print(classification_report(data['polarity_value'], data['sentiwordnet_mean_prediction']))
# Out:
# Resultados del primer método de la suma:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.82      0.62       767
#      neutral       0.13      0.17      0.15       216
#     positive       0.64      0.07      0.12       642
#
#     accuracy                           0.44      1625
#    macro avg       0.42      0.35      0.30      1625
# weighted avg       0.50      0.44      0.36      1625
#
#
# Resultados del segundo método de la media:
#               precision    recall  f1-score   support
#
#     negative       0.49      0.79      0.61       767
#      neutral       0.05      0.01      0.02       216
#     positive       0.50      0.28      0.36       642
#
#     accuracy                           0.48      1625
#    macro avg       0.35      0.36      0.33      1625
# weighted avg       0.43      0.48      0.43      1625

# %% [markdown]
# Vamos a añadir algunas reglas heurísticas que tengan en cuenta la negación, intensificadores y atenuadores.

# %%
# Lista de palabras de negación
negations = {"no", "nunca", "ninguno", "ninguna", "ningunos", "ningunas", "nada", "nadie"}

# Diccionario de modificadores de intensidad (incluye intensificadores y atenuadores)
intensity_modifiers = {
    # Intensificadores (factor > 1)
    "mucho": 1.5,
    "extremadamente": 1.8,
    "bastante": 1.2,
    "realmente": 1.3,
    "absolutamente": 1.8,
    "extremadamente": 1.4,
    "increíblemente": 1.5,
    # Atenuadores (factor < 1)
    "poco": 0.8,
    "apenas": 0.5,
    "difícilmente": 0.5,
    "escasamente": 0.7,
    "marginally": 0.6,
}

def compute_sentiment_sum(text):
    doc = nlp_es(text)
    tokenized_sent = [token.text for token in doc]

    pos_tagged_tokens = [(token.text, token.pos_) for token in doc]

    sentiment_value = 0.0

    for i, (word_text, tag) in enumerate(pos_tagged_tokens):
        wn_tag = map_spacy_tag(tag)
        if wn_tag is None:
            continue
        word = next((token for token in doc if token.text == word_text), None)
        if word is None:
          continue

        lemma = word.lemma_
        if not lemma:
          continue

        # Verificar si la palabra lematizada está en el diccionario de SentiWordNet
        # y crear la lista de synsets
        swn_synsets = []
        if lemma in spanish_sentiwordnet:
            # Obtener los puntajes positivos, negativos y los códigos de los synsets
            pos_tag, pos_score_lemma, _, neg_score_lemma, synset = spanish_sentiwordnet[lemma]

            for key, value in spanish_sentiwordnet.items():
              # Comprobar si el synset de la palabra coincide con el synset del diccionario
              if synset == value[4]:  # value[4] es el synset
                  swn_synsets.append(f"SentiSynset('{key}.{pos_tag}')")

            if len(swn_synsets) == 0:
              continue

            word_sentiment = pos_score_lemma - neg_score_lemma

            # Heurística de Negación: ventana de 5 tokens a la izquierda
            window_start = max(0, i - 5)
            window = pos_tagged_tokens[window_start:i]
            if any(tok[0].lower() in negations for tok in window):
                word_sentiment = -word_sentiment

            # Heurística de Modificadores de Intensidad/Atenuación:
            if i > 0:
                prev_word = pos_tagged_tokens[i-1][0].lower()
                if prev_word in intensity_modifiers:
                    word_sentiment *= intensity_modifiers[prev_word]

            sentiment_value += word_sentiment

        #If lemma not found, skip this word and move to next
        else:
            continue

    if sentiment_value >= 0.05:
        sentiment_label = "positive"
    elif sentiment_value <= -0.05:
        sentiment_label = "negative"
    else:
        sentiment_label = "neutral"

    return sentiment_label

# %%
def compute_sentiment_mean(text):
    doc = nlp_es(text)
    tokenized_sent = [token.text for token in doc]

    pos_tagged_tokens = [(token.text, token.pos_) for token in doc]

    pos_score_total = 0.0
    neg_score_total = 0.0
    obj_score_total = 0.0
    synset_count = 0

    for i, (word_text, tag) in enumerate(pos_tagged_tokens):
        wn_tag = map_spacy_tag(tag)
        if wn_tag is None:
            continue
        word = next((token for token in doc if token.text == word_text), None)
        if word is None:
          continue

        lemma = word.lemma_
        if not lemma:
          continue

        # Initialize pos_score_lemma, neg_score_lemma, and obj_score_lemma before the if statement
        pos_score_lemma = 0.0
        neg_score_lemma = 0.0
        obj_score_lemma = 0.0

        # Initialize pos_score, neg_score, and obj_score before the if statement
        pos_score = 0.0
        neg_score = 0.0
        obj_score = 0.0

        if lemma in spanish_sentiwordnet:
          # Obtener los puntajes positivos, negativos y los códigos de los synsets
          pos_tag, pos_score_lemma, obj_score_lemma, neg_score_lemma, synset = spanish_sentiwordnet[lemma]

          swn_synsets = []
          for key, value in spanish_sentiwordnet.items():
            # Comprobar si el synset de la palabra coincide con el synset del diccionario
            if synset == value[4]:  # value[4] es el synset
                swn_synsets.append(f"SentiSynset('{key}.{pos_tag}')")

          if len(swn_synsets) == 0:
            continue

        # Heurística de Negación: ventana de 5 tokens
        window_start = max(0, i - 5)
        window = pos_tagged_tokens[window_start:i]
        if any(tok[0].lower() in negations for tok in window):
            pos_score, neg_score = neg_score, pos_score  # Intercambia para reflejar la inversión

        # Heurística de Modificadores de Intensidad/Atenuación:
        if i > 0:
            prev_word = pos_tagged_tokens[i-1][0].lower()
            if prev_word in intensity_modifiers:
                multiplier = intensity_modifiers[prev_word]
                pos_score *= multiplier
                neg_score *= multiplier
                obj_score *= multiplier

        pos_score_total += pos_score
        neg_score_total += neg_score
        obj_score_total += obj_score
        synset_count += 1

    if synset_count == 0:
        return "neutral"

    pos_score_mean = pos_score_total / synset_count
    neg_score_mean = neg_score_total / synset_count
    obj_score_mean = obj_score_total / synset_count
    max_value = max(pos_score_mean, neg_score_mean, obj_score_mean)
    if max_value == pos_score_mean:
        sentiment_label = "positive"
    elif max_value == neg_score_mean:
        sentiment_label = "negative"
    else:
        sentiment_label = "neutral"

    return sentiment_label

# %%
# Ejemplo de uso:
text_example = "No me gusta nada esta película. Es buena, pero es realmente aburrida."
print("Sentiment (sum):", compute_sentiment_sum(text_example))
print("Sentiment (mean):", compute_sentiment_mean(text_example))
# Out:
# Sentiment (sum): negative
# Sentiment (mean): positive

# %%
# Ejecutar las predicciones y obtener nuevas columna con dichas predicciones
data["sentiwordnet_sum_improved_prediction"] = data["tweet_text"].apply(compute_sentiment_sum)
data["sentiwordnet_mean_improved_prediction"] = data["tweet_text"].apply(compute_sentiment_mean)

# Mostrar 5 filas aleatorias del dataset
data.sample(5)
# Out:
#                                             tweet_text polarity_value  \
# 993  Y yo!! pero no soy famoso  Lugar muy recomenda...       positive
# 305  @AbadesaLPD todas las críticas son calificativ...       negative
# 354  Echo de menos las barras libres del Tángara.. ...        neutral
# 20   Buenos dias, vamos a hacer algunos recados y a...       positive
# 836       La gente de mi nuevo piso es bien buen pedo        positive
#
#     sentiwordnet_sum_prediction sentiwordnet_mean_prediction  \
# 993                    negative                     negative
# 305                    negative                     negative
# 354                    negative                      neutral
# 20                      neutral                     positive
# 836                    negative                     negative
#
#     sentiwordnet_sum_improved_prediction sentiwordnet_mean_improved_prediction
# 993                             negative                              positive
# 305                             positive                              positive
# 354                             negative                              positive
# 20                               neutral                              positive
# 836                             negative                              positive

# %%
# Mostrar el informe de clasificación para cada uno de los métodos
print("Resultados del primer método de la suma:")
print(classification_report(data['polarity_value'], data['sentiwordnet_sum_improved_prediction']))
print()
print("Resultados del segundo método de la media:")
print(classification_report(data['polarity_value'], data['sentiwordnet_mean_improved_prediction']))
# Out:
# Resultados del primer método de la suma:
#               precision    recall  f1-score   support
#
#     negative       0.49      0.77      0.60       767
#      neutral       0.13      0.19      0.15       216
#     positive       0.50      0.08      0.14       642
#
#     accuracy                           0.42      1625
#    macro avg       0.37      0.35      0.30      1625
# weighted avg       0.45      0.42      0.36      1625
#
#
# Resultados del segundo método de la media:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00       767
#      neutral       0.00      0.00      0.00       216
#     positive       0.39      1.00      0.57       642
#
#     accuracy                           0.39      1625
#    macro avg       0.13      0.33      0.19      1625
# weighted avg       0.16      0.39      0.22      1625
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
